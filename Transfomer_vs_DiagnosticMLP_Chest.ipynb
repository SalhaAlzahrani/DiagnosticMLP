# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/DiagnosticMLP/blob/main/Transfomer_vs_DiagnosticMLP_Chest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟨 DiagnosticMLP versus Transfomer Architectures: CT Image classification - Computed Tomography (CT) of the Chest

# %%
# !pip install nest_asyncio
# !pip install -U -q tensorflow-addons
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 13.3 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math
import nest_asyncio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ---
#
# ## 🟡 plot_training_curves

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(len(history.history['loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('bmh') #ggplot #bmh
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10)

# %% [markdown]
# ## 🟡 Hyperparameters

# %%
path = '/content/drive/MyDrive/_MyResearch_/CT_Datasets/Computed Tomography (CT) of the Chest/'

image_size = 64 # We'll resize input images to this size.
patch_size = 256
input_shape = (64, 64, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
label_smoothing = 0.1

patch_size = 2  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2
num_transformer_blocks = 8  # Number of repetitions of the transformer layer

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 2 X 2 = 4
# Patches per image: 1024
# Elements per patch (3 channels): 12

# %% [markdown]
# ## 🟡 Dataset

# %%
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 9208 files belonging to 4 classes.
# Using 8288 files for training.
# Found 9208 files belonging to 4 classes.
# Using 920 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
##################
num_classes = len(class_names)
##################
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(num_classes): classes.append(i)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# ['COVID-19', 'Normal', 'Pneumonia-Bacterial', 'Pneumonia-Viral']
# {0: 1.7970335675253708,
#  1: 0.7039755351681957,
#  2: 0.7670776407864045,
#  3: 1.3900966183574879}

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 🟡 Experiment
# We implement a utility function to compile, train, and evaluate a given model.

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# ## 🟡 Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip('horizontal_and_vertical'),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
        layers.RandomContrast(factor=0.2),
        layers.RandomCrop(height=image_size, width=image_size),
        layers.RandomBrightness(factor=0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ---

# %% [markdown]
# # Implement the patch extraction and encoding layer

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %% [markdown]
# # Implement the external attention block

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %% [markdown]
# # Implement the MLP block

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %% [markdown]
# # Implement the Transformer block

# %%
def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %% [markdown]
# # Implement the Self-Attention and External Attention (ENet) model

# %%
def get_model(attention_type="external_attention"):
    inputs = layers.Input(shape=input_shape)
    # Image augment
    x = data_augmentation(inputs)
    #x = inputs
    # Extract patches.
    x = PatchExtract(patch_size)(x)
    # Create patch embedding.
    x = PatchEmbedding(num_patches, embedding_dim)(x)
    # Create Transformer block.
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(
            x,
            embedding_dim,
            mlp_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
            attention_type,
        )

    x = layers.GlobalAvgPool1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## 🔷 Self-Attention

# %%
model_SA = get_model(attention_type="self_attention")
model_SA.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patch_extract (PatchExtrac  (None, 1024, 12)             0         ['data_augmentation[0][0]']
#  t)
#
#  patch_embedding (PatchEmbe  (None, 1024, 64)             66368     ['patch_extract[0][0]']
#  dding)
#
#  layer_normalization (Layer  (None, 1024, 64)             128       ['patch_embedding[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 1024, 64)             66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 1024, 64)             0         ['multi_head_attention[0][0]',
#                                                                      'patch_embedding[0][0]']
#
#  layer_normalization_1 (Lay  (None, 1024, 64)             128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 1024, 64)             0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1024, 64)             4160      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024, 64)             0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 1024, 64)             0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 1024, 64)             128       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 1024, 64)             66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 1024, 64)             128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 1024, 64)             0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024, 64)             4160      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 1024, 64)             0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 1024, 64)             0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 1024, 64)             128       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 1024, 64)             66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 1024, 64)             128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 1024, 64)             0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 1024, 64)             4160      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 1024, 64)             0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 1024, 64)             0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 1024, 64)             128       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 1024, 64)             66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 1024, 64)             128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 1024, 64)             0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 1024, 64)             4160      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 1024, 64)             0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 1024, 64)             0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 1024, 64)             128       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 1024, 64)             66368     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 1024, 64)             128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_9 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 1024, 64)             0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024, 64)             4160      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024, 64)             0         ['dense_10[0][0]']
#
#  add_9 (Add)                 (None, 1024, 64)             0         ['dropout_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 1024, 64)             128       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 1024, 64)             66368     ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 1024, 64)             0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 1024, 64)             128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 1024, 64)             0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 1024, 64)             4160      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 1024, 64)             0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 1024, 64)             0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 1024, 64)             128       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 1024, 64)             66368     ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 1024, 64)             0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 1024, 64)             128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 1024, 64)             0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 1024, 64)             4160      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 1024, 64)             0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 1024, 64)             0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 1024, 64)             128       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 1024, 64)             66368     ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 1024, 64)             0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 1024, 64)             128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 1024, 64)             0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 1024, 64)             4160      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 1024, 64)             0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 1024, 64)             0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  global_average_pooling1d (  (None, 64)                   0         ['add_15[0][0]']
#  GlobalAveragePooling1D)
#
#  dense_17 (Dense)            (None, 4)                    260       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 666187 (2.54 MB)
# Trainable params: 666180 (2.54 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
history_SA = run_experiment(model_SA)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 259/259 [==============================] - 786s 2s/step - loss: 7.1363 - accuracy: 0.2739 - top5-acc: 1.0000 - Brier score: 0.2757 - F1 score: 0.2662 - Recall: 0.2367 - Precision: 0.2759 - AUC: 0.5137 - val_loss: 1.2400 - val_accuracy: 0.4489 - val_top5-acc: 1.0000 - val_Brier score: 0.1696 - val_F1 score: 0.3810 - val_Recall: 0.3793 - val_Precision: 0.5531 - val_AUC: 0.7278 - lr: 0.0010
# Epoch 2/100
# 259/259 [==============================] - 45s 170ms/step - loss: 2.1933 - accuracy: 0.3138 - top5-acc: 1.0000 - Brier score: 0.2423 - F1 score: 0.3120 - Recall: 0.2700 - Precision: 0.3215 - AUC: 0.5825 - val_loss: 2.3068 - val_accuracy: 0.3761 - val_top5-acc: 1.0000 - val_Brier score: 0.2243 - val_F1 score: 0.3792 - val_Recall: 0.3598 - val_Precision: 0.3835 - val_AUC: 0.6229 - lr: 0.0010
# Epoch 3/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.7508 - accuracy: 0.3476 - top5-acc: 1.0000 - Brier score: 0.2137 - F1 score: 0.3417 - Recall: 0.2617 - Precision: 0.3668 - AUC: 0.6179 - val_loss: 2.1805 - val_accuracy: 0.3315 - val_top5-acc: 1.0000 - val_Brier score: 0.2348 - val_F1 score: 0.2403 - val_Recall: 0.3228 - val_Precision: 0.3410 - val_AUC: 0.6429 - lr: 0.0010
# Epoch 4/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.8172 - accuracy: 0.3652 - top5-acc: 1.0000 - Brier score: 0.2172 - F1 score: 0.3610 - Recall: 0.3057 - Precision: 0.3797 - AUC: 0.6339 - val_loss: 1.4652 - val_accuracy: 0.4065 - val_top5-acc: 1.0000 - val_Brier score: 0.1989 - val_F1 score: 0.2477 - val_Recall: 0.3728 - val_Precision: 0.4256 - val_AUC: 0.7342 - lr: 0.0010
# Epoch 5/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.7533 - accuracy: 0.3612 - top5-acc: 1.0000 - Brier score: 0.2122 - F1 score: 0.3545 - Recall: 0.2897 - Precision: 0.3769 - AUC: 0.6366 - val_loss: 1.3474 - val_accuracy: 0.4739 - val_top5-acc: 1.0000 - val_Brier score: 0.1721 - val_F1 score: 0.4633 - val_Recall: 0.3978 - val_Precision: 0.5414 - val_AUC: 0.7365 - lr: 0.0010
# Epoch 6/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.6079 - accuracy: 0.3821 - top5-acc: 1.0000 - Brier score: 0.2025 - F1 score: 0.3769 - Recall: 0.2868 - Precision: 0.4055 - AUC: 0.6494 - val_loss: 1.6127 - val_accuracy: 0.4478 - val_top5-acc: 1.0000 - val_Brier score: 0.2042 - val_F1 score: 0.3653 - val_Recall: 0.4326 - val_Precision: 0.4660 - val_AUC: 0.7459 - lr: 0.0010
# Epoch 7/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.2633 - accuracy: 0.4288 - top5-acc: 1.0000 - Brier score: 0.1750 - F1 score: 0.4240 - Recall: 0.2786 - Precision: 0.4932 - AUC: 0.7099 - val_loss: 1.0067 - val_accuracy: 0.5554 - val_top5-acc: 1.0000 - val_Brier score: 0.1402 - val_F1 score: 0.5538 - val_Recall: 0.3185 - val_Precision: 0.6644 - val_AUC: 0.8140 - lr: 5.0000e-04
# Epoch 8/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.2435 - accuracy: 0.4404 - top5-acc: 1.0000 - Brier score: 0.1732 - F1 score: 0.4352 - Recall: 0.2857 - Precision: 0.4987 - AUC: 0.7142 - val_loss: 1.0615 - val_accuracy: 0.4761 - val_top5-acc: 1.0000 - val_Brier score: 0.1500 - val_F1 score: 0.4873 - val_Recall: 0.3793 - val_Precision: 0.5584 - val_AUC: 0.7966 - lr: 5.0000e-04
# Epoch 9/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.2338 - accuracy: 0.4523 - top5-acc: 1.0000 - Brier score: 0.1708 - F1 score: 0.4472 - Recall: 0.3049 - Precision: 0.5130 - AUC: 0.7228 - val_loss: 1.4929 - val_accuracy: 0.4576 - val_top5-acc: 1.0000 - val_Brier score: 0.1859 - val_F1 score: 0.3492 - val_Recall: 0.4391 - val_Precision: 0.5101 - val_AUC: 0.7629 - lr: 5.0000e-04
# Epoch 10/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.2762 - accuracy: 0.4426 - top5-acc: 1.0000 - Brier score: 0.1753 - F1 score: 0.4330 - Recall: 0.3062 - Precision: 0.4921 - AUC: 0.7165 - val_loss: 1.2719 - val_accuracy: 0.4848 - val_top5-acc: 1.0000 - val_Brier score: 0.1699 - val_F1 score: 0.4646 - val_Recall: 0.4348 - val_Precision: 0.4988 - val_AUC: 0.7586 - lr: 5.0000e-04
# Epoch 11/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.1969 - accuracy: 0.4611 - top5-acc: 1.0000 - Brier score: 0.1680 - F1 score: 0.4545 - Recall: 0.3311 - Precision: 0.5318 - AUC: 0.7351 - val_loss: 1.4223 - val_accuracy: 0.5043 - val_top5-acc: 1.0000 - val_Brier score: 0.1676 - val_F1 score: 0.4764 - val_Recall: 0.4717 - val_Precision: 0.5536 - val_AUC: 0.7475 - lr: 5.0000e-04
# Epoch 12/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.2420 - accuracy: 0.4562 - top5-acc: 1.0000 - Brier score: 0.1718 - F1 score: 0.4510 - Recall: 0.3464 - Precision: 0.5078 - AUC: 0.7306 - val_loss: 1.3539 - val_accuracy: 0.4522 - val_top5-acc: 1.0000 - val_Brier score: 0.1826 - val_F1 score: 0.2846 - val_Recall: 0.4239 - val_Precision: 0.4632 - val_AUC: 0.7602 - lr: 5.0000e-04
# Epoch 13/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0947 - accuracy: 0.4994 - top5-acc: 1.0000 - Brier score: 0.1558 - F1 score: 0.4899 - Recall: 0.3282 - Precision: 0.5913 - AUC: 0.7703 - val_loss: 1.0202 - val_accuracy: 0.5087 - val_top5-acc: 1.0000 - val_Brier score: 0.1470 - val_F1 score: 0.5263 - val_Recall: 0.4054 - val_Precision: 0.5534 - val_AUC: 0.8082 - lr: 2.5000e-04
# Epoch 14/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0661 - accuracy: 0.5124 - top5-acc: 1.0000 - Brier score: 0.1515 - F1 score: 0.4987 - Recall: 0.3231 - Precision: 0.6159 - AUC: 0.7805 - val_loss: 1.0766 - val_accuracy: 0.4815 - val_top5-acc: 1.0000 - val_Brier score: 0.1530 - val_F1 score: 0.4712 - val_Recall: 0.4120 - val_Precision: 0.5271 - val_AUC: 0.7923 - lr: 2.5000e-04
# Epoch 15/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0677 - accuracy: 0.5165 - top5-acc: 1.0000 - Brier score: 0.1518 - F1 score: 0.5066 - Recall: 0.3446 - Precision: 0.6043 - AUC: 0.7809 - val_loss: 1.0229 - val_accuracy: 0.5228 - val_top5-acc: 1.0000 - val_Brier score: 0.1414 - val_F1 score: 0.5098 - val_Recall: 0.4348 - val_Precision: 0.6400 - val_AUC: 0.8130 - lr: 2.5000e-04
# Epoch 16/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0664 - accuracy: 0.5047 - top5-acc: 1.0000 - Brier score: 0.1534 - F1 score: 0.4957 - Recall: 0.3313 - Precision: 0.5927 - AUC: 0.7775 - val_loss: 0.9277 - val_accuracy: 0.6065 - val_top5-acc: 1.0000 - val_Brier score: 0.1308 - val_F1 score: 0.5719 - val_Recall: 0.4630 - val_Precision: 0.6805 - val_AUC: 0.8461 - lr: 2.5000e-04
# Epoch 17/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0546 - accuracy: 0.5181 - top5-acc: 1.0000 - Brier score: 0.1495 - F1 score: 0.5054 - Recall: 0.3466 - Precision: 0.6263 - AUC: 0.7873 - val_loss: 0.9382 - val_accuracy: 0.5717 - val_top5-acc: 1.0000 - val_Brier score: 0.1284 - val_F1 score: 0.5619 - val_Recall: 0.4696 - val_Precision: 0.6879 - val_AUC: 0.8432 - lr: 2.5000e-04
# Epoch 18/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0623 - accuracy: 0.5112 - top5-acc: 1.0000 - Brier score: 0.1519 - F1 score: 0.5027 - Recall: 0.3533 - Precision: 0.6001 - AUC: 0.7825 - val_loss: 0.9793 - val_accuracy: 0.5924 - val_top5-acc: 1.0000 - val_Brier score: 0.1334 - val_F1 score: 0.5608 - val_Recall: 0.4663 - val_Precision: 0.6693 - val_AUC: 0.8329 - lr: 2.5000e-04
# Epoch 19/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0771 - accuracy: 0.5128 - top5-acc: 1.0000 - Brier score: 0.1524 - F1 score: 0.5014 - Recall: 0.3463 - Precision: 0.5978 - AUC: 0.7800 - val_loss: 0.9635 - val_accuracy: 0.5772 - val_top5-acc: 1.0000 - val_Brier score: 0.1358 - val_F1 score: 0.5440 - val_Recall: 0.4587 - val_Precision: 0.6512 - val_AUC: 0.8345 - lr: 2.5000e-04
# Epoch 20/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0655 - accuracy: 0.5100 - top5-acc: 1.0000 - Brier score: 0.1526 - F1 score: 0.5004 - Recall: 0.3493 - Precision: 0.5913 - AUC: 0.7818 - val_loss: 0.8708 - val_accuracy: 0.6370 - val_top5-acc: 1.0000 - val_Brier score: 0.1225 - val_F1 score: 0.6503 - val_Recall: 0.4739 - val_Precision: 0.7428 - val_AUC: 0.8675 - lr: 2.5000e-04
# Epoch 21/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0608 - accuracy: 0.5123 - top5-acc: 1.0000 - Brier score: 0.1515 - F1 score: 0.4996 - Recall: 0.3529 - Precision: 0.6136 - AUC: 0.7838 - val_loss: 0.8585 - val_accuracy: 0.6511 - val_top5-acc: 1.0000 - val_Brier score: 0.1193 - val_F1 score: 0.6361 - val_Recall: 0.4967 - val_Precision: 0.7431 - val_AUC: 0.8708 - lr: 2.5000e-04
# Epoch 22/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0582 - accuracy: 0.5244 - top5-acc: 1.0000 - Brier score: 0.1496 - F1 score: 0.5114 - Recall: 0.3644 - Precision: 0.6125 - AUC: 0.7893 - val_loss: 0.8426 - val_accuracy: 0.6598 - val_top5-acc: 1.0000 - val_Brier score: 0.1174 - val_F1 score: 0.6607 - val_Recall: 0.5022 - val_Precision: 0.7428 - val_AUC: 0.8750 - lr: 2.5000e-04
# Epoch 23/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0323 - accuracy: 0.5316 - top5-acc: 1.0000 - Brier score: 0.1473 - F1 score: 0.5188 - Recall: 0.3779 - Precision: 0.6163 - AUC: 0.7971 - val_loss: 1.0596 - val_accuracy: 0.4750 - val_top5-acc: 1.0000 - val_Brier score: 0.1517 - val_F1 score: 0.4304 - val_Recall: 0.4141 - val_Precision: 0.5314 - val_AUC: 0.7968 - lr: 2.5000e-04
# Epoch 24/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0564 - accuracy: 0.5185 - top5-acc: 1.0000 - Brier score: 0.1500 - F1 score: 0.5054 - Recall: 0.3627 - Precision: 0.6111 - AUC: 0.7891 - val_loss: 0.9543 - val_accuracy: 0.5826 - val_top5-acc: 1.0000 - val_Brier score: 0.1343 - val_F1 score: 0.5286 - val_Recall: 0.4728 - val_Precision: 0.6332 - val_AUC: 0.8411 - lr: 2.5000e-04
# Epoch 25/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0188 - accuracy: 0.5372 - top5-acc: 1.0000 - Brier score: 0.1454 - F1 score: 0.5242 - Recall: 0.3787 - Precision: 0.6302 - AUC: 0.8021 - val_loss: 0.8561 - val_accuracy: 0.6522 - val_top5-acc: 1.0000 - val_Brier score: 0.1202 - val_F1 score: 0.6680 - val_Recall: 0.5250 - val_Precision: 0.7124 - val_AUC: 0.8719 - lr: 2.5000e-04
# Epoch 26/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0148 - accuracy: 0.5409 - top5-acc: 1.0000 - Brier score: 0.1447 - F1 score: 0.5261 - Recall: 0.3826 - Precision: 0.6456 - AUC: 0.8038 - val_loss: 0.8619 - val_accuracy: 0.6435 - val_top5-acc: 1.0000 - val_Brier score: 0.1212 - val_F1 score: 0.6468 - val_Recall: 0.4793 - val_Precision: 0.7206 - val_AUC: 0.8695 - lr: 2.5000e-04
# Epoch 27/100
# 259/259 [==============================] - 45s 171ms/step - loss: 1.0276 - accuracy: 0.5314 - top5-acc: 1.0000 - Brier score: 0.1470 - F1 score: 0.5189 - Recall: 0.3840 - Precision: 0.6176 - AUC: 0.7981 - val_loss: 0.8413 - val_accuracy: 0.6467 - val_top5-acc: 1.0000 - val_Brier score: 0.1186 - val_F1 score: 0.6508 - val_Recall: 0.4913 - val_Precision: 0.7232 - val_AUC: 0.8753 - lr: 2.5000e-04
# Epoch 28/100
# 259/259 [==============================] - 45s 170ms/step - loss: 1.0254 - accuracy: 0.5343 - top5-acc: 1.0000 - Brier score: 0.1465 - F1 score: 0.5210 - Recall: 0.3860 - Precision: 0.6220 - AUC: 0.7990 - val_loss: 0.8814 - val_accuracy: 0.6348 - val_top5-acc: 1.0000 - val_Brier score: 0.1236 - val_F1 score: 0.6379 - val_Recall: 0.4815 - val_Precision: 0.7396 - val_AUC: 0.8656 - lr: 2.5000e-04
# Epoch 29/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9939 - accuracy: 0.5537 - top5-acc: 1.0000 - Brier score: 0.1427 - F1 score: 0.5407 - Recall: 0.3913 - Precision: 0.6465 - AUC: 0.8112 - val_loss: 0.7892 - val_accuracy: 0.6978 - val_top5-acc: 1.0000 - val_Brier score: 0.1086 - val_F1 score: 0.6850 - val_Recall: 0.5576 - val_Precision: 0.7785 - val_AUC: 0.8946 - lr: 2.5000e-04
# Epoch 30/100
# 259/259 [==============================] - 45s 171ms/step - loss: 0.9896 - accuracy: 0.5542 - top5-acc: 1.0000 - Brier score: 0.1417 - F1 score: 0.5380 - Recall: 0.3902 - Precision: 0.6487 - AUC: 0.8135 - val_loss: 0.8622 - val_accuracy: 0.6283 - val_top5-acc: 1.0000 - val_Brier score: 0.1224 - val_F1 score: 0.6417 - val_Recall: 0.4989 - val_Precision: 0.7072 - val_AUC: 0.8683 - lr: 2.5000e-04
# Epoch 31/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9808 - accuracy: 0.5607 - top5-acc: 1.0000 - Brier score: 0.1396 - F1 score: 0.5446 - Recall: 0.4084 - Precision: 0.6564 - AUC: 0.8186 - val_loss: 0.8675 - val_accuracy: 0.6293 - val_top5-acc: 1.0000 - val_Brier score: 0.1236 - val_F1 score: 0.6418 - val_Recall: 0.4663 - val_Precision: 0.7044 - val_AUC: 0.8670 - lr: 2.5000e-04
# Epoch 32/100
# 259/259 [==============================] - 45s 171ms/step - loss: 0.9981 - accuracy: 0.5589 - top5-acc: 1.0000 - Brier score: 0.1419 - F1 score: 0.5441 - Recall: 0.4114 - Precision: 0.6374 - AUC: 0.8139 - val_loss: 0.9316 - val_accuracy: 0.6130 - val_top5-acc: 1.0000 - val_Brier score: 0.1279 - val_F1 score: 0.5272 - val_Recall: 0.4793 - val_Precision: 0.7045 - val_AUC: 0.8479 - lr: 2.5000e-04
# Epoch 33/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9722 - accuracy: 0.5694 - top5-acc: 1.0000 - Brier score: 0.1392 - F1 score: 0.5523 - Recall: 0.4178 - Precision: 0.6658 - AUC: 0.8204 - val_loss: 0.8148 - val_accuracy: 0.6826 - val_top5-acc: 1.0000 - val_Brier score: 0.1142 - val_F1 score: 0.6891 - val_Recall: 0.5576 - val_Precision: 0.7489 - val_AUC: 0.8855 - lr: 2.5000e-04
# Epoch 34/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9930 - accuracy: 0.5618 - top5-acc: 1.0000 - Brier score: 0.1412 - F1 score: 0.5446 - Recall: 0.4128 - Precision: 0.6414 - AUC: 0.8162 - val_loss: 1.0277 - val_accuracy: 0.4522 - val_top5-acc: 1.0000 - val_Brier score: 0.1550 - val_F1 score: 0.4817 - val_Recall: 0.3772 - val_Precision: 0.4813 - val_AUC: 0.8096 - lr: 2.5000e-04
# Epoch 35/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9364 - accuracy: 0.5866 - top5-acc: 1.0000 - Brier score: 0.1343 - F1 score: 0.5691 - Recall: 0.4235 - Precision: 0.6872 - AUC: 0.8345 - val_loss: 0.8429 - val_accuracy: 0.6326 - val_top5-acc: 1.0000 - val_Brier score: 0.1202 - val_F1 score: 0.6364 - val_Recall: 0.4902 - val_Precision: 0.7193 - val_AUC: 0.8734 - lr: 1.2500e-04
# Epoch 36/100
# 259/259 [==============================] - 45s 171ms/step - loss: 0.9259 - accuracy: 0.5945 - top5-acc: 1.0000 - Brier score: 0.1327 - F1 score: 0.5759 - Recall: 0.4205 - Precision: 0.7039 - AUC: 0.8395 - val_loss: 0.7820 - val_accuracy: 0.7000 - val_top5-acc: 1.0000 - val_Brier score: 0.1093 - val_F1 score: 0.6870 - val_Recall: 0.5489 - val_Precision: 0.7903 - val_AUC: 0.8988 - lr: 1.2500e-04
# Epoch 37/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9301 - accuracy: 0.5876 - top5-acc: 1.0000 - Brier score: 0.1333 - F1 score: 0.5690 - Recall: 0.4171 - Precision: 0.6988 - AUC: 0.8373 - val_loss: 0.8398 - val_accuracy: 0.6457 - val_top5-acc: 1.0000 - val_Brier score: 0.1202 - val_F1 score: 0.6626 - val_Recall: 0.5098 - val_Precision: 0.7193 - val_AUC: 0.8749 - lr: 1.2500e-04
# Epoch 38/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9280 - accuracy: 0.5971 - top5-acc: 1.0000 - Brier score: 0.1325 - F1 score: 0.5791 - Recall: 0.4231 - Precision: 0.7093 - AUC: 0.8393 - val_loss: 0.8879 - val_accuracy: 0.5826 - val_top5-acc: 1.0000 - val_Brier score: 0.1278 - val_F1 score: 0.5834 - val_Recall: 0.4772 - val_Precision: 0.6621 - val_AUC: 0.8551 - lr: 1.2500e-04
# Epoch 39/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9294 - accuracy: 0.6020 - top5-acc: 1.0000 - Brier score: 0.1324 - F1 score: 0.5826 - Recall: 0.4251 - Precision: 0.6998 - AUC: 0.8404 - val_loss: 0.8703 - val_accuracy: 0.5946 - val_top5-acc: 1.0000 - val_Brier score: 0.1251 - val_F1 score: 0.6011 - val_Recall: 0.4880 - val_Precision: 0.6929 - val_AUC: 0.8621 - lr: 1.2500e-04
# Epoch 40/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9231 - accuracy: 0.6040 - top5-acc: 1.0000 - Brier score: 0.1320 - F1 score: 0.5872 - Recall: 0.4309 - Precision: 0.7018 - AUC: 0.8413 - val_loss: 0.7591 - val_accuracy: 0.7011 - val_top5-acc: 1.0000 - val_Brier score: 0.1057 - val_F1 score: 0.6840 - val_Recall: 0.5533 - val_Precision: 0.7978 - val_AUC: 0.9049 - lr: 1.2500e-04
# Epoch 41/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8986 - accuracy: 0.6193 - top5-acc: 1.0000 - Brier score: 0.1281 - F1 score: 0.6015 - Recall: 0.4505 - Precision: 0.7149 - AUC: 0.8508 - val_loss: 0.8102 - val_accuracy: 0.6761 - val_top5-acc: 1.0000 - val_Brier score: 0.1156 - val_F1 score: 0.6968 - val_Recall: 0.5337 - val_Precision: 0.7636 - val_AUC: 0.8877 - lr: 1.2500e-04
# Epoch 42/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8979 - accuracy: 0.6129 - top5-acc: 1.0000 - Brier score: 0.1291 - F1 score: 0.5947 - Recall: 0.4408 - Precision: 0.7088 - AUC: 0.8500 - val_loss: 0.7783 - val_accuracy: 0.7000 - val_top5-acc: 1.0000 - val_Brier score: 0.1092 - val_F1 score: 0.7006 - val_Recall: 0.5674 - val_Precision: 0.7826 - val_AUC: 0.8997 - lr: 1.2500e-04
# Epoch 43/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.9064 - accuracy: 0.6132 - top5-acc: 1.0000 - Brier score: 0.1294 - F1 score: 0.5938 - Recall: 0.4467 - Precision: 0.7070 - AUC: 0.8485 - val_loss: 0.8431 - val_accuracy: 0.6174 - val_top5-acc: 1.0000 - val_Brier score: 0.1211 - val_F1 score: 0.6218 - val_Recall: 0.5065 - val_Precision: 0.7104 - val_AUC: 0.8714 - lr: 1.2500e-04
# Epoch 44/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8922 - accuracy: 0.6182 - top5-acc: 1.0000 - Brier score: 0.1278 - F1 score: 0.6006 - Recall: 0.4563 - Precision: 0.7114 - AUC: 0.8528 - val_loss: 0.8527 - val_accuracy: 0.6087 - val_top5-acc: 1.0000 - val_Brier score: 0.1233 - val_F1 score: 0.6225 - val_Recall: 0.4967 - val_Precision: 0.6821 - val_AUC: 0.8670 - lr: 1.2500e-04
# Epoch 45/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8923 - accuracy: 0.6193 - top5-acc: 1.0000 - Brier score: 0.1277 - F1 score: 0.6012 - Recall: 0.4614 - Precision: 0.7100 - AUC: 0.8529 - val_loss: 0.8201 - val_accuracy: 0.6380 - val_top5-acc: 1.0000 - val_Brier score: 0.1160 - val_F1 score: 0.6390 - val_Recall: 0.5163 - val_Precision: 0.7387 - val_AUC: 0.8805 - lr: 1.2500e-04
# Epoch 46/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8933 - accuracy: 0.6196 - top5-acc: 1.0000 - Brier score: 0.1271 - F1 score: 0.5984 - Recall: 0.4539 - Precision: 0.7211 - AUC: 0.8546 - val_loss: 0.8162 - val_accuracy: 0.6402 - val_top5-acc: 1.0000 - val_Brier score: 0.1166 - val_F1 score: 0.6535 - val_Recall: 0.5196 - val_Precision: 0.7365 - val_AUC: 0.8838 - lr: 6.2500e-05
# Epoch 47/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8843 - accuracy: 0.6277 - top5-acc: 1.0000 - Brier score: 0.1265 - F1 score: 0.6087 - Recall: 0.4444 - Precision: 0.7359 - AUC: 0.8571 - val_loss: 0.8046 - val_accuracy: 0.6674 - val_top5-acc: 1.0000 - val_Brier score: 0.1144 - val_F1 score: 0.6853 - val_Recall: 0.5130 - val_Precision: 0.7662 - val_AUC: 0.8921 - lr: 6.2500e-05
# Epoch 48/100
# 259/259 [==============================] - 45s 171ms/step - loss: 0.8948 - accuracy: 0.6181 - top5-acc: 1.0000 - Brier score: 0.1277 - F1 score: 0.5974 - Recall: 0.4365 - Precision: 0.7269 - AUC: 0.8539 - val_loss: 0.8239 - val_accuracy: 0.6326 - val_top5-acc: 1.0000 - val_Brier score: 0.1172 - val_F1 score: 0.6445 - val_Recall: 0.5076 - val_Precision: 0.7343 - val_AUC: 0.8818 - lr: 6.2500e-05
# Epoch 49/100
# 259/259 [==============================] - 45s 170ms/step - loss: 0.8930 - accuracy: 0.6258 - top5-acc: 1.0000 - Brier score: 0.1269 - F1 score: 0.6040 - Recall: 0.4480 - Precision: 0.7312 - AUC: 0.8560 - val_loss: 0.8325 - val_accuracy: 0.6141 - val_top5-acc: 1.0000 - val_Brier score: 0.1196 - val_F1 score: 0.6285 - val_Recall: 0.5054 - val_Precision: 0.7220 - val_AUC: 0.8767 - lr: 6.2500e-05
# Epoch 50/100
# 259/259 [==============================] - 45s 171ms/step - loss: 0.8988 - accuracy: 0.6228 - top5-acc: 1.0000 - Brier score: 0.1277 - F1 score: 0.6029 - Recall: 0.4449 - Precision: 0.7352 - AUC: 0.8540 - val_loss: 0.8195 - val_accuracy: 0.6489 - val_top5-acc: 1.0000 - val_Brier score: 0.1162 - val_F1 score: 0.6523 - val_Recall: 0.5120 - val_Precision: 0.7524 - val_AUC: 0.8835 - lr: 6.2500e-05

# %%
plot_training_curves(history_SA, 'Chest, SA Transfomer')

# %% [markdown]
# ---
#
#
# ## 🔷 External-Attention

# %%
model_EA = get_model(attention_type="external_attention")
model_EA.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patch_extract_1 (PatchExtr  (None, 1024, 12)             0         ['data_augmentation[1][0]']
#  act)
#
#  patch_embedding_1 (PatchEm  (None, 1024, 64)             66368     ['patch_extract_1[0][0]']
#  bedding)
#
#  layer_normalization_16 (La  (None, 1024, 64)             128       ['patch_embedding_1[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_16[0][0]
#                                                                     ']
#
#  tf.reshape (TFOpLambda)     (None, 1024, 16, 16)         0         ['dense_19[0][0]']
#
#  tf.compat.v1.transpose (TF  (None, 16, 1024, 16)         0         ['tf.reshape[0][0]']
#  OpLambda)
#
#  dense_20 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose[0][0]
#                                                                     ']
#
#  softmax (Softmax)           (None, 16, 1024, 16)         0         ['dense_20[0][0]']
#
#  tf.math.reduce_sum (TFOpLa  (None, 16, 1024, 1)          0         ['softmax[0][0]']
#  mbda)
#
#  tf.__operators__.add (TFOp  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum[0][0]']
#  Lambda)
#
#  tf.math.truediv (TFOpLambd  (None, 16, 1024, 16)         0         ['softmax[0][0]',
#  a)                                                                  'tf.__operators__.add[0][0]']
#
#  dropout_16 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv[0][0]']
#
#  dense_21 (Dense)            (None, 16, 1024, 16)         272       ['dropout_16[0][0]']
#
#  tf.compat.v1.transpose_1 (  (None, 1024, 16, 16)         0         ['dense_21[0][0]']
#  TFOpLambda)
#
#  tf.reshape_1 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_1[0][
#                                                                     0]']
#
#  dense_22 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_1[0][0]']
#
#  dropout_17 (Dropout)        (None, 1024, 64)             0         ['dense_22[0][0]']
#
#  add_16 (Add)                (None, 1024, 64)             0         ['dropout_17[0][0]',
#                                                                      'patch_embedding_1[0][0]']
#
#  layer_normalization_17 (La  (None, 1024, 64)             128       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 1024, 64)             0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 1024, 64)             4160      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 1024, 64)             0         ['dense_24[0][0]']
#
#  add_17 (Add)                (None, 1024, 64)             0         ['dropout_19[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 1024, 64)             128       ['add_17[0][0]']
#  yerNormalization)
#
#  dense_25 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_18[0][0]
#                                                                     ']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_25[0][0]']
#
#  tf.compat.v1.transpose_2 (  (None, 16, 1024, 16)         0         ['tf.reshape_2[0][0]']
#  TFOpLambda)
#
#  dense_26 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_2[0][
#                                                                     0]']
#
#  softmax_1 (Softmax)         (None, 16, 1024, 16)         0         ['dense_26[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None, 16, 1024, 1)          0         ['softmax_1[0][0]']
#  Lambda)
#
#  tf.__operators__.add_1 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_1[0][0]']
#  OpLambda)
#
#  tf.math.truediv_1 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_1[0][0]',
#  bda)                                                                'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_1[0][0]']
#
#  dense_27 (Dense)            (None, 16, 1024, 16)         272       ['dropout_20[0][0]']
#
#  tf.compat.v1.transpose_3 (  (None, 1024, 16, 16)         0         ['dense_27[0][0]']
#  TFOpLambda)
#
#  tf.reshape_3 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  dense_28 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_3[0][0]']
#
#  dropout_21 (Dropout)        (None, 1024, 64)             0         ['dense_28[0][0]']
#
#  add_18 (Add)                (None, 1024, 64)             0         ['dropout_21[0][0]',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 1024, 64)             128       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_29 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 1024, 64)             0         ['dense_29[0][0]']
#
#  dense_30 (Dense)            (None, 1024, 64)             4160      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 1024, 64)             0         ['dense_30[0][0]']
#
#  add_19 (Add)                (None, 1024, 64)             0         ['dropout_23[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 1024, 64)             128       ['add_19[0][0]']
#  yerNormalization)
#
#  dense_31 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_20[0][0]
#                                                                     ']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_31[0][0]']
#
#  tf.compat.v1.transpose_4 (  (None, 16, 1024, 16)         0         ['tf.reshape_4[0][0]']
#  TFOpLambda)
#
#  dense_32 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_4[0][
#                                                                     0]']
#
#  softmax_2 (Softmax)         (None, 16, 1024, 16)         0         ['dense_32[0][0]']
#
#  tf.math.reduce_sum_2 (TFOp  (None, 16, 1024, 1)          0         ['softmax_2[0][0]']
#  Lambda)
#
#  tf.__operators__.add_2 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_2[0][0]']
#  OpLambda)
#
#  tf.math.truediv_2 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_2[0][0]',
#  bda)                                                                'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_2[0][0]']
#
#  dense_33 (Dense)            (None, 16, 1024, 16)         272       ['dropout_24[0][0]']
#
#  tf.compat.v1.transpose_5 (  (None, 1024, 16, 16)         0         ['dense_33[0][0]']
#  TFOpLambda)
#
#  tf.reshape_5 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  dense_34 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_5[0][0]']
#
#  dropout_25 (Dropout)        (None, 1024, 64)             0         ['dense_34[0][0]']
#
#  add_20 (Add)                (None, 1024, 64)             0         ['dropout_25[0][0]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 1024, 64)             128       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_35 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 1024, 64)             0         ['dense_35[0][0]']
#
#  dense_36 (Dense)            (None, 1024, 64)             4160      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)        (None, 1024, 64)             0         ['dense_36[0][0]']
#
#  add_21 (Add)                (None, 1024, 64)             0         ['dropout_27[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 1024, 64)             128       ['add_21[0][0]']
#  yerNormalization)
#
#  dense_37 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_22[0][0]
#                                                                     ']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_37[0][0]']
#
#  tf.compat.v1.transpose_6 (  (None, 16, 1024, 16)         0         ['tf.reshape_6[0][0]']
#  TFOpLambda)
#
#  dense_38 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_6[0][
#                                                                     0]']
#
#  softmax_3 (Softmax)         (None, 16, 1024, 16)         0         ['dense_38[0][0]']
#
#  tf.math.reduce_sum_3 (TFOp  (None, 16, 1024, 1)          0         ['softmax_3[0][0]']
#  Lambda)
#
#  tf.__operators__.add_3 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_3[0][0]']
#  OpLambda)
#
#  tf.math.truediv_3 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_3[0][0]',
#  bda)                                                                'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_3[0][0]']
#
#  dense_39 (Dense)            (None, 16, 1024, 16)         272       ['dropout_28[0][0]']
#
#  tf.compat.v1.transpose_7 (  (None, 1024, 16, 16)         0         ['dense_39[0][0]']
#  TFOpLambda)
#
#  tf.reshape_7 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  dense_40 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_7[0][0]']
#
#  dropout_29 (Dropout)        (None, 1024, 64)             0         ['dense_40[0][0]']
#
#  add_22 (Add)                (None, 1024, 64)             0         ['dropout_29[0][0]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 1024, 64)             128       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_41 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 1024, 64)             0         ['dense_41[0][0]']
#
#  dense_42 (Dense)            (None, 1024, 64)             4160      ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)        (None, 1024, 64)             0         ['dense_42[0][0]']
#
#  add_23 (Add)                (None, 1024, 64)             0         ['dropout_31[0][0]',
#                                                                      'add_22[0][0]']
#
#  layer_normalization_24 (La  (None, 1024, 64)             128       ['add_23[0][0]']
#  yerNormalization)
#
#  dense_43 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_24[0][0]
#                                                                     ']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_43[0][0]']
#
#  tf.compat.v1.transpose_8 (  (None, 16, 1024, 16)         0         ['tf.reshape_8[0][0]']
#  TFOpLambda)
#
#  dense_44 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_8[0][
#                                                                     0]']
#
#  softmax_4 (Softmax)         (None, 16, 1024, 16)         0         ['dense_44[0][0]']
#
#  tf.math.reduce_sum_4 (TFOp  (None, 16, 1024, 1)          0         ['softmax_4[0][0]']
#  Lambda)
#
#  tf.__operators__.add_4 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_4[0][0]']
#  OpLambda)
#
#  tf.math.truediv_4 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_4[0][0]',
#  bda)                                                                'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_4[0][0]']
#
#  dense_45 (Dense)            (None, 16, 1024, 16)         272       ['dropout_32[0][0]']
#
#  tf.compat.v1.transpose_9 (  (None, 1024, 16, 16)         0         ['dense_45[0][0]']
#  TFOpLambda)
#
#  tf.reshape_9 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_9[0][
#                                                                     0]']
#
#  dense_46 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_9[0][0]']
#
#  dropout_33 (Dropout)        (None, 1024, 64)             0         ['dense_46[0][0]']
#
#  add_24 (Add)                (None, 1024, 64)             0         ['dropout_33[0][0]',
#                                                                      'add_23[0][0]']
#
#  layer_normalization_25 (La  (None, 1024, 64)             128       ['add_24[0][0]']
#  yerNormalization)
#
#  dense_47 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_25[0][0]
#                                                                     ']
#
#  dropout_34 (Dropout)        (None, 1024, 64)             0         ['dense_47[0][0]']
#
#  dense_48 (Dense)            (None, 1024, 64)             4160      ['dropout_34[0][0]']
#
#  dropout_35 (Dropout)        (None, 1024, 64)             0         ['dense_48[0][0]']
#
#  add_25 (Add)                (None, 1024, 64)             0         ['dropout_35[0][0]',
#                                                                      'add_24[0][0]']
#
#  layer_normalization_26 (La  (None, 1024, 64)             128       ['add_25[0][0]']
#  yerNormalization)
#
#  dense_49 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_26[0][0]
#                                                                     ']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_49[0][0]']
#
#  tf.compat.v1.transpose_10   (None, 16, 1024, 16)         0         ['tf.reshape_10[0][0]']
#  (TFOpLambda)
#
#  dense_50 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_10[0]
#                                                                     [0]']
#
#  softmax_5 (Softmax)         (None, 16, 1024, 16)         0         ['dense_50[0][0]']
#
#  tf.math.reduce_sum_5 (TFOp  (None, 16, 1024, 1)          0         ['softmax_5[0][0]']
#  Lambda)
#
#  tf.__operators__.add_5 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_5[0][0]']
#  OpLambda)
#
#  tf.math.truediv_5 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_5[0][0]',
#  bda)                                                                'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_36 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_5[0][0]']
#
#  dense_51 (Dense)            (None, 16, 1024, 16)         272       ['dropout_36[0][0]']
#
#  tf.compat.v1.transpose_11   (None, 1024, 16, 16)         0         ['dense_51[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_11 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_11[0]
#                                                                     [0]']
#
#  dense_52 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_11[0][0]']
#
#  dropout_37 (Dropout)        (None, 1024, 64)             0         ['dense_52[0][0]']
#
#  add_26 (Add)                (None, 1024, 64)             0         ['dropout_37[0][0]',
#                                                                      'add_25[0][0]']
#
#  layer_normalization_27 (La  (None, 1024, 64)             128       ['add_26[0][0]']
#  yerNormalization)
#
#  dense_53 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_27[0][0]
#                                                                     ']
#
#  dropout_38 (Dropout)        (None, 1024, 64)             0         ['dense_53[0][0]']
#
#  dense_54 (Dense)            (None, 1024, 64)             4160      ['dropout_38[0][0]']
#
#  dropout_39 (Dropout)        (None, 1024, 64)             0         ['dense_54[0][0]']
#
#  add_27 (Add)                (None, 1024, 64)             0         ['dropout_39[0][0]',
#                                                                      'add_26[0][0]']
#
#  layer_normalization_28 (La  (None, 1024, 64)             128       ['add_27[0][0]']
#  yerNormalization)
#
#  dense_55 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_28[0][0]
#                                                                     ']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_55[0][0]']
#
#  tf.compat.v1.transpose_12   (None, 16, 1024, 16)         0         ['tf.reshape_12[0][0]']
#  (TFOpLambda)
#
#  dense_56 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_12[0]
#                                                                     [0]']
#
#  softmax_6 (Softmax)         (None, 16, 1024, 16)         0         ['dense_56[0][0]']
#
#  tf.math.reduce_sum_6 (TFOp  (None, 16, 1024, 1)          0         ['softmax_6[0][0]']
#  Lambda)
#
#  tf.__operators__.add_6 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_6[0][0]']
#  OpLambda)
#
#  tf.math.truediv_6 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_6[0][0]',
#  bda)                                                                'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_40 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_6[0][0]']
#
#  dense_57 (Dense)            (None, 16, 1024, 16)         272       ['dropout_40[0][0]']
#
#  tf.compat.v1.transpose_13   (None, 1024, 16, 16)         0         ['dense_57[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_13 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_13[0]
#                                                                     [0]']
#
#  dense_58 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_13[0][0]']
#
#  dropout_41 (Dropout)        (None, 1024, 64)             0         ['dense_58[0][0]']
#
#  add_28 (Add)                (None, 1024, 64)             0         ['dropout_41[0][0]',
#                                                                      'add_27[0][0]']
#
#  layer_normalization_29 (La  (None, 1024, 64)             128       ['add_28[0][0]']
#  yerNormalization)
#
#  dense_59 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_29[0][0]
#                                                                     ']
#
#  dropout_42 (Dropout)        (None, 1024, 64)             0         ['dense_59[0][0]']
#
#  dense_60 (Dense)            (None, 1024, 64)             4160      ['dropout_42[0][0]']
#
#  dropout_43 (Dropout)        (None, 1024, 64)             0         ['dense_60[0][0]']
#
#  add_29 (Add)                (None, 1024, 64)             0         ['dropout_43[0][0]',
#                                                                      'add_28[0][0]']
#
#  layer_normalization_30 (La  (None, 1024, 64)             128       ['add_29[0][0]']
#  yerNormalization)
#
#  dense_61 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_30[0][0]
#                                                                     ']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_61[0][0]']
#
#  tf.compat.v1.transpose_14   (None, 16, 1024, 16)         0         ['tf.reshape_14[0][0]']
#  (TFOpLambda)
#
#  dense_62 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_14[0]
#                                                                     [0]']
#
#  softmax_7 (Softmax)         (None, 16, 1024, 16)         0         ['dense_62[0][0]']
#
#  tf.math.reduce_sum_7 (TFOp  (None, 16, 1024, 1)          0         ['softmax_7[0][0]']
#  Lambda)
#
#  tf.__operators__.add_7 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_7[0][0]']
#  OpLambda)
#
#  tf.math.truediv_7 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_7[0][0]',
#  bda)                                                                'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  dropout_44 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_7[0][0]']
#
#  dense_63 (Dense)            (None, 16, 1024, 16)         272       ['dropout_44[0][0]']
#
#  tf.compat.v1.transpose_15   (None, 1024, 16, 16)         0         ['dense_63[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_15 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_15[0]
#                                                                     [0]']
#
#  dense_64 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_15[0][0]']
#
#  dropout_45 (Dropout)        (None, 1024, 64)             0         ['dense_64[0][0]']
#
#  add_30 (Add)                (None, 1024, 64)             0         ['dropout_45[0][0]',
#                                                                      'add_29[0][0]']
#
#  layer_normalization_31 (La  (None, 1024, 64)             128       ['add_30[0][0]']
#  yerNormalization)
#
#  dense_65 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_31[0][0]
#                                                                     ']
#
#  dropout_46 (Dropout)        (None, 1024, 64)             0         ['dense_65[0][0]']
#
#  dense_66 (Dense)            (None, 1024, 64)             4160      ['dropout_46[0][0]']
#
#  dropout_47 (Dropout)        (None, 1024, 64)             0         ['dense_66[0][0]']
#
#  add_31 (Add)                (None, 1024, 64)             0         ['dropout_47[0][0]',
#                                                                      'add_30[0][0]']
#
#  global_average_pooling1d_1  (None, 64)                   0         ['add_31[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_67 (Dense)            (None, 4)                    260       ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 404299 (1.54 MB)
# Trainable params: 404292 (1.54 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
history_EA = run_experiment(model_EA)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 259/259 [==============================] - 47s 130ms/step - loss: 5.8448 - accuracy: 0.2617 - top5-acc: 1.0000 - Brier score: 0.2570 - F1 score: 0.2520 - Recall: 0.1829 - Precision: 0.2575 - AUC: 0.5069 - val_loss: 1.8955 - val_accuracy: 0.2163 - val_top5-acc: 1.0000 - val_Brier score: 0.2464 - val_F1 score: 0.1179 - val_Recall: 0.1880 - val_Precision: 0.2193 - val_AUC: 0.5750 - lr: 0.0010
# Epoch 2/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.9238 - accuracy: 0.2868 - top5-acc: 1.0000 - Brier score: 0.2308 - F1 score: 0.2805 - Recall: 0.1947 - Precision: 0.2932 - AUC: 0.5516 - val_loss: 2.3926 - val_accuracy: 0.3283 - val_top5-acc: 1.0000 - val_Brier score: 0.2429 - val_F1 score: 0.3041 - val_Recall: 0.2837 - val_Precision: 0.3475 - val_AUC: 0.5236 - lr: 0.0010
# Epoch 3/100
# 259/259 [==============================] - 32s 122ms/step - loss: 1.7483 - accuracy: 0.3403 - top5-acc: 1.0000 - Brier score: 0.2177 - F1 score: 0.3394 - Recall: 0.2650 - Precision: 0.3579 - AUC: 0.6136 - val_loss: 2.3432 - val_accuracy: 0.2283 - val_top5-acc: 1.0000 - val_Brier score: 0.2803 - val_F1 score: 0.1474 - val_Recall: 0.2185 - val_Precision: 0.2300 - val_AUC: 0.5909 - lr: 0.0010
# Epoch 4/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.7858 - accuracy: 0.3715 - top5-acc: 1.0000 - Brier score: 0.2133 - F1 score: 0.3689 - Recall: 0.3009 - Precision: 0.3883 - AUC: 0.6413 - val_loss: 1.1531 - val_accuracy: 0.4652 - val_top5-acc: 1.0000 - val_Brier score: 0.1662 - val_F1 score: 0.4310 - val_Recall: 0.3228 - val_Precision: 0.4901 - val_AUC: 0.7547 - lr: 0.0010
# Epoch 5/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.6456 - accuracy: 0.4001 - top5-acc: 1.0000 - Brier score: 0.2031 - F1 score: 0.3955 - Recall: 0.3214 - Precision: 0.4197 - AUC: 0.6674 - val_loss: 1.3690 - val_accuracy: 0.4707 - val_top5-acc: 1.0000 - val_Brier score: 0.1751 - val_F1 score: 0.4176 - val_Recall: 0.4391 - val_Precision: 0.5114 - val_AUC: 0.7505 - lr: 0.0010
# Epoch 6/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.4911 - accuracy: 0.4193 - top5-acc: 1.0000 - Brier score: 0.1930 - F1 score: 0.4144 - Recall: 0.3452 - Precision: 0.4458 - AUC: 0.6887 - val_loss: 1.2888 - val_accuracy: 0.4870 - val_top5-acc: 1.0000 - val_Brier score: 0.1680 - val_F1 score: 0.4834 - val_Recall: 0.4663 - val_Precision: 0.5257 - val_AUC: 0.7565 - lr: 0.0010
# Epoch 7/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.6154 - accuracy: 0.4297 - top5-acc: 1.0000 - Brier score: 0.1949 - F1 score: 0.4254 - Recall: 0.3622 - Precision: 0.4545 - AUC: 0.6904 - val_loss: 1.1465 - val_accuracy: 0.5141 - val_top5-acc: 1.0000 - val_Brier score: 0.1511 - val_F1 score: 0.4926 - val_Recall: 0.4435 - val_Precision: 0.6108 - val_AUC: 0.7860 - lr: 0.0010
# Epoch 8/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.3793 - accuracy: 0.4552 - top5-acc: 1.0000 - Brier score: 0.1794 - F1 score: 0.4470 - Recall: 0.3616 - Precision: 0.4895 - AUC: 0.7240 - val_loss: 0.8974 - val_accuracy: 0.6228 - val_top5-acc: 1.0000 - val_Brier score: 0.1257 - val_F1 score: 0.5829 - val_Recall: 0.5174 - val_Precision: 0.6909 - val_AUC: 0.8570 - lr: 0.0010
# Epoch 9/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.3922 - accuracy: 0.4542 - top5-acc: 1.0000 - Brier score: 0.1820 - F1 score: 0.4474 - Recall: 0.3809 - Precision: 0.4867 - AUC: 0.7206 - val_loss: 1.4882 - val_accuracy: 0.4533 - val_top5-acc: 1.0000 - val_Brier score: 0.1850 - val_F1 score: 0.3720 - val_Recall: 0.4228 - val_Precision: 0.4808 - val_AUC: 0.7515 - lr: 0.0010
# Epoch 10/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.2699 - accuracy: 0.4896 - top5-acc: 1.0000 - Brier score: 0.1680 - F1 score: 0.4791 - Recall: 0.3885 - Precision: 0.5335 - AUC: 0.7517 - val_loss: 1.2441 - val_accuracy: 0.5239 - val_top5-acc: 1.0000 - val_Brier score: 0.1644 - val_F1 score: 0.4968 - val_Recall: 0.5109 - val_Precision: 0.5491 - val_AUC: 0.7983 - lr: 0.0010
# Epoch 11/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.5682 - accuracy: 0.4614 - top5-acc: 1.0000 - Brier score: 0.1878 - F1 score: 0.4530 - Recall: 0.3999 - Precision: 0.4829 - AUC: 0.7190 - val_loss: 1.1536 - val_accuracy: 0.5402 - val_top5-acc: 1.0000 - val_Brier score: 0.1563 - val_F1 score: 0.4876 - val_Recall: 0.4543 - val_Precision: 0.5781 - val_AUC: 0.8076 - lr: 0.0010
# Epoch 12/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.2907 - accuracy: 0.4884 - top5-acc: 1.0000 - Brier score: 0.1698 - F1 score: 0.4807 - Recall: 0.4038 - Precision: 0.5256 - AUC: 0.7533 - val_loss: 1.0231 - val_accuracy: 0.5565 - val_top5-acc: 1.0000 - val_Brier score: 0.1386 - val_F1 score: 0.5290 - val_Recall: 0.4739 - val_Precision: 0.6220 - val_AUC: 0.8271 - lr: 0.0010
# Epoch 13/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.2384 - accuracy: 0.4971 - top5-acc: 1.0000 - Brier score: 0.1662 - F1 score: 0.4881 - Recall: 0.4250 - Precision: 0.5374 - AUC: 0.7664 - val_loss: 1.5345 - val_accuracy: 0.5554 - val_top5-acc: 1.0000 - val_Brier score: 0.1748 - val_F1 score: 0.4686 - val_Recall: 0.5370 - val_Precision: 0.5626 - val_AUC: 0.7974 - lr: 0.0010
# Epoch 14/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0322 - accuracy: 0.5506 - top5-acc: 1.0000 - Brier score: 0.1446 - F1 score: 0.5353 - Recall: 0.4241 - Precision: 0.6223 - AUC: 0.8099 - val_loss: 0.8903 - val_accuracy: 0.5978 - val_top5-acc: 1.0000 - val_Brier score: 0.1229 - val_F1 score: 0.5725 - val_Recall: 0.4783 - val_Precision: 0.7063 - val_AUC: 0.8618 - lr: 5.0000e-04
# Epoch 15/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0329 - accuracy: 0.5553 - top5-acc: 1.0000 - Brier score: 0.1443 - F1 score: 0.5382 - Recall: 0.4276 - Precision: 0.6254 - AUC: 0.8095 - val_loss: 0.7990 - val_accuracy: 0.6728 - val_top5-acc: 1.0000 - val_Brier score: 0.1107 - val_F1 score: 0.6025 - val_Recall: 0.6011 - val_Precision: 0.7219 - val_AUC: 0.8890 - lr: 5.0000e-04
# Epoch 16/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.0570 - accuracy: 0.5427 - top5-acc: 1.0000 - Brier score: 0.1474 - F1 score: 0.5301 - Recall: 0.4194 - Precision: 0.6068 - AUC: 0.8001 - val_loss: 1.4378 - val_accuracy: 0.5076 - val_top5-acc: 1.0000 - val_Brier score: 0.1824 - val_F1 score: 0.4727 - val_Recall: 0.4935 - val_Precision: 0.5177 - val_AUC: 0.7644 - lr: 5.0000e-04
# Epoch 17/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.0445 - accuracy: 0.5368 - top5-acc: 1.0000 - Brier score: 0.1481 - F1 score: 0.5253 - Recall: 0.4210 - Precision: 0.5977 - AUC: 0.8011 - val_loss: 0.7905 - val_accuracy: 0.6924 - val_top5-acc: 1.0000 - val_Brier score: 0.1088 - val_F1 score: 0.6390 - val_Recall: 0.5554 - val_Precision: 0.7593 - val_AUC: 0.8921 - lr: 5.0000e-04
# Epoch 18/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0232 - accuracy: 0.5489 - top5-acc: 1.0000 - Brier score: 0.1447 - F1 score: 0.5329 - Recall: 0.4161 - Precision: 0.6163 - AUC: 0.8089 - val_loss: 0.8167 - val_accuracy: 0.6663 - val_top5-acc: 1.0000 - val_Brier score: 0.1149 - val_F1 score: 0.6500 - val_Recall: 0.5293 - val_Precision: 0.7345 - val_AUC: 0.8826 - lr: 5.0000e-04
# Epoch 19/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0507 - accuracy: 0.5416 - top5-acc: 1.0000 - Brier score: 0.1474 - F1 score: 0.5290 - Recall: 0.4237 - Precision: 0.6069 - AUC: 0.8018 - val_loss: 1.2795 - val_accuracy: 0.5413 - val_top5-acc: 1.0000 - val_Brier score: 0.1550 - val_F1 score: 0.4851 - val_Recall: 0.5098 - val_Precision: 0.5944 - val_AUC: 0.7860 - lr: 5.0000e-04
# Epoch 20/100
# 259/259 [==============================] - 32s 120ms/step - loss: 1.0277 - accuracy: 0.5526 - top5-acc: 1.0000 - Brier score: 0.1447 - F1 score: 0.5388 - Recall: 0.4289 - Precision: 0.6254 - AUC: 0.8071 - val_loss: 0.8835 - val_accuracy: 0.6261 - val_top5-acc: 1.0000 - val_Brier score: 0.1248 - val_F1 score: 0.5428 - val_Recall: 0.5554 - val_Precision: 0.6795 - val_AUC: 0.8671 - lr: 5.0000e-04
# Epoch 21/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0030 - accuracy: 0.5588 - top5-acc: 1.0000 - Brier score: 0.1424 - F1 score: 0.5423 - Recall: 0.4364 - Precision: 0.6282 - AUC: 0.8162 - val_loss: 0.9076 - val_accuracy: 0.6109 - val_top5-acc: 1.0000 - val_Brier score: 0.1280 - val_F1 score: 0.6398 - val_Recall: 0.5380 - val_Precision: 0.6644 - val_AUC: 0.8537 - lr: 5.0000e-04
# Epoch 22/100
# 259/259 [==============================] - 32s 122ms/step - loss: 1.0331 - accuracy: 0.5573 - top5-acc: 1.0000 - Brier score: 0.1446 - F1 score: 0.5420 - Recall: 0.4404 - Precision: 0.6206 - AUC: 0.8106 - val_loss: 0.7895 - val_accuracy: 0.6641 - val_top5-acc: 1.0000 - val_Brier score: 0.1118 - val_F1 score: 0.6631 - val_Recall: 0.5304 - val_Precision: 0.7360 - val_AUC: 0.8898 - lr: 5.0000e-04
# Epoch 23/100
# 259/259 [==============================] - 32s 121ms/step - loss: 1.0062 - accuracy: 0.5598 - top5-acc: 1.0000 - Brier score: 0.1419 - F1 score: 0.5430 - Recall: 0.4447 - Precision: 0.6286 - AUC: 0.8178 - val_loss: 1.0190 - val_accuracy: 0.5685 - val_top5-acc: 1.0000 - val_Brier score: 0.1430 - val_F1 score: 0.5359 - val_Recall: 0.4565 - val_Precision: 0.6069 - val_AUC: 0.8369 - lr: 5.0000e-04
# Epoch 24/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.9838 - accuracy: 0.5630 - top5-acc: 1.0000 - Brier score: 0.1398 - F1 score: 0.5467 - Recall: 0.4462 - Precision: 0.6378 - AUC: 0.8225 - val_loss: 1.0265 - val_accuracy: 0.5250 - val_top5-acc: 1.0000 - val_Brier score: 0.1441 - val_F1 score: 0.4735 - val_Recall: 0.4674 - val_Precision: 0.5695 - val_AUC: 0.8303 - lr: 5.0000e-04
# Epoch 25/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.9321 - accuracy: 0.5936 - top5-acc: 1.0000 - Brier score: 0.1329 - F1 score: 0.5760 - Recall: 0.4634 - Precision: 0.6685 - AUC: 0.8397 - val_loss: 0.7491 - val_accuracy: 0.7043 - val_top5-acc: 1.0000 - val_Brier score: 0.1046 - val_F1 score: 0.6790 - val_Recall: 0.6043 - val_Precision: 0.7534 - val_AUC: 0.9019 - lr: 5.0000e-04
# Epoch 26/100
# 259/259 [==============================] - 32s 122ms/step - loss: 0.9630 - accuracy: 0.5802 - top5-acc: 1.0000 - Brier score: 0.1362 - F1 score: 0.5615 - Recall: 0.4566 - Precision: 0.6525 - AUC: 0.8316 - val_loss: 0.8111 - val_accuracy: 0.6750 - val_top5-acc: 1.0000 - val_Brier score: 0.1129 - val_F1 score: 0.6516 - val_Recall: 0.5250 - val_Precision: 0.7307 - val_AUC: 0.8851 - lr: 5.0000e-04
# Epoch 27/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.9337 - accuracy: 0.5962 - top5-acc: 1.0000 - Brier score: 0.1324 - F1 score: 0.5778 - Recall: 0.4660 - Precision: 0.6725 - AUC: 0.8407 - val_loss: 0.7280 - val_accuracy: 0.7250 - val_top5-acc: 1.0000 - val_Brier score: 0.1015 - val_F1 score: 0.7123 - val_Recall: 0.5761 - val_Precision: 0.7875 - val_AUC: 0.9103 - lr: 5.0000e-04
# Epoch 28/100
# 259/259 [==============================] - 32s 120ms/step - loss: 0.9726 - accuracy: 0.5787 - top5-acc: 1.0000 - Brier score: 0.1378 - F1 score: 0.5624 - Recall: 0.4680 - Precision: 0.6444 - AUC: 0.8279 - val_loss: 0.9882 - val_accuracy: 0.5543 - val_top5-acc: 1.0000 - val_Brier score: 0.1419 - val_F1 score: 0.5277 - val_Recall: 0.5304 - val_Precision: 0.5930 - val_AUC: 0.8381 - lr: 5.0000e-04
# Epoch 29/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.9431 - accuracy: 0.5905 - top5-acc: 1.0000 - Brier score: 0.1345 - F1 score: 0.5742 - Recall: 0.4794 - Precision: 0.6511 - AUC: 0.8377 - val_loss: 0.7865 - val_accuracy: 0.6489 - val_top5-acc: 1.0000 - val_Brier score: 0.1112 - val_F1 score: 0.6400 - val_Recall: 0.5413 - val_Precision: 0.7207 - val_AUC: 0.8902 - lr: 5.0000e-04
# Epoch 30/100
# 259/259 [==============================] - 32s 120ms/step - loss: 0.9239 - accuracy: 0.5974 - top5-acc: 1.0000 - Brier score: 0.1312 - F1 score: 0.5785 - Recall: 0.4700 - Precision: 0.6683 - AUC: 0.8443 - val_loss: 0.9251 - val_accuracy: 0.6250 - val_top5-acc: 1.0000 - val_Brier score: 0.1293 - val_F1 score: 0.5183 - val_Recall: 0.5913 - val_Precision: 0.6626 - val_AUC: 0.8681 - lr: 5.0000e-04
# Epoch 31/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.9143 - accuracy: 0.6100 - top5-acc: 1.0000 - Brier score: 0.1296 - F1 score: 0.5890 - Recall: 0.4908 - Precision: 0.6723 - AUC: 0.8495 - val_loss: 0.6950 - val_accuracy: 0.7380 - val_top5-acc: 1.0000 - val_Brier score: 0.0969 - val_F1 score: 0.7215 - val_Recall: 0.6304 - val_Precision: 0.7827 - val_AUC: 0.9173 - lr: 5.0000e-04
# Epoch 32/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.8870 - accuracy: 0.6237 - top5-acc: 1.0000 - Brier score: 0.1257 - F1 score: 0.6035 - Recall: 0.4957 - Precision: 0.6975 - AUC: 0.8577 - val_loss: 0.6649 - val_accuracy: 0.7435 - val_top5-acc: 1.0000 - val_Brier score: 0.0935 - val_F1 score: 0.7294 - val_Recall: 0.6500 - val_Precision: 0.7952 - val_AUC: 0.9253 - lr: 5.0000e-04
# Epoch 33/100
# 259/259 [==============================] - 32s 120ms/step - loss: 0.8717 - accuracy: 0.6239 - top5-acc: 1.0000 - Brier score: 0.1243 - F1 score: 0.6027 - Recall: 0.5064 - Precision: 0.6883 - AUC: 0.8620 - val_loss: 0.7035 - val_accuracy: 0.7152 - val_top5-acc: 1.0000 - val_Brier score: 0.0987 - val_F1 score: 0.6500 - val_Recall: 0.6446 - val_Precision: 0.7681 - val_AUC: 0.9132 - lr: 5.0000e-04
# Epoch 34/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.8767 - accuracy: 0.6190 - top5-acc: 1.0000 - Brier score: 0.1254 - F1 score: 0.6003 - Recall: 0.5135 - Precision: 0.6899 - AUC: 0.8590 - val_loss: 0.7563 - val_accuracy: 0.6522 - val_top5-acc: 1.0000 - val_Brier score: 0.1102 - val_F1 score: 0.6627 - val_Recall: 0.5793 - val_Precision: 0.7069 - val_AUC: 0.8958 - lr: 5.0000e-04
# Epoch 35/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.8513 - accuracy: 0.6367 - top5-acc: 1.0000 - Brier score: 0.1217 - F1 score: 0.6147 - Recall: 0.5220 - Precision: 0.6991 - AUC: 0.8682 - val_loss: 0.6872 - val_accuracy: 0.7380 - val_top5-acc: 1.0000 - val_Brier score: 0.0980 - val_F1 score: 0.7450 - val_Recall: 0.6500 - val_Precision: 0.7879 - val_AUC: 0.9206 - lr: 5.0000e-04
# Epoch 36/100
# 259/259 [==============================] - 32s 120ms/step - loss: 0.8302 - accuracy: 0.6500 - top5-acc: 1.0000 - Brier score: 0.1181 - F1 score: 0.6293 - Recall: 0.5352 - Precision: 0.7133 - AUC: 0.8762 - val_loss: 0.8428 - val_accuracy: 0.6109 - val_top5-acc: 1.0000 - val_Brier score: 0.1179 - val_F1 score: 0.5903 - val_Recall: 0.5272 - val_Precision: 0.6879 - val_AUC: 0.8788 - lr: 5.0000e-04
# Epoch 37/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.8393 - accuracy: 0.6454 - top5-acc: 1.0000 - Brier score: 0.1197 - F1 score: 0.6254 - Recall: 0.5311 - Precision: 0.7057 - AUC: 0.8720 - val_loss: 0.6914 - val_accuracy: 0.7261 - val_top5-acc: 1.0000 - val_Brier score: 0.0979 - val_F1 score: 0.7141 - val_Recall: 0.6098 - val_Precision: 0.7738 - val_AUC: 0.9167 - lr: 5.0000e-04
# Epoch 38/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.7993 - accuracy: 0.6741 - top5-acc: 1.0000 - Brier score: 0.1136 - F1 score: 0.6498 - Recall: 0.5458 - Precision: 0.7485 - AUC: 0.8862 - val_loss: 0.6857 - val_accuracy: 0.7163 - val_top5-acc: 1.0000 - val_Brier score: 0.0978 - val_F1 score: 0.7160 - val_Recall: 0.6293 - val_Precision: 0.7588 - val_AUC: 0.9171 - lr: 2.5000e-04
# Epoch 39/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.8026 - accuracy: 0.6717 - top5-acc: 1.0000 - Brier score: 0.1140 - F1 score: 0.6485 - Recall: 0.5450 - Precision: 0.7453 - AUC: 0.8858 - val_loss: 0.8413 - val_accuracy: 0.6370 - val_top5-acc: 1.0000 - val_Brier score: 0.1191 - val_F1 score: 0.6152 - val_Recall: 0.5239 - val_Precision: 0.6779 - val_AUC: 0.8793 - lr: 2.5000e-04
# Epoch 40/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.7896 - accuracy: 0.6746 - top5-acc: 1.0000 - Brier score: 0.1129 - F1 score: 0.6511 - Recall: 0.5477 - Precision: 0.7459 - AUC: 0.8886 - val_loss: 0.7852 - val_accuracy: 0.6141 - val_top5-acc: 1.0000 - val_Brier score: 0.1121 - val_F1 score: 0.5945 - val_Recall: 0.5370 - val_Precision: 0.6977 - val_AUC: 0.8905 - lr: 2.5000e-04
# Epoch 41/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.7951 - accuracy: 0.6689 - top5-acc: 1.0000 - Brier score: 0.1140 - F1 score: 0.6489 - Recall: 0.5439 - Precision: 0.7448 - AUC: 0.8855 - val_loss: 0.7010 - val_accuracy: 0.7152 - val_top5-acc: 1.0000 - val_Brier score: 0.0992 - val_F1 score: 0.7072 - val_Recall: 0.6228 - val_Precision: 0.7630 - val_AUC: 0.9136 - lr: 2.5000e-04
# Epoch 42/100
# 259/259 [==============================] - 32s 121ms/step - loss: 0.7748 - accuracy: 0.6788 - top5-acc: 1.0000 - Brier score: 0.1116 - F1 score: 0.6585 - Recall: 0.5520 - Precision: 0.7568 - AUC: 0.8914 - val_loss: 0.7606 - val_accuracy: 0.6739 - val_top5-acc: 1.0000 - val_Brier score: 0.1080 - val_F1 score: 0.6711 - val_Recall: 0.5674 - val_Precision: 0.7321 - val_AUC: 0.8970 - lr: 2.5000e-04

# %%
plot_training_curves(history_EA, 'Chest, EA Transfomer')
