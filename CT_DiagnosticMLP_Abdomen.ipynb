# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/DiagnosticMLP/blob/main/CT_DiagnosticMLP_Abdomen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟨 Abdomen CT Image classification with modern MLP models

# %% [markdown]
# This notebook implements five modern attention-free, multi-layer perceptron (MLP) based models for medical image classification, demonstrated on the CT medical image datasets:
#
# - The MLP-Mixer model, by Ilya Tolstikhin et al., based on two types of MLPs.
# - The FNet model, by James Lee-Thorp et al., based on unparameterized Fourier Transform.
# - The gMLP model, by Hanxiao Liu et al., based on MLP with gating.
# - The resMLP model, by Touvron et al. (2023), based on residual connections.
# - The DiagnosticMLP moadel, by Alzahrani S. (2024), based on three types of MLPs with gating, preceded by unparameterized Fourier Transform.

# %%
# !pip install nest_asyncio
# !pip install -U -q tensorflow-addons
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.5.8)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 4.0 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math
import nest_asyncio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ---
#
# ## 🟡 plot_training_curves

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(len(history.history['loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('_mpl-gallery') #ggplot #bmh
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10)

# %% [markdown]
# ## 🟡 Hyperparameters

# %%
path = '/content/drive/MyDrive/CT_Datasets/Computed Tomography (CT) of the Abdomen/'

image_size = 64 # We'll resize input images to this size.
patch_size = 256
input_shape = (64, 64, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
patch_size = 8  # Size of the patches to be extracted from the input images.
num_patches = (image_size // patch_size) ** 2  # Size of the data array.
embedding_dim = 256  # Number of hidden units.
num_blocks = 4  # Number of blocks.

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 8 X 8 = 64
# Patches per image: 64
# Elements per patch (3 channels): 192

# %% [markdown]
# ## 🟡 Dataset

# %%
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1428 files belonging to 9 classes.
# Using 1286 files for training.
# Found 1428 files belonging to 9 classes.
# Using 142 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
##################
num_classes = len(class_names)
##################
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(num_classes): classes.append(i)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# ['abdominal_aorta_dilatation', 'aneurysmal_dilatation_of_aorta', 'aortic_aneurysm', 'cancer', 'formation_of_adrenal_gland', 'kidney_development', 'liver_formation', 'urolithiasis', 'vertebral_compression_fracture']
# {0: 1.1581508515815084,
#  1: 1.017094017094017,
#  2: 0.9558232931726908,
#  3: 0.9500998003992016,
#  4: 1.0507726269315674,
#  5: 1.0042194092827004,
#  6: 0.9855072463768116,
#  7: 0.8766114180478821,
#  8: 1.0507726269315674}

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 🟡 Classification model
# We implement a method that builds a classifier given the processing blocks.

# %%
def build_classifier(blocks, positional_encoding=False):
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size, num_patches)(augmented)
    # Encode patches to generate a [batch_size, num_patches, embedding_dim] tensor.
    x = layers.Dense(units=embedding_dim)(patches)
    if positional_encoding:
        positions = tf.range(start=0, limit=num_patches, delta=1)
        position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=embedding_dim
        )(positions)
        x = x + position_embedding
    # Process x using the module blocks.
    x = blocks(x)
    # Apply global average pooling to generate a [batch_size, embedding_dim] representation tensor.
    representation = layers.GlobalAveragePooling1D()(x)
    # Apply dropout.
    representation = layers.Dropout(rate=dropout_rate)(representation)
    # Compute logits outputs.
    logits = layers.Dense(num_classes)(representation)
    # Create the Keras model.
    return keras.Model(inputs=inputs, outputs=logits)

# %% [markdown]
# ## 🟡 Experiment
# We implement a utility function to compile, train, and evaluate a given model.

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# ## 🟡 Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip('horizontal_and_vertical'),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
        layers.RandomContrast(factor=0.2),
        layers.RandomCrop(height=image_size, width=image_size),
        layers.RandomBrightness(factor=0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ## 🟡 Patch extraction

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size, num_patches):
        super().__init__()
        self.patch_size = patch_size
        self.num_patches = num_patches

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, self.num_patches, patch_dims])
        return patches

# %% [markdown]
# # ⚛ MLP-Mixer model
# The MLP-Mixer is an architecture based exclusively on multi-layer perceptrons (MLPs), that contains two types of MLP layers:
#
# One applied independently to image patches, which mixes the per-location features.
# The other applied across patches (along channels), which mixes spatial information.
# This is similar to a depthwise separable convolution based model such as the Xception model, but with two chained dense transforms, no max pooling, and layer normalization instead of batch normalization.

# %%
class MLPMixerLayer(layers.Layer):
    def __init__(self, num_patches, hidden_units, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.mlp1 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=num_patches),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.mlp2 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=embedding_dim),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.normalize = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize(inputs)
        # Transpose inputs from [num_batches, num_patches, hidden_units] to [num_batches, hidden_units, num_patches].
        x_channels = tf.linalg.matrix_transpose(x)
        # Apply mlp1 on each channel independently.
        mlp1_outputs = self.mlp1(x_channels)
        # Transpose mlp1_outputs from [num_batches, hidden_dim, num_patches] to [num_batches, num_patches, hidden_units].
        mlp1_outputs = tf.linalg.matrix_transpose(mlp1_outputs)
        # Add skip connection.
        x = mlp1_outputs + inputs
        # Apply layer normalization.
        x_patches = self.normalize(x)
        # Apply mlp2 on each patch independtenly.
        mlp2_outputs = self.mlp2(x_patches)
        # Add skip connection.
        x = x + mlp2_outputs
        return x

# %%
mlpmixer_blocks = keras.Sequential(
    [MLPMixerLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
mlpmixer_classifier = build_classifier(mlpmixer_blocks)

# %%
history_mlpmixer = run_experiment(mlpmixer_classifier)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 49s 699ms/step - loss: 103.2687 - accuracy: 0.1330 - top5-acc: 0.5894 - Brier score: 40485.6484 - F1 score: 0.1325 - Recall: 0.5288 - Precision: 0.1203 - AUC: 0.5231 - val_loss: 9.1477 - val_accuracy: 0.1901 - val_top5-acc: 0.7465 - val_Brier score: 161.7483 - val_F1 score: 0.1390 - val_Recall: 0.5282 - val_Precision: 0.1537 - val_AUC: 0.5873 - lr: 0.0050
# Epoch 2/100
# 41/41 [==============================] - 1s 27ms/step - loss: 4.1101 - accuracy: 0.1983 - top5-acc: 0.7333 - Brier score: 21.8786 - F1 score: 0.1953 - Recall: 0.5086 - Precision: 0.1576 - AUC: 0.5947 - val_loss: 2.4744 - val_accuracy: 0.3169 - val_top5-acc: 0.8732 - val_Brier score: 19.3151 - val_F1 score: 0.2591 - val_Recall: 0.6338 - val_Precision: 0.2308 - val_AUC: 0.7050 - lr: 0.0050
# Epoch 3/100
# 41/41 [==============================] - 1s 27ms/step - loss: 2.8255 - accuracy: 0.2333 - top5-acc: 0.7862 - Brier score: 8.9041 - F1 score: 0.2315 - Recall: 0.5591 - Precision: 0.1733 - AUC: 0.6342 - val_loss: 2.3954 - val_accuracy: 0.2676 - val_top5-acc: 0.8873 - val_Brier score: 27.3038 - val_F1 score: 0.2478 - val_Recall: 0.4155 - val_Precision: 0.2706 - val_AUC: 0.6513 - lr: 0.0050
# Epoch 4/100
# 41/41 [==============================] - 1s 26ms/step - loss: 2.3908 - accuracy: 0.2675 - top5-acc: 0.8243 - Brier score: 7.2294 - F1 score: 0.2660 - Recall: 0.5855 - Precision: 0.2025 - AUC: 0.6697 - val_loss: 3.3278 - val_accuracy: 0.3099 - val_top5-acc: 0.7676 - val_Brier score: 21.5073 - val_F1 score: 0.2220 - val_Recall: 0.4789 - val_Precision: 0.2297 - val_AUC: 0.6590 - lr: 0.0050
# Epoch 5/100
# 41/41 [==============================] - 1s 26ms/step - loss: 2.1661 - accuracy: 0.3118 - top5-acc: 0.8499 - Brier score: 6.1786 - F1 score: 0.3056 - Recall: 0.6431 - Precision: 0.2023 - AUC: 0.6894 - val_loss: 1.5858 - val_accuracy: 0.4366 - val_top5-acc: 1.0000 - val_Brier score: 17.2674 - val_F1 score: 0.3689 - val_Recall: 0.6901 - val_Precision: 0.3161 - val_AUC: 0.7799 - lr: 0.0050
# Epoch 6/100
# 41/41 [==============================] - 1s 26ms/step - loss: 2.1803 - accuracy: 0.3437 - top5-acc: 0.8577 - Brier score: 7.9615 - F1 score: 0.3400 - Recall: 0.6905 - Precision: 0.2028 - AUC: 0.7009 - val_loss: 2.8593 - val_accuracy: 0.3239 - val_top5-acc: 0.7887 - val_Brier score: 20.1794 - val_F1 score: 0.2504 - val_Recall: 0.6268 - val_Precision: 0.2412 - val_AUC: 0.6988 - lr: 0.0050
# Epoch 7/100
# 41/41 [==============================] - 1s 25ms/step - loss: 2.0659 - accuracy: 0.3616 - top5-acc: 0.8670 - Brier score: 7.4215 - F1 score: 0.3594 - Recall: 0.7061 - Precision: 0.2143 - AUC: 0.7179 - val_loss: 1.6892 - val_accuracy: 0.4930 - val_top5-acc: 0.9437 - val_Brier score: 15.3535 - val_F1 score: 0.3827 - val_Recall: 0.7254 - val_Precision: 0.2682 - val_AUC: 0.7702 - lr: 0.0050
# Epoch 8/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.8926 - accuracy: 0.4005 - top5-acc: 0.8942 - Brier score: 7.4198 - F1 score: 0.3982 - Recall: 0.8033 - Precision: 0.1974 - AUC: 0.7257 - val_loss: 1.9901 - val_accuracy: 0.4366 - val_top5-acc: 0.9225 - val_Brier score: 17.5233 - val_F1 score: 0.3780 - val_Recall: 0.8099 - val_Precision: 0.2457 - val_AUC: 0.7845 - lr: 0.0050
# Epoch 9/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.8015 - accuracy: 0.4215 - top5-acc: 0.9184 - Brier score: 8.0323 - F1 score: 0.4191 - Recall: 0.8320 - Precision: 0.2070 - AUC: 0.7419 - val_loss: 1.9097 - val_accuracy: 0.4507 - val_top5-acc: 0.8803 - val_Brier score: 14.2079 - val_F1 score: 0.3563 - val_Recall: 0.8028 - val_Precision: 0.2205 - val_AUC: 0.7440 - lr: 0.0050
# Epoch 10/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.8045 - accuracy: 0.4432 - top5-acc: 0.9176 - Brier score: 8.6085 - F1 score: 0.4403 - Recall: 0.7955 - Precision: 0.2208 - AUC: 0.7534 - val_loss: 1.5447 - val_accuracy: 0.5282 - val_top5-acc: 0.9225 - val_Brier score: 13.0783 - val_F1 score: 0.4591 - val_Recall: 0.7746 - val_Precision: 0.2965 - val_AUC: 0.7892 - lr: 0.0050
# Epoch 11/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.6684 - accuracy: 0.4580 - top5-acc: 0.9176 - Brier score: 8.6004 - F1 score: 0.4520 - Recall: 0.8072 - Precision: 0.2370 - AUC: 0.7688 - val_loss: 1.4596 - val_accuracy: 0.5141 - val_top5-acc: 0.9577 - val_Brier score: 27.2666 - val_F1 score: 0.4623 - val_Recall: 0.7183 - val_Precision: 0.3938 - val_AUC: 0.8133 - lr: 0.0050
# Epoch 12/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.4789 - accuracy: 0.4860 - top5-acc: 0.9487 - Brier score: 10.1279 - F1 score: 0.4836 - Recall: 0.7939 - Precision: 0.2589 - AUC: 0.7851 - val_loss: 1.1044 - val_accuracy: 0.6056 - val_top5-acc: 1.0000 - val_Brier score: 19.1423 - val_F1 score: 0.5405 - val_Recall: 0.8732 - val_Precision: 0.2678 - val_AUC: 0.8240 - lr: 0.0050
# Epoch 13/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.3839 - accuracy: 0.5358 - top5-acc: 0.9417 - Brier score: 8.7343 - F1 score: 0.5330 - Recall: 0.8593 - Precision: 0.2381 - AUC: 0.7866 - val_loss: 1.1112 - val_accuracy: 0.6127 - val_top5-acc: 0.9859 - val_Brier score: 15.8549 - val_F1 score: 0.5449 - val_Recall: 0.9437 - val_Precision: 0.2533 - val_AUC: 0.8203 - lr: 0.0050
# Epoch 14/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.4060 - accuracy: 0.5303 - top5-acc: 0.9487 - Brier score: 10.2292 - F1 score: 0.5282 - Recall: 0.8624 - Precision: 0.2475 - AUC: 0.7984 - val_loss: 0.7696 - val_accuracy: 0.7746 - val_top5-acc: 0.9789 - val_Brier score: 18.2828 - val_F1 score: 0.7301 - val_Recall: 0.8803 - val_Precision: 0.3351 - val_AUC: 0.8602 - lr: 0.0050
# Epoch 15/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.2294 - accuracy: 0.5894 - top5-acc: 0.9689 - Brier score: 10.5517 - F1 score: 0.5868 - Recall: 0.9145 - Precision: 0.2420 - AUC: 0.8062 - val_loss: 0.8428 - val_accuracy: 0.7042 - val_top5-acc: 0.9859 - val_Brier score: 15.7562 - val_F1 score: 0.6531 - val_Recall: 0.9366 - val_Precision: 0.2623 - val_AUC: 0.8213 - lr: 0.0050
# Epoch 16/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0851 - accuracy: 0.6190 - top5-acc: 0.9767 - Brier score: 9.2921 - F1 score: 0.6164 - Recall: 0.9518 - Precision: 0.2281 - AUC: 0.8064 - val_loss: 0.7204 - val_accuracy: 0.7324 - val_top5-acc: 1.0000 - val_Brier score: 16.0171 - val_F1 score: 0.6945 - val_Recall: 0.9225 - val_Precision: 0.2707 - val_AUC: 0.8272 - lr: 0.0050
# Epoch 17/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1792 - accuracy: 0.6275 - top5-acc: 0.9697 - Brier score: 12.8149 - F1 score: 0.6256 - Recall: 0.9425 - Precision: 0.2254 - AUC: 0.7933 - val_loss: 0.8364 - val_accuracy: 0.7183 - val_top5-acc: 1.0000 - val_Brier score: 20.7187 - val_F1 score: 0.6739 - val_Recall: 0.9155 - val_Precision: 0.3178 - val_AUC: 0.8617 - lr: 0.0050
# Epoch 18/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3129 - accuracy: 0.5956 - top5-acc: 0.9658 - Brier score: 14.9134 - F1 score: 0.5923 - Recall: 0.9347 - Precision: 0.2280 - AUC: 0.7953 - val_loss: 0.8860 - val_accuracy: 0.7183 - val_top5-acc: 0.9859 - val_Brier score: 25.8056 - val_F1 score: 0.6917 - val_Recall: 0.9648 - val_Precision: 0.2645 - val_AUC: 0.8357 - lr: 0.0050
# Epoch 19/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.2665 - accuracy: 0.6159 - top5-acc: 0.9642 - Brier score: 15.4803 - F1 score: 0.6131 - Recall: 0.9627 - Precision: 0.2098 - AUC: 0.7775 - val_loss: 0.4270 - val_accuracy: 0.8592 - val_top5-acc: 0.9930 - val_Brier score: 20.6790 - val_F1 score: 0.8220 - val_Recall: 0.9718 - val_Precision: 0.2685 - val_AUC: 0.8365 - lr: 0.0050
# Epoch 20/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.1126 - accuracy: 0.6509 - top5-acc: 0.9673 - Brier score: 14.5620 - F1 score: 0.6479 - Recall: 0.9572 - Precision: 0.2122 - AUC: 0.7838 - val_loss: 0.9814 - val_accuracy: 0.6761 - val_top5-acc: 0.9718 - val_Brier score: 25.2906 - val_F1 score: 0.6369 - val_Recall: 0.9155 - val_Precision: 0.3023 - val_AUC: 0.8399 - lr: 0.0050
# Epoch 21/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0328 - accuracy: 0.6555 - top5-acc: 0.9728 - Brier score: 17.6111 - F1 score: 0.6539 - Recall: 0.9495 - Precision: 0.2395 - AUC: 0.8093 - val_loss: 0.6226 - val_accuracy: 0.7606 - val_top5-acc: 0.9859 - val_Brier score: 26.3457 - val_F1 score: 0.7409 - val_Recall: 0.9789 - val_Precision: 0.2623 - val_AUC: 0.8358 - lr: 0.0050
# Epoch 22/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.0770 - accuracy: 0.6485 - top5-acc: 0.9736 - Brier score: 17.7512 - F1 score: 0.6457 - Recall: 0.9487 - Precision: 0.2292 - AUC: 0.7982 - val_loss: 0.3292 - val_accuracy: 0.8451 - val_top5-acc: 1.0000 - val_Brier score: 28.3375 - val_F1 score: 0.8399 - val_Recall: 1.0000 - val_Precision: 0.2635 - val_AUC: 0.8460 - lr: 0.0050
# Epoch 23/100
# 41/41 [==============================] - 1s 27ms/step - loss: 1.0689 - accuracy: 0.6812 - top5-acc: 0.9806 - Brier score: 19.1583 - F1 score: 0.6800 - Recall: 0.9541 - Precision: 0.2351 - AUC: 0.8047 - val_loss: 0.8562 - val_accuracy: 0.7676 - val_top5-acc: 1.0000 - val_Brier score: 25.4866 - val_F1 score: 0.7281 - val_Recall: 0.9718 - val_Precision: 0.2754 - val_AUC: 0.8443 - lr: 0.0050
# Epoch 24/100
# 41/41 [==============================] - 1s 28ms/step - loss: 1.0030 - accuracy: 0.6975 - top5-acc: 0.9790 - Brier score: 18.4796 - F1 score: 0.6956 - Recall: 0.9619 - Precision: 0.2310 - AUC: 0.8051 - val_loss: 0.4667 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 24.1223 - val_F1 score: 0.8256 - val_Recall: 0.9859 - val_Precision: 0.2559 - val_AUC: 0.8363 - lr: 0.0050
# Epoch 25/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.9121 - accuracy: 0.6991 - top5-acc: 0.9806 - Brier score: 19.9815 - F1 score: 0.6983 - Recall: 0.9588 - Precision: 0.2322 - AUC: 0.8043 - val_loss: 0.3103 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 25.6141 - val_F1 score: 0.9022 - val_Recall: 1.0000 - val_Precision: 0.2549 - val_AUC: 0.8433 - lr: 0.0050
# Epoch 26/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9866 - accuracy: 0.6827 - top5-acc: 0.9852 - Brier score: 21.1261 - F1 score: 0.6821 - Recall: 0.9526 - Precision: 0.2341 - AUC: 0.8029 - val_loss: 0.3261 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 30.5084 - val_F1 score: 0.8803 - val_Recall: 0.9859 - val_Precision: 0.2947 - val_AUC: 0.8649 - lr: 0.0050
# Epoch 27/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.8346 - accuracy: 0.7294 - top5-acc: 0.9914 - Brier score: 20.7479 - F1 score: 0.7272 - Recall: 0.9790 - Precision: 0.2367 - AUC: 0.8141 - val_loss: 0.3613 - val_accuracy: 0.8732 - val_top5-acc: 1.0000 - val_Brier score: 30.3391 - val_F1 score: 0.8574 - val_Recall: 1.0000 - val_Precision: 0.2834 - val_AUC: 0.8605 - lr: 0.0050
# Epoch 28/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7926 - accuracy: 0.7403 - top5-acc: 0.9883 - Brier score: 20.7722 - F1 score: 0.7404 - Recall: 0.9635 - Precision: 0.2477 - AUC: 0.8223 - val_loss: 0.4265 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 39.5207 - val_F1 score: 0.8027 - val_Recall: 0.9718 - val_Precision: 0.3833 - val_AUC: 0.9044 - lr: 0.0050
# Epoch 29/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1819 - accuracy: 0.6788 - top5-acc: 0.9736 - Brier score: 32.1360 - F1 score: 0.6773 - Recall: 0.9495 - Precision: 0.2368 - AUC: 0.8012 - val_loss: 0.3152 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 37.6280 - val_F1 score: 0.8392 - val_Recall: 0.9718 - val_Precision: 0.2949 - val_AUC: 0.8531 - lr: 0.0050
# Epoch 30/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7712 - accuracy: 0.7644 - top5-acc: 0.9868 - Brier score: 23.2776 - F1 score: 0.7636 - Recall: 0.9728 - Precision: 0.2465 - AUC: 0.8202 - val_loss: 0.1606 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 35.1072 - val_F1 score: 0.9295 - val_Recall: 1.0000 - val_Precision: 0.3121 - val_AUC: 0.8816 - lr: 0.0050
# Epoch 31/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0719 - accuracy: 0.7076 - top5-acc: 0.9852 - Brier score: 32.8986 - F1 score: 0.7060 - Recall: 0.9541 - Precision: 0.2475 - AUC: 0.8156 - val_loss: 0.2813 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 37.6283 - val_F1 score: 0.8945 - val_Recall: 0.9930 - val_Precision: 0.2843 - val_AUC: 0.8517 - lr: 0.0050
# Epoch 32/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9379 - accuracy: 0.7232 - top5-acc: 0.9883 - Brier score: 32.7582 - F1 score: 0.7208 - Recall: 0.9743 - Precision: 0.2299 - AUC: 0.8022 - val_loss: 0.6420 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 46.0283 - val_F1 score: 0.7946 - val_Recall: 0.9859 - val_Precision: 0.2929 - val_AUC: 0.8608 - lr: 0.0050
# Epoch 33/100
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0817 - accuracy: 0.7263 - top5-acc: 0.9844 - Brier score: 34.6391 - F1 score: 0.7257 - Recall: 0.9712 - Precision: 0.2288 - AUC: 0.7981 - val_loss: 0.1761 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 41.1911 - val_F1 score: 0.9172 - val_Recall: 0.9930 - val_Precision: 0.2374 - val_AUC: 0.8117 - lr: 0.0050
# Epoch 34/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.8051 - accuracy: 0.7449 - top5-acc: 0.9922 - Brier score: 28.8958 - F1 score: 0.7441 - Recall: 0.9798 - Precision: 0.2281 - AUC: 0.8026 - val_loss: 0.4164 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 44.0749 - val_F1 score: 0.8244 - val_Recall: 1.0000 - val_Precision: 0.2779 - val_AUC: 0.8532 - lr: 0.0050
# Epoch 35/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7280 - accuracy: 0.7776 - top5-acc: 0.9860 - Brier score: 27.8102 - F1 score: 0.7775 - Recall: 0.9806 - Precision: 0.2260 - AUC: 0.8018 - val_loss: 0.7451 - val_accuracy: 0.7958 - val_top5-acc: 1.0000 - val_Brier score: 46.8271 - val_F1 score: 0.7413 - val_Recall: 0.9789 - val_Precision: 0.2613 - val_AUC: 0.8320 - lr: 0.0050
# Epoch 36/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.5597 - accuracy: 0.8328 - top5-acc: 0.9953 - Brier score: 29.4506 - F1 score: 0.8321 - Recall: 0.9883 - Precision: 0.2303 - AUC: 0.8089 - val_loss: 0.1796 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 38.4836 - val_F1 score: 0.9286 - val_Recall: 1.0000 - val_Precision: 0.2582 - val_AUC: 0.8371 - lr: 0.0025
# Epoch 37/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.4380 - accuracy: 0.8523 - top5-acc: 0.9984 - Brier score: 25.0773 - F1 score: 0.8515 - Recall: 0.9953 - Precision: 0.2264 - AUC: 0.8085 - val_loss: 0.1229 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 38.3268 - val_F1 score: 0.9369 - val_Recall: 1.0000 - val_Precision: 0.2500 - val_AUC: 0.8367 - lr: 0.0025
# Epoch 38/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.3541 - accuracy: 0.8678 - top5-acc: 0.9984 - Brier score: 25.3469 - F1 score: 0.8670 - Recall: 0.9977 - Precision: 0.2328 - AUC: 0.8177 - val_loss: 0.1448 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 40.8185 - val_F1 score: 0.9234 - val_Recall: 1.0000 - val_Precision: 0.2606 - val_AUC: 0.8415 - lr: 0.0025
# Epoch 39/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.3551 - accuracy: 0.8826 - top5-acc: 0.9984 - Brier score: 26.7546 - F1 score: 0.8822 - Recall: 0.9984 - Precision: 0.2297 - AUC: 0.8116 - val_loss: 0.1091 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 36.8866 - val_F1 score: 0.9683 - val_Recall: 1.0000 - val_Precision: 0.2874 - val_AUC: 0.8653 - lr: 0.0025
# Epoch 40/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.4011 - accuracy: 0.8709 - top5-acc: 0.9969 - Brier score: 25.5762 - F1 score: 0.8695 - Recall: 0.9899 - Precision: 0.2316 - AUC: 0.8119 - val_loss: 0.1618 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 36.2621 - val_F1 score: 0.9487 - val_Recall: 1.0000 - val_Precision: 0.2465 - val_AUC: 0.8288 - lr: 0.0025
# Epoch 41/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.3092 - accuracy: 0.8911 - top5-acc: 0.9992 - Brier score: 24.3728 - F1 score: 0.8905 - Recall: 0.9984 - Precision: 0.2327 - AUC: 0.8178 - val_loss: 0.2093 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 33.9483 - val_F1 score: 0.9050 - val_Recall: 1.0000 - val_Precision: 0.2644 - val_AUC: 0.8446 - lr: 0.0025
# Epoch 42/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.3660 - accuracy: 0.8577 - top5-acc: 0.9992 - Brier score: 24.6775 - F1 score: 0.8576 - Recall: 0.9977 - Precision: 0.2233 - AUC: 0.8046 - val_loss: 0.0684 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 35.8459 - val_F1 score: 0.9689 - val_Recall: 1.0000 - val_Precision: 0.2265 - val_AUC: 0.8103 - lr: 0.0025
# Epoch 43/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.3881 - accuracy: 0.8600 - top5-acc: 1.0000 - Brier score: 24.6447 - F1 score: 0.8590 - Recall: 0.9984 - Precision: 0.2349 - AUC: 0.8187 - val_loss: 0.1987 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 32.9889 - val_F1 score: 0.9313 - val_Recall: 1.0000 - val_Precision: 0.2684 - val_AUC: 0.8464 - lr: 0.0025
# Epoch 44/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.3140 - accuracy: 0.8857 - top5-acc: 0.9977 - Brier score: 23.9830 - F1 score: 0.8844 - Recall: 0.9953 - Precision: 0.2400 - AUC: 0.8226 - val_loss: 0.0615 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 34.4015 - val_F1 score: 0.9658 - val_Recall: 1.0000 - val_Precision: 0.2779 - val_AUC: 0.8556 - lr: 0.0025
# Epoch 45/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.3226 - accuracy: 0.8795 - top5-acc: 1.0000 - Brier score: 26.3008 - F1 score: 0.8788 - Recall: 0.9969 - Precision: 0.2254 - AUC: 0.8073 - val_loss: 0.1939 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 35.5659 - val_F1 score: 0.9215 - val_Recall: 1.0000 - val_Precision: 0.2531 - val_AUC: 0.8341 - lr: 0.0025
# Epoch 46/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.3156 - accuracy: 0.8834 - top5-acc: 1.0000 - Brier score: 25.1001 - F1 score: 0.8835 - Recall: 0.9977 - Precision: 0.2284 - AUC: 0.8119 - val_loss: 0.1047 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 31.7729 - val_F1 score: 0.9521 - val_Recall: 1.0000 - val_Precision: 0.2336 - val_AUC: 0.8143 - lr: 0.0025
# Epoch 47/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2924 - accuracy: 0.8958 - top5-acc: 0.9992 - Brier score: 25.5769 - F1 score: 0.8958 - Recall: 0.9992 - Precision: 0.2187 - AUC: 0.8003 - val_loss: 0.1445 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 33.9771 - val_F1 score: 0.9665 - val_Recall: 1.0000 - val_Precision: 0.2483 - val_AUC: 0.8301 - lr: 0.0025
# Epoch 48/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2710 - accuracy: 0.9036 - top5-acc: 1.0000 - Brier score: 25.6589 - F1 score: 0.9037 - Recall: 0.9992 - Precision: 0.2341 - AUC: 0.8188 - val_loss: 0.0904 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 31.8049 - val_F1 score: 0.9523 - val_Recall: 1.0000 - val_Precision: 0.2689 - val_AUC: 0.8490 - lr: 0.0025
# Epoch 49/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.3426 - accuracy: 0.8966 - top5-acc: 0.9969 - Brier score: 24.3441 - F1 score: 0.8952 - Recall: 0.9961 - Precision: 0.2302 - AUC: 0.8146 - val_loss: 0.1256 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 33.4180 - val_F1 score: 0.9293 - val_Recall: 1.0000 - val_Precision: 0.2347 - val_AUC: 0.8173 - lr: 0.0025
# Epoch 50/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2735 - accuracy: 0.9020 - top5-acc: 0.9992 - Brier score: 24.1371 - F1 score: 0.9022 - Recall: 0.9977 - Precision: 0.2244 - AUC: 0.8077 - val_loss: 0.1315 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 34.5083 - val_F1 score: 0.9409 - val_Recall: 1.0000 - val_Precision: 0.2504 - val_AUC: 0.8336 - lr: 0.0012
# Epoch 51/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2258 - accuracy: 0.9238 - top5-acc: 0.9992 - Brier score: 24.4947 - F1 score: 0.9234 - Recall: 0.9984 - Precision: 0.2317 - AUC: 0.8168 - val_loss: 0.0821 - val_accuracy: 0.9648 - val_top5-acc: 1.0000 - val_Brier score: 34.4013 - val_F1 score: 0.9594 - val_Recall: 1.0000 - val_Precision: 0.2298 - val_AUC: 0.8121 - lr: 0.0012
# Epoch 52/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2123 - accuracy: 0.9199 - top5-acc: 0.9984 - Brier score: 24.5612 - F1 score: 0.9196 - Recall: 1.0000 - Precision: 0.2189 - AUC: 0.8025 - val_loss: 0.0657 - val_accuracy: 0.9789 - val_top5-acc: 1.0000 - val_Brier score: 32.7753 - val_F1 score: 0.9738 - val_Recall: 1.0000 - val_Precision: 0.2294 - val_AUC: 0.8151 - lr: 0.0012
# Epoch 53/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.2342 - accuracy: 0.9191 - top5-acc: 0.9992 - Brier score: 24.1506 - F1 score: 0.9188 - Recall: 1.0000 - Precision: 0.2262 - AUC: 0.8100 - val_loss: 0.0870 - val_accuracy: 0.9648 - val_top5-acc: 1.0000 - val_Brier score: 32.4397 - val_F1 score: 0.9594 - val_Recall: 1.0000 - val_Precision: 0.2305 - val_AUC: 0.8178 - lr: 0.0012
# Epoch 54/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.2140 - accuracy: 0.9261 - top5-acc: 0.9977 - Brier score: 24.3636 - F1 score: 0.9260 - Recall: 0.9992 - Precision: 0.2227 - AUC: 0.8043 - val_loss: 0.1144 - val_accuracy: 0.9648 - val_top5-acc: 1.0000 - val_Brier score: 33.9152 - val_F1 score: 0.9586 - val_Recall: 1.0000 - val_Precision: 0.2399 - val_AUC: 0.8283 - lr: 0.0012

# %%
plot_training_curves(history_mlpmixer, 'MLP-Mixer for Computed Tomography of the Abdomen')

# %% [markdown]
# The MLP-Mixer model tends to have much less number of parameters compared to convolutional and transformer-based models, which leads to less training and serving computational cost.
#
# As mentioned in the MLP-Mixer paper, when pre-trained on large datasets, or with modern regularization schemes, the MLP-Mixer attains competitive scores to state-of-the-art models. You can obtain better results by increasing the embedding dimensions, increasing, increasing the number of mixer blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes.
#
#
# ---

# %% [markdown]
# # ⚛ FNet model
# The FNet uses a similar block to the Transformer block. However, FNet replaces the self-attention layer in the Transformer block with a parameter-free 2D Fourier transformation layer:
#
# - One 1D Fourier Transform is applied along the patches.
# - One 1D Fourier Transform is applied along the channels.

# %%
class FNetLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.ffn = keras.Sequential(
            [
                layers.Dense(units=embedding_dim),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
                layers.Dense(units=embedding_dim),
            ]
        )
        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        # Apply layer normalization.
        x = self.normalize1(x)
        # Apply Feedfowrad network.
        x_ffn = self.ffn(x)
        # Add skip connection.
        x = x + x_ffn
        # Apply layer normalization.
        return self.normalize2(x)

# %%
fnet_blocks = keras.Sequential(
    [FNetLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
fnet_classifier = build_classifier(fnet_blocks, positional_encoding=True)

# %%
history_fnet = run_experiment(fnet_classifier)
# Out:
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 41/41 [==============================] - ETA: 0s - loss: 2.2445 - accuracy: 0.1384 - top5-acc: 0.6042 - Brier score: 0.3221 - F1 score: 0.1351 - Recall: 0.1337 - Precision: 0.1408 - AUC: 0.5292
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 41/41 [==============================] - 7s 47ms/step - loss: 2.2445 - accuracy: 0.1384 - top5-acc: 0.6042 - Brier score: 0.3221 - F1 score: 0.1351 - Recall: 0.1337 - Precision: 0.1408 - AUC: 0.5292 - val_loss: 2.1763 - val_accuracy: 0.2183 - val_top5-acc: 0.5282 - val_Brier score: 0.3002 - val_F1 score: 0.0882 - val_Recall: 0.1690 - val_Precision: 0.2424 - val_AUC: 0.5393 - lr: 0.0010
# Epoch 2/100
# 41/41 [==============================] - 1s 23ms/step - loss: 2.1153 - accuracy: 0.2061 - top5-acc: 0.7006 - Brier score: 0.2854 - F1 score: 0.1940 - Recall: 0.1967 - Precision: 0.2200 - AUC: 0.6013 - val_loss: 1.9876 - val_accuracy: 0.2465 - val_top5-acc: 0.7535 - val_Brier score: 0.3557 - val_F1 score: 0.1572 - val_Recall: 0.2676 - val_Precision: 0.2754 - val_AUC: 0.6845 - lr: 0.0010
# Epoch 3/100
# 41/41 [==============================] - 1s 23ms/step - loss: 1.9878 - accuracy: 0.2605 - top5-acc: 0.7698 - Brier score: 0.4275 - F1 score: 0.2530 - Recall: 0.3888 - Precision: 0.2459 - AUC: 0.6755 - val_loss: 2.0412 - val_accuracy: 0.1479 - val_top5-acc: 0.8099 - val_Brier score: 0.6338 - val_F1 score: 0.1353 - val_Recall: 0.3521 - val_Precision: 0.2000 - val_AUC: 0.6795 - lr: 0.0010
# Epoch 4/100
# 41/41 [==============================] - 1s 23ms/step - loss: 1.8783 - accuracy: 0.2823 - top5-acc: 0.8305 - Brier score: 0.7832 - F1 score: 0.2712 - Recall: 0.5218 - Precision: 0.2386 - AUC: 0.7058 - val_loss: 1.7192 - val_accuracy: 0.3099 - val_top5-acc: 0.9225 - val_Brier score: 0.9661 - val_F1 score: 0.1967 - val_Recall: 0.7324 - val_Precision: 0.2842 - val_AUC: 0.7939 - lr: 0.0010
# Epoch 5/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.7908 - accuracy: 0.3227 - top5-acc: 0.8561 - Brier score: 1.2429 - F1 score: 0.3091 - Recall: 0.6804 - Precision: 0.2196 - AUC: 0.7360 - val_loss: 1.6015 - val_accuracy: 0.3803 - val_top5-acc: 0.9577 - val_Brier score: 1.8054 - val_F1 score: 0.3392 - val_Recall: 0.8451 - val_Precision: 0.2041 - val_AUC: 0.7764 - lr: 0.0010
# Epoch 6/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.6997 - accuracy: 0.3437 - top5-acc: 0.8888 - Brier score: 1.5893 - F1 score: 0.3340 - Recall: 0.7356 - Precision: 0.2128 - AUC: 0.7488 - val_loss: 1.5465 - val_accuracy: 0.4366 - val_top5-acc: 0.9507 - val_Brier score: 2.5189 - val_F1 score: 0.3618 - val_Recall: 0.7958 - val_Precision: 0.2340 - val_AUC: 0.7806 - lr: 0.0010
# Epoch 7/100
# 41/41 [==============================] - 1s 23ms/step - loss: 1.7016 - accuracy: 0.3383 - top5-acc: 0.8966 - Brier score: 2.2407 - F1 score: 0.3349 - Recall: 0.7877 - Precision: 0.2140 - AUC: 0.7512 - val_loss: 1.3955 - val_accuracy: 0.4859 - val_top5-acc: 0.9577 - val_Brier score: 2.4719 - val_F1 score: 0.3884 - val_Recall: 0.9014 - val_Precision: 0.2155 - val_AUC: 0.7933 - lr: 0.0010
# Epoch 8/100
# 41/41 [==============================] - 1s 23ms/step - loss: 1.6034 - accuracy: 0.3701 - top5-acc: 0.9082 - Brier score: 2.0609 - F1 score: 0.3591 - Recall: 0.8142 - Precision: 0.2222 - AUC: 0.7733 - val_loss: 1.3734 - val_accuracy: 0.4648 - val_top5-acc: 0.9507 - val_Brier score: 3.0412 - val_F1 score: 0.4067 - val_Recall: 0.9014 - val_Precision: 0.2393 - val_AUC: 0.8119 - lr: 0.0010
# Epoch 9/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.6625 - accuracy: 0.3561 - top5-acc: 0.8974 - Brier score: 2.4721 - F1 score: 0.3465 - Recall: 0.8142 - Precision: 0.2091 - AUC: 0.7575 - val_loss: 1.2559 - val_accuracy: 0.4577 - val_top5-acc: 0.9718 - val_Brier score: 3.3698 - val_F1 score: 0.4147 - val_Recall: 0.9577 - val_Precision: 0.2197 - val_AUC: 0.8207 - lr: 0.0010
# Epoch 10/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4808 - accuracy: 0.4386 - top5-acc: 0.9362 - Brier score: 2.9361 - F1 score: 0.4287 - Recall: 0.8779 - Precision: 0.2188 - AUC: 0.7847 - val_loss: 1.3127 - val_accuracy: 0.4648 - val_top5-acc: 0.9859 - val_Brier score: 4.2258 - val_F1 score: 0.3991 - val_Recall: 0.9296 - val_Precision: 0.2136 - val_AUC: 0.8034 - lr: 0.0010
# Epoch 11/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.4701 - accuracy: 0.4463 - top5-acc: 0.9347 - Brier score: 3.2322 - F1 score: 0.4377 - Recall: 0.8678 - Precision: 0.2179 - AUC: 0.7828 - val_loss: 1.1802 - val_accuracy: 0.6408 - val_top5-acc: 0.9648 - val_Brier score: 5.4697 - val_F1 score: 0.6144 - val_Recall: 0.9577 - val_Precision: 0.2226 - val_AUC: 0.8011 - lr: 0.0010
# Epoch 12/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4348 - accuracy: 0.4355 - top5-acc: 0.9425 - Brier score: 3.4474 - F1 score: 0.4282 - Recall: 0.8927 - Precision: 0.2263 - AUC: 0.7925 - val_loss: 1.2562 - val_accuracy: 0.5775 - val_top5-acc: 0.9507 - val_Brier score: 4.1560 - val_F1 score: 0.5066 - val_Recall: 0.9155 - val_Precision: 0.2490 - val_AUC: 0.8272 - lr: 0.0010
# Epoch 13/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.3703 - accuracy: 0.4798 - top5-acc: 0.9393 - Brier score: 3.9284 - F1 score: 0.4734 - Recall: 0.8865 - Precision: 0.2253 - AUC: 0.7969 - val_loss: 1.0932 - val_accuracy: 0.5845 - val_top5-acc: 0.9859 - val_Brier score: 5.2000 - val_F1 score: 0.5275 - val_Recall: 0.9930 - val_Precision: 0.2227 - val_AUC: 0.8211 - lr: 0.0010
# Epoch 14/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.2828 - accuracy: 0.5280 - top5-acc: 0.9588 - Brier score: 4.2036 - F1 score: 0.5236 - Recall: 0.9207 - Precision: 0.2295 - AUC: 0.8048 - val_loss: 1.1307 - val_accuracy: 0.5423 - val_top5-acc: 0.9859 - val_Brier score: 5.9018 - val_F1 score: 0.4898 - val_Recall: 0.9437 - val_Precision: 0.2380 - val_AUC: 0.8317 - lr: 0.0010
# Epoch 15/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.2795 - accuracy: 0.4984 - top5-acc: 0.9635 - Brier score: 4.3672 - F1 score: 0.4940 - Recall: 0.9215 - Precision: 0.2401 - AUC: 0.8160 - val_loss: 1.3182 - val_accuracy: 0.4014 - val_top5-acc: 0.9718 - val_Brier score: 6.7286 - val_F1 score: 0.3763 - val_Recall: 0.9507 - val_Precision: 0.2217 - val_AUC: 0.8111 - lr: 0.0010
# Epoch 16/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.2791 - accuracy: 0.5156 - top5-acc: 0.9619 - Brier score: 4.5027 - F1 score: 0.5150 - Recall: 0.9106 - Precision: 0.2388 - AUC: 0.8113 - val_loss: 1.2111 - val_accuracy: 0.5634 - val_top5-acc: 0.9718 - val_Brier score: 7.7416 - val_F1 score: 0.4787 - val_Recall: 0.9366 - val_Precision: 0.2232 - val_AUC: 0.7838 - lr: 0.0010
# Epoch 17/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1864 - accuracy: 0.5677 - top5-acc: 0.9697 - Brier score: 4.7717 - F1 score: 0.5609 - Recall: 0.9285 - Precision: 0.2352 - AUC: 0.8171 - val_loss: 0.8122 - val_accuracy: 0.7254 - val_top5-acc: 0.9930 - val_Brier score: 6.6037 - val_F1 score: 0.6969 - val_Recall: 0.9930 - val_Precision: 0.2378 - val_AUC: 0.8402 - lr: 0.0010
# Epoch 18/100
# 41/41 [==============================] - 1s 23ms/step - loss: 1.1345 - accuracy: 0.5715 - top5-acc: 0.9658 - Brier score: 5.2853 - F1 score: 0.5710 - Recall: 0.9432 - Precision: 0.2365 - AUC: 0.8210 - val_loss: 1.0273 - val_accuracy: 0.6197 - val_top5-acc: 0.9859 - val_Brier score: 6.8497 - val_F1 score: 0.5616 - val_Recall: 0.9577 - val_Precision: 0.2468 - val_AUC: 0.8327 - lr: 0.0010
# Epoch 19/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0417 - accuracy: 0.5964 - top5-acc: 0.9790 - Brier score: 5.6066 - F1 score: 0.5918 - Recall: 0.9533 - Precision: 0.2454 - AUC: 0.8352 - val_loss: 0.9506 - val_accuracy: 0.6127 - val_top5-acc: 0.9930 - val_Brier score: 10.9568 - val_F1 score: 0.5694 - val_Recall: 0.9789 - val_Precision: 0.2192 - val_AUC: 0.8084 - lr: 0.0010
# Epoch 20/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1112 - accuracy: 0.5809 - top5-acc: 0.9689 - Brier score: 6.3103 - F1 score: 0.5773 - Recall: 0.9432 - Precision: 0.2385 - AUC: 0.8180 - val_loss: 0.8842 - val_accuracy: 0.7042 - val_top5-acc: 0.9648 - val_Brier score: 9.2536 - val_F1 score: 0.6554 - val_Recall: 0.9437 - val_Precision: 0.2241 - val_AUC: 0.8108 - lr: 0.0010
# Epoch 21/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0511 - accuracy: 0.6096 - top5-acc: 0.9697 - Brier score: 5.8888 - F1 score: 0.6069 - Recall: 0.9425 - Precision: 0.2434 - AUC: 0.8268 - val_loss: 0.8630 - val_accuracy: 0.6761 - val_top5-acc: 0.9859 - val_Brier score: 7.3822 - val_F1 score: 0.6271 - val_Recall: 0.9718 - val_Precision: 0.2589 - val_AUC: 0.8466 - lr: 0.0010
# Epoch 22/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0514 - accuracy: 0.6213 - top5-acc: 0.9798 - Brier score: 6.5290 - F1 score: 0.6195 - Recall: 0.9557 - Precision: 0.2480 - AUC: 0.8291 - val_loss: 0.6979 - val_accuracy: 0.7606 - val_top5-acc: 1.0000 - val_Brier score: 7.3766 - val_F1 score: 0.7475 - val_Recall: 0.9930 - val_Precision: 0.2665 - val_AUC: 0.8629 - lr: 0.0010
# Epoch 23/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.9790 - accuracy: 0.6353 - top5-acc: 0.9743 - Brier score: 6.0121 - F1 score: 0.6353 - Recall: 0.9541 - Precision: 0.2535 - AUC: 0.8363 - val_loss: 0.8879 - val_accuracy: 0.6690 - val_top5-acc: 0.9859 - val_Brier score: 9.3435 - val_F1 score: 0.6069 - val_Recall: 0.9718 - val_Precision: 0.2560 - val_AUC: 0.8413 - lr: 0.0010
# Epoch 24/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.8873 - accuracy: 0.6773 - top5-acc: 0.9860 - Brier score: 6.5919 - F1 score: 0.6749 - Recall: 0.9689 - Precision: 0.2566 - AUC: 0.8448 - val_loss: 0.5972 - val_accuracy: 0.8028 - val_top5-acc: 1.0000 - val_Brier score: 10.0171 - val_F1 score: 0.7894 - val_Recall: 1.0000 - val_Precision: 0.2436 - val_AUC: 0.8332 - lr: 0.0010
# Epoch 25/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.8031 - accuracy: 0.6820 - top5-acc: 0.9860 - Brier score: 8.1650 - F1 score: 0.6825 - Recall: 0.9720 - Precision: 0.2530 - AUC: 0.8423 - val_loss: 0.7264 - val_accuracy: 0.7254 - val_top5-acc: 0.9789 - val_Brier score: 11.7303 - val_F1 score: 0.6928 - val_Recall: 0.9789 - val_Precision: 0.2426 - val_AUC: 0.8283 - lr: 0.0010
# Epoch 26/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.8428 - accuracy: 0.6913 - top5-acc: 0.9907 - Brier score: 7.6425 - F1 score: 0.6907 - Recall: 0.9673 - Precision: 0.2527 - AUC: 0.8374 - val_loss: 0.4942 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 12.5380 - val_F1 score: 0.8234 - val_Recall: 1.0000 - val_Precision: 0.2513 - val_AUC: 0.8468 - lr: 0.0010
# Epoch 27/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.7954 - accuracy: 0.7185 - top5-acc: 0.9852 - Brier score: 8.4623 - F1 score: 0.7184 - Recall: 0.9712 - Precision: 0.2525 - AUC: 0.8392 - val_loss: 0.8304 - val_accuracy: 0.6761 - val_top5-acc: 0.9930 - val_Brier score: 12.6941 - val_F1 score: 0.6347 - val_Recall: 0.9930 - val_Precision: 0.2487 - val_AUC: 0.8374 - lr: 0.0010
# Epoch 28/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.8421 - accuracy: 0.6796 - top5-acc: 0.9891 - Brier score: 7.3301 - F1 score: 0.6794 - Recall: 0.9790 - Precision: 0.2545 - AUC: 0.8450 - val_loss: 0.6371 - val_accuracy: 0.7606 - val_top5-acc: 1.0000 - val_Brier score: 10.3707 - val_F1 score: 0.7379 - val_Recall: 0.9930 - val_Precision: 0.2601 - val_AUC: 0.8517 - lr: 0.0010
# Epoch 29/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.7088 - accuracy: 0.7403 - top5-acc: 0.9930 - Brier score: 8.8626 - F1 score: 0.7417 - Recall: 0.9813 - Precision: 0.2520 - AUC: 0.8427 - val_loss: 0.5625 - val_accuracy: 0.8169 - val_top5-acc: 0.9930 - val_Brier score: 12.2126 - val_F1 score: 0.8159 - val_Recall: 1.0000 - val_Precision: 0.2531 - val_AUC: 0.8434 - lr: 0.0010
# Epoch 30/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.7623 - accuracy: 0.7247 - top5-acc: 0.9914 - Brier score: 8.4453 - F1 score: 0.7263 - Recall: 0.9759 - Precision: 0.2511 - AUC: 0.8398 - val_loss: 0.4735 - val_accuracy: 0.8239 - val_top5-acc: 1.0000 - val_Brier score: 10.0601 - val_F1 score: 0.7924 - val_Recall: 1.0000 - val_Precision: 0.2496 - val_AUC: 0.8539 - lr: 0.0010
# Epoch 31/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.6613 - accuracy: 0.7683 - top5-acc: 0.9938 - Brier score: 8.9864 - F1 score: 0.7689 - Recall: 0.9813 - Precision: 0.2501 - AUC: 0.8417 - val_loss: 0.6126 - val_accuracy: 0.7324 - val_top5-acc: 1.0000 - val_Brier score: 15.2362 - val_F1 score: 0.6887 - val_Recall: 1.0000 - val_Precision: 0.2436 - val_AUC: 0.8314 - lr: 0.0010
# Epoch 32/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.7556 - accuracy: 0.7146 - top5-acc: 0.9883 - Brier score: 9.1579 - F1 score: 0.7161 - Recall: 0.9736 - Precision: 0.2492 - AUC: 0.8396 - val_loss: 0.4062 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 10.7672 - val_F1 score: 0.8139 - val_Recall: 1.0000 - val_Precision: 0.2669 - val_AUC: 0.8565 - lr: 0.0010
# Epoch 33/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6716 - accuracy: 0.7519 - top5-acc: 0.9938 - Brier score: 8.8013 - F1 score: 0.7535 - Recall: 0.9837 - Precision: 0.2548 - AUC: 0.8456 - val_loss: 0.5025 - val_accuracy: 0.7958 - val_top5-acc: 1.0000 - val_Brier score: 11.0554 - val_F1 score: 0.7727 - val_Recall: 1.0000 - val_Precision: 0.2591 - val_AUC: 0.8505 - lr: 0.0010
# Epoch 34/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6741 - accuracy: 0.7426 - top5-acc: 0.9953 - Brier score: 9.1439 - F1 score: 0.7431 - Recall: 0.9876 - Precision: 0.2567 - AUC: 0.8454 - val_loss: 0.4896 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 12.9896 - val_F1 score: 0.7737 - val_Recall: 1.0000 - val_Precision: 0.2568 - val_AUC: 0.8464 - lr: 0.0010
# Epoch 35/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6274 - accuracy: 0.7558 - top5-acc: 0.9938 - Brier score: 10.3817 - F1 score: 0.7569 - Recall: 0.9876 - Precision: 0.2531 - AUC: 0.8441 - val_loss: 0.5513 - val_accuracy: 0.7465 - val_top5-acc: 1.0000 - val_Brier score: 13.2166 - val_F1 score: 0.7255 - val_Recall: 1.0000 - val_Precision: 0.2391 - val_AUC: 0.8319 - lr: 0.0010
# Epoch 36/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6521 - accuracy: 0.7652 - top5-acc: 0.9922 - Brier score: 9.1325 - F1 score: 0.7669 - Recall: 0.9844 - Precision: 0.2572 - AUC: 0.8481 - val_loss: 0.4593 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 12.3981 - val_F1 score: 0.8548 - val_Recall: 1.0000 - val_Precision: 0.2403 - val_AUC: 0.8354 - lr: 0.0010
# Epoch 37/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.5870 - accuracy: 0.7916 - top5-acc: 0.9883 - Brier score: 8.6172 - F1 score: 0.7940 - Recall: 0.9813 - Precision: 0.2580 - AUC: 0.8492 - val_loss: 0.8036 - val_accuracy: 0.7183 - val_top5-acc: 1.0000 - val_Brier score: 14.3057 - val_F1 score: 0.6884 - val_Recall: 1.0000 - val_Precision: 0.2536 - val_AUC: 0.8438 - lr: 0.0010
# Epoch 38/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4931 - accuracy: 0.8142 - top5-acc: 0.9977 - Brier score: 10.5991 - F1 score: 0.8157 - Recall: 0.9907 - Precision: 0.2588 - AUC: 0.8515 - val_loss: 0.6107 - val_accuracy: 0.7958 - val_top5-acc: 1.0000 - val_Brier score: 15.8057 - val_F1 score: 0.7446 - val_Recall: 1.0000 - val_Precision: 0.2606 - val_AUC: 0.8422 - lr: 5.0000e-04
# Epoch 39/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4983 - accuracy: 0.8149 - top5-acc: 0.9961 - Brier score: 11.0776 - F1 score: 0.8173 - Recall: 0.9914 - Precision: 0.2580 - AUC: 0.8487 - val_loss: 0.3008 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 15.6149 - val_F1 score: 0.9049 - val_Recall: 1.0000 - val_Precision: 0.2423 - val_AUC: 0.8310 - lr: 5.0000e-04
# Epoch 40/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4877 - accuracy: 0.8227 - top5-acc: 0.9922 - Brier score: 10.9257 - F1 score: 0.8240 - Recall: 0.9844 - Precision: 0.2594 - AUC: 0.8498 - val_loss: 0.2952 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 14.9355 - val_F1 score: 0.8675 - val_Recall: 1.0000 - val_Precision: 0.2587 - val_AUC: 0.8477 - lr: 5.0000e-04
# Epoch 41/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.4251 - accuracy: 0.8523 - top5-acc: 0.9977 - Brier score: 10.9378 - F1 score: 0.8541 - Recall: 0.9961 - Precision: 0.2619 - AUC: 0.8542 - val_loss: 0.2460 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 14.5536 - val_F1 score: 0.9088 - val_Recall: 1.0000 - val_Precision: 0.2522 - val_AUC: 0.8446 - lr: 5.0000e-04
# Epoch 42/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.3937 - accuracy: 0.8554 - top5-acc: 0.9984 - Brier score: 11.0471 - F1 score: 0.8574 - Recall: 0.9969 - Precision: 0.2678 - AUC: 0.8577 - val_loss: 0.3338 - val_accuracy: 0.8732 - val_top5-acc: 1.0000 - val_Brier score: 16.1862 - val_F1 score: 0.8619 - val_Recall: 1.0000 - val_Precision: 0.2601 - val_AUC: 0.8477 - lr: 5.0000e-04
# Epoch 43/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3389 - accuracy: 0.8919 - top5-acc: 0.9984 - Brier score: 11.7179 - F1 score: 0.8937 - Recall: 0.9969 - Precision: 0.2636 - AUC: 0.8555 - val_loss: 0.2897 - val_accuracy: 0.8873 - val_top5-acc: 1.0000 - val_Brier score: 16.4571 - val_F1 score: 0.8734 - val_Recall: 1.0000 - val_Precision: 0.2630 - val_AUC: 0.8499 - lr: 5.0000e-04
# Epoch 44/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3494 - accuracy: 0.8927 - top5-acc: 0.9961 - Brier score: 12.2765 - F1 score: 0.8946 - Recall: 0.9922 - Precision: 0.2622 - AUC: 0.8528 - val_loss: 0.2263 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 15.9129 - val_F1 score: 0.9138 - val_Recall: 1.0000 - val_Precision: 0.2664 - val_AUC: 0.8517 - lr: 5.0000e-04
# Epoch 45/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3483 - accuracy: 0.8826 - top5-acc: 0.9969 - Brier score: 12.3345 - F1 score: 0.8833 - Recall: 0.9938 - Precision: 0.2642 - AUC: 0.8529 - val_loss: 0.2701 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 16.2935 - val_F1 score: 0.9051 - val_Recall: 1.0000 - val_Precision: 0.2606 - val_AUC: 0.8473 - lr: 5.0000e-04
# Epoch 46/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3309 - accuracy: 0.8880 - top5-acc: 0.9977 - Brier score: 12.2752 - F1 score: 0.8891 - Recall: 0.9953 - Precision: 0.2629 - AUC: 0.8547 - val_loss: 0.3062 - val_accuracy: 0.8944 - val_top5-acc: 1.0000 - val_Brier score: 16.9107 - val_F1 score: 0.8705 - val_Recall: 1.0000 - val_Precision: 0.2509 - val_AUC: 0.8380 - lr: 5.0000e-04
# Epoch 47/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3544 - accuracy: 0.8717 - top5-acc: 0.9984 - Brier score: 12.2129 - F1 score: 0.8725 - Recall: 0.9961 - Precision: 0.2635 - AUC: 0.8533 - val_loss: 0.2887 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 15.8866 - val_F1 score: 0.8729 - val_Recall: 1.0000 - val_Precision: 0.2601 - val_AUC: 0.8548 - lr: 5.0000e-04
# Epoch 48/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3358 - accuracy: 0.8787 - top5-acc: 0.9992 - Brier score: 12.5408 - F1 score: 0.8802 - Recall: 0.9961 - Precision: 0.2668 - AUC: 0.8554 - val_loss: 0.2577 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 18.3143 - val_F1 score: 0.9086 - val_Recall: 1.0000 - val_Precision: 0.2587 - val_AUC: 0.8446 - lr: 5.0000e-04
# Epoch 49/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.3307 - accuracy: 0.8950 - top5-acc: 0.9961 - Brier score: 13.0004 - F1 score: 0.8965 - Recall: 0.9953 - Precision: 0.2644 - AUC: 0.8552 - val_loss: 0.3993 - val_accuracy: 0.8380 - val_top5-acc: 1.0000 - val_Brier score: 18.0035 - val_F1 score: 0.8302 - val_Recall: 1.0000 - val_Precision: 0.2536 - val_AUC: 0.8407 - lr: 5.0000e-04
# Epoch 50/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.2980 - accuracy: 0.9028 - top5-acc: 0.9977 - Brier score: 12.8362 - F1 score: 0.9037 - Recall: 0.9953 - Precision: 0.2644 - AUC: 0.8543 - val_loss: 0.2031 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 16.6543 - val_F1 score: 0.9009 - val_Recall: 1.0000 - val_Precision: 0.2630 - val_AUC: 0.8521 - lr: 2.5000e-04
# Epoch 51/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.2764 - accuracy: 0.9121 - top5-acc: 1.0000 - Brier score: 12.5972 - F1 score: 0.9136 - Recall: 0.9984 - Precision: 0.2675 - AUC: 0.8582 - val_loss: 0.2241 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 17.3927 - val_F1 score: 0.8959 - val_Recall: 1.0000 - val_Precision: 0.2644 - val_AUC: 0.8539 - lr: 2.5000e-04
# Epoch 52/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2387 - accuracy: 0.9285 - top5-acc: 0.9992 - Brier score: 13.2551 - F1 score: 0.9295 - Recall: 0.9992 - Precision: 0.2695 - AUC: 0.8587 - val_loss: 0.1710 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 18.1277 - val_F1 score: 0.9267 - val_Recall: 1.0000 - val_Precision: 0.2587 - val_AUC: 0.8490 - lr: 2.5000e-04
# Epoch 53/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2354 - accuracy: 0.9269 - top5-acc: 0.9992 - Brier score: 13.0902 - F1 score: 0.9282 - Recall: 0.9992 - Precision: 0.2709 - AUC: 0.8615 - val_loss: 0.2334 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 18.3847 - val_F1 score: 0.8915 - val_Recall: 1.0000 - val_Precision: 0.2591 - val_AUC: 0.8477 - lr: 2.5000e-04
# Epoch 54/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2085 - accuracy: 0.9323 - top5-acc: 1.0000 - Brier score: 13.4977 - F1 score: 0.9333 - Recall: 1.0000 - Precision: 0.2706 - AUC: 0.8601 - val_loss: 0.1109 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 18.7282 - val_F1 score: 0.9697 - val_Recall: 1.0000 - val_Precision: 0.2644 - val_AUC: 0.8442 - lr: 2.5000e-04
# Epoch 55/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.2493 - accuracy: 0.9152 - top5-acc: 0.9992 - Brier score: 13.0230 - F1 score: 0.9161 - Recall: 0.9961 - Precision: 0.2695 - AUC: 0.8602 - val_loss: 0.1751 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 17.5781 - val_F1 score: 0.9222 - val_Recall: 1.0000 - val_Precision: 0.2644 - val_AUC: 0.8530 - lr: 2.5000e-04
# Epoch 56/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2569 - accuracy: 0.9152 - top5-acc: 1.0000 - Brier score: 12.8030 - F1 score: 0.9166 - Recall: 0.9984 - Precision: 0.2747 - AUC: 0.8619 - val_loss: 0.1773 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 17.0047 - val_F1 score: 0.9095 - val_Recall: 1.0000 - val_Precision: 0.2615 - val_AUC: 0.8486 - lr: 2.5000e-04
# Epoch 57/100
# 41/41 [==============================] - 1s 23ms/step - loss: 0.2503 - accuracy: 0.9168 - top5-acc: 0.9984 - Brier score: 12.8235 - F1 score: 0.9179 - Recall: 0.9977 - Precision: 0.2697 - AUC: 0.8581 - val_loss: 0.1768 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 17.9032 - val_F1 score: 0.9309 - val_Recall: 1.0000 - val_Precision: 0.2587 - val_AUC: 0.8477 - lr: 2.5000e-04
# Epoch 58/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2221 - accuracy: 0.9285 - top5-acc: 1.0000 - Brier score: 13.1667 - F1 score: 0.9298 - Recall: 0.9992 - Precision: 0.2715 - AUC: 0.8616 - val_loss: 0.1800 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 18.0129 - val_F1 score: 0.9283 - val_Recall: 1.0000 - val_Precision: 0.2635 - val_AUC: 0.8486 - lr: 2.5000e-04
# Epoch 59/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2139 - accuracy: 0.9316 - top5-acc: 1.0000 - Brier score: 13.4332 - F1 score: 0.9319 - Recall: 0.9984 - Precision: 0.2720 - AUC: 0.8615 - val_loss: 0.2456 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 18.0177 - val_F1 score: 0.9063 - val_Recall: 1.0000 - val_Precision: 0.2591 - val_AUC: 0.8468 - lr: 2.5000e-04
# Epoch 60/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1914 - accuracy: 0.9331 - top5-acc: 1.0000 - Brier score: 13.4233 - F1 score: 0.9341 - Recall: 1.0000 - Precision: 0.2694 - AUC: 0.8600 - val_loss: 0.1605 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 18.2565 - val_F1 score: 0.9270 - val_Recall: 1.0000 - val_Precision: 0.2568 - val_AUC: 0.8482 - lr: 1.2500e-04
# Epoch 61/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2182 - accuracy: 0.9191 - top5-acc: 0.9992 - Brier score: 13.8778 - F1 score: 0.9209 - Recall: 0.9984 - Precision: 0.2736 - AUC: 0.8614 - val_loss: 0.1601 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 18.1782 - val_F1 score: 0.9428 - val_Recall: 1.0000 - val_Precision: 0.2639 - val_AUC: 0.8495 - lr: 1.2500e-04
# Epoch 62/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.2144 - accuracy: 0.9246 - top5-acc: 1.0000 - Brier score: 13.8180 - F1 score: 0.9247 - Recall: 0.9992 - Precision: 0.2724 - AUC: 0.8590 - val_loss: 0.1799 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 17.3034 - val_F1 score: 0.9152 - val_Recall: 1.0000 - val_Precision: 0.2639 - val_AUC: 0.8499 - lr: 1.2500e-04
# Epoch 63/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1948 - accuracy: 0.9417 - top5-acc: 0.9992 - Brier score: 13.0057 - F1 score: 0.9429 - Recall: 0.9984 - Precision: 0.2747 - AUC: 0.8653 - val_loss: 0.1773 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 17.3874 - val_F1 score: 0.9112 - val_Recall: 1.0000 - val_Precision: 0.2654 - val_AUC: 0.8548 - lr: 1.2500e-04
# Epoch 64/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.1961 - accuracy: 0.9425 - top5-acc: 1.0000 - Brier score: 13.0388 - F1 score: 0.9437 - Recall: 1.0000 - Precision: 0.2736 - AUC: 0.8630 - val_loss: 0.1165 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 17.1550 - val_F1 score: 0.9454 - val_Recall: 1.0000 - val_Precision: 0.2664 - val_AUC: 0.8539 - lr: 1.2500e-04

# %%
plot_training_curves(history_fnet, 'FNet for Computed Tomography of the Abdomen')

# %% [markdown]
# As shown in the FNet paper, better results can be achieved by increasing the embedding dimensions, increasing the number of FNet blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes. The FNet scales very efficiently to long inputs, runs much faster than attention-based Transformer models, and produces competitive accuracy results.
#
#
#
# ---

# %% [markdown]
# # ⚛ gMLP model
# The gMLP is a MLP architecture that features a Spatial Gating Unit (SGU). The SGU enables cross-patch interactions across the spatial (channel) dimension, by:
#
# - Transforming the input spatially by applying linear projection across patches (along channels).
# - Applying element-wise multiplication of the input and its spatial transformation.

# %%
class gMLPLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.channel_projection1 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.channel_projection2 = layers.Dense(units=embedding_dim)
        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )
        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize2(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize1(inputs)
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.channel_projection1(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        return x + x_projected

# %%
gmlp_blocks = keras.Sequential(
    [gMLPLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
gmlp_classifier = build_classifier(gmlp_blocks)

# %%
history_gmlp = run_experiment(gmlp_classifier)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 7s 50ms/step - loss: 2.4794 - accuracy: 0.1267 - top5-acc: 0.5956 - Brier score: 1.0271 - F1 score: 0.1237 - Recall: 0.2488 - Precision: 0.1236 - AUC: 0.5268 - val_loss: 2.1456 - val_accuracy: 0.1901 - val_top5-acc: 0.6197 - val_Brier score: 0.2966 - val_F1 score: 0.0920 - val_Recall: 0.4507 - val_Precision: 0.1404 - val_AUC: 0.5842 - lr: 0.0030
# Epoch 2/100
# 41/41 [==============================] - 1s 25ms/step - loss: 2.2025 - accuracy: 0.1501 - top5-acc: 0.6415 - Brier score: 0.3393 - F1 score: 0.1477 - Recall: 0.2745 - Precision: 0.1450 - AUC: 0.5575 - val_loss: 1.9777 - val_accuracy: 0.2606 - val_top5-acc: 0.7324 - val_Brier score: 0.3837 - val_F1 score: 0.1485 - val_Recall: 0.4437 - val_Precision: 0.1869 - val_AUC: 0.6459 - lr: 0.0030
# Epoch 3/100
# 41/41 [==============================] - 1s 25ms/step - loss: 2.1039 - accuracy: 0.1851 - top5-acc: 0.6820 - Brier score: 0.5371 - F1 score: 0.1817 - Recall: 0.4020 - Precision: 0.1690 - AUC: 0.6078 - val_loss: 1.6670 - val_accuracy: 0.4577 - val_top5-acc: 0.8873 - val_Brier score: 0.9106 - val_F1 score: 0.3398 - val_Recall: 0.8028 - val_Precision: 0.2107 - val_AUC: 0.7936 - lr: 0.0030
# Epoch 4/100
# 41/41 [==============================] - 1s 25ms/step - loss: 2.0874 - accuracy: 0.2030 - top5-acc: 0.6936 - Brier score: 0.7443 - F1 score: 0.2010 - Recall: 0.4681 - Precision: 0.1579 - AUC: 0.6154 - val_loss: 1.6716 - val_accuracy: 0.3732 - val_top5-acc: 0.9014 - val_Brier score: 1.0150 - val_F1 score: 0.3429 - val_Recall: 0.7746 - val_Precision: 0.2227 - val_AUC: 0.7938 - lr: 0.0030
# Epoch 5/100
# 41/41 [==============================] - 1s 25ms/step - loss: 2.0736 - accuracy: 0.1983 - top5-acc: 0.7053 - Brier score: 0.7079 - F1 score: 0.1964 - Recall: 0.4401 - Precision: 0.1746 - AUC: 0.6278 - val_loss: 1.5309 - val_accuracy: 0.4789 - val_top5-acc: 0.9577 - val_Brier score: 0.8018 - val_F1 score: 0.3891 - val_Recall: 0.9085 - val_Precision: 0.2660 - val_AUC: 0.8504 - lr: 0.0030
# Epoch 6/100
# 41/41 [==============================] - 1s 26ms/step - loss: 2.0217 - accuracy: 0.2247 - top5-acc: 0.7030 - Brier score: 0.8023 - F1 score: 0.2234 - Recall: 0.4378 - Precision: 0.1829 - AUC: 0.6338 - val_loss: 1.5373 - val_accuracy: 0.4155 - val_top5-acc: 0.9718 - val_Brier score: 1.6115 - val_F1 score: 0.2961 - val_Recall: 0.9225 - val_Precision: 0.2417 - val_AUC: 0.8067 - lr: 0.0030
# Epoch 7/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.9757 - accuracy: 0.2527 - top5-acc: 0.7271 - Brier score: 0.9838 - F1 score: 0.2507 - Recall: 0.4736 - Precision: 0.1936 - AUC: 0.6537 - val_loss: 1.8635 - val_accuracy: 0.2465 - val_top5-acc: 0.8803 - val_Brier score: 2.2919 - val_F1 score: 0.1762 - val_Recall: 0.7465 - val_Precision: 0.1927 - val_AUC: 0.7357 - lr: 0.0030
# Epoch 8/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.9457 - accuracy: 0.2457 - top5-acc: 0.7294 - Brier score: 1.2261 - F1 score: 0.2454 - Recall: 0.4774 - Precision: 0.1959 - AUC: 0.6565 - val_loss: 1.7056 - val_accuracy: 0.3310 - val_top5-acc: 0.8592 - val_Brier score: 1.3616 - val_F1 score: 0.2637 - val_Recall: 0.8239 - val_Precision: 0.2035 - val_AUC: 0.7663 - lr: 0.0030
# Epoch 9/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.8567 - accuracy: 0.2877 - top5-acc: 0.7994 - Brier score: 1.4079 - F1 score: 0.2854 - Recall: 0.6501 - Precision: 0.1997 - AUC: 0.7111 - val_loss: 1.6711 - val_accuracy: 0.3662 - val_top5-acc: 0.9366 - val_Brier score: 1.9323 - val_F1 score: 0.2897 - val_Recall: 0.8662 - val_Precision: 0.2053 - val_AUC: 0.7678 - lr: 0.0030
# Epoch 10/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.8163 - accuracy: 0.2963 - top5-acc: 0.8250 - Brier score: 1.6583 - F1 score: 0.2831 - Recall: 0.6742 - Precision: 0.1968 - AUC: 0.7190 - val_loss: 1.1311 - val_accuracy: 0.5563 - val_top5-acc: 0.9859 - val_Brier score: 3.7346 - val_F1 score: 0.4576 - val_Recall: 0.9225 - val_Precision: 0.2251 - val_AUC: 0.8320 - lr: 0.0030
# Epoch 11/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.7302 - accuracy: 0.3429 - top5-acc: 0.8585 - Brier score: 2.3029 - F1 score: 0.3331 - Recall: 0.7271 - Precision: 0.2086 - AUC: 0.7392 - val_loss: 1.4339 - val_accuracy: 0.3944 - val_top5-acc: 0.9577 - val_Brier score: 1.8537 - val_F1 score: 0.3180 - val_Recall: 0.8873 - val_Precision: 0.2312 - val_AUC: 0.8088 - lr: 0.0030
# Epoch 12/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.6554 - accuracy: 0.3880 - top5-acc: 0.8834 - Brier score: 2.6463 - F1 score: 0.3758 - Recall: 0.7698 - Precision: 0.2144 - AUC: 0.7557 - val_loss: 1.2920 - val_accuracy: 0.5423 - val_top5-acc: 0.9718 - val_Brier score: 4.0968 - val_F1 score: 0.5073 - val_Recall: 0.9789 - val_Precision: 0.2301 - val_AUC: 0.8283 - lr: 0.0030
# Epoch 13/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.5646 - accuracy: 0.4005 - top5-acc: 0.9075 - Brier score: 3.0415 - F1 score: 0.3974 - Recall: 0.8390 - Precision: 0.2182 - AUC: 0.7770 - val_loss: 0.9999 - val_accuracy: 0.6972 - val_top5-acc: 0.9789 - val_Brier score: 4.9413 - val_F1 score: 0.6345 - val_Recall: 0.9507 - val_Precision: 0.2385 - val_AUC: 0.8316 - lr: 0.0030
# Epoch 14/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.5167 - accuracy: 0.4168 - top5-acc: 0.9176 - Brier score: 3.1629 - F1 score: 0.4097 - Recall: 0.8227 - Precision: 0.2330 - AUC: 0.7873 - val_loss: 0.9294 - val_accuracy: 0.6479 - val_top5-acc: 0.9718 - val_Brier score: 6.7963 - val_F1 score: 0.6258 - val_Recall: 0.9648 - val_Precision: 0.2383 - val_AUC: 0.8324 - lr: 0.0030
# Epoch 15/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.4056 - accuracy: 0.4549 - top5-acc: 0.9300 - Brier score: 4.5067 - F1 score: 0.4479 - Recall: 0.8740 - Precision: 0.2280 - AUC: 0.7972 - val_loss: 0.7678 - val_accuracy: 0.6972 - val_top5-acc: 0.9930 - val_Brier score: 6.2965 - val_F1 score: 0.6811 - val_Recall: 1.0000 - val_Precision: 0.2371 - val_AUC: 0.8458 - lr: 0.0030
# Epoch 16/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.3049 - accuracy: 0.4806 - top5-acc: 0.9619 - Brier score: 4.8470 - F1 score: 0.4739 - Recall: 0.9238 - Precision: 0.2380 - AUC: 0.8210 - val_loss: 0.7383 - val_accuracy: 0.7254 - val_top5-acc: 0.9930 - val_Brier score: 8.4138 - val_F1 score: 0.7009 - val_Recall: 0.9930 - val_Precision: 0.2378 - val_AUC: 0.8341 - lr: 0.0030
# Epoch 17/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.2999 - accuracy: 0.4891 - top5-acc: 0.9479 - Brier score: 5.0827 - F1 score: 0.4825 - Recall: 0.9207 - Precision: 0.2309 - AUC: 0.8066 - val_loss: 0.9571 - val_accuracy: 0.6761 - val_top5-acc: 0.9789 - val_Brier score: 10.0551 - val_F1 score: 0.6300 - val_Recall: 0.9859 - val_Precision: 0.2389 - val_AUC: 0.8161 - lr: 0.0030
# Epoch 18/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.2157 - accuracy: 0.5381 - top5-acc: 0.9635 - Brier score: 5.8720 - F1 score: 0.5323 - Recall: 0.9386 - Precision: 0.2304 - AUC: 0.8129 - val_loss: 0.8280 - val_accuracy: 0.6479 - val_top5-acc: 1.0000 - val_Brier score: 7.8943 - val_F1 score: 0.6477 - val_Recall: 1.0000 - val_Precision: 0.2375 - val_AUC: 0.8467 - lr: 0.0030
# Epoch 19/100
# 41/41 [==============================] - 1s 25ms/step - loss: 1.1771 - accuracy: 0.5614 - top5-acc: 0.9712 - Brier score: 5.9021 - F1 score: 0.5535 - Recall: 0.9471 - Precision: 0.2404 - AUC: 0.8263 - val_loss: 0.7247 - val_accuracy: 0.7465 - val_top5-acc: 0.9718 - val_Brier score: 9.0009 - val_F1 score: 0.6882 - val_Recall: 0.9648 - val_Precision: 0.2366 - val_AUC: 0.8282 - lr: 0.0030
# Epoch 20/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0974 - accuracy: 0.5886 - top5-acc: 0.9666 - Brier score: 7.0297 - F1 score: 0.5832 - Recall: 0.9510 - Precision: 0.2356 - AUC: 0.8182 - val_loss: 0.6473 - val_accuracy: 0.7606 - val_top5-acc: 1.0000 - val_Brier score: 8.5074 - val_F1 score: 0.7476 - val_Recall: 1.0000 - val_Precision: 0.2568 - val_AUC: 0.8521 - lr: 0.0030
# Epoch 21/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1266 - accuracy: 0.5739 - top5-acc: 0.9666 - Brier score: 7.0025 - F1 score: 0.5680 - Recall: 0.9479 - Precision: 0.2383 - AUC: 0.8193 - val_loss: 1.0041 - val_accuracy: 0.6127 - val_top5-acc: 1.0000 - val_Brier score: 8.1006 - val_F1 score: 0.6061 - val_Recall: 0.9930 - val_Precision: 0.2338 - val_AUC: 0.8342 - lr: 0.0030
# Epoch 22/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1784 - accuracy: 0.5770 - top5-acc: 0.9627 - Brier score: 6.2698 - F1 score: 0.5709 - Recall: 0.9285 - Precision: 0.2369 - AUC: 0.8152 - val_loss: 0.8362 - val_accuracy: 0.6831 - val_top5-acc: 0.9789 - val_Brier score: 10.9812 - val_F1 score: 0.6729 - val_Recall: 0.9789 - val_Precision: 0.2565 - val_AUC: 0.8444 - lr: 0.0030
# Epoch 23/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0672 - accuracy: 0.6128 - top5-acc: 0.9782 - Brier score: 7.2138 - F1 score: 0.6078 - Recall: 0.9502 - Precision: 0.2446 - AUC: 0.8301 - val_loss: 0.6881 - val_accuracy: 0.8099 - val_top5-acc: 0.9859 - val_Brier score: 7.7958 - val_F1 score: 0.7557 - val_Recall: 0.9789 - val_Precision: 0.2473 - val_AUC: 0.8420 - lr: 0.0030
# Epoch 24/100
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0289 - accuracy: 0.6081 - top5-acc: 0.9813 - Brier score: 7.3374 - F1 score: 0.6021 - Recall: 0.9697 - Precision: 0.2492 - AUC: 0.8383 - val_loss: 0.4931 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 9.2447 - val_F1 score: 0.8272 - val_Recall: 1.0000 - val_Precision: 0.2554 - val_AUC: 0.8543 - lr: 0.0030
# Epoch 25/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.9932 - accuracy: 0.6299 - top5-acc: 0.9806 - Brier score: 6.8707 - F1 score: 0.6285 - Recall: 0.9611 - Precision: 0.2558 - AUC: 0.8402 - val_loss: 0.6122 - val_accuracy: 0.7817 - val_top5-acc: 1.0000 - val_Brier score: 8.2546 - val_F1 score: 0.7626 - val_Recall: 1.0000 - val_Precision: 0.2639 - val_AUC: 0.8635 - lr: 0.0030
# Epoch 26/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.9589 - accuracy: 0.6407 - top5-acc: 0.9844 - Brier score: 8.0608 - F1 score: 0.6372 - Recall: 0.9658 - Precision: 0.2488 - AUC: 0.8335 - val_loss: 0.8940 - val_accuracy: 0.6761 - val_top5-acc: 0.9930 - val_Brier score: 11.0342 - val_F1 score: 0.6404 - val_Recall: 0.9648 - val_Precision: 0.2645 - val_AUC: 0.8361 - lr: 0.0030
# Epoch 27/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9236 - accuracy: 0.6687 - top5-acc: 0.9829 - Brier score: 7.9190 - F1 score: 0.6656 - Recall: 0.9635 - Precision: 0.2558 - AUC: 0.8399 - val_loss: 0.8359 - val_accuracy: 0.7465 - val_top5-acc: 0.9859 - val_Brier score: 12.8219 - val_F1 score: 0.7133 - val_Recall: 0.9789 - val_Precision: 0.2648 - val_AUC: 0.8451 - lr: 0.0030
# Epoch 28/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.9341 - accuracy: 0.6540 - top5-acc: 0.9844 - Brier score: 8.3815 - F1 score: 0.6497 - Recall: 0.9720 - Precision: 0.2544 - AUC: 0.8399 - val_loss: 0.5416 - val_accuracy: 0.8028 - val_top5-acc: 0.9930 - val_Brier score: 10.3786 - val_F1 score: 0.7765 - val_Recall: 0.9930 - val_Precision: 0.2655 - val_AUC: 0.8596 - lr: 0.0030
# Epoch 29/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.8645 - accuracy: 0.6719 - top5-acc: 0.9860 - Brier score: 8.9290 - F1 score: 0.6712 - Recall: 0.9728 - Precision: 0.2618 - AUC: 0.8462 - val_loss: 0.6509 - val_accuracy: 0.7324 - val_top5-acc: 1.0000 - val_Brier score: 13.5461 - val_F1 score: 0.7342 - val_Recall: 1.0000 - val_Precision: 0.2689 - val_AUC: 0.8653 - lr: 0.0030
# Epoch 30/100
# 41/41 [==============================] - 1s 28ms/step - loss: 0.8214 - accuracy: 0.7138 - top5-acc: 0.9852 - Brier score: 8.1349 - F1 score: 0.7126 - Recall: 0.9728 - Precision: 0.2667 - AUC: 0.8495 - val_loss: 0.5127 - val_accuracy: 0.7958 - val_top5-acc: 0.9930 - val_Brier score: 13.2496 - val_F1 score: 0.7792 - val_Recall: 0.9930 - val_Precision: 0.2717 - val_AUC: 0.8639 - lr: 0.0015
# Epoch 31/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7418 - accuracy: 0.7309 - top5-acc: 0.9899 - Brier score: 9.6089 - F1 score: 0.7298 - Recall: 0.9806 - Precision: 0.2627 - AUC: 0.8491 - val_loss: 0.8086 - val_accuracy: 0.7394 - val_top5-acc: 0.9930 - val_Brier score: 13.7923 - val_F1 score: 0.7234 - val_Recall: 0.9718 - val_Precision: 0.2649 - val_AUC: 0.8497 - lr: 0.0015
# Epoch 32/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7349 - accuracy: 0.7302 - top5-acc: 0.9922 - Brier score: 9.3933 - F1 score: 0.7304 - Recall: 0.9798 - Precision: 0.2582 - AUC: 0.8485 - val_loss: 0.5422 - val_accuracy: 0.7746 - val_top5-acc: 1.0000 - val_Brier score: 11.9937 - val_F1 score: 0.7508 - val_Recall: 0.9930 - val_Precision: 0.2696 - val_AUC: 0.8569 - lr: 0.0015
# Epoch 33/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7501 - accuracy: 0.7177 - top5-acc: 0.9914 - Brier score: 9.4076 - F1 score: 0.7153 - Recall: 0.9798 - Precision: 0.2574 - AUC: 0.8476 - val_loss: 0.4645 - val_accuracy: 0.7958 - val_top5-acc: 1.0000 - val_Brier score: 14.5130 - val_F1 score: 0.7805 - val_Recall: 0.9930 - val_Precision: 0.2759 - val_AUC: 0.8639 - lr: 0.0015
# Epoch 34/100
# 41/41 [==============================] - 1s 27ms/step - loss: 0.6880 - accuracy: 0.7566 - top5-acc: 0.9922 - Brier score: 11.0186 - F1 score: 0.7556 - Recall: 0.9821 - Precision: 0.2605 - AUC: 0.8487 - val_loss: 0.6039 - val_accuracy: 0.7183 - val_top5-acc: 1.0000 - val_Brier score: 16.5594 - val_F1 score: 0.7023 - val_Recall: 1.0000 - val_Precision: 0.2705 - val_AUC: 0.8548 - lr: 0.0015
# Epoch 35/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.6815 - accuracy: 0.7465 - top5-acc: 0.9946 - Brier score: 11.1715 - F1 score: 0.7459 - Recall: 0.9829 - Precision: 0.2584 - AUC: 0.8466 - val_loss: 0.5072 - val_accuracy: 0.7465 - val_top5-acc: 1.0000 - val_Brier score: 15.6846 - val_F1 score: 0.7312 - val_Recall: 1.0000 - val_Precision: 0.2635 - val_AUC: 0.8570 - lr: 0.0015
# Epoch 36/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6969 - accuracy: 0.7449 - top5-acc: 0.9891 - Brier score: 11.8190 - F1 score: 0.7436 - Recall: 0.9844 - Precision: 0.2593 - AUC: 0.8466 - val_loss: 0.3180 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 16.6950 - val_F1 score: 0.8207 - val_Recall: 1.0000 - val_Precision: 0.2773 - val_AUC: 0.8631 - lr: 0.0015
# Epoch 37/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6434 - accuracy: 0.7519 - top5-acc: 0.9930 - Brier score: 11.0046 - F1 score: 0.7514 - Recall: 0.9868 - Precision: 0.2666 - AUC: 0.8541 - val_loss: 0.3679 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 15.9856 - val_F1 score: 0.8412 - val_Recall: 1.0000 - val_Precision: 0.2625 - val_AUC: 0.8490 - lr: 0.0015
# Epoch 38/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6281 - accuracy: 0.7621 - top5-acc: 0.9914 - Brier score: 11.6691 - F1 score: 0.7607 - Recall: 0.9844 - Precision: 0.2732 - AUC: 0.8575 - val_loss: 0.5179 - val_accuracy: 0.7746 - val_top5-acc: 1.0000 - val_Brier score: 17.4862 - val_F1 score: 0.7521 - val_Recall: 0.9930 - val_Precision: 0.2981 - val_AUC: 0.8742 - lr: 0.0015
# Epoch 39/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6165 - accuracy: 0.7729 - top5-acc: 0.9953 - Brier score: 11.6621 - F1 score: 0.7721 - Recall: 0.9829 - Precision: 0.2704 - AUC: 0.8555 - val_loss: 0.6573 - val_accuracy: 0.7535 - val_top5-acc: 1.0000 - val_Brier score: 18.1255 - val_F1 score: 0.7356 - val_Recall: 1.0000 - val_Precision: 0.2840 - val_AUC: 0.8693 - lr: 0.0015
# Epoch 40/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6483 - accuracy: 0.7613 - top5-acc: 0.9914 - Brier score: 11.7133 - F1 score: 0.7601 - Recall: 0.9837 - Precision: 0.2663 - AUC: 0.8500 - val_loss: 0.4200 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 16.7503 - val_F1 score: 0.8040 - val_Recall: 1.0000 - val_Precision: 0.2674 - val_AUC: 0.8539 - lr: 0.0015
# Epoch 41/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6140 - accuracy: 0.7722 - top5-acc: 0.9922 - Brier score: 11.4693 - F1 score: 0.7716 - Recall: 0.9883 - Precision: 0.2663 - AUC: 0.8532 - val_loss: 0.4861 - val_accuracy: 0.7887 - val_top5-acc: 1.0000 - val_Brier score: 17.3452 - val_F1 score: 0.7765 - val_Recall: 1.0000 - val_Precision: 0.2630 - val_AUC: 0.8499 - lr: 0.0015
# Epoch 42/100
# 41/41 [==============================] - 1s 26ms/step - loss: 0.5713 - accuracy: 0.7908 - top5-acc: 0.9946 - Brier score: 12.1279 - F1 score: 0.7899 - Recall: 0.9891 - Precision: 0.2650 - AUC: 0.8540 - val_loss: 0.5394 - val_accuracy: 0.7535 - val_top5-acc: 1.0000 - val_Brier score: 20.2729 - val_F1 score: 0.7387 - val_Recall: 1.0000 - val_Precision: 0.2659 - val_AUC: 0.8488 - lr: 7.5000e-04
# Epoch 43/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5345 - accuracy: 0.8118 - top5-acc: 0.9914 - Brier score: 14.5462 - F1 score: 0.8121 - Recall: 0.9837 - Precision: 0.2683 - AUC: 0.8518 - val_loss: 0.5364 - val_accuracy: 0.7817 - val_top5-acc: 1.0000 - val_Brier score: 19.6948 - val_F1 score: 0.7546 - val_Recall: 1.0000 - val_Precision: 0.2752 - val_AUC: 0.8568 - lr: 7.5000e-04
# Epoch 44/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5002 - accuracy: 0.8204 - top5-acc: 0.9946 - Brier score: 13.4967 - F1 score: 0.8193 - Recall: 0.9883 - Precision: 0.2697 - AUC: 0.8561 - val_loss: 0.6323 - val_accuracy: 0.7465 - val_top5-acc: 1.0000 - val_Brier score: 19.5302 - val_F1 score: 0.7249 - val_Recall: 1.0000 - val_Precision: 0.2726 - val_AUC: 0.8552 - lr: 7.5000e-04
# Epoch 45/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5059 - accuracy: 0.8126 - top5-acc: 0.9930 - Brier score: 14.6820 - F1 score: 0.8128 - Recall: 0.9899 - Precision: 0.2709 - AUC: 0.8571 - val_loss: 0.3807 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 20.8485 - val_F1 score: 0.8000 - val_Recall: 1.0000 - val_Precision: 0.2625 - val_AUC: 0.8468 - lr: 7.5000e-04
# Epoch 46/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5105 - accuracy: 0.8196 - top5-acc: 0.9961 - Brier score: 14.3914 - F1 score: 0.8179 - Recall: 0.9868 - Precision: 0.2681 - AUC: 0.8549 - val_loss: 0.3094 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 20.6168 - val_F1 score: 0.8276 - val_Recall: 1.0000 - val_Precision: 0.2630 - val_AUC: 0.8499 - lr: 7.5000e-04
# Epoch 47/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5259 - accuracy: 0.8064 - top5-acc: 0.9930 - Brier score: 14.7721 - F1 score: 0.8061 - Recall: 0.9876 - Precision: 0.2714 - AUC: 0.8557 - val_loss: 0.3567 - val_accuracy: 0.8380 - val_top5-acc: 1.0000 - val_Brier score: 18.9543 - val_F1 score: 0.8133 - val_Recall: 1.0000 - val_Precision: 0.2715 - val_AUC: 0.8592 - lr: 7.5000e-04
# Epoch 48/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5255 - accuracy: 0.8056 - top5-acc: 0.9961 - Brier score: 14.2264 - F1 score: 0.8045 - Recall: 0.9899 - Precision: 0.2691 - AUC: 0.8537 - val_loss: 0.3160 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 20.0095 - val_F1 score: 0.8397 - val_Recall: 1.0000 - val_Precision: 0.2747 - val_AUC: 0.8573 - lr: 7.5000e-04
# Epoch 49/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4901 - accuracy: 0.8219 - top5-acc: 0.9969 - Brier score: 13.4041 - F1 score: 0.8224 - Recall: 0.9938 - Precision: 0.2702 - AUC: 0.8582 - val_loss: 0.3625 - val_accuracy: 0.8451 - val_top5-acc: 1.0000 - val_Brier score: 18.9152 - val_F1 score: 0.8207 - val_Recall: 0.9930 - val_Precision: 0.2743 - val_AUC: 0.8522 - lr: 7.5000e-04
# Epoch 50/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4484 - accuracy: 0.8437 - top5-acc: 0.9938 - Brier score: 14.8778 - F1 score: 0.8436 - Recall: 0.9907 - Precision: 0.2777 - AUC: 0.8608 - val_loss: 0.2676 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 21.4467 - val_F1 score: 0.8938 - val_Recall: 1.0000 - val_Precision: 0.2763 - val_AUC: 0.8565 - lr: 7.5000e-04
# Epoch 51/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.4393 - accuracy: 0.8375 - top5-acc: 0.9977 - Brier score: 16.1737 - F1 score: 0.8379 - Recall: 0.9914 - Precision: 0.2727 - AUC: 0.8571 - val_loss: 0.2249 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 20.4108 - val_F1 score: 0.9038 - val_Recall: 1.0000 - val_Precision: 0.2768 - val_AUC: 0.8556 - lr: 7.5000e-04
# Epoch 52/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.5111 - accuracy: 0.8134 - top5-acc: 0.9953 - Brier score: 14.9932 - F1 score: 0.8116 - Recall: 0.9907 - Precision: 0.2680 - AUC: 0.8538 - val_loss: 0.3860 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 21.9630 - val_F1 score: 0.8385 - val_Recall: 0.9930 - val_Precision: 0.2837 - val_AUC: 0.8532 - lr: 7.5000e-04
# Epoch 53/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.4452 - accuracy: 0.8375 - top5-acc: 0.9938 - Brier score: 15.8810 - F1 score: 0.8375 - Recall: 0.9922 - Precision: 0.2694 - AUC: 0.8572 - val_loss: 0.2825 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 25.2094 - val_F1 score: 0.9055 - val_Recall: 0.9930 - val_Precision: 0.2820 - val_AUC: 0.8519 - lr: 7.5000e-04
# Epoch 54/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.4236 - accuracy: 0.8406 - top5-acc: 0.9961 - Brier score: 16.6817 - F1 score: 0.8401 - Recall: 0.9914 - Precision: 0.2709 - AUC: 0.8556 - val_loss: 0.4167 - val_accuracy: 0.8239 - val_top5-acc: 1.0000 - val_Brier score: 24.1552 - val_F1 score: 0.8075 - val_Recall: 0.9930 - val_Precision: 0.2754 - val_AUC: 0.8532 - lr: 7.5000e-04
# Epoch 55/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.4055 - accuracy: 0.8577 - top5-acc: 0.9969 - Brier score: 15.8432 - F1 score: 0.8564 - Recall: 0.9953 - Precision: 0.2727 - AUC: 0.8588 - val_loss: 0.5327 - val_accuracy: 0.7887 - val_top5-acc: 1.0000 - val_Brier score: 21.3775 - val_F1 score: 0.7600 - val_Recall: 1.0000 - val_Precision: 0.2736 - val_AUC: 0.8534 - lr: 7.5000e-04
# Epoch 56/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4091 - accuracy: 0.8507 - top5-acc: 0.9984 - Brier score: 16.3634 - F1 score: 0.8511 - Recall: 0.9946 - Precision: 0.2730 - AUC: 0.8565 - val_loss: 0.5047 - val_accuracy: 0.7887 - val_top5-acc: 1.0000 - val_Brier score: 24.5944 - val_F1 score: 0.7739 - val_Recall: 1.0000 - val_Precision: 0.2757 - val_AUC: 0.8597 - lr: 7.5000e-04
# Epoch 57/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3784 - accuracy: 0.8694 - top5-acc: 0.9992 - Brier score: 17.1029 - F1 score: 0.8677 - Recall: 0.9914 - Precision: 0.2700 - AUC: 0.8539 - val_loss: 0.4630 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 25.0481 - val_F1 score: 0.7879 - val_Recall: 0.9930 - val_Precision: 0.2765 - val_AUC: 0.8523 - lr: 3.7500e-04
# Epoch 58/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4247 - accuracy: 0.8491 - top5-acc: 0.9977 - Brier score: 17.0140 - F1 score: 0.8495 - Recall: 0.9946 - Precision: 0.2641 - AUC: 0.8517 - val_loss: 0.2986 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 23.3730 - val_F1 score: 0.8451 - val_Recall: 1.0000 - val_Precision: 0.2812 - val_AUC: 0.8570 - lr: 3.7500e-04
# Epoch 59/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4102 - accuracy: 0.8616 - top5-acc: 0.9961 - Brier score: 15.9783 - F1 score: 0.8603 - Recall: 0.9907 - Precision: 0.2686 - AUC: 0.8528 - val_loss: 0.2444 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 22.3469 - val_F1 score: 0.8882 - val_Recall: 1.0000 - val_Precision: 0.2679 - val_AUC: 0.8539 - lr: 3.7500e-04
# Epoch 60/100
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3614 - accuracy: 0.8733 - top5-acc: 0.9984 - Brier score: 16.1480 - F1 score: 0.8727 - Recall: 0.9969 - Precision: 0.2674 - AUC: 0.8559 - val_loss: 0.2463 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 23.3961 - val_F1 score: 0.8866 - val_Recall: 1.0000 - val_Precision: 0.2784 - val_AUC: 0.8583 - lr: 3.7500e-04
# Epoch 61/100
# 41/41 [==============================] - 1s 25ms/step - loss: 0.3597 - accuracy: 0.8678 - top5-acc: 0.9992 - Brier score: 17.1861 - F1 score: 0.8673 - Recall: 0.9953 - Precision: 0.2689 - AUC: 0.8569 - val_loss: 0.2282 - val_accuracy: 0.8944 - val_top5-acc: 1.0000 - val_Brier score: 24.8332 - val_F1 score: 0.8771 - val_Recall: 1.0000 - val_Precision: 0.2773 - val_AUC: 0.8556 - lr: 3.7500e-04

# %%
plot_training_curves(history_gmlp, 'gMLP for Computed Tomography of the Abdomen')

# %% [markdown]
# As shown in the gMLP paper, better results can be achieved by increasing the embedding dimensions, increasing the number of gMLP blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes. Note that, the paper used advanced regularization strategies, such as MixUp and CutMix, as well as AutoAugment.
#
#
#
# ---

# %% [markdown]
# # ⚛ ResMLP

# %%
class Affine(tf.keras.layers.Layer):
    def __init__(self, n_channels:int, biased:bool):
        super(Affine, self).__init__()
        self.n_channels = n_channels
        self.biased = biased
        self.a = tf.Variable(tf.ones([1,1,self.n_channels]), dtype = 'float32') if self.biased else tf.Variable(tf.random.normal([1,1,self.n_channels], 0, 0.001), dtype = 'float32')
        self.b = tf.Variable(tf.zeros([1,1,self.n_channels]), dtype = 'float32') if self.biased else None

    def call(self, X):
        X = X * self.a
        if self.biased:
            X = X + self.b
        return X

class ResLayer(tf.keras.layers.Layer):
    def __init__(self, n_dims:int, n_patches:int):
        super(ResLayer, self).__init__()
        self.n_dims = n_dims
        self.n_patches = n_patches
        self.affine_pre1 = Affine(self.n_dims, True)
        self.affine_pre2 = Affine(self.n_dims, True)
        self.affine_pos1 = Affine(self.n_dims, False)
        self.affine_pos2 = Affine(self.n_dims, False)
        self.t = tf.keras.layers.Permute((2,1))
        self.linear1 = tf.keras.layers.Dense(self.n_patches, kernel_initializer = tf.keras.initializers.glorot_normal())
        self.linear2 = tf.keras.layers.Dense(self.n_dims*4, kernel_initializer = tf.keras.initializers.glorot_normal())
        self.linear3 = tf.keras.layers.Dense(self.n_dims, kernel_initializer = tf.keras.initializers.glorot_normal())

    def call(self, X):
        #Cross-patch
        y = self.affine_pre1(X)
        y = self.t(y)
        y = self.linear1(y)
        y = self.t(y)
        y = self.affine_pos1(y)
        X = X + y
        #Cross-channel
        y = self.affine_pre2(X)
        y = self.linear2(y)
        y = tf.nn.gelu(y)
        y = self.linear3(y)
        y = self.affine_pos2(y)
        y = X + y
        return y

class ResMLP(tf.keras.models.Model):
    def __init__(self, n_dims:int, image_size:int, patch_size:int, n_res_layers:int, n_labels:int, mode:str = 'softmax'):
        super(ResMLP, self).__init__()
        self.n_dims = n_dims
        self.image_size = image_size
        self.patch_size = patch_size
        if (self.image_size % self.patch_size) != 0:
            raise ValueError('size error')
        self.n_patches = int((tf.square(self.image_size) / tf.square(self.patch_size)).numpy())
        self.n_res_layers = n_res_layers
        self.n_labels = n_labels
        if mode not in ['sigmoid','softmax']:
            raise ValueError('mode must be sigmoid or softmax')
        else:
            self.mode = mode
        self.patchConv = tf.keras.layers.Conv2D(self.n_dims, (self.patch_size, self.patch_size), strides = (self.patch_size, self.patch_size))
        self.reshapeL = tf.keras.layers.Reshape((self.n_patches, self.n_dims))
        self.ResLayers = [ResLayer(self.n_dims, self.n_patches) for x in range(self.n_res_layers)]
        self.gap = tf.keras.layers.GlobalAveragePooling1D()
        self.classifier = tf.keras.layers.Dense(self.n_labels if self.n_labels > 2 else 1, activation = mode, kernel_initializer = tf.keras.initializers.glorot_normal(seed = 42))

    def call(self, X):
        X = self.patchConv(X)
        X = self.reshapeL(X)
        for reslayer in self.ResLayers:
            X = reslayer(X)
        X = self.gap(X)
        X = self.classifier(X)
        return X

# %%
resmlp = ResMLP(n_dims=384, image_size=64, patch_size=16, n_res_layers=4, n_labels=num_classes, mode = 'softmax')

# %%
history_resmlp = run_experiment(resmlp)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5577: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 41/41 [==============================] - 10s 40ms/step - loss: 445.8396 - accuracy: 0.2294 - top5-acc: 0.9712 - Brier score: 0.1689 - F1 score: 0.2283 - Recall: 0.2271 - Precision: 0.2292 - AUC: 0.5681 - val_loss: 2.8481 - val_accuracy: 0.8732 - val_top5-acc: 0.9930 - val_Brier score: 0.0259 - val_F1 score: 0.8652 - val_Recall: 0.8732 - val_Precision: 0.8732 - val_AUC: 0.9474 - lr: 0.0030
# Epoch 2/100
# 41/41 [==============================] - 1s 20ms/step - loss: 5.6252 - accuracy: 0.8639 - top5-acc: 0.9922 - Brier score: 0.0294 - F1 score: 0.8659 - Recall: 0.8639 - Precision: 0.8639 - AUC: 0.9302 - val_loss: 2.4526e-06 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.8856e-10 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 3/100
# 41/41 [==============================] - 1s 20ms/step - loss: 0.0270 - accuracy: 0.9961 - top5-acc: 1.0000 - Brier score: 7.6713e-04 - F1 score: 0.9962 - Recall: 0.9961 - Precision: 0.9961 - AUC: 0.9987 - val_loss: 1.9452e-05 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.1907e-08 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 4/100
# 41/41 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9984 - top5-acc: 1.0000 - Brier score: 2.3693e-04 - F1 score: 0.9985 - Recall: 0.9984 - Precision: 0.9984 - AUC: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 6.8464e-05 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 5/100
# 41/41 [==============================] - 1s 20ms/step - loss: 0.0214 - accuracy: 0.9977 - top5-acc: 1.0000 - Brier score: 5.1470e-04 - F1 score: 0.9977 - Recall: 0.9977 - Precision: 0.9977 - AUC: 0.9996 - val_loss: 1.3439e-06 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 5.6846e-11 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 6/100
# 41/41 [==============================] - 1s 20ms/step - loss: 1.9296e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.1527e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 2.6025e-08 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 2.1334e-14 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 7/100
# 41/41 [==============================] - 1s 21ms/step - loss: 1.7128e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 9.0594e-12 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.6790e-08 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 8.7202e-15 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0030
# Epoch 8/100
# 41/41 [==============================] - 1s 21ms/step - loss: 2.0944e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.3406e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.0914e-08 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.8462e-15 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0015
# Epoch 9/100
# 41/41 [==============================] - 1s 21ms/step - loss: 2.8429e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 2.4572e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 7.5555e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.8224e-15 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0015
# Epoch 10/100
# 41/41 [==============================] - 1s 21ms/step - loss: 3.3868e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 3.3512e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 5.0370e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 8.3129e-16 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0015
# Epoch 11/100
# 41/41 [==============================] - 1s 20ms/step - loss: 4.3810e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 4.9898e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 3.3580e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.8329e-16 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0015
# Epoch 12/100
# 41/41 [==============================] - 1s 20ms/step - loss: 5.3535e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 6.7925e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 2.5185e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.9889e-16 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 0.0015
# Epoch 13/100
# 41/41 [==============================] - 1s 20ms/step - loss: 6.8893e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 9.6227e-11 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.6790e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 9.4897e-17 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 7.5000e-04
# Epoch 14/100
# 41/41 [==============================] - 1s 20ms/step - loss: 9.9949e-07 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.6288e-10 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.6790e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 7.1181e-17 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 7.5000e-04
# Epoch 15/100
# 41/41 [==============================] - 1s 20ms/step - loss: 1.6594e-06 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 4.0101e-10 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 8.3950e-10 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 2.7027e-17 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 7.5000e-04
# Epoch 16/100
# 41/41 [==============================] - 1s 19ms/step - loss: 2.6611e-06 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.0924e-09 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.6790e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 4.9863e-17 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 7.5000e-04
# Epoch 17/100
# 41/41 [==============================] - 1s 20ms/step - loss: 4.3083e-06 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 3.2112e-09 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 5.8765e-09 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 7.7071e-16 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 7.5000e-04
# Epoch 18/100
# 41/41 [==============================] - 1s 20ms/step - loss: 6.2572e-06 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 7.2569e-09 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 2.0988e-08 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.2624e-14 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 3.7500e-04
# Epoch 19/100
# 41/41 [==============================] - 1s 20ms/step - loss: 1.0474e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 2.1660e-08 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 7.8073e-08 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 1.9334e-13 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 3.7500e-04
# Epoch 20/100
# 41/41 [==============================] - 1s 19ms/step - loss: 1.4400e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 4.6196e-08 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 2.8710e-07 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 2.5975e-12 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 3.7500e-04
# Epoch 21/100
# 41/41 [==============================] - 1s 19ms/step - loss: 1.8894e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 8.0302e-08 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.0090e-06 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.2126e-11 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 3.7500e-04
# Epoch 22/100
# 41/41 [==============================] - 1s 20ms/step - loss: 2.0353e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 9.0016e-08 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 3.3765e-06 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.5955e-10 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 3.7500e-04
# Epoch 23/100
# 41/41 [==============================] - 1s 20ms/step - loss: 2.0328e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 8.6684e-08 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.1052e-05 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.8482e-09 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 1.8750e-04
# Epoch 24/100
# 41/41 [==============================] - 1s 20ms/step - loss: 2.3601e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.1590e-07 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 3.4443e-05 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.7252e-08 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 1.8750e-04
# Epoch 25/100
# 41/41 [==============================] - 1s 21ms/step - loss: 2.8906e-05 - accuracy: 1.0000 - top5-acc: 1.0000 - Brier score: 1.7338e-07 - F1 score: 1.0000 - Recall: 1.0000 - Precision: 1.0000 - AUC: 1.0000 - val_loss: 1.0198e-04 - val_accuracy: 1.0000 - val_top5-acc: 1.0000 - val_Brier score: 3.2346e-07 - val_F1 score: 1.0000 - val_Recall: 1.0000 - val_Precision: 1.0000 - val_AUC: 1.0000 - lr: 1.8750e-04

# %%
plot_training_curves(history_resmlp, 'ResMLP for Computed Tomography of the Abdomen')

# %% [markdown]
# ---

# %% [markdown]
# # ⚛ DiagnosticMLP (proposed model)

# %%
class DiagnosticMLP(layers.Layer):
    def __init__(self, num_patches, hidden_units, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.mlp1 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=num_patches),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.mlp2 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=embedding_dim),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.normalize = layers.LayerNormalization(epsilon=1e-6)
        self.mlp3 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.channel_projection2 = layers.Dense(units=embedding_dim)
        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        ########################################################################
        # Apply layer normalization.
        x = self.normalize(x)
        # Transpose inputs from [num_batches, num_patches, hidden_units] to [num_batches, hidden_units, num_patches].
        x_channels = tf.linalg.matrix_transpose(x)
        # Apply mlp1 on each channel independently.
        mlp1_outputs = self.mlp1(x_channels)
        # Transpose mlp1_outputs from [num_batches, hidden_dim, num_patches] to [num_batches, num_patches, hidden_units].
        mlp1_outputs = tf.linalg.matrix_transpose(mlp1_outputs)
        # Add skip connection.
        x = mlp1_outputs + inputs
        # Apply layer normalization.
        x_patches = self.normalize(x)
        # Apply mlp2 on each patch independtenly.
        mlp2_outputs = self.mlp2(x_patches)
        # Add skip connection.
        x = x + mlp2_outputs
        ########################################################################
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.mlp3(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        x= x + x_projected
        return x

# %%
DiagnosticMLP_blocks = keras.Sequential(
    [DiagnosticMLP(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
DiagnosticMLP_classifier = build_classifier(DiagnosticMLP_blocks)

# %%
history_DiagnosticMLP = run_experiment(DiagnosticMLP_classifier)
# Out:
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 41/41 [==============================] - ETA: 0s - loss: 90.6293 - accuracy: 0.1275 - top5-acc: 0.5560 - Brier score: 16126.8643 - F1 score: 0.1256 - Recall: 0.7084 - Precision: 0.1134 - AUC: 0.5082
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 41/41 [==============================] - 12s 79ms/step - loss: 90.6293 - accuracy: 0.1275 - top5-acc: 0.5560 - Brier score: 16126.8643 - F1 score: 0.1256 - Recall: 0.7084 - Precision: 0.1134 - AUC: 0.5082 - val_loss: 23.0504 - val_accuracy: 0.2183 - val_top5-acc: 0.5282 - val_Brier score: 518.1155 - val_F1 score: 0.1156 - val_Recall: 0.6831 - val_Precision: 0.1069 - val_AUC: 0.4876 - lr: 0.0010
# Epoch 2/100
# 41/41 [==============================] - 2s 36ms/step - loss: 22.5580 - accuracy: 0.1734 - top5-acc: 0.6275 - Brier score: 484.5124 - F1 score: 0.1748 - Recall: 0.6921 - Precision: 0.1210 - AUC: 0.5336 - val_loss: 19.7522 - val_accuracy: 0.2535 - val_top5-acc: 0.6056 - val_Brier score: 353.2053 - val_F1 score: 0.1077 - val_Recall: 0.5915 - val_Precision: 0.1165 - val_AUC: 0.5179 - lr: 0.0010
# Epoch 3/100
# 41/41 [==============================] - 2s 36ms/step - loss: 17.6312 - accuracy: 0.2076 - top5-acc: 0.6890 - Brier score: 299.7650 - F1 score: 0.2065 - Recall: 0.6757 - Precision: 0.1375 - AUC: 0.5744 - val_loss: 12.5828 - val_accuracy: 0.2042 - val_top5-acc: 0.7817 - val_Brier score: 143.4910 - val_F1 score: 0.1378 - val_Recall: 0.8803 - val_Precision: 0.1598 - val_AUC: 0.6574 - lr: 0.0010
# Epoch 4/100
# 41/41 [==============================] - 2s 36ms/step - loss: 14.1807 - accuracy: 0.2286 - top5-acc: 0.7185 - Brier score: 275.7406 - F1 score: 0.2278 - Recall: 0.7356 - Precision: 0.1409 - AUC: 0.5906 - val_loss: 6.6266 - val_accuracy: 0.3592 - val_top5-acc: 0.8310 - val_Brier score: 129.2860 - val_F1 score: 0.2843 - val_Recall: 0.6620 - val_Precision: 0.2298 - val_AUC: 0.7011 - lr: 0.0010
# Epoch 5/100
# 41/41 [==============================] - 2s 36ms/step - loss: 13.3134 - accuracy: 0.2566 - top5-acc: 0.7473 - Brier score: 281.0695 - F1 score: 0.2564 - Recall: 0.7605 - Precision: 0.1455 - AUC: 0.6050 - val_loss: 3.4403 - val_accuracy: 0.4859 - val_top5-acc: 0.9296 - val_Brier score: 129.0388 - val_F1 score: 0.4107 - val_Recall: 0.9437 - val_Precision: 0.1564 - val_AUC: 0.6671 - lr: 0.0010
# Epoch 6/100
# 41/41 [==============================] - 2s 35ms/step - loss: 12.5071 - accuracy: 0.2986 - top5-acc: 0.7799 - Brier score: 301.9637 - F1 score: 0.2984 - Recall: 0.8538 - Precision: 0.1431 - AUC: 0.6135 - val_loss: 5.1948 - val_accuracy: 0.4577 - val_top5-acc: 0.8803 - val_Brier score: 127.5083 - val_F1 score: 0.4035 - val_Recall: 0.8732 - val_Precision: 0.1882 - val_AUC: 0.7098 - lr: 0.0010
# Epoch 7/100
# 41/41 [==============================] - 2s 35ms/step - loss: 9.4620 - accuracy: 0.3328 - top5-acc: 0.8297 - Brier score: 206.0892 - F1 score: 0.3336 - Recall: 0.8429 - Precision: 0.1634 - AUC: 0.6553 - val_loss: 7.0578 - val_accuracy: 0.4366 - val_top5-acc: 0.8873 - val_Brier score: 304.5189 - val_F1 score: 0.2851 - val_Recall: 0.8944 - val_Precision: 0.1843 - val_AUC: 0.7058 - lr: 0.0010
# Epoch 8/100
# 41/41 [==============================] - 2s 37ms/step - loss: 12.1563 - accuracy: 0.3289 - top5-acc: 0.8165 - Brier score: 322.8506 - F1 score: 0.3281 - Recall: 0.8375 - Precision: 0.1567 - AUC: 0.6407 - val_loss: 7.1594 - val_accuracy: 0.4014 - val_top5-acc: 0.8592 - val_Brier score: 267.2618 - val_F1 score: 0.3658 - val_Recall: 0.8803 - val_Precision: 0.1812 - val_AUC: 0.6970 - lr: 0.0010
# Epoch 9/100
# 41/41 [==============================] - 2s 36ms/step - loss: 9.0971 - accuracy: 0.3810 - top5-acc: 0.8538 - Brier score: 246.1792 - F1 score: 0.3794 - Recall: 0.8709 - Precision: 0.1668 - AUC: 0.6686 - val_loss: 4.4000 - val_accuracy: 0.5282 - val_top5-acc: 0.9648 - val_Brier score: 252.4595 - val_F1 score: 0.4573 - val_Recall: 0.9296 - val_Precision: 0.2563 - val_AUC: 0.8019 - lr: 0.0010
# Epoch 10/100
# 41/41 [==============================] - 2s 36ms/step - loss: 7.2056 - accuracy: 0.4199 - top5-acc: 0.8880 - Brier score: 258.5898 - F1 score: 0.4195 - Recall: 0.9098 - Precision: 0.1637 - AUC: 0.6705 - val_loss: 3.9071 - val_accuracy: 0.6338 - val_top5-acc: 0.9718 - val_Brier score: 312.4951 - val_F1 score: 0.5500 - val_Recall: 1.0000 - val_Precision: 0.1615 - val_AUC: 0.6871 - lr: 0.0010
# Epoch 11/100
# 41/41 [==============================] - 2s 36ms/step - loss: 4.6170 - accuracy: 0.5179 - top5-acc: 0.9199 - Brier score: 192.5856 - F1 score: 0.5155 - Recall: 0.9393 - Precision: 0.1782 - AUC: 0.7063 - val_loss: 1.1158 - val_accuracy: 0.7817 - val_top5-acc: 0.9930 - val_Brier score: 177.2557 - val_F1 score: 0.7679 - val_Recall: 0.9789 - val_Precision: 0.2145 - val_AUC: 0.7741 - lr: 5.0000e-04
# Epoch 12/100
# 41/41 [==============================] - 2s 35ms/step - loss: 3.9678 - accuracy: 0.5342 - top5-acc: 0.9409 - Brier score: 151.8321 - F1 score: 0.5336 - Recall: 0.9471 - Precision: 0.1841 - AUC: 0.7202 - val_loss: 1.2875 - val_accuracy: 0.7113 - val_top5-acc: 0.9859 - val_Brier score: 180.5691 - val_F1 score: 0.6705 - val_Recall: 0.9718 - val_Precision: 0.2143 - val_AUC: 0.7693 - lr: 5.0000e-04
# Epoch 13/100
# 41/41 [==============================] - 2s 35ms/step - loss: 3.3164 - accuracy: 0.5801 - top5-acc: 0.9479 - Brier score: 144.1613 - F1 score: 0.5808 - Recall: 0.9448 - Precision: 0.1926 - AUC: 0.7331 - val_loss: 1.7117 - val_accuracy: 0.7324 - val_top5-acc: 0.9859 - val_Brier score: 187.8649 - val_F1 score: 0.6902 - val_Recall: 1.0000 - val_Precision: 0.1784 - val_AUC: 0.7240 - lr: 5.0000e-04
# Epoch 14/100
# 41/41 [==============================] - 2s 35ms/step - loss: 2.7348 - accuracy: 0.5933 - top5-acc: 0.9572 - Brier score: 126.3783 - F1 score: 0.5924 - Recall: 0.9603 - Precision: 0.1960 - AUC: 0.7443 - val_loss: 1.2624 - val_accuracy: 0.7746 - val_top5-acc: 0.9930 - val_Brier score: 174.1665 - val_F1 score: 0.7664 - val_Recall: 0.9648 - val_Precision: 0.2546 - val_AUC: 0.8168 - lr: 5.0000e-04
# Epoch 15/100
# 41/41 [==============================] - 2s 37ms/step - loss: 3.2239 - accuracy: 0.5677 - top5-acc: 0.9588 - Brier score: 132.4133 - F1 score: 0.5687 - Recall: 0.8997 - Precision: 0.2356 - AUC: 0.7781 - val_loss: 0.9440 - val_accuracy: 0.7606 - val_top5-acc: 0.9930 - val_Brier score: 159.9131 - val_F1 score: 0.7294 - val_Recall: 0.9859 - val_Precision: 0.2393 - val_AUC: 0.8083 - lr: 5.0000e-04
# Epoch 16/100
# 41/41 [==============================] - 2s 36ms/step - loss: 3.2922 - accuracy: 0.5754 - top5-acc: 0.9487 - Brier score: 129.8941 - F1 score: 0.5773 - Recall: 0.8896 - Precision: 0.2384 - AUC: 0.7770 - val_loss: 1.1613 - val_accuracy: 0.7676 - val_top5-acc: 0.9859 - val_Brier score: 162.0564 - val_F1 score: 0.7328 - val_Recall: 0.9789 - val_Precision: 0.2017 - val_AUC: 0.7572 - lr: 5.0000e-04
# Epoch 17/100
# 41/41 [==============================] - 2s 37ms/step - loss: 2.8155 - accuracy: 0.5941 - top5-acc: 0.9526 - Brier score: 131.7065 - F1 score: 0.5963 - Recall: 0.9619 - Precision: 0.1907 - AUC: 0.7365 - val_loss: 1.8421 - val_accuracy: 0.7042 - val_top5-acc: 0.9859 - val_Brier score: 186.1373 - val_F1 score: 0.6613 - val_Recall: 0.9859 - val_Precision: 0.1892 - val_AUC: 0.7370 - lr: 5.0000e-04
# Epoch 18/100
# 41/41 [==============================] - 2s 37ms/step - loss: 3.2825 - accuracy: 0.5816 - top5-acc: 0.9619 - Brier score: 148.1146 - F1 score: 0.5805 - Recall: 0.9697 - Precision: 0.1746 - AUC: 0.7071 - val_loss: 2.3799 - val_accuracy: 0.6197 - val_top5-acc: 0.9789 - val_Brier score: 216.9028 - val_F1 score: 0.5941 - val_Recall: 0.9859 - val_Precision: 0.2044 - val_AUC: 0.7608 - lr: 5.0000e-04
# Epoch 19/100
# 41/41 [==============================] - 2s 36ms/step - loss: 3.1589 - accuracy: 0.5879 - top5-acc: 0.9541 - Brier score: 150.6449 - F1 score: 0.5879 - Recall: 0.9635 - Precision: 0.1793 - AUC: 0.7164 - val_loss: 0.8319 - val_accuracy: 0.7817 - val_top5-acc: 0.9930 - val_Brier score: 197.6951 - val_F1 score: 0.7662 - val_Recall: 0.9930 - val_Precision: 0.1860 - val_AUC: 0.7344 - lr: 5.0000e-04
# Epoch 20/100
# 41/41 [==============================] - 2s 35ms/step - loss: 2.5398 - accuracy: 0.6089 - top5-acc: 0.9759 - Brier score: 127.0967 - F1 score: 0.6100 - Recall: 0.9658 - Precision: 0.2135 - AUC: 0.7716 - val_loss: 0.8914 - val_accuracy: 0.8310 - val_top5-acc: 0.9930 - val_Brier score: 193.6203 - val_F1 score: 0.8035 - val_Recall: 1.0000 - val_Precision: 0.1956 - val_AUC: 0.7526 - lr: 5.0000e-04
# Epoch 21/100
# 41/41 [==============================] - 2s 35ms/step - loss: 2.2435 - accuracy: 0.6493 - top5-acc: 0.9689 - Brier score: 135.5841 - F1 score: 0.6482 - Recall: 0.9806 - Precision: 0.1818 - AUC: 0.7251 - val_loss: 2.0135 - val_accuracy: 0.6901 - val_top5-acc: 0.9718 - val_Brier score: 257.8855 - val_F1 score: 0.6078 - val_Recall: 0.9859 - val_Precision: 0.1980 - val_AUC: 0.7516 - lr: 5.0000e-04
# Epoch 22/100
# 41/41 [==============================] - 2s 36ms/step - loss: 2.4000 - accuracy: 0.6594 - top5-acc: 0.9642 - Brier score: 138.5435 - F1 score: 0.6597 - Recall: 0.9541 - Precision: 0.2084 - AUC: 0.7599 - val_loss: 0.8703 - val_accuracy: 0.8169 - val_top5-acc: 0.9859 - val_Brier score: 188.4710 - val_F1 score: 0.7911 - val_Recall: 0.9789 - val_Precision: 0.2328 - val_AUC: 0.8006 - lr: 5.0000e-04
# Epoch 23/100
# 41/41 [==============================] - 2s 36ms/step - loss: 2.0782 - accuracy: 0.6835 - top5-acc: 0.9720 - Brier score: 133.0579 - F1 score: 0.6827 - Recall: 0.9533 - Precision: 0.2149 - AUC: 0.7691 - val_loss: 0.7142 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 205.8432 - val_F1 score: 0.8040 - val_Recall: 0.9930 - val_Precision: 0.2035 - val_AUC: 0.7631 - lr: 5.0000e-04
# Epoch 24/100
# 41/41 [==============================] - 2s 36ms/step - loss: 2.0152 - accuracy: 0.6796 - top5-acc: 0.9705 - Brier score: 110.9445 - F1 score: 0.6783 - Recall: 0.9572 - Precision: 0.2194 - AUC: 0.7786 - val_loss: 0.8848 - val_accuracy: 0.8380 - val_top5-acc: 0.9859 - val_Brier score: 185.5199 - val_F1 score: 0.8169 - val_Recall: 0.9718 - val_Precision: 0.2460 - val_AUC: 0.8093 - lr: 5.0000e-04
# Epoch 25/100
# 41/41 [==============================] - 2s 37ms/step - loss: 2.2928 - accuracy: 0.6680 - top5-acc: 0.9712 - Brier score: 132.9932 - F1 score: 0.6677 - Recall: 0.9495 - Precision: 0.2246 - AUC: 0.7824 - val_loss: 0.7751 - val_accuracy: 0.8239 - val_top5-acc: 0.9930 - val_Brier score: 215.5916 - val_F1 score: 0.8035 - val_Recall: 0.9930 - val_Precision: 0.1964 - val_AUC: 0.7481 - lr: 5.0000e-04
# Epoch 26/100
# 41/41 [==============================] - 2s 38ms/step - loss: 1.6987 - accuracy: 0.6983 - top5-acc: 0.9767 - Brier score: 129.4487 - F1 score: 0.6974 - Recall: 0.9642 - Precision: 0.2157 - AUC: 0.7742 - val_loss: 0.6098 - val_accuracy: 0.8732 - val_top5-acc: 0.9859 - val_Brier score: 199.5162 - val_F1 score: 0.8509 - val_Recall: 0.9930 - val_Precision: 0.2308 - val_AUC: 0.7942 - lr: 5.0000e-04
# Epoch 27/100
# 41/41 [==============================] - 2s 37ms/step - loss: 1.7728 - accuracy: 0.6851 - top5-acc: 0.9868 - Brier score: 117.8448 - F1 score: 0.6850 - Recall: 0.9798 - Precision: 0.2105 - AUC: 0.7721 - val_loss: 0.6618 - val_accuracy: 0.8662 - val_top5-acc: 0.9859 - val_Brier score: 198.6887 - val_F1 score: 0.8463 - val_Recall: 0.9930 - val_Precision: 0.2104 - val_AUC: 0.7707 - lr: 5.0000e-04
# Epoch 28/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.7025 - accuracy: 0.7154 - top5-acc: 0.9821 - Brier score: 130.5091 - F1 score: 0.7137 - Recall: 0.9852 - Precision: 0.2019 - AUC: 0.7608 - val_loss: 0.6499 - val_accuracy: 0.9014 - val_top5-acc: 0.9930 - val_Brier score: 209.9700 - val_F1 score: 0.8914 - val_Recall: 0.9930 - val_Precision: 0.2029 - val_AUC: 0.7644 - lr: 5.0000e-04
# Epoch 29/100
# 41/41 [==============================] - 2s 36ms/step - loss: 2.0259 - accuracy: 0.6781 - top5-acc: 0.9798 - Brier score: 129.7900 - F1 score: 0.6766 - Recall: 0.9743 - Precision: 0.2107 - AUC: 0.7701 - val_loss: 0.5890 - val_accuracy: 0.8803 - val_top5-acc: 0.9930 - val_Brier score: 191.5825 - val_F1 score: 0.8675 - val_Recall: 0.9859 - val_Precision: 0.2181 - val_AUC: 0.7900 - lr: 5.0000e-04
# Epoch 30/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.4164 - accuracy: 0.7255 - top5-acc: 0.9837 - Brier score: 122.4639 - F1 score: 0.7267 - Recall: 0.9829 - Precision: 0.2115 - AUC: 0.7722 - val_loss: 0.3646 - val_accuracy: 0.9085 - val_top5-acc: 0.9930 - val_Brier score: 227.9068 - val_F1 score: 0.9018 - val_Recall: 1.0000 - val_Precision: 0.1989 - val_AUC: 0.7579 - lr: 5.0000e-04
# Epoch 31/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.7242 - accuracy: 0.7302 - top5-acc: 0.9813 - Brier score: 160.9002 - F1 score: 0.7295 - Recall: 0.9860 - Precision: 0.1858 - AUC: 0.7340 - val_loss: 0.4875 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 247.6966 - val_F1 score: 0.8422 - val_Recall: 1.0000 - val_Precision: 0.1809 - val_AUC: 0.7254 - lr: 5.0000e-04
# Epoch 32/100
# 41/41 [==============================] - 2s 35ms/step - loss: 1.9517 - accuracy: 0.7006 - top5-acc: 0.9806 - Brier score: 179.1013 - F1 score: 0.7007 - Recall: 0.9930 - Precision: 0.1704 - AUC: 0.7043 - val_loss: 0.7796 - val_accuracy: 0.8592 - val_top5-acc: 0.9930 - val_Brier score: 252.0297 - val_F1 score: 0.8234 - val_Recall: 1.0000 - val_Precision: 0.2006 - val_AUC: 0.7588 - lr: 5.0000e-04
# Epoch 33/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.4188 - accuracy: 0.7434 - top5-acc: 0.9883 - Brier score: 166.6132 - F1 score: 0.7430 - Recall: 0.9922 - Precision: 0.1912 - AUC: 0.7444 - val_loss: 0.1269 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 271.0097 - val_F1 score: 0.9356 - val_Recall: 1.0000 - val_Precision: 0.2188 - val_AUC: 0.7865 - lr: 5.0000e-04
# Epoch 34/100
# 41/41 [==============================] - 2s 37ms/step - loss: 1.5671 - accuracy: 0.7551 - top5-acc: 0.9891 - Brier score: 174.4384 - F1 score: 0.7562 - Recall: 0.9806 - Precision: 0.2170 - AUC: 0.7795 - val_loss: 0.1462 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 314.1057 - val_F1 score: 0.9536 - val_Recall: 1.0000 - val_Precision: 0.2023 - val_AUC: 0.7610 - lr: 5.0000e-04
# Epoch 35/100
# 41/41 [==============================] - 2s 37ms/step - loss: 1.6958 - accuracy: 0.7449 - top5-acc: 0.9829 - Brier score: 179.0584 - F1 score: 0.7444 - Recall: 0.9914 - Precision: 0.1850 - AUC: 0.7318 - val_loss: 0.2227 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 324.2923 - val_F1 score: 0.9246 - val_Recall: 1.0000 - val_Precision: 0.1632 - val_AUC: 0.6901 - lr: 5.0000e-04
# Epoch 36/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.3824 - accuracy: 0.7574 - top5-acc: 0.9868 - Brier score: 172.0295 - F1 score: 0.7574 - Recall: 0.9907 - Precision: 0.1985 - AUC: 0.7549 - val_loss: 0.2302 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 308.1759 - val_F1 score: 0.9079 - val_Recall: 1.0000 - val_Precision: 0.2347 - val_AUC: 0.8050 - lr: 5.0000e-04
# Epoch 37/100
# 41/41 [==============================] - 2s 37ms/step - loss: 1.3481 - accuracy: 0.7846 - top5-acc: 0.9922 - Brier score: 163.3027 - F1 score: 0.7836 - Recall: 0.9907 - Precision: 0.1950 - AUC: 0.7505 - val_loss: 0.1148 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 304.6627 - val_F1 score: 0.9385 - val_Recall: 1.0000 - val_Precision: 0.1762 - val_AUC: 0.7152 - lr: 5.0000e-04
# Epoch 38/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.5390 - accuracy: 0.7652 - top5-acc: 0.9899 - Brier score: 198.4825 - F1 score: 0.7653 - Recall: 0.9868 - Precision: 0.2038 - AUC: 0.7618 - val_loss: 0.3298 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 375.4672 - val_F1 score: 0.8760 - val_Recall: 1.0000 - val_Precision: 0.2058 - val_AUC: 0.7685 - lr: 5.0000e-04
# Epoch 39/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.1970 - accuracy: 0.7854 - top5-acc: 0.9891 - Brier score: 196.6768 - F1 score: 0.7859 - Recall: 0.9946 - Precision: 0.1792 - AUC: 0.7231 - val_loss: 0.2399 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 284.7602 - val_F1 score: 0.9117 - val_Recall: 1.0000 - val_Precision: 0.2110 - val_AUC: 0.7742 - lr: 5.0000e-04
# Epoch 40/100
# 41/41 [==============================] - 2s 36ms/step - loss: 0.9665 - accuracy: 0.8040 - top5-acc: 0.9930 - Brier score: 154.9724 - F1 score: 0.8037 - Recall: 0.9953 - Precision: 0.1945 - AUC: 0.7523 - val_loss: 0.2678 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 259.1242 - val_F1 score: 0.9142 - val_Recall: 1.0000 - val_Precision: 0.2073 - val_AUC: 0.7707 - lr: 5.0000e-04
# Epoch 41/100
# 41/41 [==============================] - 2s 35ms/step - loss: 1.1931 - accuracy: 0.7893 - top5-acc: 0.9914 - Brier score: 139.3005 - F1 score: 0.7884 - Recall: 0.9891 - Precision: 0.2164 - AUC: 0.7828 - val_loss: 0.4314 - val_accuracy: 0.8944 - val_top5-acc: 1.0000 - val_Brier score: 289.1060 - val_F1 score: 0.8746 - val_Recall: 1.0000 - val_Precision: 0.2011 - val_AUC: 0.7610 - lr: 5.0000e-04
# Epoch 42/100
# 41/41 [==============================] - 2s 36ms/step - loss: 1.5967 - accuracy: 0.7449 - top5-acc: 0.9891 - Brier score: 193.1552 - F1 score: 0.7454 - Recall: 0.9891 - Precision: 0.2216 - AUC: 0.7874 - val_loss: 0.4040 - val_accuracy: 0.8944 - val_top5-acc: 1.0000 - val_Brier score: 358.8172 - val_F1 score: 0.8698 - val_Recall: 1.0000 - val_Precision: 0.2279 - val_AUC: 0.7993 - lr: 5.0000e-04
# Epoch 43/100
# 41/41 [==============================] - 2s 36ms/step - loss: 0.8655 - accuracy: 0.8173 - top5-acc: 0.9938 - Brier score: 161.0909 - F1 score: 0.8170 - Recall: 0.9907 - Precision: 0.2298 - AUC: 0.7984 - val_loss: 0.2544 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 330.3336 - val_F1 score: 0.9129 - val_Recall: 1.0000 - val_Precision: 0.2320 - val_AUC: 0.8037 - lr: 2.5000e-04
# Epoch 44/100
# 41/41 [==============================] - 2s 37ms/step - loss: 0.6850 - accuracy: 0.8289 - top5-acc: 0.9969 - Brier score: 144.5068 - F1 score: 0.8286 - Recall: 0.9946 - Precision: 0.2352 - AUC: 0.8069 - val_loss: 0.1302 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 280.5113 - val_F1 score: 0.9565 - val_Recall: 1.0000 - val_Precision: 0.2309 - val_AUC: 0.8033 - lr: 2.5000e-04
# Epoch 45/100
# 41/41 [==============================] - 2s 36ms/step - loss: 0.4259 - accuracy: 0.8841 - top5-acc: 0.9977 - Brier score: 134.1328 - F1 score: 0.8842 - Recall: 0.9961 - Precision: 0.2463 - AUC: 0.8190 - val_loss: 0.1772 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 267.1002 - val_F1 score: 0.9335 - val_Recall: 1.0000 - val_Precision: 0.2363 - val_AUC: 0.8063 - lr: 2.5000e-04
# Epoch 46/100
# 41/41 [==============================] - 2s 36ms/step - loss: 0.7199 - accuracy: 0.8390 - top5-acc: 0.9922 - Brier score: 131.7067 - F1 score: 0.8393 - Recall: 0.9907 - Precision: 0.2283 - AUC: 0.7987 - val_loss: 0.1601 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 232.9966 - val_F1 score: 0.9372 - val_Recall: 1.0000 - val_Precision: 0.2276 - val_AUC: 0.7971 - lr: 2.5000e-04
# Epoch 47/100
# 41/41 [==============================] - 2s 36ms/step - loss: 0.5743 - accuracy: 0.8678 - top5-acc: 0.9946 - Brier score: 129.6380 - F1 score: 0.8682 - Recall: 0.9977 - Precision: 0.2140 - AUC: 0.7812 - val_loss: 0.1497 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 231.2724 - val_F1 score: 0.9480 - val_Recall: 1.0000 - val_Precision: 0.2097 - val_AUC: 0.7724 - lr: 2.5000e-04

# %%
plot_training_curves(history_DiagnosticMLP, 'DiagnosticMLP for Computed Tomography of the Abdomen')

# %% [markdown]
# ---

# %% [markdown]
# # 🟨 Comparison: CT of the Abdomen

# %%
def run_experiment_2(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=50,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %%
history_mlpmixer_ = run_experiment_2(mlpmixer_classifier)
history_fnet_ = run_experiment_2(fnet_classifier)
history_gmlp_ = run_experiment_2(gmlp_classifier)
history_resmlp_ = run_experiment_2(resmlp)
history_DiagnosticMLP_ = run_experiment_2(DiagnosticMLP_classifier)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 12s 57ms/step - loss: 48.0166 - accuracy: 0.1143 - top5-acc: 0.5358 - Brier score: 2678.0815 - F1 score: 0.1132 - Recall: 0.7613 - Precision: 0.1092 - AUC: 0.4924 - val_loss: 11.8827 - val_accuracy: 0.1549 - val_top5-acc: 0.5915 - val_Brier score: 106.8057 - val_F1 score: 0.0398 - val_Recall: 0.8803 - val_Precision: 0.1223 - val_AUC: 0.5502 - lr: 0.0010
# Epoch 2/50
# 41/41 [==============================] - 1s 26ms/step - loss: 9.3306 - accuracy: 0.1485 - top5-acc: 0.6019 - Brier score: 91.0458 - F1 score: 0.1488 - Recall: 0.6229 - Precision: 0.1206 - AUC: 0.5297 - val_loss: 5.6154 - val_accuracy: 0.1972 - val_top5-acc: 0.6831 - val_Brier score: 21.6076 - val_F1 score: 0.0883 - val_Recall: 0.5211 - val_Precision: 0.1291 - val_AUC: 0.5478 - lr: 0.0010
# Epoch 3/50
# 41/41 [==============================] - 1s 26ms/step - loss: 3.5266 - accuracy: 0.2302 - top5-acc: 0.7146 - Brier score: 9.2983 - F1 score: 0.2237 - Recall: 0.6034 - Precision: 0.1558 - AUC: 0.6103 - val_loss: 3.1479 - val_accuracy: 0.2113 - val_top5-acc: 0.8310 - val_Brier score: 11.2591 - val_F1 score: 0.1692 - val_Recall: 0.6620 - val_Precision: 0.1926 - val_AUC: 0.6722 - lr: 0.0010
# Epoch 4/50
# 41/41 [==============================] - 1s 26ms/step - loss: 3.0208 - accuracy: 0.2418 - top5-acc: 0.7636 - Brier score: 7.7970 - F1 score: 0.2414 - Recall: 0.6011 - Precision: 0.1663 - AUC: 0.6353 - val_loss: 2.6243 - val_accuracy: 0.2676 - val_top5-acc: 0.8310 - val_Brier score: 9.8312 - val_F1 score: 0.2292 - val_Recall: 0.5986 - val_Precision: 0.2094 - val_AUC: 0.6772 - lr: 0.0010
# Epoch 5/50
# 41/41 [==============================] - 1s 26ms/step - loss: 2.5636 - accuracy: 0.2986 - top5-acc: 0.7963 - Brier score: 7.1386 - F1 score: 0.2953 - Recall: 0.6687 - Precision: 0.1841 - AUC: 0.6684 - val_loss: 1.8400 - val_accuracy: 0.3662 - val_top5-acc: 0.9225 - val_Brier score: 11.3994 - val_F1 score: 0.3305 - val_Recall: 0.7606 - val_Precision: 0.2085 - val_AUC: 0.7253 - lr: 0.0010
# Epoch 6/50
# 41/41 [==============================] - 1s 26ms/step - loss: 2.2427 - accuracy: 0.3336 - top5-acc: 0.8445 - Brier score: 7.1430 - F1 score: 0.3306 - Recall: 0.7232 - Precision: 0.2036 - AUC: 0.7107 - val_loss: 1.8448 - val_accuracy: 0.4296 - val_top5-acc: 0.8521 - val_Brier score: 13.0544 - val_F1 score: 0.3974 - val_Recall: 0.7535 - val_Precision: 0.2094 - val_AUC: 0.7209 - lr: 0.0010
# Epoch 7/50
# 41/41 [==============================] - 1s 26ms/step - loss: 2.0849 - accuracy: 0.3694 - top5-acc: 0.8802 - Brier score: 7.4097 - F1 score: 0.3693 - Recall: 0.7613 - Precision: 0.2091 - AUC: 0.7249 - val_loss: 1.9835 - val_accuracy: 0.4437 - val_top5-acc: 0.9225 - val_Brier score: 13.6194 - val_F1 score: 0.3397 - val_Recall: 0.6197 - val_Precision: 0.2418 - val_AUC: 0.7205 - lr: 0.0010
# Epoch 8/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.9291 - accuracy: 0.4036 - top5-acc: 0.8974 - Brier score: 7.5122 - F1 score: 0.3972 - Recall: 0.7986 - Precision: 0.2173 - AUC: 0.7462 - val_loss: 2.7586 - val_accuracy: 0.3380 - val_top5-acc: 0.8380 - val_Brier score: 22.0572 - val_F1 score: 0.2185 - val_Recall: 0.7324 - val_Precision: 0.1818 - val_AUC: 0.6862 - lr: 0.0010
# Epoch 9/50
# 41/41 [==============================] - 1s 30ms/step - loss: 1.7123 - accuracy: 0.4565 - top5-acc: 0.9207 - Brier score: 7.4031 - F1 score: 0.4535 - Recall: 0.8429 - Precision: 0.2133 - AUC: 0.7555 - val_loss: 1.9029 - val_accuracy: 0.4648 - val_top5-acc: 0.8944 - val_Brier score: 14.6027 - val_F1 score: 0.3872 - val_Recall: 0.7887 - val_Precision: 0.2063 - val_AUC: 0.7260 - lr: 0.0010
# Epoch 10/50
# 41/41 [==============================] - 1s 28ms/step - loss: 1.8861 - accuracy: 0.4300 - top5-acc: 0.9184 - Brier score: 9.2796 - F1 score: 0.4279 - Recall: 0.8507 - Precision: 0.2136 - AUC: 0.7550 - val_loss: 2.1177 - val_accuracy: 0.4507 - val_top5-acc: 0.9507 - val_Brier score: 21.0308 - val_F1 score: 0.3960 - val_Recall: 0.9155 - val_Precision: 0.1943 - val_AUC: 0.7399 - lr: 0.0010
# Epoch 11/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.6173 - accuracy: 0.4798 - top5-acc: 0.9277 - Brier score: 8.4484 - F1 score: 0.4738 - Recall: 0.8958 - Precision: 0.2120 - AUC: 0.7692 - val_loss: 1.3473 - val_accuracy: 0.4859 - val_top5-acc: 0.9648 - val_Brier score: 14.5601 - val_F1 score: 0.4118 - val_Recall: 0.8592 - val_Precision: 0.2276 - val_AUC: 0.7783 - lr: 5.0000e-04
# Epoch 12/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.4171 - accuracy: 0.5358 - top5-acc: 0.9386 - Brier score: 7.5899 - F1 score: 0.5349 - Recall: 0.8880 - Precision: 0.2314 - AUC: 0.7927 - val_loss: 1.2946 - val_accuracy: 0.5070 - val_top5-acc: 0.9648 - val_Brier score: 14.1039 - val_F1 score: 0.4491 - val_Recall: 0.9155 - val_Precision: 0.2434 - val_AUC: 0.8077 - lr: 5.0000e-04
# Epoch 13/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3493 - accuracy: 0.5443 - top5-acc: 0.9557 - Brier score: 8.0508 - F1 score: 0.5414 - Recall: 0.9082 - Precision: 0.2269 - AUC: 0.7939 - val_loss: 1.1048 - val_accuracy: 0.6268 - val_top5-acc: 0.9718 - val_Brier score: 14.6684 - val_F1 score: 0.5933 - val_Recall: 0.9296 - val_Precision: 0.2361 - val_AUC: 0.7979 - lr: 5.0000e-04
# Epoch 14/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3516 - accuracy: 0.5404 - top5-acc: 0.9495 - Brier score: 8.0035 - F1 score: 0.5373 - Recall: 0.9106 - Precision: 0.2229 - AUC: 0.7902 - val_loss: 0.9300 - val_accuracy: 0.5986 - val_top5-acc: 0.9930 - val_Brier score: 15.1565 - val_F1 score: 0.5407 - val_Recall: 0.9437 - val_Precision: 0.2509 - val_AUC: 0.8290 - lr: 5.0000e-04
# Epoch 15/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.3161 - accuracy: 0.5451 - top5-acc: 0.9681 - Brier score: 9.1333 - F1 score: 0.5406 - Recall: 0.9308 - Precision: 0.2274 - AUC: 0.7989 - val_loss: 1.0352 - val_accuracy: 0.6408 - val_top5-acc: 0.9930 - val_Brier score: 14.3481 - val_F1 score: 0.5723 - val_Recall: 0.9507 - val_Precision: 0.2406 - val_AUC: 0.8162 - lr: 5.0000e-04
# Epoch 16/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.3585 - accuracy: 0.5684 - top5-acc: 0.9495 - Brier score: 8.4471 - F1 score: 0.5666 - Recall: 0.9176 - Precision: 0.2215 - AUC: 0.7870 - val_loss: 0.9690 - val_accuracy: 0.6620 - val_top5-acc: 0.9718 - val_Brier score: 14.9366 - val_F1 score: 0.5897 - val_Recall: 0.9507 - val_Precision: 0.2296 - val_AUC: 0.7992 - lr: 5.0000e-04
# Epoch 17/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.2651 - accuracy: 0.5645 - top5-acc: 0.9658 - Brier score: 8.3195 - F1 score: 0.5611 - Recall: 0.9261 - Precision: 0.2358 - AUC: 0.8080 - val_loss: 0.8274 - val_accuracy: 0.6972 - val_top5-acc: 0.9859 - val_Brier score: 15.5261 - val_F1 score: 0.6510 - val_Recall: 0.9507 - val_Precision: 0.2711 - val_AUC: 0.8344 - lr: 5.0000e-04
# Epoch 18/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1321 - accuracy: 0.6050 - top5-acc: 0.9774 - Brier score: 8.4183 - F1 score: 0.6034 - Recall: 0.9456 - Precision: 0.2347 - AUC: 0.8095 - val_loss: 0.9082 - val_accuracy: 0.6620 - val_top5-acc: 0.9930 - val_Brier score: 16.7218 - val_F1 score: 0.6056 - val_Recall: 0.9437 - val_Precision: 0.2633 - val_AUC: 0.8365 - lr: 5.0000e-04
# Epoch 19/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.1877 - accuracy: 0.5925 - top5-acc: 0.9635 - Brier score: 9.1179 - F1 score: 0.5905 - Recall: 0.9285 - Precision: 0.2279 - AUC: 0.8021 - val_loss: 1.0338 - val_accuracy: 0.5704 - val_top5-acc: 0.9930 - val_Brier score: 17.3619 - val_F1 score: 0.4662 - val_Recall: 0.9155 - val_Precision: 0.2500 - val_AUC: 0.8194 - lr: 5.0000e-04
# Epoch 20/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.2454 - accuracy: 0.5863 - top5-acc: 0.9658 - Brier score: 8.8137 - F1 score: 0.5804 - Recall: 0.9292 - Precision: 0.2328 - AUC: 0.8006 - val_loss: 0.6707 - val_accuracy: 0.7676 - val_top5-acc: 1.0000 - val_Brier score: 18.3960 - val_F1 score: 0.7440 - val_Recall: 0.9859 - val_Precision: 0.2369 - val_AUC: 0.8155 - lr: 5.0000e-04
# Epoch 21/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.1423 - accuracy: 0.6073 - top5-acc: 0.9673 - Brier score: 9.0942 - F1 score: 0.6075 - Recall: 0.9471 - Precision: 0.2260 - AUC: 0.8043 - val_loss: 0.7047 - val_accuracy: 0.7113 - val_top5-acc: 1.0000 - val_Brier score: 11.9566 - val_F1 score: 0.6618 - val_Recall: 0.9718 - val_Precision: 0.2777 - val_AUC: 0.8615 - lr: 5.0000e-04
# Epoch 22/50
# 41/41 [==============================] - 1s 28ms/step - loss: 1.1224 - accuracy: 0.6065 - top5-acc: 0.9705 - Brier score: 9.6472 - F1 score: 0.6049 - Recall: 0.9471 - Precision: 0.2309 - AUC: 0.8078 - val_loss: 0.7730 - val_accuracy: 0.7042 - val_top5-acc: 1.0000 - val_Brier score: 15.3478 - val_F1 score: 0.6522 - val_Recall: 0.9718 - val_Precision: 0.2594 - val_AUC: 0.8322 - lr: 5.0000e-04
# Epoch 23/50
# 41/41 [==============================] - 1s 27ms/step - loss: 1.0139 - accuracy: 0.6439 - top5-acc: 0.9782 - Brier score: 9.7166 - F1 score: 0.6405 - Recall: 0.9572 - Precision: 0.2326 - AUC: 0.8137 - val_loss: 0.6813 - val_accuracy: 0.7535 - val_top5-acc: 0.9930 - val_Brier score: 17.6853 - val_F1 score: 0.7352 - val_Recall: 0.9648 - val_Precision: 0.2660 - val_AUC: 0.8353 - lr: 5.0000e-04
# Epoch 24/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0229 - accuracy: 0.6516 - top5-acc: 0.9736 - Brier score: 9.6025 - F1 score: 0.6488 - Recall: 0.9541 - Precision: 0.2385 - AUC: 0.8175 - val_loss: 0.5662 - val_accuracy: 0.7887 - val_top5-acc: 0.9930 - val_Brier score: 16.7891 - val_F1 score: 0.7466 - val_Recall: 0.9789 - val_Precision: 0.2736 - val_AUC: 0.8547 - lr: 5.0000e-04
# Epoch 25/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9646 - accuracy: 0.6656 - top5-acc: 0.9774 - Brier score: 9.7125 - F1 score: 0.6640 - Recall: 0.9448 - Precision: 0.2424 - AUC: 0.8203 - val_loss: 0.6778 - val_accuracy: 0.7324 - val_top5-acc: 1.0000 - val_Brier score: 17.8845 - val_F1 score: 0.7178 - val_Recall: 0.9789 - val_Precision: 0.2430 - val_AUC: 0.8253 - lr: 5.0000e-04
# Epoch 26/50
# 41/41 [==============================] - 1s 26ms/step - loss: 1.0612 - accuracy: 0.6415 - top5-acc: 0.9782 - Brier score: 9.4791 - F1 score: 0.6406 - Recall: 0.9666 - Precision: 0.2338 - AUC: 0.8184 - val_loss: 0.8246 - val_accuracy: 0.6761 - val_top5-acc: 0.9859 - val_Brier score: 18.1016 - val_F1 score: 0.6217 - val_Recall: 0.9648 - val_Precision: 0.2438 - val_AUC: 0.8240 - lr: 5.0000e-04
# Epoch 27/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9703 - accuracy: 0.6586 - top5-acc: 0.9813 - Brier score: 10.0071 - F1 score: 0.6546 - Recall: 0.9596 - Precision: 0.2386 - AUC: 0.8183 - val_loss: 0.6019 - val_accuracy: 0.7817 - val_top5-acc: 1.0000 - val_Brier score: 19.8404 - val_F1 score: 0.7268 - val_Recall: 0.9648 - val_Precision: 0.2500 - val_AUC: 0.8259 - lr: 5.0000e-04
# Epoch 28/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9453 - accuracy: 0.6711 - top5-acc: 0.9852 - Brier score: 10.4215 - F1 score: 0.6678 - Recall: 0.9712 - Precision: 0.2254 - AUC: 0.8082 - val_loss: 0.5271 - val_accuracy: 0.8239 - val_top5-acc: 1.0000 - val_Brier score: 18.5399 - val_F1 score: 0.7979 - val_Recall: 0.9789 - val_Precision: 0.2584 - val_AUC: 0.8372 - lr: 5.0000e-04
# Epoch 29/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.9098 - accuracy: 0.6858 - top5-acc: 0.9790 - Brier score: 11.2457 - F1 score: 0.6831 - Recall: 0.9705 - Precision: 0.2353 - AUC: 0.8201 - val_loss: 0.4718 - val_accuracy: 0.8451 - val_top5-acc: 1.0000 - val_Brier score: 18.1951 - val_F1 score: 0.8109 - val_Recall: 0.9930 - val_Precision: 0.2611 - val_AUC: 0.8473 - lr: 5.0000e-04
# Epoch 30/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.8587 - accuracy: 0.7014 - top5-acc: 0.9829 - Brier score: 11.7870 - F1 score: 0.6994 - Recall: 0.9728 - Precision: 0.2355 - AUC: 0.8167 - val_loss: 0.4589 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 21.4646 - val_F1 score: 0.7843 - val_Recall: 0.9930 - val_Precision: 0.2554 - val_AUC: 0.8380 - lr: 5.0000e-04
# Epoch 31/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.8544 - accuracy: 0.7045 - top5-acc: 0.9876 - Brier score: 12.3640 - F1 score: 0.7027 - Recall: 0.9790 - Precision: 0.2412 - AUC: 0.8249 - val_loss: 0.4560 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 24.6202 - val_F1 score: 0.7895 - val_Recall: 0.9859 - val_Precision: 0.2672 - val_AUC: 0.8409 - lr: 5.0000e-04
# Epoch 32/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.8274 - accuracy: 0.7123 - top5-acc: 0.9891 - Brier score: 12.1982 - F1 score: 0.7107 - Recall: 0.9736 - Precision: 0.2465 - AUC: 0.8304 - val_loss: 0.6143 - val_accuracy: 0.7817 - val_top5-acc: 1.0000 - val_Brier score: 22.8870 - val_F1 score: 0.7256 - val_Recall: 0.9859 - val_Precision: 0.2734 - val_AUC: 0.8524 - lr: 5.0000e-04
# Epoch 33/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.8511 - accuracy: 0.7045 - top5-acc: 0.9868 - Brier score: 12.0968 - F1 score: 0.7014 - Recall: 0.9806 - Precision: 0.2375 - AUC: 0.8226 - val_loss: 0.3769 - val_accuracy: 0.8732 - val_top5-acc: 1.0000 - val_Brier score: 21.4694 - val_F1 score: 0.8372 - val_Recall: 0.9930 - val_Precision: 0.2452 - val_AUC: 0.8324 - lr: 5.0000e-04
# Epoch 34/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7396 - accuracy: 0.7473 - top5-acc: 0.9883 - Brier score: 12.1181 - F1 score: 0.7456 - Recall: 0.9837 - Precision: 0.2341 - AUC: 0.8195 - val_loss: 0.2852 - val_accuracy: 0.9085 - val_top5-acc: 1.0000 - val_Brier score: 20.4083 - val_F1 score: 0.8907 - val_Recall: 1.0000 - val_Precision: 0.2720 - val_AUC: 0.8528 - lr: 5.0000e-04
# Epoch 35/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7690 - accuracy: 0.7278 - top5-acc: 0.9930 - Brier score: 12.4995 - F1 score: 0.7262 - Recall: 0.9673 - Precision: 0.2473 - AUC: 0.8336 - val_loss: 0.3345 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 25.2074 - val_F1 score: 0.8475 - val_Recall: 0.9930 - val_Precision: 0.2831 - val_AUC: 0.8581 - lr: 5.0000e-04
# Epoch 36/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7470 - accuracy: 0.7364 - top5-acc: 0.9922 - Brier score: 14.0878 - F1 score: 0.7337 - Recall: 0.9844 - Precision: 0.2387 - AUC: 0.8234 - val_loss: 0.3202 - val_accuracy: 0.8873 - val_top5-acc: 1.0000 - val_Brier score: 26.7722 - val_F1 score: 0.8634 - val_Recall: 0.9930 - val_Precision: 0.2545 - val_AUC: 0.8309 - lr: 5.0000e-04
# Epoch 37/50
# 41/41 [==============================] - 1s 28ms/step - loss: 0.6999 - accuracy: 0.7481 - top5-acc: 0.9922 - Brier score: 13.8403 - F1 score: 0.7479 - Recall: 0.9790 - Precision: 0.2454 - AUC: 0.8287 - val_loss: 0.2626 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 25.0045 - val_F1 score: 0.9098 - val_Recall: 1.0000 - val_Precision: 0.2784 - val_AUC: 0.8605 - lr: 5.0000e-04
# Epoch 38/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7473 - accuracy: 0.7434 - top5-acc: 0.9938 - Brier score: 13.5384 - F1 score: 0.7425 - Recall: 0.9790 - Precision: 0.2443 - AUC: 0.8299 - val_loss: 0.2710 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 20.5996 - val_F1 score: 0.8489 - val_Recall: 1.0000 - val_Precision: 0.2545 - val_AUC: 0.8407 - lr: 5.0000e-04
# Epoch 39/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.7709 - accuracy: 0.7356 - top5-acc: 0.9876 - Brier score: 13.4036 - F1 score: 0.7346 - Recall: 0.9798 - Precision: 0.2267 - AUC: 0.8095 - val_loss: 0.3773 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 23.9161 - val_F1 score: 0.8425 - val_Recall: 1.0000 - val_Precision: 0.2790 - val_AUC: 0.8539 - lr: 5.0000e-04
# Epoch 40/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6891 - accuracy: 0.7582 - top5-acc: 0.9907 - Brier score: 13.9390 - F1 score: 0.7565 - Recall: 0.9837 - Precision: 0.2397 - AUC: 0.8230 - val_loss: 0.2187 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 25.4264 - val_F1 score: 0.9287 - val_Recall: 1.0000 - val_Precision: 0.2715 - val_AUC: 0.8543 - lr: 5.0000e-04
# Epoch 41/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.6642 - accuracy: 0.7527 - top5-acc: 0.9946 - Brier score: 14.8762 - F1 score: 0.7523 - Recall: 0.9899 - Precision: 0.2390 - AUC: 0.8254 - val_loss: 0.3970 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 29.7739 - val_F1 score: 0.8066 - val_Recall: 1.0000 - val_Precision: 0.2371 - val_AUC: 0.8182 - lr: 5.0000e-04
# Epoch 42/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.5843 - accuracy: 0.7955 - top5-acc: 0.9922 - Brier score: 14.9358 - F1 score: 0.7937 - Recall: 0.9883 - Precision: 0.2347 - AUC: 0.8208 - val_loss: 0.1808 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 26.2709 - val_F1 score: 0.9206 - val_Recall: 1.0000 - val_Precision: 0.2500 - val_AUC: 0.8336 - lr: 5.0000e-04
# Epoch 43/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.5862 - accuracy: 0.8009 - top5-acc: 0.9930 - Brier score: 14.5387 - F1 score: 0.7984 - Recall: 0.9914 - Precision: 0.2434 - AUC: 0.8325 - val_loss: 0.2003 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 22.8936 - val_F1 score: 0.9165 - val_Recall: 1.0000 - val_Precision: 0.2478 - val_AUC: 0.8354 - lr: 5.0000e-04
# Epoch 44/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.5888 - accuracy: 0.7947 - top5-acc: 0.9946 - Brier score: 15.2041 - F1 score: 0.7939 - Recall: 0.9899 - Precision: 0.2390 - AUC: 0.8247 - val_loss: 0.2443 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 25.5318 - val_F1 score: 0.8872 - val_Recall: 1.0000 - val_Precision: 0.2834 - val_AUC: 0.8644 - lr: 5.0000e-04
# Epoch 45/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.7034 - accuracy: 0.7574 - top5-acc: 0.9891 - Brier score: 14.7767 - F1 score: 0.7559 - Recall: 0.9821 - Precision: 0.2412 - AUC: 0.8250 - val_loss: 0.3005 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 24.8888 - val_F1 score: 0.8850 - val_Recall: 1.0000 - val_Precision: 0.2840 - val_AUC: 0.8627 - lr: 5.0000e-04
# Epoch 46/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.6034 - accuracy: 0.7908 - top5-acc: 0.9953 - Brier score: 17.2472 - F1 score: 0.7899 - Recall: 0.9907 - Precision: 0.2404 - AUC: 0.8238 - val_loss: 0.1869 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 24.9798 - val_F1 score: 0.9248 - val_Recall: 1.0000 - val_Precision: 0.2568 - val_AUC: 0.8398 - lr: 5.0000e-04
# Epoch 47/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.6471 - accuracy: 0.7768 - top5-acc: 0.9930 - Brier score: 16.0565 - F1 score: 0.7766 - Recall: 0.9883 - Precision: 0.2376 - AUC: 0.8252 - val_loss: 0.2036 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 22.9356 - val_F1 score: 0.9195 - val_Recall: 1.0000 - val_Precision: 0.3100 - val_AUC: 0.8803 - lr: 5.0000e-04
# Epoch 48/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.5078 - accuracy: 0.8235 - top5-acc: 0.9953 - Brier score: 15.2614 - F1 score: 0.8223 - Recall: 0.9899 - Precision: 0.2610 - AUC: 0.8447 - val_loss: 0.1510 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 25.3409 - val_F1 score: 0.9511 - val_Recall: 1.0000 - val_Precision: 0.2715 - val_AUC: 0.8521 - lr: 2.5000e-04
# Epoch 49/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.4401 - accuracy: 0.8398 - top5-acc: 0.9992 - Brier score: 15.2522 - F1 score: 0.8387 - Recall: 0.9961 - Precision: 0.2488 - AUC: 0.8367 - val_loss: 0.2011 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 26.4448 - val_F1 score: 0.9255 - val_Recall: 1.0000 - val_Precision: 0.2587 - val_AUC: 0.8393 - lr: 2.5000e-04
# Epoch 50/50
# 41/41 [==============================] - 1s 26ms/step - loss: 0.4811 - accuracy: 0.8250 - top5-acc: 0.9961 - Brier score: 15.7423 - F1 score: 0.8243 - Recall: 0.9914 - Precision: 0.2520 - AUC: 0.8370 - val_loss: 0.2077 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 25.3074 - val_F1 score: 0.8967 - val_Recall: 1.0000 - val_Precision: 0.2644 - val_AUC: 0.8495 - lr: 2.5000e-04
# Epoch 1/50
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 40/41 [============================>.] - ETA: 0s - loss: 2.2311 - accuracy: 0.1539 - top5-acc: 0.6164 - Brier score: 0.3042 - F1 score: 0.1478 - Recall: 0.2875 - Precision: 0.1347 - AUC: 0.5451
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 41/41 [==============================] - 7s 48ms/step - loss: 2.2303 - accuracy: 0.1532 - top5-acc: 0.6174 - Brier score: 0.3036 - F1 score: 0.1470 - Recall: 0.2885 - Precision: 0.1352 - AUC: 0.5457 - val_loss: 2.1337 - val_accuracy: 0.1831 - val_top5-acc: 0.6831 - val_Brier score: 0.1934 - val_F1 score: 0.1120 - val_Recall: 0.3169 - val_Precision: 0.1475 - val_AUC: 0.5983 - lr: 0.0010
# Epoch 2/50
# 41/41 [==============================] - 1s 24ms/step - loss: 2.0735 - accuracy: 0.2208 - top5-acc: 0.7395 - Brier score: 0.2435 - F1 score: 0.2155 - Recall: 0.3499 - Precision: 0.2069 - AUC: 0.6496 - val_loss: 1.8801 - val_accuracy: 0.3521 - val_top5-acc: 0.8944 - val_Brier score: 0.2483 - val_F1 score: 0.1960 - val_Recall: 0.4437 - val_Precision: 0.3043 - val_AUC: 0.7757 - lr: 0.0010
# Epoch 3/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.9807 - accuracy: 0.2675 - top5-acc: 0.7877 - Brier score: 0.5132 - F1 score: 0.2575 - Recall: 0.4806 - Precision: 0.2035 - AUC: 0.6823 - val_loss: 1.7258 - val_accuracy: 0.4155 - val_top5-acc: 0.8662 - val_Brier score: 0.5091 - val_F1 score: 0.3133 - val_Recall: 0.7324 - val_Precision: 0.2633 - val_AUC: 0.7948 - lr: 0.0010
# Epoch 4/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.7767 - accuracy: 0.3235 - top5-acc: 0.8616 - Brier score: 0.9818 - F1 score: 0.3064 - Recall: 0.6866 - Precision: 0.2283 - AUC: 0.7500 - val_loss: 1.5946 - val_accuracy: 0.3944 - val_top5-acc: 0.9014 - val_Brier score: 1.5722 - val_F1 score: 0.2917 - val_Recall: 0.7535 - val_Precision: 0.2530 - val_AUC: 0.8038 - lr: 0.0010
# Epoch 5/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.7356 - accuracy: 0.3258 - top5-acc: 0.8771 - Brier score: 1.6600 - F1 score: 0.3193 - Recall: 0.7481 - Precision: 0.2179 - AUC: 0.7504 - val_loss: 1.4983 - val_accuracy: 0.4366 - val_top5-acc: 0.9155 - val_Brier score: 1.7576 - val_F1 score: 0.3294 - val_Recall: 0.7746 - val_Precision: 0.2771 - val_AUC: 0.8196 - lr: 0.0010
# Epoch 6/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.7074 - accuracy: 0.3577 - top5-acc: 0.8733 - Brier score: 1.7819 - F1 score: 0.3470 - Recall: 0.7193 - Precision: 0.2201 - AUC: 0.7547 - val_loss: 1.3385 - val_accuracy: 0.5000 - val_top5-acc: 0.9507 - val_Brier score: 1.9606 - val_F1 score: 0.4001 - val_Recall: 0.8310 - val_Precision: 0.2206 - val_AUC: 0.8119 - lr: 0.0010
# Epoch 7/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.5971 - accuracy: 0.3740 - top5-acc: 0.9114 - Brier score: 2.1742 - F1 score: 0.3692 - Recall: 0.7869 - Precision: 0.2258 - AUC: 0.7700 - val_loss: 1.3099 - val_accuracy: 0.5141 - val_top5-acc: 0.9296 - val_Brier score: 2.7995 - val_F1 score: 0.4627 - val_Recall: 0.8732 - val_Precision: 0.2589 - val_AUC: 0.8186 - lr: 0.0010
# Epoch 8/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.5868 - accuracy: 0.3888 - top5-acc: 0.8997 - Brier score: 2.4840 - F1 score: 0.3790 - Recall: 0.8056 - Precision: 0.2284 - AUC: 0.7703 - val_loss: 1.3948 - val_accuracy: 0.4718 - val_top5-acc: 0.9366 - val_Brier score: 2.4980 - val_F1 score: 0.3835 - val_Recall: 0.8521 - val_Precision: 0.2642 - val_AUC: 0.8182 - lr: 0.0010
# Epoch 9/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.5827 - accuracy: 0.3981 - top5-acc: 0.9137 - Brier score: 2.4927 - F1 score: 0.3886 - Recall: 0.8157 - Precision: 0.2281 - AUC: 0.7742 - val_loss: 1.3127 - val_accuracy: 0.4577 - val_top5-acc: 0.9718 - val_Brier score: 3.4680 - val_F1 score: 0.3906 - val_Recall: 0.9225 - val_Precision: 0.2310 - val_AUC: 0.8082 - lr: 0.0010
# Epoch 10/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4913 - accuracy: 0.4285 - top5-acc: 0.9370 - Brier score: 2.7097 - F1 score: 0.4188 - Recall: 0.8616 - Precision: 0.2299 - AUC: 0.7922 - val_loss: 1.1408 - val_accuracy: 0.5282 - val_top5-acc: 0.9718 - val_Brier score: 4.4222 - val_F1 score: 0.4684 - val_Recall: 0.9648 - val_Precision: 0.2231 - val_AUC: 0.8232 - lr: 0.0010
# Epoch 11/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.5079 - accuracy: 0.4222 - top5-acc: 0.9269 - Brier score: 3.2025 - F1 score: 0.4150 - Recall: 0.8616 - Precision: 0.2263 - AUC: 0.7809 - val_loss: 1.1566 - val_accuracy: 0.5493 - val_top5-acc: 0.9507 - val_Brier score: 3.2340 - val_F1 score: 0.4730 - val_Recall: 0.9225 - val_Precision: 0.2314 - val_AUC: 0.8221 - lr: 0.0010
# Epoch 12/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4005 - accuracy: 0.4611 - top5-acc: 0.9456 - Brier score: 2.9994 - F1 score: 0.4503 - Recall: 0.8911 - Precision: 0.2241 - AUC: 0.7991 - val_loss: 1.1875 - val_accuracy: 0.5000 - val_top5-acc: 0.9718 - val_Brier score: 4.4063 - val_F1 score: 0.4167 - val_Recall: 0.9437 - val_Precision: 0.2127 - val_AUC: 0.8114 - lr: 0.0010
# Epoch 13/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4454 - accuracy: 0.4401 - top5-acc: 0.9331 - Brier score: 3.7472 - F1 score: 0.4327 - Recall: 0.8981 - Precision: 0.2189 - AUC: 0.7882 - val_loss: 1.3406 - val_accuracy: 0.4789 - val_top5-acc: 0.9718 - val_Brier score: 4.7029 - val_F1 score: 0.3998 - val_Recall: 0.9225 - val_Precision: 0.2096 - val_AUC: 0.7882 - lr: 0.0010
# Epoch 14/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.3521 - accuracy: 0.4876 - top5-acc: 0.9432 - Brier score: 3.6728 - F1 score: 0.4816 - Recall: 0.9020 - Precision: 0.2255 - AUC: 0.8032 - val_loss: 1.1594 - val_accuracy: 0.5704 - val_top5-acc: 0.9437 - val_Brier score: 5.7816 - val_F1 score: 0.5073 - val_Recall: 0.9225 - val_Precision: 0.2116 - val_AUC: 0.7892 - lr: 0.0010
# Epoch 15/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.3992 - accuracy: 0.4611 - top5-acc: 0.9425 - Brier score: 3.8120 - F1 score: 0.4531 - Recall: 0.9121 - Precision: 0.2228 - AUC: 0.7956 - val_loss: 1.0669 - val_accuracy: 0.6549 - val_top5-acc: 0.9648 - val_Brier score: 4.7877 - val_F1 score: 0.5968 - val_Recall: 0.9437 - val_Precision: 0.2428 - val_AUC: 0.8239 - lr: 0.0010
# Epoch 16/50
# 41/41 [==============================] - 1s 25ms/step - loss: 1.2594 - accuracy: 0.5358 - top5-acc: 0.9635 - Brier score: 4.1658 - F1 score: 0.5312 - Recall: 0.9300 - Precision: 0.2306 - AUC: 0.8111 - val_loss: 0.9306 - val_accuracy: 0.7042 - val_top5-acc: 0.9648 - val_Brier score: 6.2646 - val_F1 score: 0.6727 - val_Recall: 0.9577 - val_Precision: 0.2317 - val_AUC: 0.8182 - lr: 0.0010
# Epoch 17/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1788 - accuracy: 0.5653 - top5-acc: 0.9697 - Brier score: 5.0097 - F1 score: 0.5621 - Recall: 0.9440 - Precision: 0.2393 - AUC: 0.8231 - val_loss: 1.0321 - val_accuracy: 0.5775 - val_top5-acc: 0.9859 - val_Brier score: 6.6570 - val_F1 score: 0.5457 - val_Recall: 0.9648 - val_Precision: 0.2264 - val_AUC: 0.8207 - lr: 0.0010
# Epoch 18/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1420 - accuracy: 0.5879 - top5-acc: 0.9627 - Brier score: 5.1685 - F1 score: 0.5858 - Recall: 0.9378 - Precision: 0.2384 - AUC: 0.8181 - val_loss: 1.0018 - val_accuracy: 0.6338 - val_top5-acc: 0.9718 - val_Brier score: 6.6461 - val_F1 score: 0.5709 - val_Recall: 0.9718 - val_Precision: 0.2383 - val_AUC: 0.8174 - lr: 0.0010
# Epoch 19/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.1625 - accuracy: 0.5451 - top5-acc: 0.9673 - Brier score: 4.5646 - F1 score: 0.5415 - Recall: 0.9456 - Precision: 0.2421 - AUC: 0.8252 - val_loss: 1.1237 - val_accuracy: 0.5070 - val_top5-acc: 0.9930 - val_Brier score: 7.5946 - val_F1 score: 0.4534 - val_Recall: 0.9718 - val_Precision: 0.2339 - val_AUC: 0.8392 - lr: 0.0010
# Epoch 20/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0270 - accuracy: 0.6244 - top5-acc: 0.9736 - Brier score: 5.6123 - F1 score: 0.6208 - Recall: 0.9565 - Precision: 0.2364 - AUC: 0.8257 - val_loss: 0.8413 - val_accuracy: 0.6972 - val_top5-acc: 0.9930 - val_Brier score: 9.3423 - val_F1 score: 0.6456 - val_Recall: 0.9859 - val_Precision: 0.2496 - val_AUC: 0.8319 - lr: 0.0010
# Epoch 21/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.0409 - accuracy: 0.6128 - top5-acc: 0.9658 - Brier score: 5.8875 - F1 score: 0.6120 - Recall: 0.9463 - Precision: 0.2375 - AUC: 0.8199 - val_loss: 0.6468 - val_accuracy: 0.7746 - val_top5-acc: 0.9930 - val_Brier score: 7.4942 - val_F1 score: 0.7499 - val_Recall: 0.9859 - val_Precision: 0.2597 - val_AUC: 0.8474 - lr: 0.0010
# Epoch 22/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.0062 - accuracy: 0.6547 - top5-acc: 0.9697 - Brier score: 5.5525 - F1 score: 0.6524 - Recall: 0.9471 - Precision: 0.2462 - AUC: 0.8303 - val_loss: 0.7498 - val_accuracy: 0.7254 - val_top5-acc: 0.9930 - val_Brier score: 7.2865 - val_F1 score: 0.7080 - val_Recall: 0.9789 - val_Precision: 0.2623 - val_AUC: 0.8529 - lr: 0.0010
# Epoch 23/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.9063 - accuracy: 0.6579 - top5-acc: 0.9868 - Brier score: 6.1547 - F1 score: 0.6569 - Recall: 0.9697 - Precision: 0.2547 - AUC: 0.8439 - val_loss: 0.7009 - val_accuracy: 0.7394 - val_top5-acc: 0.9930 - val_Brier score: 10.4575 - val_F1 score: 0.7297 - val_Recall: 0.9859 - val_Precision: 0.2418 - val_AUC: 0.8299 - lr: 0.0010
# Epoch 24/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.0342 - accuracy: 0.6089 - top5-acc: 0.9790 - Brier score: 6.4603 - F1 score: 0.6099 - Recall: 0.9565 - Precision: 0.2439 - AUC: 0.8293 - val_loss: 0.5643 - val_accuracy: 0.8310 - val_top5-acc: 0.9930 - val_Brier score: 8.3106 - val_F1 score: 0.8140 - val_Recall: 0.9859 - val_Precision: 0.2607 - val_AUC: 0.8565 - lr: 0.0010
# Epoch 25/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.8654 - accuracy: 0.6687 - top5-acc: 0.9883 - Brier score: 6.3753 - F1 score: 0.6684 - Recall: 0.9736 - Precision: 0.2562 - AUC: 0.8485 - val_loss: 0.5894 - val_accuracy: 0.7465 - val_top5-acc: 0.9930 - val_Brier score: 9.8606 - val_F1 score: 0.7184 - val_Recall: 0.9859 - val_Precision: 0.2642 - val_AUC: 0.8571 - lr: 0.0010
# Epoch 26/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.8309 - accuracy: 0.6827 - top5-acc: 0.9860 - Brier score: 7.3410 - F1 score: 0.6843 - Recall: 0.9767 - Precision: 0.2604 - AUC: 0.8489 - val_loss: 0.6785 - val_accuracy: 0.7254 - val_top5-acc: 0.9859 - val_Brier score: 11.4844 - val_F1 score: 0.6699 - val_Recall: 0.9789 - val_Precision: 0.2500 - val_AUC: 0.8366 - lr: 0.0010
# Epoch 27/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.8188 - accuracy: 0.7045 - top5-acc: 0.9852 - Brier score: 8.3003 - F1 score: 0.7043 - Recall: 0.9728 - Precision: 0.2508 - AUC: 0.8405 - val_loss: 0.6753 - val_accuracy: 0.7042 - val_top5-acc: 0.9930 - val_Brier score: 13.4057 - val_F1 score: 0.6526 - val_Recall: 0.9930 - val_Precision: 0.2410 - val_AUC: 0.8301 - lr: 0.0010
# Epoch 28/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.8022 - accuracy: 0.6952 - top5-acc: 0.9891 - Brier score: 8.1309 - F1 score: 0.6966 - Recall: 0.9798 - Precision: 0.2455 - AUC: 0.8350 - val_loss: 0.4994 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 12.6316 - val_F1 score: 0.8079 - val_Recall: 0.9930 - val_Precision: 0.2509 - val_AUC: 0.8364 - lr: 0.0010
# Epoch 29/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.7798 - accuracy: 0.7170 - top5-acc: 0.9868 - Brier score: 8.1862 - F1 score: 0.7178 - Recall: 0.9743 - Precision: 0.2507 - AUC: 0.8389 - val_loss: 1.4213 - val_accuracy: 0.5563 - val_top5-acc: 0.9930 - val_Brier score: 9.8488 - val_F1 score: 0.5103 - val_Recall: 0.9577 - val_Precision: 0.2455 - val_AUC: 0.8286 - lr: 0.0010
# Epoch 30/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.8408 - accuracy: 0.6890 - top5-acc: 0.9806 - Brier score: 7.5812 - F1 score: 0.6903 - Recall: 0.9689 - Precision: 0.2467 - AUC: 0.8375 - val_loss: 0.5360 - val_accuracy: 0.8099 - val_top5-acc: 1.0000 - val_Brier score: 11.4813 - val_F1 score: 0.8016 - val_Recall: 1.0000 - val_Precision: 0.2419 - val_AUC: 0.8376 - lr: 0.0010
# Epoch 31/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.7757 - accuracy: 0.7240 - top5-acc: 0.9837 - Brier score: 8.3102 - F1 score: 0.7245 - Recall: 0.9736 - Precision: 0.2517 - AUC: 0.8389 - val_loss: 0.7374 - val_accuracy: 0.7324 - val_top5-acc: 1.0000 - val_Brier score: 11.9425 - val_F1 score: 0.7270 - val_Recall: 1.0000 - val_Precision: 0.2294 - val_AUC: 0.8183 - lr: 0.0010
# Epoch 32/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.7151 - accuracy: 0.7341 - top5-acc: 0.9907 - Brier score: 7.9878 - F1 score: 0.7369 - Recall: 0.9844 - Precision: 0.2524 - AUC: 0.8442 - val_loss: 0.4142 - val_accuracy: 0.8451 - val_top5-acc: 0.9930 - val_Brier score: 10.4109 - val_F1 score: 0.8234 - val_Recall: 0.9930 - val_Precision: 0.2559 - val_AUC: 0.8464 - lr: 0.0010
# Epoch 33/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6575 - accuracy: 0.7543 - top5-acc: 0.9946 - Brier score: 8.9126 - F1 score: 0.7565 - Recall: 0.9907 - Precision: 0.2598 - AUC: 0.8517 - val_loss: 0.5284 - val_accuracy: 0.8099 - val_top5-acc: 1.0000 - val_Brier score: 12.4437 - val_F1 score: 0.7874 - val_Recall: 1.0000 - val_Precision: 0.2518 - val_AUC: 0.8351 - lr: 0.0010
# Epoch 34/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.7013 - accuracy: 0.7403 - top5-acc: 0.9922 - Brier score: 9.3299 - F1 score: 0.7411 - Recall: 0.9876 - Precision: 0.2473 - AUC: 0.8371 - val_loss: 0.6635 - val_accuracy: 0.7394 - val_top5-acc: 0.9859 - val_Brier score: 14.6820 - val_F1 score: 0.7317 - val_Recall: 0.9859 - val_Precision: 0.2341 - val_AUC: 0.8144 - lr: 0.0010
# Epoch 35/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.6286 - accuracy: 0.7745 - top5-acc: 0.9883 - Brier score: 8.6587 - F1 score: 0.7758 - Recall: 0.9829 - Precision: 0.2582 - AUC: 0.8501 - val_loss: 0.3983 - val_accuracy: 0.8662 - val_top5-acc: 0.9930 - val_Brier score: 12.1497 - val_F1 score: 0.8616 - val_Recall: 0.9930 - val_Precision: 0.2474 - val_AUC: 0.8389 - lr: 0.0010
# Epoch 36/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5882 - accuracy: 0.7737 - top5-acc: 0.9938 - Brier score: 9.8518 - F1 score: 0.7759 - Recall: 0.9868 - Precision: 0.2575 - AUC: 0.8484 - val_loss: 0.4000 - val_accuracy: 0.8451 - val_top5-acc: 0.9930 - val_Brier score: 13.1491 - val_F1 score: 0.8162 - val_Recall: 0.9930 - val_Precision: 0.2522 - val_AUC: 0.8435 - lr: 0.0010
# Epoch 37/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5544 - accuracy: 0.7893 - top5-acc: 0.9938 - Brier score: 9.8923 - F1 score: 0.7909 - Recall: 0.9907 - Precision: 0.2632 - AUC: 0.8550 - val_loss: 0.4247 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 12.7548 - val_F1 score: 0.8252 - val_Recall: 1.0000 - val_Precision: 0.2572 - val_AUC: 0.8539 - lr: 0.0010
# Epoch 38/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5788 - accuracy: 0.7908 - top5-acc: 0.9938 - Brier score: 9.9351 - F1 score: 0.7922 - Recall: 0.9899 - Precision: 0.2618 - AUC: 0.8509 - val_loss: 0.4138 - val_accuracy: 0.8592 - val_top5-acc: 0.9930 - val_Brier score: 11.7003 - val_F1 score: 0.8336 - val_Recall: 0.9930 - val_Precision: 0.2776 - val_AUC: 0.8624 - lr: 0.0010
# Epoch 39/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.5828 - accuracy: 0.7994 - top5-acc: 0.9946 - Brier score: 10.5411 - F1 score: 0.8012 - Recall: 0.9899 - Precision: 0.2541 - AUC: 0.8452 - val_loss: 0.4725 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 14.9456 - val_F1 score: 0.8232 - val_Recall: 1.0000 - val_Precision: 0.2509 - val_AUC: 0.8430 - lr: 0.0010
# Epoch 40/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.6219 - accuracy: 0.7854 - top5-acc: 0.9953 - Brier score: 9.8804 - F1 score: 0.7869 - Recall: 0.9821 - Precision: 0.2597 - AUC: 0.8483 - val_loss: 0.3546 - val_accuracy: 0.8451 - val_top5-acc: 1.0000 - val_Brier score: 13.4576 - val_F1 score: 0.8245 - val_Recall: 1.0000 - val_Precision: 0.2483 - val_AUC: 0.8477 - lr: 0.0010
# Epoch 41/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.5128 - accuracy: 0.8243 - top5-acc: 0.9961 - Brier score: 10.2494 - F1 score: 0.8248 - Recall: 0.9891 - Precision: 0.2638 - AUC: 0.8537 - val_loss: 0.6758 - val_accuracy: 0.7183 - val_top5-acc: 1.0000 - val_Brier score: 15.7303 - val_F1 score: 0.7026 - val_Recall: 1.0000 - val_Precision: 0.2478 - val_AUC: 0.8367 - lr: 0.0010
# Epoch 42/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.5730 - accuracy: 0.7877 - top5-acc: 0.9969 - Brier score: 9.9991 - F1 score: 0.7891 - Recall: 0.9907 - Precision: 0.2596 - AUC: 0.8486 - val_loss: 0.3133 - val_accuracy: 0.8662 - val_top5-acc: 1.0000 - val_Brier score: 14.0930 - val_F1 score: 0.8469 - val_Recall: 1.0000 - val_Precision: 0.2518 - val_AUC: 0.8398 - lr: 0.0010
# Epoch 43/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.5200 - accuracy: 0.8087 - top5-acc: 0.9922 - Brier score: 10.3286 - F1 score: 0.8099 - Recall: 0.9891 - Precision: 0.2598 - AUC: 0.8513 - val_loss: 0.4396 - val_accuracy: 0.8592 - val_top5-acc: 0.9930 - val_Brier score: 13.5959 - val_F1 score: 0.8549 - val_Recall: 0.9859 - val_Precision: 0.2513 - val_AUC: 0.8372 - lr: 0.0010
# Epoch 44/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4802 - accuracy: 0.8421 - top5-acc: 0.9984 - Brier score: 10.2199 - F1 score: 0.8438 - Recall: 0.9922 - Precision: 0.2701 - AUC: 0.8591 - val_loss: 0.5358 - val_accuracy: 0.8099 - val_top5-acc: 0.9930 - val_Brier score: 12.3641 - val_F1 score: 0.7928 - val_Recall: 0.9930 - val_Precision: 0.2655 - val_AUC: 0.8438 - lr: 0.0010
# Epoch 45/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4748 - accuracy: 0.8383 - top5-acc: 0.9946 - Brier score: 10.8741 - F1 score: 0.8391 - Recall: 0.9891 - Precision: 0.2603 - AUC: 0.8503 - val_loss: 0.5111 - val_accuracy: 0.8239 - val_top5-acc: 1.0000 - val_Brier score: 16.3419 - val_F1 score: 0.8196 - val_Recall: 1.0000 - val_Precision: 0.2522 - val_AUC: 0.8380 - lr: 0.0010
# Epoch 46/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4401 - accuracy: 0.8375 - top5-acc: 0.9969 - Brier score: 12.0011 - F1 score: 0.8391 - Recall: 0.9938 - Precision: 0.2653 - AUC: 0.8553 - val_loss: 0.4800 - val_accuracy: 0.8099 - val_top5-acc: 0.9930 - val_Brier score: 14.5098 - val_F1 score: 0.7940 - val_Recall: 0.9859 - val_Precision: 0.2578 - val_AUC: 0.8461 - lr: 0.0010
# Epoch 47/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.4839 - accuracy: 0.8320 - top5-acc: 0.9930 - Brier score: 11.1514 - F1 score: 0.8327 - Recall: 0.9922 - Precision: 0.2628 - AUC: 0.8545 - val_loss: 0.4205 - val_accuracy: 0.8451 - val_top5-acc: 0.9930 - val_Brier score: 14.3221 - val_F1 score: 0.8377 - val_Recall: 0.9859 - val_Precision: 0.2496 - val_AUC: 0.8329 - lr: 0.0010
# Epoch 48/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3685 - accuracy: 0.8826 - top5-acc: 0.9953 - Brier score: 11.9154 - F1 score: 0.8834 - Recall: 0.9938 - Precision: 0.2657 - AUC: 0.8555 - val_loss: 0.3438 - val_accuracy: 0.8732 - val_top5-acc: 1.0000 - val_Brier score: 15.7811 - val_F1 score: 0.8635 - val_Recall: 0.9930 - val_Precision: 0.2611 - val_AUC: 0.8498 - lr: 5.0000e-04
# Epoch 49/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3266 - accuracy: 0.8865 - top5-acc: 0.9992 - Brier score: 12.8438 - F1 score: 0.8877 - Recall: 0.9969 - Precision: 0.2700 - AUC: 0.8584 - val_loss: 0.3642 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 19.4244 - val_F1 score: 0.8699 - val_Recall: 1.0000 - val_Precision: 0.2415 - val_AUC: 0.8297 - lr: 5.0000e-04
# Epoch 50/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.3275 - accuracy: 0.8818 - top5-acc: 0.9992 - Brier score: 12.5961 - F1 score: 0.8837 - Recall: 0.9961 - Precision: 0.2692 - AUC: 0.8596 - val_loss: 0.2752 - val_accuracy: 0.9014 - val_top5-acc: 1.0000 - val_Brier score: 16.3241 - val_F1 score: 0.8999 - val_Recall: 1.0000 - val_Precision: 0.2496 - val_AUC: 0.8508 - lr: 5.0000e-04
# Epoch 1/50
# 41/41 [==============================] - 7s 50ms/step - loss: 2.4560 - accuracy: 0.1236 - top5-acc: 0.5692 - Brier score: 0.7439 - F1 score: 0.1221 - Recall: 0.1602 - Precision: 0.1137 - AUC: 0.5017 - val_loss: 2.1934 - val_accuracy: 0.1761 - val_top5-acc: 0.6197 - val_Brier score: 0.4086 - val_F1 score: 0.0665 - val_Recall: 0.2465 - val_Precision: 0.1683 - val_AUC: 0.5595 - lr: 0.0010
# Epoch 2/50
# 41/41 [==============================] - 1s 24ms/step - loss: 2.1538 - accuracy: 0.1812 - top5-acc: 0.6586 - Brier score: 0.4122 - F1 score: 0.1757 - Recall: 0.1835 - Precision: 0.1942 - AUC: 0.5837 - val_loss: 1.8749 - val_accuracy: 0.2254 - val_top5-acc: 0.8521 - val_Brier score: 0.4392 - val_F1 score: 0.1263 - val_Recall: 0.4225 - val_Precision: 0.3000 - val_AUC: 0.7311 - lr: 0.0010
# Epoch 3/50
# 41/41 [==============================] - 1s 24ms/step - loss: 2.0709 - accuracy: 0.2045 - top5-acc: 0.7146 - Brier score: 0.5666 - F1 score: 0.2015 - Recall: 0.3367 - Precision: 0.1933 - AUC: 0.6184 - val_loss: 1.7993 - val_accuracy: 0.2113 - val_top5-acc: 0.8662 - val_Brier score: 1.0598 - val_F1 score: 0.1577 - val_Recall: 0.6620 - val_Precision: 0.2000 - val_AUC: 0.7264 - lr: 0.0010
# Epoch 4/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.9129 - accuracy: 0.2558 - top5-acc: 0.8048 - Brier score: 1.0003 - F1 score: 0.2442 - Recall: 0.5669 - Precision: 0.2070 - AUC: 0.6934 - val_loss: 1.5137 - val_accuracy: 0.4155 - val_top5-acc: 0.9507 - val_Brier score: 1.6785 - val_F1 score: 0.3884 - val_Recall: 0.8521 - val_Precision: 0.2591 - val_AUC: 0.8424 - lr: 0.0010
# Epoch 5/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.7575 - accuracy: 0.3266 - top5-acc: 0.8484 - Brier score: 1.6293 - F1 score: 0.3145 - Recall: 0.7076 - Precision: 0.2041 - AUC: 0.7353 - val_loss: 1.3436 - val_accuracy: 0.4789 - val_top5-acc: 0.9718 - val_Brier score: 2.4360 - val_F1 score: 0.3948 - val_Recall: 0.9648 - val_Precision: 0.2358 - val_AUC: 0.8612 - lr: 0.0010
# Epoch 6/50
# 41/41 [==============================] - 1s 23ms/step - loss: 1.6067 - accuracy: 0.3981 - top5-acc: 0.9044 - Brier score: 2.2890 - F1 score: 0.3868 - Recall: 0.7939 - Precision: 0.2131 - AUC: 0.7642 - val_loss: 1.0772 - val_accuracy: 0.5845 - val_top5-acc: 0.9859 - val_Brier score: 6.2214 - val_F1 score: 0.5408 - val_Recall: 0.9507 - val_Precision: 0.2300 - val_AUC: 0.8185 - lr: 0.0010
# Epoch 7/50
# 41/41 [==============================] - 1s 24ms/step - loss: 1.4600 - accuracy: 0.4168 - top5-acc: 0.9355 - Brier score: 3.5370 - F1 score: 0.4102 - Recall: 0.8686 - Precision: 0.2203 - AUC: 0.7866 - val_loss: 0.9587 - val_accuracy: 0.6479 - val_top5-acc: 0.9930 - val_Brier score: 6.6327 - val_F1 score: 0.6261 - val_Recall: 0.9930 - val_Precision: 0.2386 - val_AUC: 0.8365 - lr: 0.0010
# Epoch 8/50
# 41/41 [==============================] - 1s 25ms/step - loss: 1.4355 - accuracy: 0.4705 - top5-acc: 0.9222 - Brier score: 3.6614 - F1 score: 0.4648 - Recall: 0.8647 - Precision: 0.2310 - AUC: 0.7889 - val_loss: 0.7128 - val_accuracy: 0.7535 - val_top5-acc: 0.9930 - val_Brier score: 7.6384 - val_F1 score: 0.7328 - val_Recall: 0.9859 - val_Precision: 0.2550 - val_AUC: 0.8452 - lr: 0.0010
# Epoch 9/50
# 41/41 [==============================] - 1s 25ms/step - loss: 1.1557 - accuracy: 0.5560 - top5-acc: 0.9712 - Brier score: 5.4198 - F1 score: 0.5467 - Recall: 0.9362 - Precision: 0.2375 - AUC: 0.8213 - val_loss: 0.8013 - val_accuracy: 0.7324 - val_top5-acc: 0.9789 - val_Brier score: 10.6924 - val_F1 score: 0.7209 - val_Recall: 0.9789 - val_Precision: 0.2509 - val_AUC: 0.8433 - lr: 0.0010
# Epoch 10/50
# 41/41 [==============================] - 1s 25ms/step - loss: 1.0697 - accuracy: 0.5925 - top5-acc: 0.9728 - Brier score: 7.2836 - F1 score: 0.5893 - Recall: 0.9533 - Precision: 0.2350 - AUC: 0.8157 - val_loss: 0.9830 - val_accuracy: 0.6761 - val_top5-acc: 0.9648 - val_Brier score: 15.2467 - val_F1 score: 0.5905 - val_Recall: 0.9507 - val_Precision: 0.2235 - val_AUC: 0.7963 - lr: 0.0010
# Epoch 11/50
# ...
# Epoch 12/50
# 41/41 [==============================] - 2s 37ms/step - loss: 6.3114 - accuracy: 0.4642 - top5-acc: 0.8911 - Brier score: 308.2041 - F1 score: 0.4627 - Recall: 0.9588 - Precision: 0.1513 - AUC: 0.6494 - val_loss: 1.0263 - val_accuracy: 0.7887 - val_top5-acc: 1.0000 - val_Brier score: 381.0864 - val_F1 score: 0.7523 - val_Recall: 1.0000 - val_Precision: 0.2104 - val_AUC: 0.7716 - lr: 0.0010
# Epoch 13/50
# 41/41 [==============================] - 2s 36ms/step - loss: 4.9024 - accuracy: 0.5319 - top5-acc: 0.9393 - Brier score: 237.0505 - F1 score: 0.5302 - Recall: 0.9044 - Precision: 0.2047 - AUC: 0.7405 - val_loss: 1.6717 - val_accuracy: 0.6620 - val_top5-acc: 1.0000 - val_Brier score: 375.4712 - val_F1 score: 0.6441 - val_Recall: 1.0000 - val_Precision: 0.2023 - val_AUC: 0.7610 - lr: 0.0010
# Epoch 14/50
# 41/41 [==============================] - 2s 36ms/step - loss: 4.4679 - accuracy: 0.5505 - top5-acc: 0.9456 - Brier score: 240.0514 - F1 score: 0.5489 - Recall: 0.8468 - Precision: 0.2411 - AUC: 0.7635 - val_loss: 2.0389 - val_accuracy: 0.6268 - val_top5-acc: 1.0000 - val_Brier score: 368.1169 - val_F1 score: 0.5848 - val_Recall: 1.0000 - val_Precision: 0.2491 - val_AUC: 0.8173 - lr: 0.0010
# Epoch 15/50
# 41/41 [==============================] - 2s 36ms/step - loss: 5.1707 - accuracy: 0.5210 - top5-acc: 0.9261 - Brier score: 325.8319 - F1 score: 0.5212 - Recall: 0.9650 - Precision: 0.1653 - AUC: 0.6839 - val_loss: 0.8196 - val_accuracy: 0.8451 - val_top5-acc: 0.9930 - val_Brier score: 442.7325 - val_F1 score: 0.8186 - val_Recall: 1.0000 - val_Precision: 0.1760 - val_AUC: 0.7157 - lr: 0.0010
# Epoch 16/50
# 41/41 [==============================] - 2s 36ms/step - loss: 4.0999 - accuracy: 0.5793 - top5-acc: 0.9572 - Brier score: 287.7617 - F1 score: 0.5782 - Recall: 0.9666 - Precision: 0.1788 - AUC: 0.7141 - val_loss: 1.8250 - val_accuracy: 0.7324 - val_top5-acc: 0.9859 - val_Brier score: 604.0887 - val_F1 score: 0.6788 - val_Recall: 1.0000 - val_Precision: 0.1883 - val_AUC: 0.7346 - lr: 0.0010
# Epoch 17/50
# 41/41 [==============================] - 2s 36ms/step - loss: 5.1030 - accuracy: 0.5568 - top5-acc: 0.9355 - Brier score: 346.9708 - F1 score: 0.5564 - Recall: 0.9207 - Precision: 0.1994 - AUC: 0.7369 - val_loss: 0.6091 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 436.0674 - val_F1 score: 0.8236 - val_Recall: 1.0000 - val_Precision: 0.2076 - val_AUC: 0.7694 - lr: 0.0010
# Epoch 18/50
# 41/41 [==============================] - 2s 36ms/step - loss: 3.9987 - accuracy: 0.6042 - top5-acc: 0.9642 - Brier score: 367.2650 - F1 score: 0.6045 - Recall: 0.9806 - Precision: 0.1738 - AUC: 0.7066 - val_loss: 1.1062 - val_accuracy: 0.8099 - val_top5-acc: 0.9930 - val_Brier score: 336.5562 - val_F1 score: 0.7650 - val_Recall: 1.0000 - val_Precision: 0.1951 - val_AUC: 0.7469 - lr: 0.0010
# Epoch 19/50
# 41/41 [==============================] - 2s 37ms/step - loss: 3.5351 - accuracy: 0.6291 - top5-acc: 0.9580 - Brier score: 294.1710 - F1 score: 0.6279 - Recall: 0.9720 - Precision: 0.1827 - AUC: 0.7219 - val_loss: 1.4770 - val_accuracy: 0.7887 - val_top5-acc: 1.0000 - val_Brier score: 485.8964 - val_F1 score: 0.7505 - val_Recall: 1.0000 - val_Precision: 0.2097 - val_AUC: 0.7746 - lr: 0.0010
# Epoch 20/50
# 41/41 [==============================] - 2s 37ms/step - loss: 3.7109 - accuracy: 0.6369 - top5-acc: 0.9627 - Brier score: 331.8432 - F1 score: 0.6341 - Recall: 0.9479 - Precision: 0.2037 - AUC: 0.7506 - val_loss: 0.7451 - val_accuracy: 0.8521 - val_top5-acc: 1.0000 - val_Brier score: 614.5121 - val_F1 score: 0.8034 - val_Recall: 1.0000 - val_Precision: 0.1703 - val_AUC: 0.6994 - lr: 0.0010
# Epoch 21/50
# 41/41 [==============================] - 2s 36ms/step - loss: 2.8894 - accuracy: 0.6734 - top5-acc: 0.9736 - Brier score: 351.1430 - F1 score: 0.6741 - Recall: 0.9821 - Precision: 0.1741 - AUC: 0.7063 - val_loss: 0.4963 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 505.9827 - val_F1 score: 0.8260 - val_Recall: 1.0000 - val_Precision: 0.1980 - val_AUC: 0.7548 - lr: 0.0010
# Epoch 22/50
# 41/41 [==============================] - 2s 36ms/step - loss: 2.7156 - accuracy: 0.6820 - top5-acc: 0.9806 - Brier score: 294.1655 - F1 score: 0.6804 - Recall: 0.9720 - Precision: 0.2062 - AUC: 0.7599 - val_loss: 0.9023 - val_accuracy: 0.8592 - val_top5-acc: 0.9789 - val_Brier score: 493.7924 - val_F1 score: 0.7879 - val_Recall: 0.9507 - val_Precision: 0.2552 - val_AUC: 0.8084 - lr: 0.0010
# Epoch 23/50
# 41/41 [==============================] - 2s 36ms/step - loss: 2.3458 - accuracy: 0.7030 - top5-acc: 0.9736 - Brier score: 329.5583 - F1 score: 0.7021 - Recall: 0.8779 - Precision: 0.2865 - AUC: 0.8099 - val_loss: 0.7909 - val_accuracy: 0.8169 - val_top5-acc: 1.0000 - val_Brier score: 620.4904 - val_F1 score: 0.7831 - val_Recall: 1.0000 - val_Precision: 0.1697 - val_AUC: 0.6989 - lr: 0.0010
# Epoch 24/50
# 41/41 [==============================] - 2s 36ms/step - loss: 2.3828 - accuracy: 0.7131 - top5-acc: 0.9790 - Brier score: 408.3903 - F1 score: 0.7139 - Recall: 0.9922 - Precision: 0.1732 - AUC: 0.7077 - val_loss: 0.7597 - val_accuracy: 0.8451 - val_top5-acc: 1.0000 - val_Brier score: 929.7441 - val_F1 score: 0.8085 - val_Recall: 1.0000 - val_Precision: 0.1972 - val_AUC: 0.7509 - lr: 0.0010
# Epoch 25/50
# 41/41 [==============================] - 2s 35ms/step - loss: 2.6843 - accuracy: 0.6874 - top5-acc: 0.9798 - Brier score: 361.7762 - F1 score: 0.6885 - Recall: 0.9860 - Precision: 0.1871 - AUC: 0.7329 - val_loss: 0.7958 - val_accuracy: 0.8732 - val_top5-acc: 1.0000 - val_Brier score: 782.2336 - val_F1 score: 0.8201 - val_Recall: 1.0000 - val_Precision: 0.1804 - val_AUC: 0.7223 - lr: 0.0010
# Epoch 26/50
# 41/41 [==============================] - 2s 36ms/step - loss: 2.2568 - accuracy: 0.7193 - top5-acc: 0.9852 - Brier score: 322.7866 - F1 score: 0.7187 - Recall: 0.9844 - Precision: 0.1971 - AUC: 0.7491 - val_loss: 1.2688 - val_accuracy: 0.8592 - val_top5-acc: 1.0000 - val_Brier score: 478.3551 - val_F1 score: 0.8159 - val_Recall: 1.0000 - val_Precision: 0.1994 - val_AUC: 0.7562 - lr: 0.0010
# Epoch 27/50
# 41/41 [==============================] - 2s 36ms/step - loss: 1.4169 - accuracy: 0.7815 - top5-acc: 0.9899 - Brier score: 258.4669 - F1 score: 0.7826 - Recall: 0.9914 - Precision: 0.2005 - AUC: 0.7579 - val_loss: 0.6554 - val_accuracy: 0.8803 - val_top5-acc: 1.0000 - val_Brier score: 427.9536 - val_F1 score: 0.8355 - val_Recall: 1.0000 - val_Precision: 0.2411 - val_AUC: 0.8125 - lr: 5.0000e-04
# Epoch 28/50
# 41/41 [==============================] - 2s 37ms/step - loss: 1.1411 - accuracy: 0.8079 - top5-acc: 0.9922 - Brier score: 219.0492 - F1 score: 0.8082 - Recall: 0.9673 - Precision: 0.2751 - AUC: 0.8330 - val_loss: 0.3429 - val_accuracy: 0.9155 - val_top5-acc: 1.0000 - val_Brier score: 435.2928 - val_F1 score: 0.8992 - val_Recall: 1.0000 - val_Precision: 0.2243 - val_AUC: 0.7949 - lr: 5.0000e-04
# Epoch 29/50
# 41/41 [==============================] - 2s 37ms/step - loss: 1.0748 - accuracy: 0.8040 - top5-acc: 0.9922 - Brier score: 209.0238 - F1 score: 0.8044 - Recall: 0.9813 - Precision: 0.2419 - AUC: 0.8095 - val_loss: 0.2016 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 430.8429 - val_F1 score: 0.9476 - val_Recall: 1.0000 - val_Precision: 0.1951 - val_AUC: 0.7544 - lr: 5.0000e-04
# Epoch 30/50
# 41/41 [==============================] - 2s 36ms/step - loss: 1.0035 - accuracy: 0.8173 - top5-acc: 0.9914 - Brier score: 243.4143 - F1 score: 0.8178 - Recall: 0.9961 - Precision: 0.1812 - AUC: 0.7264 - val_loss: 0.3709 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 423.2855 - val_F1 score: 0.8986 - val_Recall: 1.0000 - val_Precision: 0.1823 - val_AUC: 0.7227 - lr: 5.0000e-04
# Epoch 31/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.9438 - accuracy: 0.8250 - top5-acc: 0.9922 - Brier score: 208.1612 - F1 score: 0.8251 - Recall: 0.9946 - Precision: 0.2111 - AUC: 0.7750 - val_loss: 0.2076 - val_accuracy: 0.9507 - val_top5-acc: 1.0000 - val_Brier score: 354.0117 - val_F1 score: 0.9425 - val_Recall: 1.0000 - val_Precision: 0.2339 - val_AUC: 0.8055 - lr: 5.0000e-04
# Epoch 32/50
# 41/41 [==============================] - 2s 36ms/step - loss: 1.0317 - accuracy: 0.8266 - top5-acc: 0.9914 - Brier score: 213.5108 - F1 score: 0.8265 - Recall: 0.9907 - Precision: 0.2136 - AUC: 0.7776 - val_loss: 0.1946 - val_accuracy: 0.9296 - val_top5-acc: 1.0000 - val_Brier score: 386.2017 - val_F1 score: 0.9176 - val_Recall: 1.0000 - val_Precision: 0.2113 - val_AUC: 0.7768 - lr: 5.0000e-04
# Epoch 33/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.9148 - accuracy: 0.8274 - top5-acc: 0.9961 - Brier score: 233.2980 - F1 score: 0.8275 - Recall: 0.9969 - Precision: 0.1767 - AUC: 0.7186 - val_loss: 0.2357 - val_accuracy: 0.9366 - val_top5-acc: 1.0000 - val_Brier score: 382.9829 - val_F1 score: 0.9148 - val_Recall: 1.0000 - val_Precision: 0.1861 - val_AUC: 0.7359 - lr: 5.0000e-04
# Epoch 34/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.9260 - accuracy: 0.8204 - top5-acc: 0.9938 - Brier score: 248.4471 - F1 score: 0.8206 - Recall: 0.9977 - Precision: 0.1665 - AUC: 0.6968 - val_loss: 0.1404 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 399.7021 - val_F1 score: 0.9719 - val_Recall: 1.0000 - val_Precision: 0.1723 - val_AUC: 0.7051 - lr: 5.0000e-04
# Epoch 35/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.9115 - accuracy: 0.8219 - top5-acc: 0.9922 - Brier score: 201.6752 - F1 score: 0.8228 - Recall: 0.9922 - Precision: 0.1907 - AUC: 0.7439 - val_loss: 0.1977 - val_accuracy: 0.9225 - val_top5-acc: 1.0000 - val_Brier score: 322.0448 - val_F1 score: 0.9177 - val_Recall: 1.0000 - val_Precision: 0.2276 - val_AUC: 0.7997 - lr: 5.0000e-04
# Epoch 36/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.9102 - accuracy: 0.8188 - top5-acc: 0.9938 - Brier score: 201.4859 - F1 score: 0.8187 - Recall: 0.9938 - Precision: 0.2135 - AUC: 0.7795 - val_loss: 0.0885 - val_accuracy: 0.9859 - val_top5-acc: 1.0000 - val_Brier score: 325.2845 - val_F1 score: 0.9835 - val_Recall: 1.0000 - val_Precision: 0.2419 - val_AUC: 0.8151 - lr: 5.0000e-04
# Epoch 37/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.6118 - accuracy: 0.8546 - top5-acc: 0.9946 - Brier score: 176.0154 - F1 score: 0.8550 - Recall: 0.9899 - Precision: 0.2448 - AUC: 0.8145 - val_loss: 0.1024 - val_accuracy: 0.9789 - val_top5-acc: 1.0000 - val_Brier score: 278.6266 - val_F1 score: 0.9723 - val_Recall: 1.0000 - val_Precision: 0.2313 - val_AUC: 0.8041 - lr: 5.0000e-04
# Epoch 38/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.8930 - accuracy: 0.8227 - top5-acc: 0.9930 - Brier score: 195.5610 - F1 score: 0.8225 - Recall: 0.9914 - Precision: 0.1993 - AUC: 0.7567 - val_loss: 0.1204 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 296.2064 - val_F1 score: 0.9702 - val_Recall: 1.0000 - val_Precision: 0.1924 - val_AUC: 0.7456 - lr: 5.0000e-04
# Epoch 39/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.7737 - accuracy: 0.8344 - top5-acc: 0.9977 - Brier score: 185.4520 - F1 score: 0.8347 - Recall: 0.9946 - Precision: 0.2252 - AUC: 0.7943 - val_loss: 0.0932 - val_accuracy: 0.9859 - val_top5-acc: 1.0000 - val_Brier score: 271.7853 - val_F1 score: 0.9825 - val_Recall: 1.0000 - val_Precision: 0.2347 - val_AUC: 0.8068 - lr: 5.0000e-04
# Epoch 40/50
# 41/41 [==============================] - 2s 35ms/step - loss: 0.6719 - accuracy: 0.8569 - top5-acc: 0.9938 - Brier score: 166.4370 - F1 score: 0.8574 - Recall: 0.9953 - Precision: 0.2020 - AUC: 0.7637 - val_loss: 0.1200 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 267.8572 - val_F1 score: 0.9508 - val_Recall: 1.0000 - val_Precision: 0.1919 - val_AUC: 0.7434 - lr: 5.0000e-04
# Epoch 41/50
# 41/41 [==============================] - 2s 35ms/step - loss: 0.6219 - accuracy: 0.8507 - top5-acc: 0.9938 - Brier score: 168.9878 - F1 score: 0.8510 - Recall: 0.9984 - Precision: 0.1850 - AUC: 0.7364 - val_loss: 0.2148 - val_accuracy: 0.9437 - val_top5-acc: 1.0000 - val_Brier score: 257.4677 - val_F1 score: 0.9278 - val_Recall: 1.0000 - val_Precision: 0.2014 - val_AUC: 0.7680 - lr: 5.0000e-04
# Epoch 42/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.4452 - accuracy: 0.8865 - top5-acc: 0.9977 - Brier score: 151.2720 - F1 score: 0.8860 - Recall: 0.9984 - Precision: 0.2057 - AUC: 0.7704 - val_loss: 0.0610 - val_accuracy: 0.9789 - val_top5-acc: 1.0000 - val_Brier score: 226.1713 - val_F1 score: 0.9766 - val_Recall: 1.0000 - val_Precision: 0.2126 - val_AUC: 0.7795 - lr: 2.5000e-04
# Epoch 43/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.5789 - accuracy: 0.8771 - top5-acc: 0.9961 - Brier score: 128.9901 - F1 score: 0.8747 - Recall: 0.9946 - Precision: 0.2063 - AUC: 0.7713 - val_loss: 0.1237 - val_accuracy: 0.9577 - val_top5-acc: 1.0000 - val_Brier score: 224.7480 - val_F1 score: 0.9443 - val_Recall: 1.0000 - val_Precision: 0.2067 - val_AUC: 0.7746 - lr: 2.5000e-04
# Epoch 44/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.4335 - accuracy: 0.8701 - top5-acc: 0.9969 - Brier score: 118.7698 - F1 score: 0.8709 - Recall: 0.9984 - Precision: 0.2040 - AUC: 0.7707 - val_loss: 0.0807 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 212.6403 - val_F1 score: 0.9676 - val_Recall: 1.0000 - val_Precision: 0.1951 - val_AUC: 0.7540 - lr: 2.5000e-04
# Epoch 45/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.4576 - accuracy: 0.8764 - top5-acc: 0.9946 - Brier score: 118.7028 - F1 score: 0.8759 - Recall: 0.9977 - Precision: 0.2111 - AUC: 0.7785 - val_loss: 0.0625 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 201.6142 - val_F1 score: 0.9682 - val_Recall: 1.0000 - val_Precision: 0.2229 - val_AUC: 0.7962 - lr: 2.5000e-04
# Epoch 46/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.4299 - accuracy: 0.8834 - top5-acc: 0.9977 - Brier score: 113.2527 - F1 score: 0.8836 - Recall: 0.9969 - Precision: 0.2292 - AUC: 0.8040 - val_loss: 0.1152 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 195.9656 - val_F1 score: 0.9645 - val_Recall: 1.0000 - val_Precision: 0.2276 - val_AUC: 0.7967 - lr: 2.5000e-04
# Epoch 47/50
# 41/41 [==============================] - 2s 37ms/step - loss: 0.3804 - accuracy: 0.8911 - top5-acc: 0.9984 - Brier score: 105.9150 - F1 score: 0.8913 - Recall: 0.9969 - Precision: 0.2142 - AUC: 0.7852 - val_loss: 0.0653 - val_accuracy: 0.9789 - val_top5-acc: 1.0000 - val_Brier score: 202.4543 - val_F1 score: 0.9796 - val_Recall: 1.0000 - val_Precision: 0.1888 - val_AUC: 0.7443 - lr: 2.5000e-04
# Epoch 48/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.3855 - accuracy: 0.8935 - top5-acc: 0.9992 - Brier score: 107.2151 - F1 score: 0.8934 - Recall: 1.0000 - Precision: 0.1851 - AUC: 0.7403 - val_loss: 0.0706 - val_accuracy: 0.9789 - val_top5-acc: 1.0000 - val_Brier score: 189.8503 - val_F1 score: 0.9784 - val_Recall: 1.0000 - val_Precision: 0.1861 - val_AUC: 0.7381 - lr: 1.2500e-04
# Epoch 49/50
# 41/41 [==============================] - 2s 36ms/step - loss: 0.3085 - accuracy: 0.9067 - top5-acc: 0.9992 - Brier score: 105.3023 - F1 score: 0.9072 - Recall: 0.9992 - Precision: 0.1836 - AUC: 0.7365 - val_loss: 0.0864 - val_accuracy: 0.9718 - val_top5-acc: 1.0000 - val_Brier score: 172.6582 - val_F1 score: 0.9654 - val_Recall: 1.0000 - val_Precision: 0.1919 - val_AUC: 0.7531 - lr: 1.2500e-04
# Epoch 50/50
# 41/41 [==============================] - 2s 39ms/step - loss: 0.3224 - accuracy: 0.9145 - top5-acc: 0.9984 - Brier score: 91.2918 - F1 score: 0.9142 - Recall: 1.0000 - Precision: 0.1986 - AUC: 0.7637 - val_loss: 0.0756 - val_accuracy: 0.9648 - val_top5-acc: 1.0000 - val_Brier score: 168.2819 - val_F1 score: 0.9616 - val_Recall: 1.0000 - val_Precision: 0.1972 - val_AUC: 0.7584 - lr: 1.2500e-04

# %%
def plot_comparison_curves(history_mlpmixer_, history_fnet_, history_gmlp_, history_resmlp_, history_DiagnosticMLP_):
    epochs = range(len(history_mlpmixer_.history['loss']))
    loss_1 = np.array(history_mlpmixer_.history['val_loss'])
    loss_2 = np.array(history_fnet_.history['val_loss'])
    loss_3 = np.array(history_gmlp_.history['val_loss'])
    loss_4 = np.array(history_resmlp_.history['val_loss'])
    loss_5 = np.array(history_DiagnosticMLP_.history['val_loss'])

    accuracy_1 = np.array(history_mlpmixer_.history['val_accuracy'])
    accuracy_2 = np.array(history_fnet_.history['val_accuracy'])
    accuracy_3 = np.array(history_gmlp_.history['val_accuracy'])
    accuracy_4 = np.array(history_resmlp_.history['val_accuracy'])
    accuracy_5 = np.array(history_DiagnosticMLP_.history['val_accuracy'])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    #plt.style.use('ggplot')
    plt.style.use('seaborn-whitegrid')

    # Plot loss
    ax1.plot(epochs, loss_1, label='MLP-Mixer', marker='.', )
    ax1.plot(epochs, loss_2, label='FNet', marker='.', )
    ax1.plot(epochs, loss_3, label='gMLP', marker='.', )
    ax1.plot(epochs, loss_4, label='ResMLP', marker='.', )
    ax1.plot(epochs, loss_5, label='DiagnosticMLP', marker='.', )

    ax1.set_title('Loss Comparison - CT of the Abdomen', fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10, borderaxespad=1, frameon=True)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy_1, label='MLP-Mixer', marker='.')
    ax2.plot(epochs, accuracy_2, label='FNet', marker='.')
    ax2.plot(epochs, accuracy_3, label='gMLP', marker='.')
    ax2.plot(epochs, accuracy_4, label='ResMLP', marker='.')
    ax2.plot(epochs, accuracy_5, label='DiagnosticMLP', marker='.')

    ax2.set_title('Accuracy Comparison - CT of the Abdomen', fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10, borderaxespad=1, frameon=True)

# %%
plot_comparison_curves(history_mlpmixer_, history_fnet_, history_gmlp_, history_resmlp_, history_DiagnosticMLP_)
# Out:
# <ipython-input-28-534b26427113>:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
