# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/DiagnosticMLP/blob/main/Transfomer_vs_DiagnosticMLP_Abdomen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟨 DiagnosticMLP versus Transfomer Architectures: CT Image classification - Computed Tomography (CT) of the Abdomen

# %%
# !pip install nest_asyncio
# !pip install -U -q tensorflow-addons
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 12.7 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math
import nest_asyncio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ---
#
# ## 🟡 plot_training_curves

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(len(history.history['loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('bmh') #ggplot #bmh
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10)

# %% [markdown]
# ## 🟡 Hyperparameters

# %%
path = '/content/drive/MyDrive/_MyResearch_/CT_Datasets/Computed Tomography (CT) of the Abdomen/'

image_size = 64 # We'll resize input images to this size.
patch_size = 256
input_shape = (64, 64, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
label_smoothing = 0.1

patch_size = 2  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2
num_transformer_blocks = 8  # Number of repetitions of the transformer layer

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 2 X 2 = 4
# Patches per image: 1024
# Elements per patch (3 channels): 12

# %% [markdown]
# ## 🟡 Dataset

# %%
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1428 files belonging to 9 classes.
# Using 1286 files for training.
# Found 1428 files belonging to 9 classes.
# Using 142 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
##################
num_classes = len(class_names)
##################
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(num_classes): classes.append(i)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# ['abdominal_aorta_dilatation', 'aneurysmal_dilatation_of_aorta', 'aortic_aneurysm', 'cancer', 'formation_of_adrenal_gland', 'kidney_development', 'liver_formation', 'urolithiasis', 'vertebral_compression_fracture']
# {0: 1.1581508515815084,
#  1: 1.017094017094017,
#  2: 0.9558232931726908,
#  3: 0.9500998003992016,
#  4: 1.0507726269315674,
#  5: 1.0042194092827004,
#  6: 0.9855072463768116,
#  7: 0.8766114180478821,
#  8: 1.0507726269315674}

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 🟡 Experiment
# We implement a utility function to compile, train, and evaluate a given model.

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# ## 🟡 Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip('horizontal_and_vertical'),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
        layers.RandomContrast(factor=0.2),
        layers.RandomCrop(height=image_size, width=image_size),
        layers.RandomBrightness(factor=0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ---

# %% [markdown]
# # Implement the patch extraction and encoding layer

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %% [markdown]
# # Implement the external attention block

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %% [markdown]
# # Implement the MLP block

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %% [markdown]
# # Implement the Transformer block

# %%
def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %% [markdown]
# # Implement the Self-Attention and External Attention (ENet) model

# %%
def get_model(attention_type="external_attention"):
    inputs = layers.Input(shape=input_shape)
    # Image augment
    x = data_augmentation(inputs)
    #x = inputs
    # Extract patches.
    x = PatchExtract(patch_size)(x)
    # Create patch embedding.
    x = PatchEmbedding(num_patches, embedding_dim)(x)
    # Create Transformer block.
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(
            x,
            embedding_dim,
            mlp_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
            attention_type,
        )

    x = layers.GlobalAvgPool1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## 🔷 Self-Attention

# %%
model_SA = get_model(attention_type="self_attention")
model_SA.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patch_extract (PatchExtrac  (None, 1024, 12)             0         ['data_augmentation[0][0]']
#  t)
#
#  patch_embedding (PatchEmbe  (None, 1024, 64)             66368     ['patch_extract[0][0]']
#  dding)
#
#  layer_normalization (Layer  (None, 1024, 64)             128       ['patch_embedding[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 1024, 64)             66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 1024, 64)             0         ['multi_head_attention[0][0]',
#                                                                      'patch_embedding[0][0]']
#
#  layer_normalization_1 (Lay  (None, 1024, 64)             128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 1024, 64)             0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1024, 64)             4160      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024, 64)             0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 1024, 64)             0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 1024, 64)             128       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 1024, 64)             66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 1024, 64)             128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 1024, 64)             0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024, 64)             4160      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 1024, 64)             0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 1024, 64)             0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 1024, 64)             128       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 1024, 64)             66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 1024, 64)             128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 1024, 64)             0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 1024, 64)             4160      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 1024, 64)             0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 1024, 64)             0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 1024, 64)             128       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 1024, 64)             66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 1024, 64)             128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 1024, 64)             0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 1024, 64)             4160      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 1024, 64)             0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 1024, 64)             0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 1024, 64)             128       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 1024, 64)             66368     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 1024, 64)             128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_9 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 1024, 64)             0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024, 64)             4160      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024, 64)             0         ['dense_10[0][0]']
#
#  add_9 (Add)                 (None, 1024, 64)             0         ['dropout_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 1024, 64)             128       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 1024, 64)             66368     ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 1024, 64)             0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 1024, 64)             128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 1024, 64)             0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 1024, 64)             4160      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 1024, 64)             0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 1024, 64)             0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 1024, 64)             128       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 1024, 64)             66368     ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 1024, 64)             0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 1024, 64)             128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 1024, 64)             0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 1024, 64)             4160      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 1024, 64)             0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 1024, 64)             0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 1024, 64)             128       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 1024, 64)             66368     ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 1024, 64)             0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 1024, 64)             128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 1024, 64)             0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 1024, 64)             4160      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 1024, 64)             0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 1024, 64)             0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  global_average_pooling1d (  (None, 64)                   0         ['add_15[0][0]']
#  GlobalAveragePooling1D)
#
#  dense_17 (Dense)            (None, 9)                    585       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params:
# 41/41 [==============================] - 7s 164ms/step - loss: 1.7077 - accuracy: 0.3624 - top5-acc: 0.8631 - Brier score: 0.0832 - F1 score: 0.3534 - Recall: 0.1089 - Precision: 0.7216 - AUC: 0.7996 - val_loss: 1.4492 - val_accuracy: 0.4225 - val_top5-acc: 0.9155 - val_Brier score: 0.0738 - val_F1 score: 0.3655 - val_Recall: 0.1831 - val_Precision: 0.8387 - val_AUC: 0.8651 - lr: 2.5000e-04

# %%
plot_training_curves(history_SA, 'Abdomen, SA Transfomer')

# %% [markdown]
# ---
#
#
# ## 🔷 External-Attention

# %%
model_EA = get_model(attention_type="external_attention")
model_EA.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patch_extract_1 (PatchExtr  (None, 1024, 12)             0         ['data_augmentation[1][0]']
#  act)
#
#  patch_embedding_1 (PatchEm  (None, 1024, 64)             66368     ['patch_extract_1[0][0]']
#  bedding)
#
#  layer_normalization_16 (La  (None, 1024, 64)             128       ['patch_embedding_1[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_16[0][0]
#                                                                     ']
#
#  tf.reshape (TFOpLambda)     (None, 1024, 16, 16)         0         ['dense_19[0][0]']
#
#  tf.compat.v1.transpose (TF  (None, 16, 1024, 16)         0         ['tf.reshape[0][0]']
#  OpLambda)
#
#  dense_20 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose[0][0]
#                                                                     ']
#
#  softmax (Softmax)           (None, 16, 1024, 16)         0         ['dense_20[0][0]']
#
#  tf.math.reduce_sum (TFOpLa  (None, 16, 1024, 1)          0         ['softmax[0][0]']
#  mbda)
#
#  tf.__operators__.add (TFOp  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum[0][0]']
#  Lambda)
#
#  tf.math.truediv (TFOpLambd  (None, 16, 1024, 16)         0         ['softmax[0][0]',
#  a)                                                                  'tf.__operators__.add[0][0]']
#
#  dropout_16 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv[0][0]']
#
#  dense_21 (Dense)            (None, 16, 1024, 16)         272       ['dropout_16[0][0]']
#
#  tf.compat.v1.transpose_1 (  (None, 1024, 16, 16)         0         ['dense_21[0][0]']
#  TFOpLambda)
#
#  tf.reshape_1 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_1[0][
#                                                                     0]']
#
#  dense_22 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_1[0][0]']
#
#  dropout_17 (Dropout)        (None, 1024, 64)             0         ['dense_22[0][0]']
#
#  add_16 (Add)                (None, 1024, 64)             0         ['dropout_17[0][0]',
#                                                                      'patch_embedding_1[0][0]']
#
#  layer_normalization_17 (La  (None, 1024, 64)             128       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 1024, 64)             0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 1024, 64)             4160      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 1024, 64)             0         ['dense_24[0][0]']
#
#  add_17 (Add)                (None, 1024, 64)             0         ['dropout_19[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 1024, 64)             128       ['add_17[0][0]']
#  yerNormalization)
#
#  dense_25 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_18[0][0]
#                                                                     ']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_25[0][0]']
#
#  tf.compat.v1.transpose_2 (  (None, 16, 1024, 16)         0         ['tf.reshape_2[0][0]']
#  TFOpLambda)
#
#  dense_26 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_2[0][
#                                                                     0]']
#
#  softmax_1 (Softmax)         (None, 16, 1024, 16)         0         ['dense_26[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None, 16, 1024, 1)          0         ['softmax_1[0][0]']
#  Lambda)
#
#  tf.__operators__.add_1 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_1[0][0]']
#  OpLambda)
#
#  tf.math.truediv_1 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_1[0][0]',
#  bda)                                                                'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_1[0][0]']
#
#  dense_27 (Dense)            (None, 16, 1024, 16)         272       ['dropout_20[0][0]']
#
#  tf.compat.v1.transpose_3 (  (None, 1024, 16, 16)         0         ['dense_27[0][0]']
#  TFOpLambda)
#
#  tf.reshape_3 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  dense_28 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_3[0][0]']
#
#  dropout_21 (Dropout)        (None, 1024, 64)             0         ['dense_28[0][0]']
#
#  add_18 (Add)                (None, 1024, 64)             0         ['dropout_21[0][0]',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 1024, 64)             128       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_29 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 1024, 64)             0         ['dense_29[0][0]']
#
#  dense_30 (Dense)            (None, 1024, 64)             4160      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 1024, 64)             0         ['dense_30[0][0]']
#
#  add_19 (Add)                (None, 1024, 64)             0         ['dropout_23[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 1024, 64)             128       ['add_19[0][0]']
#  yerNormalization)
#
#  dense_31 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_20[0][0]
#                                                                     ']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_31[0][0]']
#
#  tf.compat.v1.transpose_4 (  (None, 16, 1024, 16)         0         ['tf.reshape_4[0][0]']
#  TFOpLambda)
#
#  dense_32 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_4[0][
#                                                                     0]']
#
#  softmax_2 (Softmax)         (None, 16, 1024, 16)         0         ['dense_32[0][0]']
#
#  tf.math.reduce_sum_2 (TFOp  (None, 16, 1024, 1)          0         ['softmax_2[0][0]']
#  Lambda)
#
#  tf.__operators__.add_2 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_2[0][0]']
#  OpLambda)
#
#  tf.math.truediv_2 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_2[0][0]',
#  bda)                                                                'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_2[0][0]']
#
#  dense_33 (Dense)            (None, 16, 1024, 16)         272       ['dropout_24[0][0]']
#
#  tf.compat.v1.transpose_5 (  (None, 1024, 16, 16)         0         ['dense_33[0][0]']
#  TFOpLambda)
#
#  tf.reshape_5 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  dense_34 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_5[0][0]']
#
#  dropout_25 (Dropout)        (None, 1024, 64)             0         ['dense_34[0][0]']
#
#  add_20 (Add)                (None, 1024, 64)             0         ['dropout_25[0][0]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 1024, 64)             128       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_35 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 1024, 64)             0         ['dense_35[0][0]']
#
#  dense_36 (Dense)            (None, 1024, 64)             4160      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)        (None, 1024, 64)             0         ['dense_36[0][0]']
#
#  add_21 (Add)                (None, 1024, 64)             0         ['dropout_27[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 1024, 64)             128       ['add_21[0][0]']
#  yerNormalization)
#
#  dense_37 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_22[0][0]
#                                                                     ']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_37[0][0]']
#
#  tf.compat.v1.transpose_6 (  (None, 16, 1024, 16)         0         ['tf.reshape_6[0][0]']
#  TFOpLambda)
#
#  dense_38 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_6[0][
#                                                                     0]']
#
#  softmax_3 (Softmax)         (None, 16, 1024, 16)         0         ['dense_38[0][0]']
#
#  tf.math.reduce_sum_3 (TFOp  (None, 16, 1024, 1)          0         ['softmax_3[0][0]']
#  Lambda)
#
#  tf.__operators__.add_3 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_3[0][0]']
#  OpLambda)
#
#  tf.math.truediv_3 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_3[0][0]',
#  bda)                                                                'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_3[0][0]']
#
#  dense_39 (Dense)            (None, 16, 1024, 16)         272       ['dropout_28[0][0]']
#
#  tf.compat.v1.transpose_7 (  (None, 1024, 16, 16)         0         ['dense_39[0][0]']
#  TFOpLambda)
#
#  tf.reshape_7 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  dense_40 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_7[0][0]']
#
#  dropout_29 (Dropout)        (None, 1024, 64)             0         ['dense_40[0][0]']
#
#  add_22 (Add)                (None, 1024, 64)             0         ['dropout_29[0][0]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 1024, 64)             128       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_41 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 1024, 64)             0         ['dense_41[0][0]']
#
#  dense_42 (Dense)            (None, 1024, 64)             4160      ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)        (None, 1024, 64)             0         ['dense_42[0][0]']
#
#  add_23 (Add)                (None, 1024, 64)             0         ['dropout_31[0][0]',
#                                                                      'add_22[0][0]']
#
#  layer_normalization_24 (La  (None, 1024, 64)             128       ['add_23[0][0]']
#  yerNormalization)
#
#  dense_43 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_24[0][0]
#                                                                     ']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_43[0][0]']
#
#  tf.compat.v1.transpose_8 (  (None, 16, 1024, 16)         0         ['tf.reshape_8[0][0]']
#  TFOpLambda)
#
#  dense_44 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_8[0][
#                                                                     0]']
#
#  softmax_4 (Softmax)         (None, 16, 1024, 16)         0         ['dense_44[0][0]']
#
#  tf.math.reduce_sum_4 (TFOp  (None, 16, 1024, 1)          0         ['softmax_4[0][0]']
#  Lambda)
#
#  tf.__operators__.add_4 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_4[0][0]']
#  OpLambda)
#
#  tf.math.truediv_4 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_4[0][0]',
#  bda)                                                                'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_4[0][0]']
#
#  dense_45 (Dense)            (None, 16, 1024, 16)         272       ['dropout_32[0][0]']
#
#  tf.compat.v1.transpose_9 (  (None, 1024, 16, 16)         0         ['dense_45[0][0]']
#  TFOpLambda)
#
#  tf.reshape_9 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_9[0][
#                                                                     0]']
#
#  dense_46 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_9[0][0]']
#
#  dropout_33 (Dropout)        (None, 1024, 64)             0         ['dense_46[0][0]']
#
#  add_24 (Add)                (None, 1024, 64)             0         ['dropout_33[0][0]',
#                                                                      'add_23[0][0]']
#
#  layer_normalization_25 (La  (None, 1024, 64)             128       ['add_24[0][0]']
#  yerNormalization)
#
#  dense_47 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_25[0][0]
#                                                                     ']
#
#  dropout_34 (Dropout)        (None, 1024, 64)             0         ['dense_47[0][0]']
#
#  dense_48 (Dense)            (None, 1024, 64)             4160      ['dropout_34[0][0]']
#
#  dropout_35 (Dropout)        (None, 1024, 64)             0         ['dense_48[0][0]']
#
#  add_25 (Add)                (None, 1024, 64)             0         ['dropout_35[0][0]',
#                                                                      'add_24[0][0]']
#
#  layer_normalization_26 (La  (None, 1024, 64)             128       ['add_25[0][0]']
#  yerNormalization)
#
#  dense_49 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_26[0][0]
#                                                                     ']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_49[0][0]']
#
#  tf.compat.v1.transpose_10   (None, 16, 1024, 16)         0         ['tf.reshape_10[0][0]']
#  (TFOpLambda)
#
#  dense_50 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_10[0]
#                                                                     [0]']
#
#  softmax_5 (Softmax)         (None, 16, 1024, 16)         0         ['dense_50[0][0]']
#
#  tf.math.reduce_sum_5 (TFOp  (None, 16, 1024, 1)          0         ['softmax_5[0][0]']
#  Lambda)
#
#  tf.__operators__.add_5 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_5[0][0]']
#  OpLambda)
#
#  tf.math.truediv_5 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_5[0][0]',
#  bda)                                                                'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_36 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_5[0][0]']
#
#  dense_51 (Dense)            (None, 16, 1024, 16)         272       ['dropout_36[0][0]']
#
#  tf.compat.v1.transpose_11   (None, 1024, 16, 16)         0         ['dense_51[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_11 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_11[0]
#                                                                     [0]']
#
#  dense_52 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_11[0][0]']
#
#  dropout_37 (Dropout)        (None, 1024, 64)             0         ['dense_52[0][0]']
#
#  add_26 (Add)                (None, 1024, 64)             0         ['dropout_37[0][0]',
#                                                                      'add_25[0][0]']
#
#  layer_normalization_27 (La  (None, 1024, 64)             128       ['add_26[0][0]']
#  yerNormalization)
#
#  dense_53 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_27[0][0]
#                                                                     ']
#
#  dropout_38 (Dropout)        (None, 1024, 64)             0         ['dense_53[0][0]']
#
#  dense_54 (Dense)            (None, 1024, 64)             4160      ['dropout_38[0][0]']
#
#  dropout_39 (Dropout)        (None, 1024, 64)             0         ['dense_54[0][0]']
#
#  add_27 (Add)                (None, 1024, 64)             0         ['dropout_39[0][0]',
#                                                                      'add_26[0][0]']
#
#  layer_normalization_28 (La  (None, 1024, 64)             128       ['add_27[0][0]']
#  yerNormalization)
#
#  dense_55 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_28[0][0]
#                                                                     ']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_55[0][0]']
#
#  tf.compat.v1.transpose_12   (None, 16, 1024, 16)         0         ['tf.reshape_12[0][0]']
#  (TFOpLambda)
#
#  dense_56 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_12[0]
#                                                                     [0]']
#
#  softmax_6 (Softmax)         (None, 16, 1024, 16)         0         ['dense_56[0][0]']
#
#  tf.math.reduce_sum_6 (TFOp  (None, 16, 1024, 1)          0         ['softmax_6[0][0]']
#  Lambda)
#
#  tf.__operators__.add_6 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_6[0][0]']
#  OpLambda)
#
#  tf.math.truediv_6 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_6[0][0]',
#  bda)                                                                'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_40 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_6[0][0]']
#
#  dense_57 (Dense)            (None, 16, 1024, 16)         272       ['dropout_40[0][0]']
#
#  tf.compat.v1.transpose_13   (None, 1024, 16, 16)         0         ['dense_57[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_13 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_13[0]
#                                                                     [0]']
#
#  dense_58 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_13[0][0]']
#
#  dropout_41 (Dropout)        (None, 1024, 64)             0         ['dense_58[0][0]']
#
#  add_28 (Add)                (None, 1024, 64)             0         ['dropout_41[0][0]',
#                                                                      'add_27[0][0]']
#
#  layer_normalization_29 (La  (None, 1024, 64)             128       ['add_28[0][0]']
#  yerNormalization)
#
#  dense_59 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_29[0][0]
#                                                                     ']
#
#  dropout_42 (Dropout)        (None, 1024, 64)             0         ['dense_59[0][0]']
#
#  dense_60 (Dense)            (None, 1024, 64)             4160      ['dropout_42[0][0]']
#
#  dropout_43 (Dropout)        (None, 1024, 64)             0         ['dense_60[0][0]']
#
#  add_29 (Add)                (None, 1024, 64)             0         ['dropout_43[0][0]',
#                                                                      'add_28[0][0]']
#
#  layer_normalization_30 (La  (None, 1024, 64)             128       ['add_29[0][0]']
#  yerNormalization)
#
#  dense_61 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_30[0][0]
#                                                                     ']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_61[0][0]']
#
#  tf.compat.v1.transpose_14   (None, 16, 1024, 16)         0         ['tf.reshape_14[0][0]']
#  (TFOpLambda)
#
#  dense_62 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_14[0]
#                                                                     [0]']
#
#  softmax_7 (Softmax)         (None, 16, 1024, 16)         0         ['dense_62[0][0]']
#
#  tf.math.reduce_sum_7 (TFOp  (None, 16, 1024, 1)          0         ['softmax_7[0][0]']
#  Lambda)
#
#  tf.__operators__.add_7 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_7[0][0]']
#  OpLambda)
#
#  tf.math.truediv_7 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_7[0][0]',
#  bda)                                                                'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  dropout_44 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_7[0][0]']
#
#  dense_63 (Dense)            (None, 16, 1024, 16)         272       ['dropout_44[0][0]']
#
#  tf.compat.v1.transpose_15   (None, 1024, 16, 16)         0         ['dense_63[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_15 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_15[0]
#                                                                     [0]']
#
#  dense_64 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_15[0][0]']
#
#  dropout_45 (Dropout)        (None, 1024, 64)             0         ['dense_64[0][0]']
#
#  add_30 (Add)                (None, 1024, 64)             0         ['dropout_45[0][0]',
#                                                                      'add_29[0][0]']
#
#  layer_normalization_31 (La  (None, 1024, 64)             128       ['add_30[0][0]']
#  yerNormalization)
#
#  dense_65 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_31[0][0]
#                                                                     ']
#
#  dropout_46 (Dropout)        (None, 1024, 64)             0         ['dense_65[0][0]']
#
#  dense_66 (Dense)            (None, 1024, 64)             4160      ['dropout_46[0][0]']
#
#  dropout_47 (Dropout)        (None, 1024, 64)             0         ['dense_66[0][0]']
#
#  add_31 (Add)                (None, 1024, 64)             0         ['dropout_47[0][0]',
#                                                                      'add_30[0][0]']
#
#  global_average_pooling1d_1  (None, 64)                   0         ['add_31[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_67 (Dense)            (None, 9)                    585       ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 404624 (1.54 MB)
# Trainable params: 404617 (1.54 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
history_EA = run_experiment(model_EA)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 41/41 [==============================] - 18s 136ms/step - loss: 12.7569 - accuracy: 0.1229 - top5-acc: 0.5902 - Brier score: 0.1466 - F1 score: 0.1187 - Recall: 0.0855 - Precision: 0.1192 - AUC: 0.5134 - val_loss: 2.9916 - val_accuracy: 0.1127 - val_top5-acc: 0.6620 - val_Brier score: 0.1346 - val_F1 score: 0.0237 - val_Recall: 0.0845 - val_Precision: 0.1111 - val_AUC: 0.5913 - lr: 0.0010
# Epoch 2/100
# 41/41 [==============================] - 4s 77ms/step - loss: 3.0488 - accuracy: 0.1369 - top5-acc: 0.5832 - Brier score: 0.1136 - F1 score: 0.1367 - Recall: 0.0311 - Precision: 0.1594 - AUC: 0.5311 - val_loss: 2.4433 - val_accuracy: 0.2042 - val_top5-acc: 0.7324 - val_Brier score: 0.1035 - val_F1 score: 0.1198 - val_Recall: 0.0070 - val_Precision: 0.0526 - val_AUC: 0.6174 - lr: 0.0010
# Epoch 3/100
# 41/41 [==============================] - 3s 77ms/step - loss: 2.5617 - accuracy: 0.1439 - top5-acc: 0.6330 - Brier score: 0.1078 - F1 score: 0.1428 - Recall: 0.0171 - Precision: 0.1257 - AUC: 0.5637 - val_loss: 2.2622 - val_accuracy: 0.1056 - val_top5-acc: 0.6690 - val_Brier score: 0.1017 - val_F1 score: 0.0675 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.5876 - lr: 0.0010
# Epoch 4/100
# 41/41 [==============================] - 3s 77ms/step - loss: 2.3992 - accuracy: 0.1625 - top5-acc: 0.6337 - Brier score: 0.1026 - F1 score: 0.1634 - Recall: 0.0093 - Precision: 0.1846 - AUC: 0.5612 - val_loss: 2.1092 - val_accuracy: 0.1972 - val_top5-acc: 0.6690 - val_Brier score: 0.0962 - val_F1 score: 0.1153 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.6432 - lr: 0.0010
# Epoch 5/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.3530 - accuracy: 0.1851 - top5-acc: 0.6516 - Brier score: 0.1013 - F1 score: 0.1796 - Recall: 0.0101 - Precision: 0.2321 - AUC: 0.5822 - val_loss: 2.2408 - val_accuracy: 0.1620 - val_top5-acc: 0.7042 - val_Brier score: 0.1024 - val_F1 score: 0.0572 - val_Recall: 0.1268 - val_Precision: 0.4737 - val_AUC: 0.6150 - lr: 0.0010
# Epoch 6/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.4636 - accuracy: 0.1781 - top5-acc: 0.6431 - Brier score: 0.1044 - F1 score: 0.1795 - Recall: 0.0226 - Precision: 0.2339 - AUC: 0.5747 - val_loss: 2.2298 - val_accuracy: 0.0493 - val_top5-acc: 0.8169 - val_Brier score: 0.1062 - val_F1 score: 0.0237 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.6616 - lr: 0.0010
# Epoch 7/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.6846 - accuracy: 0.1540 - top5-acc: 0.6229 - Brier score: 0.1091 - F1 score: 0.1514 - Recall: 0.0241 - Precision: 0.1527 - AUC: 0.5494 - val_loss: 2.1120 - val_accuracy: 0.2465 - val_top5-acc: 0.6831 - val_Brier score: 0.0947 - val_F1 score: 0.1988 - val_Recall: 0.0141 - val_Precision: 0.6667 - val_AUC: 0.6649 - lr: 0.0010
# Epoch 8/100
# 41/41 [==============================] - 3s 77ms/step - loss: 2.4225 - accuracy: 0.1796 - top5-acc: 0.6695 - Brier score: 0.1025 - F1 score: 0.1606 - Recall: 0.0233 - Precision: 0.2206 - AUC: 0.5944 - val_loss: 2.4110 - val_accuracy: 0.1056 - val_top5-acc: 0.6338 - val_Brier score: 0.1061 - val_F1 score: 0.0594 - val_Recall: 0.0070 - val_Precision: 0.0909 - val_AUC: 0.6048 - lr: 0.0010
# Epoch 9/100
# 41/41 [==============================] - 4s 76ms/step - loss: 2.5731 - accuracy: 0.1586 - top5-acc: 0.6540 - Brier score: 0.1052 - F1 score: 0.1511 - Recall: 0.0428 - Precision: 0.2657 - AUC: 0.5800 - val_loss: 2.1163 - val_accuracy: 0.2746 - val_top5-acc: 0.6972 - val_Brier score: 0.0959 - val_F1 score: 0.1823 - val_Recall: 0.0141 - val_Precision: 0.2857 - val_AUC: 0.6542 - lr: 0.0010
# Epoch 10/100
# 41/41 [==============================] - 4s 76ms/step - loss: 2.2826 - accuracy: 0.1983 - top5-acc: 0.6975 - Brier score: 0.0999 - F1 score: 0.1893 - Recall: 0.0163 - Precision: 0.2692 - AUC: 0.6114 - val_loss: 1.9933 - val_accuracy: 0.2113 - val_top5-acc: 0.7535 - val_Brier score: 0.0938 - val_F1 score: 0.1374 - val_Recall: 0.0070 - val_Precision: 0.3333 - val_AUC: 0.6941 - lr: 5.0000e-04
# Epoch 11/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1651 - accuracy: 0.2271 - top5-acc: 0.7185 - Brier score: 0.0972 - F1 score: 0.2197 - Recall: 0.0070 - Precision: 0.2368 - AUC: 0.6391 - val_loss: 1.9480 - val_accuracy: 0.3239 - val_top5-acc: 0.7183 - val_Brier score: 0.0903 - val_F1 score: 0.2294 - val_Recall: 0.0282 - val_Precision: 0.8000 - val_AUC: 0.6941 - lr: 5.0000e-04
# Epoch 12/100
# 41/41 [==============================] - 4s 78ms/step - loss: 2.2513 - accuracy: 0.1851 - top5-acc: 0.6913 - Brier score: 0.1004 - F1 score: 0.1754 - Recall: 0.0171 - Precision: 0.2366 - AUC: 0.6177 - val_loss: 1.8934 - val_accuracy: 0.2606 - val_top5-acc: 0.8380 - val_Brier score: 0.0906 - val_F1 score: 0.1859 - val_Recall: 0.0141 - val_Precision: 0.5000 - val_AUC: 0.7405 - lr: 5.0000e-04
# Epoch 13/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.1381 - accuracy: 0.2138 - top5-acc: 0.7154 - Brier score: 0.0969 - F1 score: 0.2003 - Recall: 0.0101 - Precision: 0.3250 - AUC: 0.6399 - val_loss: 1.9398 - val_accuracy: 0.2746 - val_top5-acc: 0.7183 - val_Brier score: 0.0898 - val_F1 score: 0.1314 - val_Recall: 0.1197 - val_Precision: 0.7391 - val_AUC: 0.7118 - lr: 5.0000e-04
# Epoch 14/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.2025 - accuracy: 0.2030 - top5-acc: 0.7014 - Brier score: 0.0983 - F1 score: 0.2015 - Recall: 0.0124 - Precision: 0.3810 - AUC: 0.6268 - val_loss: 1.9278 - val_accuracy: 0.2324 - val_top5-acc: 0.7535 - val_Brier score: 0.0925 - val_F1 score: 0.1800 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.7215 - lr: 5.0000e-04
# Epoch 15/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.2204 - accuracy: 0.1866 - top5-acc: 0.6882 - Brier score: 0.0989 - F1 score: 0.1808 - Recall: 0.0140 - Precision: 0.3529 - AUC: 0.6158 - val_loss: 2.0021 - val_accuracy: 0.1479 - val_top5-acc: 0.8169 - val_Brier score: 0.0962 - val_F1 score: 0.1044 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.6982 - lr: 5.0000e-04
# Epoch 16/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1244 - accuracy: 0.2193 - top5-acc: 0.7333 - Brier score: 0.0963 - F1 score: 0.2067 - Recall: 0.0163 - Precision: 0.4667 - AUC: 0.6532 - val_loss: 1.9356 - val_accuracy: 0.2465 - val_top5-acc: 0.7817 - val_Brier score: 0.0931 - val_F1 score: 0.1512 - val_Recall: 0.0282 - val_Precision: 0.2857 - val_AUC: 0.7195 - lr: 5.0000e-04
# Epoch 17/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1258 - accuracy: 0.2263 - top5-acc: 0.7341 - Brier score: 0.0965 - F1 score: 0.2079 - Recall: 0.0264 - Precision: 0.4000 - AUC: 0.6554 - val_loss: 1.8597 - val_accuracy: 0.2324 - val_top5-acc: 0.9155 - val_Brier score: 0.0901 - val_F1 score: 0.1742 - val_Recall: 0.1056 - val_Precision: 0.7895 - val_AUC: 0.7458 - lr: 5.0000e-04
# Epoch 18/100
# 41/41 [==============================] - 3s 77ms/step - loss: 2.1181 - accuracy: 0.2348 - top5-acc: 0.7240 - Brier score: 0.0956 - F1 score: 0.2225 - Recall: 0.0295 - Precision: 0.5205 - AUC: 0.6562 - val_loss: 1.8488 - val_accuracy: 0.2042 - val_top5-acc: 0.8521 - val_Brier score: 0.0903 - val_F1 score: 0.1341 - val_Recall: 0.1268 - val_Precision: 0.5294 - val_AUC: 0.7618 - lr: 5.0000e-04
# Epoch 19/100
# 41/41 [==============================] - 4s 77ms/step - loss: 2.0927 - accuracy: 0.2426 - top5-acc: 0.7240 - Brier score: 0.0951 - F1 score: 0.2318 - Recall: 0.0397 - Precision: 0.5100 - AUC: 0.6667 - val_loss: 1.7840 - val_accuracy: 0.2465 - val_top5-acc: 0.8521 - val_Brier score: 0.0870 - val_F1 score: 0.2093 - val_Recall: 0.1338 - val_Precision: 0.8636 - val_AUC: 0.7704 - lr: 5.0000e-04
# Epoch 20/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.0833 - accuracy: 0.2247 - top5-acc: 0.7387 - Brier score: 0.0953 - F1 score: 0.2052 - Recall: 0.0365 - Precision: 0.5802 - AUC: 0.6608 - val_loss: 1.8641 - val_accuracy: 0.2535 - val_top5-acc: 0.8662 - val_Brier score: 0.0913 - val_F1 score: 0.1801 - val_Recall: 0.1127 - val_Precision: 0.6667 - val_AUC: 0.7523 - lr: 5.0000e-04
# Epoch 21/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1228 - accuracy: 0.2278 - top5-acc: 0.7286 - Brier score: 0.0963 - F1 score: 0.2180 - Recall: 0.0272 - Precision: 0.4795 - AUC: 0.6577 - val_loss: 1.9068 - val_accuracy: 0.2254 - val_top5-acc: 0.7958 - val_Brier score: 0.0917 - val_F1 score: 0.1521 - val_Recall: 0.1197 - val_Precision: 0.6538 - val_AUC: 0.7386 - lr: 5.0000e-04
# Epoch 22/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1011 - accuracy: 0.2348 - top5-acc: 0.7387 - Brier score: 0.0958 - F1 score: 0.2257 - Recall: 0.0327 - Precision: 0.4884 - AUC: 0.6675 - val_loss: 1.8100 - val_accuracy: 0.2676 - val_top5-acc: 0.9014 - val_Brier score: 0.0885 - val_F1 score: 0.1679 - val_Recall: 0.1549 - val_Precision: 0.7097 - val_AUC: 0.7639 - lr: 5.0000e-04
# Epoch 23/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.0333 - accuracy: 0.2535 - top5-acc: 0.7683 - Brier score: 0.0935 - F1 score: 0.2442 - Recall: 0.0435 - Precision: 0.5283 - AUC: 0.6924 - val_loss: 1.7902 - val_accuracy: 0.2958 - val_top5-acc: 0.8521 - val_Brier score: 0.0868 - val_F1 score: 0.2034 - val_Recall: 0.1831 - val_Precision: 0.6341 - val_AUC: 0.7739 - lr: 5.0000e-04
# Epoch 24/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.0651 - accuracy: 0.2263 - top5-acc: 0.7582 - Brier score: 0.0947 - F1 score: 0.2114 - Recall: 0.0389 - Precision: 0.5319 - AUC: 0.6763 - val_loss: 1.8313 - val_accuracy: 0.2535 - val_top5-acc: 0.8592 - val_Brier score: 0.0916 - val_F1 score: 0.1530 - val_Recall: 0.1408 - val_Precision: 0.4545 - val_AUC: 0.7792 - lr: 5.0000e-04
# Epoch 25/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.0207 - accuracy: 0.2473 - top5-acc: 0.7659 - Brier score: 0.0937 - F1 score: 0.2309 - Recall: 0.0428 - Precision: 0.4955 - AUC: 0.6917 - val_loss: 1.6835 - val_accuracy: 0.3169 - val_top5-acc: 0.9155 - val_Brier score: 0.0842 - val_F1 score: 0.2774 - val_Recall: 0.0563 - val_Precision: 0.8000 - val_AUC: 0.8150 - lr: 2.5000e-04
# Epoch 26/100
# 41/41 [==============================] - 3s 77ms/step - loss: 1.9854 - accuracy: 0.2543 - top5-acc: 0.7776 - Brier score: 0.0920 - F1 score: 0.2398 - Recall: 0.0428 - Precision: 0.7432 - AUC: 0.7014 - val_loss: 1.7032 - val_accuracy: 0.2817 - val_top5-acc: 0.8803 - val_Brier score: 0.0842 - val_F1 score: 0.2234 - val_Recall: 0.1268 - val_Precision: 0.8571 - val_AUC: 0.7988 - lr: 2.5000e-04
# Epoch 27/100
# 41/41 [==============================] - 3s 75ms/step - loss: 1.9571 - accuracy: 0.2714 - top5-acc: 0.7652 - Brier score: 0.0906 - F1 score: 0.2572 - Recall: 0.0607 - Precision: 0.7290 - AUC: 0.7102 - val_loss: 1.6924 - val_accuracy: 0.3451 - val_top5-acc: 0.8803 - val_Brier score: 0.0835 - val_F1 score: 0.2964 - val_Recall: 0.1268 - val_Precision: 0.8182 - val_AUC: 0.8008 - lr: 2.5000e-04
# Epoch 28/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.0019 - accuracy: 0.2714 - top5-acc: 0.7683 - Brier score: 0.0925 - F1 score: 0.2574 - Recall: 0.0381 - Precision: 0.6282 - AUC: 0.6979 - val_loss: 1.6959 - val_accuracy: 0.2817 - val_top5-acc: 0.9437 - val_Brier score: 0.0850 - val_F1 score: 0.2081 - val_Recall: 0.1690 - val_Precision: 0.7742 - val_AUC: 0.8019 - lr: 2.5000e-04
# Epoch 29/100
# 41/41 [==============================] - 4s 78ms/step - loss: 2.0205 - accuracy: 0.2597 - top5-acc: 0.7597 - Brier score: 0.0928 - F1 score: 0.2488 - Recall: 0.0373 - Precision: 0.5926 - AUC: 0.6926 - val_loss: 1.6613 - val_accuracy: 0.3239 - val_top5-acc: 0.9085 - val_Brier score: 0.0821 - val_F1 score: 0.2415 - val_Recall: 0.1690 - val_Precision: 0.7500 - val_AUC: 0.8121 - lr: 2.5000e-04
# Epoch 30/100
# 41/41 [==============================] - 4s 76ms/step - loss: 1.9543 - accuracy: 0.2729 - top5-acc: 0.7706 - Brier score: 0.0909 - F1 score: 0.2524 - Recall: 0.0459 - Precision: 0.7973 - AUC: 0.7080 - val_loss: 1.7562 - val_accuracy: 0.3239 - val_top5-acc: 0.8239 - val_Brier score: 0.0860 - val_F1 score: 0.2463 - val_Recall: 0.1831 - val_Precision: 0.6190 - val_AUC: 0.7841 - lr: 2.5000e-04
# Epoch 31/100
# 41/41 [==============================] - 3s 75ms/step - loss: 2.0045 - accuracy: 0.2589 - top5-acc: 0.7504 - Brier score: 0.0927 - F1 score: 0.2470 - Recall: 0.0365 - Precision: 0.6714 - AUC: 0.6901 - val_loss: 1.6815 - val_accuracy: 0.3451 - val_top5-acc: 0.9085 - val_Brier score: 0.0838 - val_F1 score: 0.3030 - val_Recall: 0.0845 - val_Precision: 0.7059 - val_AUC: 0.8116 - lr: 2.5000e-04
# Epoch 32/100
# 41/41 [==============================] - 3s 76ms/step - loss: 2.0279 - accuracy: 0.2582 - top5-acc: 0.7729 - Brier score: 0.0934 - F1 score: 0.2413 - Recall: 0.0513 - Precision: 0.4853 - AUC: 0.6922 - val_loss: 1.7896 - val_accuracy: 0.3028 - val_top5-acc: 0.8873 - val_Brier score: 0.0871 - val_F1 score: 0.2439 - val_Recall: 0.1479 - val_Precision: 0.6000 - val_AUC: 0.7770 - lr: 2.5000e-04
# Epoch 33/100
# 41/41 [==============================] - 3s 77ms/step - loss: 1.9136 - accuracy: 0.2698 - top5-acc: 0.8025 - Brier score: 0.0903 - F1 score: 0.2523 - Recall: 0.0474 - Precision: 0.6932 - AUC: 0.7278 - val_loss: 1.8004 - val_accuracy: 0.2746 - val_top5-acc: 0.8662 - val_Brier score: 0.0900 - val_F1 score: 0.2242 - val_Recall: 0.0634 - val_Precision: 0.6000 - val_AUC: 0.7781 - lr: 2.5000e-04
# Epoch 34/100
# 41/41 [==============================] - 3s 76ms/step - loss: 1.9538 - accuracy: 0.2628 - top5-acc: 0.7830 - Brier score: 0.0913 - F1 score: 0.2499 - Recall: 0.0505 - Precision: 0.6500 - AUC: 0.7166 - val_loss: 1.7566 - val_accuracy: 0.2394 - val_top5-acc: 0.9085 - val_Brier score: 0.0898 - val_F1 score: 0.1938 - val_Recall: 0.0986 - val_Precision: 0.3590 - val_AUC: 0.7997 - lr: 2.5000e-04
# Epoch 35/100
# 41/41 [==============================] - 3s 77ms/step - loss: 1.9142 - accuracy: 0.2675 - top5-acc: 0.7885 - Brier score: 0.0901 - F1 score: 0.2483 - Recall: 0.0404 - Precision: 0.8387 - AUC: 0.7226 - val_loss: 1.7234 - val_accuracy: 0.2746 - val_top5-acc: 0.8944 - val_Brier score: 0.0864 - val_F1 score: 0.2216 - val_Recall: 0.1197 - val_Precision: 0.7083 - val_AUC: 0.8003 - lr: 1.2500e-04
# Epoch 36/100
# 41/41 [==============================] - 3s 76ms/step - loss: 1.9080 - accuracy: 0.2846 - top5-acc: 0.7978 - Brier score: 0.0897 - F1 score: 0.2725 - Recall: 0.0373 - Precision: 0.7059 - AUC: 0.7255 - val_loss: 1.6858 - val_accuracy: 0.2887 - val_top5-acc: 0.9296 - val_Brier score: 0.0853 - val_F1 score: 0.1943 - val_Recall: 0.1972 - val_Precision: 0.5957 - val_AUC: 0.8069 - lr: 1.2500e-04
# Epoch 37/100
# 41/41 [==============================] - 3s 75ms/step - loss: 1.8720 - accuracy: 0.3017 - top5-acc: 0.8072 - Brier score: 0.0885 - F1 score: 0.2862 - Recall: 0.0482 - Precision: 0.8158 - AUC: 0.7387 - val_loss: 1.7313 - val_accuracy: 0.3239 - val_top5-acc: 0.8803 - val_Brier score: 0.0861 - val_F1 score: 0.2372 - val_Recall: 0.1620 - val_Precision: 0.6389 - val_AUC: 0.7957 - lr: 1.2500e-04
# Epoch 38/100
# 41/41 [==============================] - 3s 76ms/step - loss: 1.9000 - accuracy: 0.2698 - top5-acc: 0.7932 - Brier score: 0.0899 - F1 score: 0.2588 - Recall: 0.0451 - Precision: 0.7632 - AUC: 0.7266 - val_loss: 1.6929 - val_accuracy: 0.2676 - val_top5-acc: 0.9014 - val_Brier score: 0.0853 - val_F1 score: 0.2255 - val_Recall: 0.0986 - val_Precision: 0.6087 - val_AUC: 0.8112 - lr: 1.2500e-04
# Epoch 39/100
# 41/41 [==============================] - 3s 77ms/step - loss: 1.8747 - accuracy: 0.2768 - top5-acc: 0.8025 - Brier score: 0.0891 - F1 score: 0.2644 - Recall: 0.0474 - Precision: 0.7625 - AUC: 0.7391 - val_loss: 1.6868 - val_accuracy: 0.3310 - val_top5-acc: 0.9296 - val_Brier score: 0.0847 - val_F1 score: 0.2517 - val_Recall: 0.2113 - val_Precision: 0.6122 - val_AUC: 0.8109 - lr: 1.2500e-04

# %%
plot_training_curves(history_EA, 'Abdomen, EA Transfomer')
