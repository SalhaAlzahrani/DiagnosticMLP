# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/DiagnosticMLP/blob/main/Transfomer_vs_DiagnosticMLP_KidneyCancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟨 DiagnosticMLP versus Transfomer Architectures: CT Image classification - Computed Tomography (CT) - Kidney Cancer

# %%
# !pip install nest_asyncio
# !pip install -U -q tensorflow-addons
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.0 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math
import nest_asyncio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Mounted at /content/drive

# %% [markdown]
# ---
#
# ## 🟡 plot_training_curves

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(len(history.history['loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('bmh') #ggplot #bmh
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10)

# %% [markdown]
# ## 🟡 Hyperparameters

# %%
path = '/content/drive/MyDrive/_MyResearch_/CT_Datasets/Computed Tomography (CT) - Kidney Cancer/'

image_size = 64 # We'll resize input images to this size.
patch_size = 256
input_shape = (64, 64, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
label_smoothing = 0.1

patch_size = 2  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2
num_transformer_blocks = 8  # Number of repetitions of the transformer layer

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 2 X 2 = 4
# Patches per image: 1024
# Elements per patch (3 channels): 12

# %% [markdown]
# ## 🟡 Dataset

# %%
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 10062 files belonging to 2 classes.
# Using 9056 files for training.
# Found 10062 files belonging to 2 classes.
# Using 1006 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
##################
num_classes = len(class_names)
##################
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(num_classes): classes.append(i)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# ['Normal', 'Tumor']
# {0: 1.002191235059761, 1: 0.9978183260610869}

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 🟡 Experiment
# We implement a utility function to compile, train, and evaluate a given model.

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# ## 🟡 Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip('horizontal_and_vertical'),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
        layers.RandomContrast(factor=0.2),
        layers.RandomCrop(height=image_size, width=image_size),
        layers.RandomBrightness(factor=0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ---

# %% [markdown]
# # Implement the patch extraction and encoding layer

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %% [markdown]
# # Implement the external attention block

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %% [markdown]
# # Implement the MLP block

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %% [markdown]
# # Implement the Transformer block

# %%
def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %% [markdown]
# # Implement the Self-Attention and External Attention (ENet) model

# %%
def get_model(attention_type="external_attention"):
    inputs = layers.Input(shape=input_shape)
    # Image augment
    x = data_augmentation(inputs)
    #x = inputs
    # Extract patches.
    x = PatchExtract(patch_size)(x)
    # Create patch embedding.
    x = PatchEmbedding(num_patches, embedding_dim)(x)
    # Create Transformer block.
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(
            x,
            embedding_dim,
            mlp_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
            attention_type,
        )

    x = layers.GlobalAvgPool1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## 🔷 Self-Attention

# %%
model_SA = get_model(attention_type="self_attention")
model_SA.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patch_extract (PatchExtrac  (None, 1024, 12)             0         ['data_augmentation[0][0]']
#  t)
#
#  patch_embedding (PatchEmbe  (None, 1024, 64)             66368     ['patch_extract[0][0]']
#  dding)
#
#  layer_normalization (Layer  (None, 1024, 64)             128       ['patch_embedding[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 1024, 64)             66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 1024, 64)             0         ['multi_head_attention[0][0]',
#                                                                      'patch_embedding[0][0]']
#
#  layer_normalization_1 (Lay  (None, 1024, 64)             128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 1024, 64)             0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1024, 64)             4160      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024, 64)             0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 1024, 64)             0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 1024, 64)             128       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 1024, 64)             66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 1024, 64)             128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 1024, 64)             0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024, 64)             4160      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 1024, 64)             0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 1024, 64)             0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 1024, 64)             128       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 1024, 64)             66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 1024, 64)             128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 1024, 64)             0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 1024, 64)             4160      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 1024, 64)             0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 1024, 64)             0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 1024, 64)             128       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 1024, 64)             66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 1024, 64)             128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 1024, 64)             0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 1024, 64)             4160      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 1024, 64)             0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 1024, 64)             0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 1024, 64)             128       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 1024, 64)             66368     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 1024, 64)             0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 1024, 64)             128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_9 (Dense)             (None, 1024, 64)             4160      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 1024, 64)             0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024, 64)             4160      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024, 64)             0         ['dense_10[0][0]']
#
#  add_9 (Add)                 (None, 1024, 64)             0         ['dropout_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 1024, 64)             128       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 1024, 64)             66368     ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 1024, 64)             0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 1024, 64)             128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 1024, 64)             0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 1024, 64)             4160      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 1024, 64)             0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 1024, 64)             0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 1024, 64)             128       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 1024, 64)             66368     ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 1024, 64)             0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 1024, 64)             128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 1024, 64)             0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 1024, 64)             4160      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 1024, 64)             0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 1024, 64)             0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 1024, 64)             128       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 1024, 64)             66368     ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 1024, 64)             0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 1024, 64)             128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 1024, 64)             0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 1024, 64)             4160      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 1024, 64)             0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 1024, 64)             0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  global_average_pooling1d (  (None, 64)                   0         ['add_15[0][0]']
#  GlobalAveragePooling1D)
#
#  dense_17 (Dense)            (None, 2)                    130       ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 666057 (2.54 MB)
# Trainable params: 666050 (2.54 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
history_SA = run_experiment(model_SA)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 283/283 [==============================] - 409s 971ms/step - loss: 1.2055 - accuracy: 0.5522 - top5-acc: 1.0000 - Brier score: 0.3168 - F1 score: 0.5521 - Recall: 0.5522 - Precision: 0.5522 - AUC: 0.5720 - val_loss: 0.9237 - val_accuracy: 0.5825 - val_top5-acc: 1.0000 - val_Brier score: 0.2985 - val_F1 score: 0.5235 - val_Recall: 0.5825 - val_Precision: 0.5825 - val_AUC: 0.6594 - lr: 0.0010
# Epoch 2/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.7046 - accuracy: 0.6151 - top5-acc: 1.0000 - Brier score: 0.2453 - F1 score: 0.6147 - Recall: 0.6151 - Precision: 0.6151 - AUC: 0.6601 - val_loss: 0.5402 - val_accuracy: 0.7097 - val_top5-acc: 1.0000 - val_Brier score: 0.1840 - val_F1 score: 0.7008 - val_Recall: 0.7097 - val_Precision: 0.7097 - val_AUC: 0.7951 - lr: 0.0010
# Epoch 3/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.6800 - accuracy: 0.6387 - top5-acc: 1.0000 - Brier score: 0.2339 - F1 score: 0.6386 - Recall: 0.6387 - Precision: 0.6387 - AUC: 0.6936 - val_loss: 0.6660 - val_accuracy: 0.7068 - val_top5-acc: 1.0000 - val_Brier score: 0.2123 - val_F1 score: 0.6965 - val_Recall: 0.7068 - val_Precision: 0.7068 - val_AUC: 0.7868 - lr: 0.0010
# Epoch 4/100
# 283/283 [==============================] - 47s 163ms/step - loss: 0.6852 - accuracy: 0.6581 - top5-acc: 1.0000 - Brier score: 0.2284 - F1 score: 0.6581 - Recall: 0.6581 - Precision: 0.6581 - AUC: 0.7141 - val_loss: 0.8870 - val_accuracy: 0.6461 - val_top5-acc: 1.0000 - val_Brier score: 0.2685 - val_F1 score: 0.6145 - val_Recall: 0.6461 - val_Precision: 0.6461 - val_AUC: 0.7246 - lr: 0.0010
# Epoch 5/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.6571 - accuracy: 0.6685 - top5-acc: 1.0000 - Brier score: 0.2210 - F1 score: 0.6685 - Recall: 0.6685 - Precision: 0.6685 - AUC: 0.7283 - val_loss: 0.5096 - val_accuracy: 0.7674 - val_top5-acc: 1.0000 - val_Brier score: 0.1692 - val_F1 score: 0.7615 - val_Recall: 0.7674 - val_Precision: 0.7674 - val_AUC: 0.8352 - lr: 0.0010
# Epoch 6/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5797 - accuracy: 0.7094 - top5-acc: 1.0000 - Brier score: 0.1951 - F1 score: 0.7094 - Recall: 0.7094 - Precision: 0.7094 - AUC: 0.7765 - val_loss: 0.7740 - val_accuracy: 0.6759 - val_top5-acc: 1.0000 - val_Brier score: 0.2402 - val_F1 score: 0.6531 - val_Recall: 0.6759 - val_Precision: 0.6759 - val_AUC: 0.7665 - lr: 0.0010
# Epoch 7/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5900 - accuracy: 0.7057 - top5-acc: 1.0000 - Brier score: 0.1974 - F1 score: 0.7057 - Recall: 0.7057 - Precision: 0.7057 - AUC: 0.7779 - val_loss: 0.4216 - val_accuracy: 0.8012 - val_top5-acc: 1.0000 - val_Brier score: 0.1375 - val_F1 score: 0.7998 - val_Recall: 0.8012 - val_Precision: 0.8012 - val_AUC: 0.8859 - lr: 0.0010
# Epoch 8/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5826 - accuracy: 0.7148 - top5-acc: 1.0000 - Brier score: 0.1936 - F1 score: 0.7147 - Recall: 0.7148 - Precision: 0.7148 - AUC: 0.7841 - val_loss: 0.5903 - val_accuracy: 0.7316 - val_top5-acc: 1.0000 - val_Brier score: 0.1925 - val_F1 score: 0.7208 - val_Recall: 0.7316 - val_Precision: 0.7316 - val_AUC: 0.8227 - lr: 0.0010
# Epoch 9/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5627 - accuracy: 0.7316 - top5-acc: 1.0000 - Brier score: 0.1853 - F1 score: 0.7316 - Recall: 0.7316 - Precision: 0.7316 - AUC: 0.8003 - val_loss: 0.4402 - val_accuracy: 0.8032 - val_top5-acc: 1.0000 - val_Brier score: 0.1418 - val_F1 score: 0.8013 - val_Recall: 0.8032 - val_Precision: 0.8032 - val_AUC: 0.8807 - lr: 0.0010
# Epoch 10/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5661 - accuracy: 0.7284 - top5-acc: 1.0000 - Brier score: 0.1857 - F1 score: 0.7283 - Recall: 0.7284 - Precision: 0.7284 - AUC: 0.8002 - val_loss: 0.7473 - val_accuracy: 0.6869 - val_top5-acc: 1.0000 - val_Brier score: 0.2323 - val_F1 score: 0.6668 - val_Recall: 0.6869 - val_Precision: 0.6869 - val_AUC: 0.7843 - lr: 0.0010
# Epoch 11/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5509 - accuracy: 0.7348 - top5-acc: 1.0000 - Brier score: 0.1808 - F1 score: 0.7348 - Recall: 0.7348 - Precision: 0.7348 - AUC: 0.8093 - val_loss: 0.4687 - val_accuracy: 0.7813 - val_top5-acc: 1.0000 - val_Brier score: 0.1539 - val_F1 score: 0.7763 - val_Recall: 0.7813 - val_Precision: 0.7813 - val_AUC: 0.8728 - lr: 0.0010
# Epoch 12/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.5073 - accuracy: 0.7524 - top5-acc: 1.0000 - Brier score: 0.1682 - F1 score: 0.7524 - Recall: 0.7524 - Precision: 0.7524 - AUC: 0.8327 - val_loss: 0.3642 - val_accuracy: 0.8260 - val_top5-acc: 1.0000 - val_Brier score: 0.1169 - val_F1 score: 0.8250 - val_Recall: 0.8260 - val_Precision: 0.8260 - val_AUC: 0.9184 - lr: 0.0010
# Epoch 13/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4829 - accuracy: 0.7663 - top5-acc: 1.0000 - Brier score: 0.1590 - F1 score: 0.7663 - Recall: 0.7663 - Precision: 0.7663 - AUC: 0.8490 - val_loss: 0.3633 - val_accuracy: 0.8250 - val_top5-acc: 1.0000 - val_Brier score: 0.1199 - val_F1 score: 0.8232 - val_Recall: 0.8250 - val_Precision: 0.8250 - val_AUC: 0.9174 - lr: 0.0010
# Epoch 14/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4646 - accuracy: 0.7816 - top5-acc: 1.0000 - Brier score: 0.1513 - F1 score: 0.7816 - Recall: 0.7816 - Precision: 0.7816 - AUC: 0.8621 - val_loss: 0.3094 - val_accuracy: 0.8579 - val_top5-acc: 1.0000 - val_Brier score: 0.0989 - val_F1 score: 0.8571 - val_Recall: 0.8579 - val_Precision: 0.8579 - val_AUC: 0.9409 - lr: 0.0010
# Epoch 15/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4521 - accuracy: 0.7902 - top5-acc: 1.0000 - Brier score: 0.1464 - F1 score: 0.7902 - Recall: 0.7902 - Precision: 0.7902 - AUC: 0.8705 - val_loss: 0.3443 - val_accuracy: 0.8539 - val_top5-acc: 1.0000 - val_Brier score: 0.1069 - val_F1 score: 0.8529 - val_Recall: 0.8539 - val_Precision: 0.8539 - val_AUC: 0.9278 - lr: 0.0010
# Epoch 16/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4144 - accuracy: 0.8085 - top5-acc: 1.0000 - Brier score: 0.1337 - F1 score: 0.8085 - Recall: 0.8085 - Precision: 0.8085 - AUC: 0.8911 - val_loss: 0.2479 - val_accuracy: 0.8996 - val_top5-acc: 1.0000 - val_Brier score: 0.0746 - val_F1 score: 0.8996 - val_Recall: 0.8996 - val_Precision: 0.8996 - val_AUC: 0.9639 - lr: 0.0010
# Epoch 17/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4062 - accuracy: 0.8124 - top5-acc: 1.0000 - Brier score: 0.1306 - F1 score: 0.8123 - Recall: 0.8124 - Precision: 0.8124 - AUC: 0.8960 - val_loss: 0.3457 - val_accuracy: 0.8579 - val_top5-acc: 1.0000 - val_Brier score: 0.1052 - val_F1 score: 0.8572 - val_Recall: 0.8579 - val_Precision: 0.8579 - val_AUC: 0.9302 - lr: 0.0010
# Epoch 18/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.4130 - accuracy: 0.8100 - top5-acc: 1.0000 - Brier score: 0.1318 - F1 score: 0.8099 - Recall: 0.8100 - Precision: 0.8100 - AUC: 0.8940 - val_loss: 0.4050 - val_accuracy: 0.8181 - val_top5-acc: 1.0000 - val_Brier score: 0.1280 - val_F1 score: 0.8154 - val_Recall: 0.8181 - val_Precision: 0.8181 - val_AUC: 0.9081 - lr: 0.0010
# Epoch 19/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3861 - accuracy: 0.8261 - top5-acc: 1.0000 - Brier score: 0.1224 - F1 score: 0.8260 - Recall: 0.8261 - Precision: 0.8261 - AUC: 0.9073 - val_loss: 0.3534 - val_accuracy: 0.8449 - val_top5-acc: 1.0000 - val_Brier score: 0.1128 - val_F1 score: 0.8438 - val_Recall: 0.8449 - val_Precision: 0.8449 - val_AUC: 0.9230 - lr: 0.0010
# Epoch 20/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3641 - accuracy: 0.8362 - top5-acc: 1.0000 - Brier score: 0.1155 - F1 score: 0.8362 - Recall: 0.8362 - Precision: 0.8362 - AUC: 0.9173 - val_loss: 0.4159 - val_accuracy: 0.7992 - val_top5-acc: 1.0000 - val_Brier score: 0.1366 - val_F1 score: 0.7952 - val_Recall: 0.7992 - val_Precision: 0.7992 - val_AUC: 0.9016 - lr: 0.0010
# Epoch 21/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3666 - accuracy: 0.8379 - top5-acc: 1.0000 - Brier score: 0.1158 - F1 score: 0.8378 - Recall: 0.8379 - Precision: 0.8379 - AUC: 0.9164 - val_loss: 0.2963 - val_accuracy: 0.8698 - val_top5-acc: 1.0000 - val_Brier score: 0.0942 - val_F1 score: 0.8695 - val_Recall: 0.8698 - val_Precision: 0.8698 - val_AUC: 0.9459 - lr: 0.0010
# Epoch 22/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3300 - accuracy: 0.8577 - top5-acc: 1.0000 - Brier score: 0.1030 - F1 score: 0.8576 - Recall: 0.8577 - Precision: 0.8577 - AUC: 0.9328 - val_loss: 0.3911 - val_accuracy: 0.8062 - val_top5-acc: 1.0000 - val_Brier score: 0.1323 - val_F1 score: 0.8027 - val_Recall: 0.8062 - val_Precision: 0.8062 - val_AUC: 0.9105 - lr: 5.0000e-04
# Epoch 23/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3239 - accuracy: 0.8570 - top5-acc: 1.0000 - Brier score: 0.1019 - F1 score: 0.8569 - Recall: 0.8570 - Precision: 0.8570 - AUC: 0.9350 - val_loss: 0.3658 - val_accuracy: 0.8290 - val_top5-acc: 1.0000 - val_Brier score: 0.1192 - val_F1 score: 0.8270 - val_Recall: 0.8290 - val_Precision: 0.8290 - val_AUC: 0.9261 - lr: 5.0000e-04
# Epoch 24/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3149 - accuracy: 0.8665 - top5-acc: 1.0000 - Brier score: 0.0978 - F1 score: 0.8664 - Recall: 0.8665 - Precision: 0.8665 - AUC: 0.9390 - val_loss: 0.3766 - val_accuracy: 0.8171 - val_top5-acc: 1.0000 - val_Brier score: 0.1270 - val_F1 score: 0.8144 - val_Recall: 0.8171 - val_Precision: 0.8171 - val_AUC: 0.9119 - lr: 5.0000e-04
# Epoch 25/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3128 - accuracy: 0.8674 - top5-acc: 1.0000 - Brier score: 0.0969 - F1 score: 0.8673 - Recall: 0.8674 - Precision: 0.8674 - AUC: 0.9400 - val_loss: 0.2729 - val_accuracy: 0.8867 - val_top5-acc: 1.0000 - val_Brier score: 0.0849 - val_F1 score: 0.8864 - val_Recall: 0.8867 - val_Precision: 0.8867 - val_AUC: 0.9543 - lr: 5.0000e-04
# Epoch 26/100
# 283/283 [==============================] - 47s 164ms/step - loss: 0.3002 - accuracy: 0.8744 - top5-acc: 1.0000 - Brier score: 0.0927 - F1 score: 0.8744 - Recall: 0.8744 - Precision: 0.8744 - AUC: 0.9447 - val_loss: 0.2754 - val_accuracy: 0.8807 - val_top5-acc: 1.0000 - val_Brier score: 0.0852 - val_F1 score: 0.8803 - val_Recall: 0.8807 - val_Precision: 0.8807 - val_AUC: 0.9538 - lr: 5.0000e-04

# %%
plot_training_curves(history_SA, 'Kidney Cancer, SA Transfomer')

# %% [markdown]
# ---
#
#
# ## 🔷 External-Attention

# %%
model_EA = get_model(attention_type="external_attention")
model_EA.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patch_extract_1 (PatchExtr  (None, 1024, 12)             0         ['data_augmentation[1][0]']
#  act)
#
#  patch_embedding_1 (PatchEm  (None, 1024, 64)             66368     ['patch_extract_1[0][0]']
#  bedding)
#
#  layer_normalization_16 (La  (None, 1024, 64)             128       ['patch_embedding_1[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_16[0][0]
#                                                                     ']
#
#  tf.reshape (TFOpLambda)     (None, 1024, 16, 16)         0         ['dense_19[0][0]']
#
#  tf.compat.v1.transpose (TF  (None, 16, 1024, 16)         0         ['tf.reshape[0][0]']
#  OpLambda)
#
#  dense_20 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose[0][0]
#                                                                     ']
#
#  softmax (Softmax)           (None, 16, 1024, 16)         0         ['dense_20[0][0]']
#
#  tf.math.reduce_sum (TFOpLa  (None, 16, 1024, 1)          0         ['softmax[0][0]']
#  mbda)
#
#  tf.__operators__.add (TFOp  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum[0][0]']
#  Lambda)
#
#  tf.math.truediv (TFOpLambd  (None, 16, 1024, 16)         0         ['softmax[0][0]',
#  a)                                                                  'tf.__operators__.add[0][0]']
#
#  dropout_16 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv[0][0]']
#
#  dense_21 (Dense)            (None, 16, 1024, 16)         272       ['dropout_16[0][0]']
#
#  tf.compat.v1.transpose_1 (  (None, 1024, 16, 16)         0         ['dense_21[0][0]']
#  TFOpLambda)
#
#  tf.reshape_1 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_1[0][
#                                                                     0]']
#
#  dense_22 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_1[0][0]']
#
#  dropout_17 (Dropout)        (None, 1024, 64)             0         ['dense_22[0][0]']
#
#  add_16 (Add)                (None, 1024, 64)             0         ['dropout_17[0][0]',
#                                                                      'patch_embedding_1[0][0]']
#
#  layer_normalization_17 (La  (None, 1024, 64)             128       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 1024, 64)             0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 1024, 64)             4160      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 1024, 64)             0         ['dense_24[0][0]']
#
#  add_17 (Add)                (None, 1024, 64)             0         ['dropout_19[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 1024, 64)             128       ['add_17[0][0]']
#  yerNormalization)
#
#  dense_25 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_18[0][0]
#                                                                     ']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_25[0][0]']
#
#  tf.compat.v1.transpose_2 (  (None, 16, 1024, 16)         0         ['tf.reshape_2[0][0]']
#  TFOpLambda)
#
#  dense_26 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_2[0][
#                                                                     0]']
#
#  softmax_1 (Softmax)         (None, 16, 1024, 16)         0         ['dense_26[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None, 16, 1024, 1)          0         ['softmax_1[0][0]']
#  Lambda)
#
#  tf.__operators__.add_1 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_1[0][0]']
#  OpLambda)
#
#  tf.math.truediv_1 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_1[0][0]',
#  bda)                                                                'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_1[0][0]']
#
#  dense_27 (Dense)            (None, 16, 1024, 16)         272       ['dropout_20[0][0]']
#
#  tf.compat.v1.transpose_3 (  (None, 1024, 16, 16)         0         ['dense_27[0][0]']
#  TFOpLambda)
#
#  tf.reshape_3 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  dense_28 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_3[0][0]']
#
#  dropout_21 (Dropout)        (None, 1024, 64)             0         ['dense_28[0][0]']
#
#  add_18 (Add)                (None, 1024, 64)             0         ['dropout_21[0][0]',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 1024, 64)             128       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_29 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 1024, 64)             0         ['dense_29[0][0]']
#
#  dense_30 (Dense)            (None, 1024, 64)             4160      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 1024, 64)             0         ['dense_30[0][0]']
#
#  add_19 (Add)                (None, 1024, 64)             0         ['dropout_23[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 1024, 64)             128       ['add_19[0][0]']
#  yerNormalization)
#
#  dense_31 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_20[0][0]
#                                                                     ']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_31[0][0]']
#
#  tf.compat.v1.transpose_4 (  (None, 16, 1024, 16)         0         ['tf.reshape_4[0][0]']
#  TFOpLambda)
#
#  dense_32 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_4[0][
#                                                                     0]']
#
#  softmax_2 (Softmax)         (None, 16, 1024, 16)         0         ['dense_32[0][0]']
#
#  tf.math.reduce_sum_2 (TFOp  (None, 16, 1024, 1)          0         ['softmax_2[0][0]']
#  Lambda)
#
#  tf.__operators__.add_2 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_2[0][0]']
#  OpLambda)
#
#  tf.math.truediv_2 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_2[0][0]',
#  bda)                                                                'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_2[0][0]']
#
#  dense_33 (Dense)            (None, 16, 1024, 16)         272       ['dropout_24[0][0]']
#
#  tf.compat.v1.transpose_5 (  (None, 1024, 16, 16)         0         ['dense_33[0][0]']
#  TFOpLambda)
#
#  tf.reshape_5 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  dense_34 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_5[0][0]']
#
#  dropout_25 (Dropout)        (None, 1024, 64)             0         ['dense_34[0][0]']
#
#  add_20 (Add)                (None, 1024, 64)             0         ['dropout_25[0][0]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 1024, 64)             128       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_35 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 1024, 64)             0         ['dense_35[0][0]']
#
#  dense_36 (Dense)            (None, 1024, 64)             4160      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)        (None, 1024, 64)             0         ['dense_36[0][0]']
#
#  add_21 (Add)                (None, 1024, 64)             0         ['dropout_27[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 1024, 64)             128       ['add_21[0][0]']
#  yerNormalization)
#
#  dense_37 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_22[0][0]
#                                                                     ']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_37[0][0]']
#
#  tf.compat.v1.transpose_6 (  (None, 16, 1024, 16)         0         ['tf.reshape_6[0][0]']
#  TFOpLambda)
#
#  dense_38 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_6[0][
#                                                                     0]']
#
#  softmax_3 (Softmax)         (None, 16, 1024, 16)         0         ['dense_38[0][0]']
#
#  tf.math.reduce_sum_3 (TFOp  (None, 16, 1024, 1)          0         ['softmax_3[0][0]']
#  Lambda)
#
#  tf.__operators__.add_3 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_3[0][0]']
#  OpLambda)
#
#  tf.math.truediv_3 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_3[0][0]',
#  bda)                                                                'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_3[0][0]']
#
#  dense_39 (Dense)            (None, 16, 1024, 16)         272       ['dropout_28[0][0]']
#
#  tf.compat.v1.transpose_7 (  (None, 1024, 16, 16)         0         ['dense_39[0][0]']
#  TFOpLambda)
#
#  tf.reshape_7 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  dense_40 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_7[0][0]']
#
#  dropout_29 (Dropout)        (None, 1024, 64)             0         ['dense_40[0][0]']
#
#  add_22 (Add)                (None, 1024, 64)             0         ['dropout_29[0][0]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 1024, 64)             128       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_41 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 1024, 64)             0         ['dense_41[0][0]']
#
#  dense_42 (Dense)            (None, 1024, 64)             4160      ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)        (None, 1024, 64)             0         ['dense_42[0][0]']
#
#  add_23 (Add)                (None, 1024, 64)             0         ['dropout_31[0][0]',
#                                                                      'add_22[0][0]']
#
#  layer_normalization_24 (La  (None, 1024, 64)             128       ['add_23[0][0]']
#  yerNormalization)
#
#  dense_43 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_24[0][0]
#                                                                     ']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1024, 16, 16)         0         ['dense_43[0][0]']
#
#  tf.compat.v1.transpose_8 (  (None, 16, 1024, 16)         0         ['tf.reshape_8[0][0]']
#  TFOpLambda)
#
#  dense_44 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_8[0][
#                                                                     0]']
#
#  softmax_4 (Softmax)         (None, 16, 1024, 16)         0         ['dense_44[0][0]']
#
#  tf.math.reduce_sum_4 (TFOp  (None, 16, 1024, 1)          0         ['softmax_4[0][0]']
#  Lambda)
#
#  tf.__operators__.add_4 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_4[0][0]']
#  OpLambda)
#
#  tf.math.truediv_4 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_4[0][0]',
#  bda)                                                                'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_4[0][0]']
#
#  dense_45 (Dense)            (None, 16, 1024, 16)         272       ['dropout_32[0][0]']
#
#  tf.compat.v1.transpose_9 (  (None, 1024, 16, 16)         0         ['dense_45[0][0]']
#  TFOpLambda)
#
#  tf.reshape_9 (TFOpLambda)   (None, 1024, 256)            0         ['tf.compat.v1.transpose_9[0][
#                                                                     0]']
#
#  dense_46 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_9[0][0]']
#
#  dropout_33 (Dropout)        (None, 1024, 64)             0         ['dense_46[0][0]']
#
#  add_24 (Add)                (None, 1024, 64)             0         ['dropout_33[0][0]',
#                                                                      'add_23[0][0]']
#
#  layer_normalization_25 (La  (None, 1024, 64)             128       ['add_24[0][0]']
#  yerNormalization)
#
#  dense_47 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_25[0][0]
#                                                                     ']
#
#  dropout_34 (Dropout)        (None, 1024, 64)             0         ['dense_47[0][0]']
#
#  dense_48 (Dense)            (None, 1024, 64)             4160      ['dropout_34[0][0]']
#
#  dropout_35 (Dropout)        (None, 1024, 64)             0         ['dense_48[0][0]']
#
#  add_25 (Add)                (None, 1024, 64)             0         ['dropout_35[0][0]',
#                                                                      'add_24[0][0]']
#
#  layer_normalization_26 (La  (None, 1024, 64)             128       ['add_25[0][0]']
#  yerNormalization)
#
#  dense_49 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_26[0][0]
#                                                                     ']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_49[0][0]']
#
#  tf.compat.v1.transpose_10   (None, 16, 1024, 16)         0         ['tf.reshape_10[0][0]']
#  (TFOpLambda)
#
#  dense_50 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_10[0]
#                                                                     [0]']
#
#  softmax_5 (Softmax)         (None, 16, 1024, 16)         0         ['dense_50[0][0]']
#
#  tf.math.reduce_sum_5 (TFOp  (None, 16, 1024, 1)          0         ['softmax_5[0][0]']
#  Lambda)
#
#  tf.__operators__.add_5 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_5[0][0]']
#  OpLambda)
#
#  tf.math.truediv_5 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_5[0][0]',
#  bda)                                                                'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_36 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_5[0][0]']
#
#  dense_51 (Dense)            (None, 16, 1024, 16)         272       ['dropout_36[0][0]']
#
#  tf.compat.v1.transpose_11   (None, 1024, 16, 16)         0         ['dense_51[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_11 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_11[0]
#                                                                     [0]']
#
#  dense_52 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_11[0][0]']
#
#  dropout_37 (Dropout)        (None, 1024, 64)             0         ['dense_52[0][0]']
#
#  add_26 (Add)                (None, 1024, 64)             0         ['dropout_37[0][0]',
#                                                                      'add_25[0][0]']
#
#  layer_normalization_27 (La  (None, 1024, 64)             128       ['add_26[0][0]']
#  yerNormalization)
#
#  dense_53 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_27[0][0]
#                                                                     ']
#
#  dropout_38 (Dropout)        (None, 1024, 64)             0         ['dense_53[0][0]']
#
#  dense_54 (Dense)            (None, 1024, 64)             4160      ['dropout_38[0][0]']
#
#  dropout_39 (Dropout)        (None, 1024, 64)             0         ['dense_54[0][0]']
#
#  add_27 (Add)                (None, 1024, 64)             0         ['dropout_39[0][0]',
#                                                                      'add_26[0][0]']
#
#  layer_normalization_28 (La  (None, 1024, 64)             128       ['add_27[0][0]']
#  yerNormalization)
#
#  dense_55 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_28[0][0]
#                                                                     ']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_55[0][0]']
#
#  tf.compat.v1.transpose_12   (None, 16, 1024, 16)         0         ['tf.reshape_12[0][0]']
#  (TFOpLambda)
#
#  dense_56 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_12[0]
#                                                                     [0]']
#
#  softmax_6 (Softmax)         (None, 16, 1024, 16)         0         ['dense_56[0][0]']
#
#  tf.math.reduce_sum_6 (TFOp  (None, 16, 1024, 1)          0         ['softmax_6[0][0]']
#  Lambda)
#
#  tf.__operators__.add_6 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_6[0][0]']
#  OpLambda)
#
#  tf.math.truediv_6 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_6[0][0]',
#  bda)                                                                'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_40 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_6[0][0]']
#
#  dense_57 (Dense)            (None, 16, 1024, 16)         272       ['dropout_40[0][0]']
#
#  tf.compat.v1.transpose_13   (None, 1024, 16, 16)         0         ['dense_57[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_13 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_13[0]
#                                                                     [0]']
#
#  dense_58 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_13[0][0]']
#
#  dropout_41 (Dropout)        (None, 1024, 64)             0         ['dense_58[0][0]']
#
#  add_28 (Add)                (None, 1024, 64)             0         ['dropout_41[0][0]',
#                                                                      'add_27[0][0]']
#
#  layer_normalization_29 (La  (None, 1024, 64)             128       ['add_28[0][0]']
#  yerNormalization)
#
#  dense_59 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_29[0][0]
#                                                                     ']
#
#  dropout_42 (Dropout)        (None, 1024, 64)             0         ['dense_59[0][0]']
#
#  dense_60 (Dense)            (None, 1024, 64)             4160      ['dropout_42[0][0]']
#
#  dropout_43 (Dropout)        (None, 1024, 64)             0         ['dense_60[0][0]']
#
#  add_29 (Add)                (None, 1024, 64)             0         ['dropout_43[0][0]',
#                                                                      'add_28[0][0]']
#
#  layer_normalization_30 (La  (None, 1024, 64)             128       ['add_29[0][0]']
#  yerNormalization)
#
#  dense_61 (Dense)            (None, 1024, 256)            16640     ['layer_normalization_30[0][0]
#                                                                     ']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1024, 16, 16)         0         ['dense_61[0][0]']
#
#  tf.compat.v1.transpose_14   (None, 16, 1024, 16)         0         ['tf.reshape_14[0][0]']
#  (TFOpLambda)
#
#  dense_62 (Dense)            (None, 16, 1024, 16)         272       ['tf.compat.v1.transpose_14[0]
#                                                                     [0]']
#
#  softmax_7 (Softmax)         (None, 16, 1024, 16)         0         ['dense_62[0][0]']
#
#  tf.math.reduce_sum_7 (TFOp  (None, 16, 1024, 1)          0         ['softmax_7[0][0]']
#  Lambda)
#
#  tf.__operators__.add_7 (TF  (None, 16, 1024, 1)          0         ['tf.math.reduce_sum_7[0][0]']
#  OpLambda)
#
#  tf.math.truediv_7 (TFOpLam  (None, 16, 1024, 16)         0         ['softmax_7[0][0]',
#  bda)                                                                'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  dropout_44 (Dropout)        (None, 16, 1024, 16)         0         ['tf.math.truediv_7[0][0]']
#
#  dense_63 (Dense)            (None, 16, 1024, 16)         272       ['dropout_44[0][0]']
#
#  tf.compat.v1.transpose_15   (None, 1024, 16, 16)         0         ['dense_63[0][0]']
#  (TFOpLambda)
#
#  tf.reshape_15 (TFOpLambda)  (None, 1024, 256)            0         ['tf.compat.v1.transpose_15[0]
#                                                                     [0]']
#
#  dense_64 (Dense)            (None, 1024, 64)             16448     ['tf.reshape_15[0][0]']
#
#  dropout_45 (Dropout)        (None, 1024, 64)             0         ['dense_64[0][0]']
#
#  add_30 (Add)                (None, 1024, 64)             0         ['dropout_45[0][0]',
#                                                                      'add_29[0][0]']
#
#  layer_normalization_31 (La  (None, 1024, 64)             128       ['add_30[0][0]']
#  yerNormalization)
#
#  dense_65 (Dense)            (None, 1024, 64)             4160      ['layer_normalization_31[0][0]
#                                                                     ']
#
#  dropout_46 (Dropout)        (None, 1024, 64)             0         ['dense_65[0][0]']
#
#  dense_66 (Dense)            (None, 1024, 64)             4160      ['dropout_46[0][0]']
#
#  dropout_47 (Dropout)        (None, 1024, 64)             0         ['dense_66[0][0]']
#
#  add_31 (Add)                (None, 1024, 64)             0         ['dropout_47[0][0]',
#                                                                      'add_30[0][0]']
#
#  global_average_pooling1d_1  (None, 64)                   0         ['add_31[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_67 (Dense)            (None, 2)                    130       ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 404169 (1.54 MB)
# Trainable params: 404162 (1.54 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
history_EA = run_experiment(model_EA)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5575: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 283/283 [==============================] - 37s 85ms/step - loss: 1.1109 - accuracy: 0.5405 - top5-acc: 1.0000 - Brier score: 0.3207 - F1 score: 0.5405 - Recall: 0.5405 - Precision: 0.5405 - AUC: 0.5497 - val_loss: 1.4241 - val_accuracy: 0.4871 - val_top5-acc: 1.0000 - val_Brier score: 0.4113 - val_F1 score: 0.3559 - val_Recall: 0.4871 - val_Precision: 0.4871 - val_AUC: 0.5698 - lr: 0.0010
# Epoch 2/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.7668 - accuracy: 0.5867 - top5-acc: 1.0000 - Brier score: 0.2659 - F1 score: 0.5866 - Recall: 0.5867 - Precision: 0.5867 - AUC: 0.6072 - val_loss: 0.5679 - val_accuracy: 0.7127 - val_top5-acc: 1.0000 - val_Brier score: 0.1921 - val_F1 score: 0.7116 - val_Recall: 0.7127 - val_Precision: 0.7127 - val_AUC: 0.7791 - lr: 0.0010
# Epoch 3/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.7635 - accuracy: 0.6105 - top5-acc: 1.0000 - Brier score: 0.2581 - F1 score: 0.6104 - Recall: 0.6105 - Precision: 0.6105 - AUC: 0.6444 - val_loss: 0.7445 - val_accuracy: 0.6292 - val_top5-acc: 1.0000 - val_Brier score: 0.2507 - val_F1 score: 0.5978 - val_Recall: 0.6292 - val_Precision: 0.6292 - val_AUC: 0.6913 - lr: 0.0010
# Epoch 4/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.7611 - accuracy: 0.6151 - top5-acc: 1.0000 - Brier score: 0.2561 - F1 score: 0.6150 - Recall: 0.6151 - Precision: 0.6151 - AUC: 0.6497 - val_loss: 0.5427 - val_accuracy: 0.7326 - val_top5-acc: 1.0000 - val_Brier score: 0.1829 - val_F1 score: 0.7266 - val_Recall: 0.7326 - val_Precision: 0.7326 - val_AUC: 0.7986 - lr: 0.0010
# Epoch 5/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.7144 - accuracy: 0.6407 - top5-acc: 1.0000 - Brier score: 0.2386 - F1 score: 0.6407 - Recall: 0.6407 - Precision: 0.6407 - AUC: 0.6907 - val_loss: 0.4566 - val_accuracy: 0.7803 - val_top5-acc: 1.0000 - val_Brier score: 0.1481 - val_F1 score: 0.7763 - val_Recall: 0.7803 - val_Precision: 0.7803 - val_AUC: 0.8768 - lr: 0.0010
# Epoch 6/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.6544 - accuracy: 0.6814 - top5-acc: 1.0000 - Brier score: 0.2173 - F1 score: 0.6814 - Recall: 0.6814 - Precision: 0.6814 - AUC: 0.7338 - val_loss: 0.4302 - val_accuracy: 0.7982 - val_top5-acc: 1.0000 - val_Brier score: 0.1371 - val_F1 score: 0.7974 - val_Recall: 0.7982 - val_Precision: 0.7982 - val_AUC: 0.8963 - lr: 0.0010
# Epoch 7/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.6275 - accuracy: 0.6914 - top5-acc: 1.0000 - Brier score: 0.2086 - F1 score: 0.6913 - Recall: 0.6914 - Precision: 0.6914 - AUC: 0.7549 - val_loss: 0.5278 - val_accuracy: 0.7197 - val_top5-acc: 1.0000 - val_Brier score: 0.1819 - val_F1 score: 0.7081 - val_Recall: 0.7197 - val_Precision: 0.7197 - val_AUC: 0.8151 - lr: 0.0010
# Epoch 8/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.6164 - accuracy: 0.6952 - top5-acc: 1.0000 - Brier score: 0.2042 - F1 score: 0.6952 - Recall: 0.6952 - Precision: 0.6952 - AUC: 0.7671 - val_loss: 0.4538 - val_accuracy: 0.7664 - val_top5-acc: 1.0000 - val_Brier score: 0.1524 - val_F1 score: 0.7622 - val_Recall: 0.7664 - val_Precision: 0.7664 - val_AUC: 0.8630 - lr: 0.0010
# Epoch 9/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5929 - accuracy: 0.7169 - top5-acc: 1.0000 - Brier score: 0.1946 - F1 score: 0.7168 - Recall: 0.7169 - Precision: 0.7169 - AUC: 0.7853 - val_loss: 0.4722 - val_accuracy: 0.7535 - val_top5-acc: 1.0000 - val_Brier score: 0.1608 - val_F1 score: 0.7486 - val_Recall: 0.7535 - val_Precision: 0.7535 - val_AUC: 0.8506 - lr: 0.0010
# Epoch 10/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5619 - accuracy: 0.7297 - top5-acc: 1.0000 - Brier score: 0.1855 - F1 score: 0.7296 - Recall: 0.7297 - Precision: 0.7297 - AUC: 0.8011 - val_loss: 0.4766 - val_accuracy: 0.7614 - val_top5-acc: 1.0000 - val_Brier score: 0.1602 - val_F1 score: 0.7564 - val_Recall: 0.7614 - val_Precision: 0.7614 - val_AUC: 0.8513 - lr: 0.0010
# Epoch 11/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5145 - accuracy: 0.7533 - top5-acc: 1.0000 - Brier score: 0.1693 - F1 score: 0.7533 - Recall: 0.7533 - Precision: 0.7533 - AUC: 0.8291 - val_loss: 0.4040 - val_accuracy: 0.8032 - val_top5-acc: 1.0000 - val_Brier score: 0.1343 - val_F1 score: 0.8019 - val_Recall: 0.8032 - val_Precision: 0.8032 - val_AUC: 0.8924 - lr: 0.0010
# Epoch 12/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5360 - accuracy: 0.7433 - top5-acc: 1.0000 - Brier score: 0.1765 - F1 score: 0.7432 - Recall: 0.7433 - Precision: 0.7433 - AUC: 0.8177 - val_loss: 0.3702 - val_accuracy: 0.8181 - val_top5-acc: 1.0000 - val_Brier score: 0.1193 - val_F1 score: 0.8181 - val_Recall: 0.8181 - val_Precision: 0.8181 - val_AUC: 0.9167 - lr: 0.0010
# Epoch 13/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5124 - accuracy: 0.7552 - top5-acc: 1.0000 - Brier score: 0.1672 - F1 score: 0.7551 - Recall: 0.7552 - Precision: 0.7552 - AUC: 0.8330 - val_loss: 0.4546 - val_accuracy: 0.7624 - val_top5-acc: 1.0000 - val_Brier score: 0.1548 - val_F1 score: 0.7577 - val_Recall: 0.7624 - val_Precision: 0.7624 - val_AUC: 0.8601 - lr: 0.0010
# Epoch 14/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5035 - accuracy: 0.7624 - top5-acc: 1.0000 - Brier score: 0.1651 - F1 score: 0.7623 - Recall: 0.7624 - Precision: 0.7624 - AUC: 0.8376 - val_loss: 0.3383 - val_accuracy: 0.8529 - val_top5-acc: 1.0000 - val_Brier score: 0.1056 - val_F1 score: 0.8514 - val_Recall: 0.8529 - val_Precision: 0.8529 - val_AUC: 0.9362 - lr: 0.0010
# Epoch 15/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5169 - accuracy: 0.7512 - top5-acc: 1.0000 - Brier score: 0.1702 - F1 score: 0.7512 - Recall: 0.7512 - Precision: 0.7512 - AUC: 0.8317 - val_loss: 0.3424 - val_accuracy: 0.8330 - val_top5-acc: 1.0000 - val_Brier score: 0.1095 - val_F1 score: 0.8330 - val_Recall: 0.8330 - val_Precision: 0.8330 - val_AUC: 0.9297 - lr: 0.0010
# Epoch 16/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.5087 - accuracy: 0.7571 - top5-acc: 1.0000 - Brier score: 0.1666 - F1 score: 0.7570 - Recall: 0.7571 - Precision: 0.7571 - AUC: 0.8377 - val_loss: 0.5795 - val_accuracy: 0.6998 - val_top5-acc: 1.0000 - val_Brier score: 0.1990 - val_F1 score: 0.6838 - val_Recall: 0.6998 - val_Precision: 0.6998 - val_AUC: 0.8091 - lr: 0.0010
# Epoch 17/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4760 - accuracy: 0.7759 - top5-acc: 1.0000 - Brier score: 0.1553 - F1 score: 0.7759 - Recall: 0.7759 - Precision: 0.7759 - AUC: 0.8550 - val_loss: 0.4218 - val_accuracy: 0.7803 - val_top5-acc: 1.0000 - val_Brier score: 0.1419 - val_F1 score: 0.7772 - val_Recall: 0.7803 - val_Precision: 0.7803 - val_AUC: 0.8798 - lr: 0.0010
# Epoch 18/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4721 - accuracy: 0.7748 - top5-acc: 1.0000 - Brier score: 0.1536 - F1 score: 0.7748 - Recall: 0.7748 - Precision: 0.7748 - AUC: 0.8579 - val_loss: 0.3353 - val_accuracy: 0.8360 - val_top5-acc: 1.0000 - val_Brier score: 0.1057 - val_F1 score: 0.8359 - val_Recall: 0.8360 - val_Precision: 0.8360 - val_AUC: 0.9364 - lr: 0.0010
# Epoch 19/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4721 - accuracy: 0.7759 - top5-acc: 1.0000 - Brier score: 0.1537 - F1 score: 0.7759 - Recall: 0.7759 - Precision: 0.7759 - AUC: 0.8582 - val_loss: 0.4250 - val_accuracy: 0.7763 - val_top5-acc: 1.0000 - val_Brier score: 0.1427 - val_F1 score: 0.7741 - val_Recall: 0.7763 - val_Precision: 0.7763 - val_AUC: 0.8780 - lr: 0.0010
# Epoch 20/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4556 - accuracy: 0.7808 - top5-acc: 1.0000 - Brier score: 0.1493 - F1 score: 0.7807 - Recall: 0.7808 - Precision: 0.7808 - AUC: 0.8664 - val_loss: 0.3606 - val_accuracy: 0.8400 - val_top5-acc: 1.0000 - val_Brier score: 0.1133 - val_F1 score: 0.8399 - val_Recall: 0.8400 - val_Precision: 0.8400 - val_AUC: 0.9255 - lr: 0.0010
# Epoch 21/100
# 283/283 [==============================] - 22s 77ms/step - loss: 0.4572 - accuracy: 0.7847 - top5-acc: 1.0000 - Brier score: 0.1489 - F1 score: 0.7846 - Recall: 0.7847 - Precision: 0.7847 - AUC: 0.8666 - val_loss: 0.3666 - val_accuracy: 0.8241 - val_top5-acc: 1.0000 - val_Brier score: 0.1190 - val_F1 score: 0.8234 - val_Recall: 0.8241 - val_Precision: 0.8241 - val_AUC: 0.9163 - lr: 0.0010
# Epoch 22/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4484 - accuracy: 0.7868 - top5-acc: 1.0000 - Brier score: 0.1454 - F1 score: 0.7867 - Recall: 0.7868 - Precision: 0.7868 - AUC: 0.8721 - val_loss: 0.4571 - val_accuracy: 0.7565 - val_top5-acc: 1.0000 - val_Brier score: 0.1567 - val_F1 score: 0.7505 - val_Recall: 0.7565 - val_Precision: 0.7565 - val_AUC: 0.8582 - lr: 0.0010
# Epoch 23/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4577 - accuracy: 0.7892 - top5-acc: 1.0000 - Brier score: 0.1483 - F1 score: 0.7892 - Recall: 0.7892 - Precision: 0.7892 - AUC: 0.8676 - val_loss: 0.3479 - val_accuracy: 0.8320 - val_top5-acc: 1.0000 - val_Brier score: 0.1098 - val_F1 score: 0.8319 - val_Recall: 0.8320 - val_Precision: 0.8320 - val_AUC: 0.9300 - lr: 0.0010
# Epoch 24/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4102 - accuracy: 0.8090 - top5-acc: 1.0000 - Brier score: 0.1322 - F1 score: 0.8089 - Recall: 0.8090 - Precision: 0.8090 - AUC: 0.8939 - val_loss: 0.3282 - val_accuracy: 0.8539 - val_top5-acc: 1.0000 - val_Brier score: 0.1008 - val_F1 score: 0.8539 - val_Recall: 0.8539 - val_Precision: 0.8539 - val_AUC: 0.9427 - lr: 5.0000e-04
# Epoch 25/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4166 - accuracy: 0.8078 - top5-acc: 1.0000 - Brier score: 0.1341 - F1 score: 0.8077 - Recall: 0.8078 - Precision: 0.8078 - AUC: 0.8906 - val_loss: 0.3315 - val_accuracy: 0.8509 - val_top5-acc: 1.0000 - val_Brier score: 0.1041 - val_F1 score: 0.8508 - val_Recall: 0.8509 - val_Precision: 0.8509 - val_AUC: 0.9378 - lr: 5.0000e-04
# Epoch 26/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4101 - accuracy: 0.8065 - top5-acc: 1.0000 - Brier score: 0.1325 - F1 score: 0.8065 - Recall: 0.8065 - Precision: 0.8065 - AUC: 0.8938 - val_loss: 0.3365 - val_accuracy: 0.8539 - val_top5-acc: 1.0000 - val_Brier score: 0.1049 - val_F1 score: 0.8538 - val_Recall: 0.8539 - val_Precision: 0.8539 - val_AUC: 0.9369 - lr: 5.0000e-04
# Epoch 27/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4174 - accuracy: 0.8084 - top5-acc: 1.0000 - Brier score: 0.1343 - F1 score: 0.8083 - Recall: 0.8084 - Precision: 0.8084 - AUC: 0.8901 - val_loss: 0.3032 - val_accuracy: 0.8787 - val_top5-acc: 1.0000 - val_Brier score: 0.0909 - val_F1 score: 0.8786 - val_Recall: 0.8787 - val_Precision: 0.8787 - val_AUC: 0.9542 - lr: 5.0000e-04
# Epoch 28/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4304 - accuracy: 0.7974 - top5-acc: 1.0000 - Brier score: 0.1395 - F1 score: 0.7973 - Recall: 0.7974 - Precision: 0.7974 - AUC: 0.8819 - val_loss: 0.3163 - val_accuracy: 0.8698 - val_top5-acc: 1.0000 - val_Brier score: 0.0960 - val_F1 score: 0.8695 - val_Recall: 0.8698 - val_Precision: 0.8698 - val_AUC: 0.9483 - lr: 5.0000e-04
# Epoch 29/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3992 - accuracy: 0.8168 - top5-acc: 1.0000 - Brier score: 0.1282 - F1 score: 0.8167 - Recall: 0.8168 - Precision: 0.8168 - AUC: 0.9001 - val_loss: 0.2925 - val_accuracy: 0.8718 - val_top5-acc: 1.0000 - val_Brier score: 0.0885 - val_F1 score: 0.8716 - val_Recall: 0.8718 - val_Precision: 0.8718 - val_AUC: 0.9569 - lr: 5.0000e-04
# Epoch 30/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4038 - accuracy: 0.8126 - top5-acc: 1.0000 - Brier score: 0.1297 - F1 score: 0.8125 - Recall: 0.8126 - Precision: 0.8126 - AUC: 0.8976 - val_loss: 0.3398 - val_accuracy: 0.8429 - val_top5-acc: 1.0000 - val_Brier score: 0.1086 - val_F1 score: 0.8425 - val_Recall: 0.8429 - val_Precision: 0.8429 - val_AUC: 0.9299 - lr: 5.0000e-04
# Epoch 31/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3937 - accuracy: 0.8208 - top5-acc: 1.0000 - Brier score: 0.1260 - F1 score: 0.8207 - Recall: 0.8208 - Precision: 0.8208 - AUC: 0.9032 - val_loss: 0.4337 - val_accuracy: 0.7694 - val_top5-acc: 1.0000 - val_Brier score: 0.1473 - val_F1 score: 0.7647 - val_Recall: 0.7694 - val_Precision: 0.7694 - val_AUC: 0.8733 - lr: 5.0000e-04
# Epoch 32/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.4077 - accuracy: 0.8132 - top5-acc: 1.0000 - Brier score: 0.1315 - F1 score: 0.8131 - Recall: 0.8132 - Precision: 0.8132 - AUC: 0.8947 - val_loss: 0.3218 - val_accuracy: 0.8529 - val_top5-acc: 1.0000 - val_Brier score: 0.1009 - val_F1 score: 0.8528 - val_Recall: 0.8529 - val_Precision: 0.8529 - val_AUC: 0.9413 - lr: 5.0000e-04
# Epoch 33/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3846 - accuracy: 0.8261 - top5-acc: 1.0000 - Brier score: 0.1229 - F1 score: 0.8260 - Recall: 0.8261 - Precision: 0.8261 - AUC: 0.9078 - val_loss: 0.3148 - val_accuracy: 0.8549 - val_top5-acc: 1.0000 - val_Brier score: 0.0995 - val_F1 score: 0.8548 - val_Recall: 0.8549 - val_Precision: 0.8549 - val_AUC: 0.9409 - lr: 5.0000e-04
# Epoch 34/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3872 - accuracy: 0.8265 - top5-acc: 1.0000 - Brier score: 0.1235 - F1 score: 0.8264 - Recall: 0.8265 - Precision: 0.8265 - AUC: 0.9065 - val_loss: 0.3287 - val_accuracy: 0.8459 - val_top5-acc: 1.0000 - val_Brier score: 0.1053 - val_F1 score: 0.8453 - val_Recall: 0.8459 - val_Precision: 0.8459 - val_AUC: 0.9338 - lr: 5.0000e-04
# Epoch 35/100
# 283/283 [==============================] - 22s 77ms/step - loss: 0.3778 - accuracy: 0.8344 - top5-acc: 1.0000 - Brier score: 0.1195 - F1 score: 0.8343 - Recall: 0.8344 - Precision: 0.8344 - AUC: 0.9121 - val_loss: 0.2810 - val_accuracy: 0.8738 - val_top5-acc: 1.0000 - val_Brier score: 0.0848 - val_F1 score: 0.8737 - val_Recall: 0.8738 - val_Precision: 0.8738 - val_AUC: 0.9589 - lr: 2.5000e-04
# Epoch 36/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3666 - accuracy: 0.8407 - top5-acc: 1.0000 - Brier score: 0.1152 - F1 score: 0.8406 - Recall: 0.8407 - Precision: 0.8407 - AUC: 0.9189 - val_loss: 0.2620 - val_accuracy: 0.8857 - val_top5-acc: 1.0000 - val_Brier score: 0.0780 - val_F1 score: 0.8855 - val_Recall: 0.8857 - val_Precision: 0.8857 - val_AUC: 0.9658 - lr: 2.5000e-04
# Epoch 37/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3850 - accuracy: 0.8245 - top5-acc: 1.0000 - Brier score: 0.1227 - F1 score: 0.8244 - Recall: 0.8245 - Precision: 0.8245 - AUC: 0.9082 - val_loss: 0.2679 - val_accuracy: 0.8797 - val_top5-acc: 1.0000 - val_Brier score: 0.0804 - val_F1 score: 0.8797 - val_Recall: 0.8797 - val_Precision: 0.8797 - val_AUC: 0.9646 - lr: 2.5000e-04
# Epoch 38/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3744 - accuracy: 0.8335 - top5-acc: 1.0000 - Brier score: 0.1186 - F1 score: 0.8334 - Recall: 0.8335 - Precision: 0.8335 - AUC: 0.9143 - val_loss: 0.3255 - val_accuracy: 0.8529 - val_top5-acc: 1.0000 - val_Brier score: 0.1052 - val_F1 score: 0.8524 - val_Recall: 0.8529 - val_Precision: 0.8529 - val_AUC: 0.9342 - lr: 2.5000e-04
# Epoch 39/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3809 - accuracy: 0.8299 - top5-acc: 1.0000 - Brier score: 0.1214 - F1 score: 0.8299 - Recall: 0.8299 - Precision: 0.8299 - AUC: 0.9102 - val_loss: 0.4057 - val_accuracy: 0.7922 - val_top5-acc: 1.0000 - val_Brier score: 0.1375 - val_F1 score: 0.7888 - val_Recall: 0.7922 - val_Precision: 0.7922 - val_AUC: 0.8887 - lr: 2.5000e-04
# Epoch 40/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3828 - accuracy: 0.8280 - top5-acc: 1.0000 - Brier score: 0.1218 - F1 score: 0.8279 - Recall: 0.8280 - Precision: 0.8280 - AUC: 0.9096 - val_loss: 0.3385 - val_accuracy: 0.8390 - val_top5-acc: 1.0000 - val_Brier score: 0.1107 - val_F1 score: 0.8382 - val_Recall: 0.8390 - val_Precision: 0.8390 - val_AUC: 0.9274 - lr: 2.5000e-04
# Epoch 41/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3818 - accuracy: 0.8315 - top5-acc: 1.0000 - Brier score: 0.1206 - F1 score: 0.8314 - Recall: 0.8315 - Precision: 0.8315 - AUC: 0.9104 - val_loss: 0.4756 - val_accuracy: 0.7465 - val_top5-acc: 1.0000 - val_Brier score: 0.1642 - val_F1 score: 0.7374 - val_Recall: 0.7465 - val_Precision: 0.7465 - val_AUC: 0.8624 - lr: 2.5000e-04
# Epoch 42/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3743 - accuracy: 0.8378 - top5-acc: 1.0000 - Brier score: 0.1178 - F1 score: 0.8377 - Recall: 0.8378 - Precision: 0.8378 - AUC: 0.9155 - val_loss: 0.3454 - val_accuracy: 0.8250 - val_top5-acc: 1.0000 - val_Brier score: 0.1139 - val_F1 score: 0.8239 - val_Recall: 0.8250 - val_Precision: 0.8250 - val_AUC: 0.9237 - lr: 1.2500e-04
# Epoch 43/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3722 - accuracy: 0.8387 - top5-acc: 1.0000 - Brier score: 0.1171 - F1 score: 0.8385 - Recall: 0.8387 - Precision: 0.8387 - AUC: 0.9185 - val_loss: 0.3420 - val_accuracy: 0.8310 - val_top5-acc: 1.0000 - val_Brier score: 0.1120 - val_F1 score: 0.8300 - val_Recall: 0.8310 - val_Precision: 0.8310 - val_AUC: 0.9259 - lr: 1.2500e-04
# Epoch 44/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3811 - accuracy: 0.8326 - top5-acc: 1.0000 - Brier score: 0.1203 - F1 score: 0.8325 - Recall: 0.8326 - Precision: 0.8326 - AUC: 0.9135 - val_loss: 0.2747 - val_accuracy: 0.8777 - val_top5-acc: 1.0000 - val_Brier score: 0.0822 - val_F1 score: 0.8776 - val_Recall: 0.8777 - val_Precision: 0.8777 - val_AUC: 0.9642 - lr: 1.2500e-04
# Epoch 45/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3964 - accuracy: 0.8248 - top5-acc: 1.0000 - Brier score: 0.1260 - F1 score: 0.8246 - Recall: 0.8248 - Precision: 0.8248 - AUC: 0.9048 - val_loss: 0.3085 - val_accuracy: 0.8698 - val_top5-acc: 1.0000 - val_Brier score: 0.0950 - val_F1 score: 0.8697 - val_Recall: 0.8698 - val_Precision: 0.8698 - val_AUC: 0.9492 - lr: 1.2500e-04
# Epoch 46/100
# 283/283 [==============================] - 22s 76ms/step - loss: 0.3848 - accuracy: 0.8322 - top5-acc: 1.0000 - Brier score: 0.1214 - F1 score: 0.8320 - Recall: 0.8322 - Precision: 0.8322 - AUC: 0.9136 - val_loss: 0.3446 - val_accuracy: 0.8340 - val_top5-acc: 1.0000 - val_Brier score: 0.1121 - val_F1 score: 0.8330 - val_Recall: 0.8340 - val_Precision: 0.8340 - val_AUC: 0.9256 - lr: 1.2500e-04

# %%
plot_training_curves(history_EA, 'Kidney Cancer, EA Transfomer')
