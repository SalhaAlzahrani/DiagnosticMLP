# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/DiagnosticMLP/blob/main/CT_DiagnosticMLP_Chest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟨 Chest CT Image classification with modern MLP models

# %% [markdown]
# This notebook implements five modern attention-free, multi-layer perceptron (MLP) based models for medical image classification, demonstrated on the CT medical image datasets:
#
# - The MLP-Mixer model, by Ilya Tolstikhin et al., based on two types of MLPs.
# - The FNet model, by James Lee-Thorp et al., based on unparameterized Fourier Transform.
# - The gMLP model, by Hanxiao Liu et al., based on MLP with gating.
# - The resMLP model, by Touvron et al. (2023), based on residual connections.
# - The DiagnosticMLP moadel, by Alzahrani S. (2024), based on three types of MLPs with gating, preceded by unparameterized Fourier Transform.

# %%
# !pip install nest_asyncio
# !pip install -U -q tensorflow-addons
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.5.8)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.4 MB/s eta 0:00:00

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math
import nest_asyncio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
# ## 🟡 plot_training_curves

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(len(history.history['loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('_mpl-gallery') #ggplot #bmh
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10)

# %% [markdown]
# ## 🟡 Hyperparameters

# %%
path = '/content/drive/MyDrive/CT_Datasets/Computed Tomography (CT) of the Chest/'

image_size = 64 # We'll resize input images to this size.
patch_size = 256
input_shape = (64, 64, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
patch_size = 8  # Size of the patches to be extracted from the input images.
num_patches = (image_size // patch_size) ** 2  # Size of the data array.
embedding_dim = 256  # Number of hidden units.
num_blocks = 4  # Number of blocks.

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 8 X 8 = 64
# Patches per image: 64
# Elements per patch (3 channels): 192

# %% [markdown]
# ## 🟡 Dataset

# %%
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(image_size, image_size),
    color_mode='rgb',
    seed=128,
    validation_split=0.1,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 9208 files belonging to 4 classes.
# Using 8288 files for training.
# Found 9208 files belonging to 4 classes.
# Using 920 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
##################
num_classes = len(class_names)
##################
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(num_classes): classes.append(i)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# ['COVID-19', 'Normal', 'Pneumonia-Bacterial', 'Pneumonia-Viral']
# {0: 1.7970335675253708,
#  1: 0.7039755351681957,
#  2: 0.7670776407864045,
#  3: 1.3900966183574879}

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 🟡 Classification model
# We implement a method that builds a classifier given the processing blocks.

# %%
def build_classifier(blocks, positional_encoding=False):
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size, num_patches)(augmented)
    # Encode patches to generate a [batch_size, num_patches, embedding_dim] tensor.
    x = layers.Dense(units=embedding_dim)(patches)
    if positional_encoding:
        positions = tf.range(start=0, limit=num_patches, delta=1)
        position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=embedding_dim
        )(positions)
        x = x + position_embedding
    # Process x using the module blocks.
    x = blocks(x)
    # Apply global average pooling to generate a [batch_size, embedding_dim] representation tensor.
    representation = layers.GlobalAveragePooling1D()(x)
    # Apply dropout.
    representation = layers.Dropout(rate=dropout_rate)(representation)
    # Compute logits outputs.
    logits = layers.Dense(num_classes)(representation)
    # Create the Keras model.
    return keras.Model(inputs=inputs, outputs=logits)

# %% [markdown]
# ## 🟡 Experiment
# We implement a utility function to compile, train, and evaluate a given model.

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# ## 🟡 Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip('horizontal_and_vertical'),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
        layers.RandomContrast(factor=0.2),
        layers.RandomCrop(height=image_size, width=image_size),
        layers.RandomBrightness(factor=0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ## 🟡 Patch extraction

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size, num_patches):
        super().__init__()
        self.patch_size = patch_size
        self.num_patches = num_patches

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, self.num_patches, patch_dims])
        return patches

# %% [markdown]
# # ⚛ MLP-Mixer model
# The MLP-Mixer is an architecture based exclusively on multi-layer perceptrons (MLPs), that contains two types of MLP layers:
#
# One applied independently to image patches, which mixes the per-location features.
# The other applied across patches (along channels), which mixes spatial information.
# This is similar to a depthwise separable convolution based model such as the Xception model, but with two chained dense transforms, no max pooling, and layer normalization instead of batch normalization.

# %%
class MLPMixerLayer(layers.Layer):
    def __init__(self, num_patches, hidden_units, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.mlp1 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=num_patches),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.mlp2 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=embedding_dim),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.normalize = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize(inputs)
        # Transpose inputs from [num_batches, num_patches, hidden_units] to [num_batches, hidden_units, num_patches].
        x_channels = tf.linalg.matrix_transpose(x)
        # Apply mlp1 on each channel independently.
        mlp1_outputs = self.mlp1(x_channels)
        # Transpose mlp1_outputs from [num_batches, hidden_dim, num_patches] to [num_batches, num_patches, hidden_units].
        mlp1_outputs = tf.linalg.matrix_transpose(mlp1_outputs)
        # Add skip connection.
        x = mlp1_outputs + inputs
        # Apply layer normalization.
        x_patches = self.normalize(x)
        # Apply mlp2 on each patch independtenly.
        mlp2_outputs = self.mlp2(x_patches)
        # Add skip connection.
        x = x + mlp2_outputs
        return x

# %%
mlpmixer_blocks = keras.Sequential(
    [MLPMixerLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
mlpmixer_classifier = build_classifier(mlpmixer_blocks)

# %%
history_mlpmixer = run_experiment(mlpmixer_classifier)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 856s 3s/step - loss: 22.9137 - accuracy: 0.3860 - top5-acc: 1.0000 - Brier score: 2693.8057 - F1 score: 0.3778 - Recall: 0.5520 - Precision: 0.3392 - AUC: 0.6053 - val_loss: 1.1759 - val_accuracy: 0.5293 - val_top5-acc: 1.0000 - val_Brier score: 10.0107 - val_F1 score: 0.5174 - val_Recall: 0.7446 - val_Precision: 0.4377 - val_AUC: 0.7397 - lr: 0.0010
# Epoch 2/100
100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5749 - accuracy: 0.7400 - top5-acc: 1.0000 - Brier score: 6.0544 - F1 score: 0.7285 - Recall: 0.9324 - Precision: 0.5193 - AUC: 0.8544 - val_loss: 0.5310 - val_accuracy: 0.7772 - val_top5-acc: 1.0000 - val_Brier score: 11.2383 - val_F1 score: 0.7704 - val_Recall: 0.9826 - val_Precision: 0.4536 - val_AUC: 0.8211 - lr: 5.0000e-04
# Epoch 25/100
# 259/259 [==============================] - 23s 88ms/step - loss: 0.5946 - accuracy: 0.7396 - top5-acc: 1.0000 - Brier score: 5.7659 - F1 score: 0.7270 - Recall: 0.9292 - Precision: 0.5210 - AUC: 0.8530 - val_loss: 0.5283 - val_accuracy: 0.7848 - val_top5-acc: 1.0000 - val_Brier score: 14.3402 - val_F1 score: 0.7716 - val_Recall: 0.9543 - val_Precision: 0.5632 - val_AUC: 0.8738 - lr: 5.0000e-04

# %%
plot_training_curves(history_mlpmixer, 'MLP-Mixer for Computed Tomography of the Chest')

# %% [markdown]
# The MLP-Mixer model tends to have much less number of parameters compared to convolutional and transformer-based models, which leads to less training and serving computational cost.
#
# As mentioned in the MLP-Mixer paper, when pre-trained on large datasets, or with modern regularization schemes, the MLP-Mixer attains competitive scores to state-of-the-art models. You can obtain better results by increasing the embedding dimensions, increasing, increasing the number of mixer blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes.
#
#
# ---

# %% [markdown]
# # ⚛ FNet model
# The FNet uses a similar block to the Transformer block. However, FNet replaces the self-attention layer in the Transformer block with a parameter-free 2D Fourier transformation layer:
#
# - One 1D Fourier Transform is applied along the patches.
# - One 1D Fourier Transform is applied along the channels.

# %%
class FNetLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.ffn = keras.Sequential(
            [
                layers.Dense(units=embedding_dim),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
                layers.Dense(units=embedding_dim),
            ]
        )
        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        # Apply layer normalization.
        x = self.normalize1(x)
        # Apply Feedfowrad network.
        x_ffn = self.ffn(x)
        # Add skip connection.
        x = x + x_ffn
        # Apply layer normalization.
        return self.normalize2(x)

# %%
fnet_blocks = keras.Sequential(
    [FNetLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
fnet_classifier = build_classifier(fnet_blocks, positional_encoding=True)

# %%
history_fnet = run_experiment(fnet_classifier)
# Out:
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
100
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5953 - accuracy: 0.7553 - top5-acc: 1.0000 - Brier score: 2.8271 - F1 score: 0.7394 - Recall: 0.8842 - Precision: 0.5927 - AUC: 0.8899 - val_loss: 0.5838 - val_accuracy: 0.7489 - val_top5-acc: 1.0000 - val_Brier score: 3.6373 - val_F1 score: 0.7388 - val_Recall: 0.8967 - val_Precision: 0.5922 - val_AUC: 0.8891 - lr: 3.1250e-05

# %%
plot_training_curves(history_fnet, 'FNet for Computed Tomography of the Chest')

# %% [markdown]
# As shown in the FNet paper, better results can be achieved by increasing the embedding dimensions, increasing the number of FNet blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes. The FNet scales very efficiently to long inputs, runs much faster than attention-based Transformer models, and produces competitive accuracy results.
#
#
#
# ---

# %% [markdown]
# # ⚛ gMLP model
# The gMLP is a MLP architecture that features a Spatial Gating Unit (SGU). The SGU enables cross-patch interactions across the spatial (channel) dimension, by:
#
# - Transforming the input spatially by applying linear projection across patches (along channels).
# - Applying element-wise multiplication of the input and its spatial transformation.

# %%
class gMLPLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.channel_projection1 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.channel_projection2 = layers.Dense(units=embedding_dim)
        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )
        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize2(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize1(inputs)
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.channel_projection1(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        return x + x_projected

# %%
gmlp_blocks = keras.Sequential(
    [gMLPLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
gmlp_classifier = build_classifier(gmlp_blocks)

# %%
history_gmlp = run_experiment(gmlp_classifier)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 29s 91ms/step - loss: 1.3563 - accuracy: 0.3236 - top5-acc: 1.0000 - Brier score: 0.9802 - F1 score: 0.3210 - Recall: 0.4484 - Precision: 0.3185 - AUC: 0.6003 - val_loss: 0.9826 - val_accuracy: 0.5728 - val_top5-acc: 1.0000 - val_Brier score: 1.9829 - val_F1 score: 0.4973 - val_Recall: 0.8478 - val_Precision: 0.4075 - val_AUC: 0.7674 - lr: 0.0010
# Epoch 2/100
# 259/259 [==============================] - 23s 86ms/step - loss: 0
100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5540 - accuracy: 0.7593 - top5-acc: 1.0000 - Brier score: 5.6620 - F1 score: 0.7461 - Recall: 0.9263 - Precision: 0.5494 - AUC: 0.8748 - val_loss: 0.5541 - val_accuracy: 0.7630 - val_top5-acc: 1.0000 - val_Brier score: 10.1194 - val_F1 score: 0.7631 - val_Recall: 0.9489 - val_Precision: 0.5432 - val_AUC: 0.8658 - lr: 1.2500e-04
# Epoch 31/100
# 259/259 [==============================] - 23s 88ms/step - loss: 0.5414 - accuracy: 0.7639 - top5-acc: 1.0000 - Brier score: 5.8770 - F1 score: 0.7527 - Recall: 0.9274 - Precision: 0.5517 - AUC: 0.8761 - val_loss: 0.6187 - val_accuracy: 0.7315 - val_top5-acc: 1.0000 - val_Brier score: 9.9537 - val_F1 score: 0.7358 - val_Recall: 0.9359 - val_Precision: 0.5446 - val_AUC: 0.8653 - lr: 1.2500e-04
# Epoch 32/100
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5446 - accuracy: 0.7644 - top5-acc: 1.0000 - Brier score: 5.6877 - F1 score: 0.7513 - Recall: 0.9260 - Precision: 0.5546 - AUC: 0.8763 - val_loss: 0.5786 - val_accuracy: 0.7435 - val_top5-acc: 1.0000 - val_Brier score: 9.1007 - val_F1 score: 0.7464 - val_Recall: 0.9380 - val_Precision: 0.5539 - val_AUC: 0.8711 - lr: 6.2500e-05
# Epoch 33/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5395 - accuracy: 0.7633 - top5-acc: 1.0000 - Brier score: 5.4999 - F1 score: 0.7515 - Recall: 0.9262 - Precision: 0.5549 - AUC: 0.8786 - val_loss: 0.5786 - val_accuracy: 0.7533 - val_top5-acc: 1.0000 - val_Brier score: 9.7870 - val_F1 score: 0.7559 - val_Recall: 0.9424 - val_Precision: 0.5470 - val_AUC: 0.8676 - lr: 6.2500e-05
# Epoch 34/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5465 - accuracy: 0.7695 - top5-acc: 1.0000 - Brier score: 5.3203 - F1 score: 0.7577 - Recall: 0.9272 - Precision: 0.5577 - AUC: 0.8790 - val_loss: 0.6155 - val_accuracy: 0.7283 - val_top5-acc: 1.0000 - val_Brier score: 9.5703 - val_F1 score: 0.7318 - val_Recall: 0.9348 - val_Precision: 0.5372 - val_AUC: 0.8631 - lr: 6.2500e-05
# Epoch 35/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5480 - accuracy: 0.7642 - top5-acc: 1.0000 - Brier score: 5.2271 - F1 score: 0.7513 - Recall: 0.9210 - Precision: 0.5542 - AUC: 0.8776 - val_loss: 0.5573 - val_accuracy: 0.7652 - val_top5-acc: 1.0000 - val_Brier score: 8.4226 - val_F1 score: 0.7646 - val_Recall: 0.9370 - val_Precision: 0.5554 - val_AUC: 0.8727 - lr: 6.2500e-05
# Epoch 36/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5470 - accuracy: 0.7609 - top5-acc: 1.0000 - Brier score: 5.2691 - F1 score: 0.7484 - Recall: 0.9231 - Precision: 0.5555 - AUC: 0.8785 - val_loss: 0.5587 - val_accuracy: 0.7630 - val_top5-acc: 1.0000 - val_Brier score: 9.5210 - val_F1 score: 0.7667 - val_Recall: 0.9424 - val_Precision: 0.5480 - val_AUC: 0.8692 - lr: 6.2500e-05

# %%
plot_training_curves(history_gmlp, 'gMLP for Computed Tomography of the Chest')

# %% [markdown]
# As shown in the gMLP paper, better results can be achieved by increasing the embedding dimensions, increasing the number of gMLP blocks, and training the model for longer. You may also try to increase the size of the input images and use different patch sizes. Note that, the paper used advanced regularization strategies, such as MixUp and CutMix, as well as AutoAugment.
#
#
#
# ---

# %% [markdown]
# # ⚛ ResMLP

# %%
class Affine(tf.keras.layers.Layer):
    def __init__(self, n_channels:int, biased:bool):
        super(Affine, self).__init__()
        self.n_channels = n_channels
        self.biased = biased
        self.a = tf.Variable(tf.ones([1,1,self.n_channels]), dtype = 'float32') if self.biased else tf.Variable(tf.random.normal([1,1,self.n_channels], 0, 0.001), dtype = 'float32')
        self.b = tf.Variable(tf.zeros([1,1,self.n_channels]), dtype = 'float32') if self.biased else None

    def call(self, X):
        X = X * self.a
        if self.biased:
            X = X + self.b
        return X

class ResLayer(tf.keras.layers.Layer):
    def __init__(self, n_dims:int, n_patches:int):
        super(ResLayer, self).__init__()
        self.n_dims = n_dims
        self.n_patches = n_patches
        self.affine_pre1 = Affine(self.n_dims, True)
        self.affine_pre2 = Affine(self.n_dims, True)
        self.affine_pos1 = Affine(self.n_dims, False)
        self.affine_pos2 = Affine(self.n_dims, False)
        self.t = tf.keras.layers.Permute((2,1))
        self.linear1 = tf.keras.layers.Dense(self.n_patches, kernel_initializer = tf.keras.initializers.glorot_normal())
        self.linear2 = tf.keras.layers.Dense(self.n_dims*4, kernel_initializer = tf.keras.initializers.glorot_normal())
        self.linear3 = tf.keras.layers.Dense(self.n_dims, kernel_initializer = tf.keras.initializers.glorot_normal())

    def call(self, X):
        #Cross-patch
        y = self.affine_pre1(X)
        y = self.t(y)
        y = self.linear1(y)
        y = self.t(y)
        y = self.affine_pos1(y)
        X = X + y
        #Cross-channel
        y = self.affine_pre2(X)
        y = self.linear2(y)
        y = tf.nn.gelu(y)
        y = self.linear3(y)
        y = self.affine_pos2(y)
        y = X + y
        return y

class ResMLP(tf.keras.models.Model):
    def __init__(self, n_dims:int, image_size:int, patch_size:int, n_res_layers:int, n_labels:int, mode:str = 'softmax'):
        super(ResMLP, self).__init__()
        self.n_dims = n_dims
        self.image_size = image_size
        self.patch_size = patch_size
        if (self.image_size % self.patch_size) != 0:
            raise ValueError('size error')
        self.n_patches = int((tf.square(self.image_size) / tf.square(self.patch_size)).numpy())
        self.n_res_layers = n_res_layers
        self.n_labels = n_labels
        if mode not in ['sigmoid','softmax']:
            raise ValueError('mode must be sigmoid or softmax')
        else:
            self.mode = mode
        self.patchConv = tf.keras.layers.Conv2D(self.n_dims, (self.patch_size, self.patch_size), strides = (self.patch_size, self.patch_size))
        self.reshapeL = tf.keras.layers.Reshape((self.n_patches, self.n_dims))
        self.ResLayers = [ResLayer(self.n_dims, self.n_patches) for x in range(self.n_res_layers)]
        self.gap = tf.keras.layers.GlobalAveragePooling1D()
        self.classifier = tf.keras.layers.Dense(self.n_labels if self.n_labels > 2 else 1, activation = mode, kernel_initializer = tf.keras.initializers.glorot_normal(seed = 42))

    def call(self, X):
        X = self.patchConv(X)
        X = self.reshapeL(X)
        for reslayer in self.ResLayers:
            X = reslayer(X)
        X = self.gap(X)
        X = self.classifier(X)
        return X

# %%
resmlp = ResMLP(n_dims=384, image_size=64, patch_size=16, n_res_layers=4, n_labels=num_classes, mode = 'softmax')

# %%
history_resmlp = run_experiment(resmlp)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:
100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.1437 - accuracy: 0.9470 - top5-acc: 1.0000 - Brier score: 0.0206 - F1 score: 0.9431 - Recall: 0.9437 - Precision: 0.9497 - AUC: 0.9962 - val_loss: 0.4451 - val_accuracy: 0.8337 - val_top5-acc: 1.0000 - val_Brier score: 0.0605 - val_F1 score: 0.8319 - val_Recall: 0.8283 - val_Precision: 0.8420 - val_AUC: 0.9674 - lr: 1.2500e-04

# %%
plot_training_curves(history_resmlp, 'ResMLP for Computed Tomography of the Chest')

# %% [markdown]
# ---

# %% [markdown]
# # ⚛ DiagnosticMLP (proposed model)

# %%
class DiagnosticMLP(layers.Layer):
    def __init__(self, num_patches, hidden_units, dropout_rate, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.mlp1 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=num_patches),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.mlp2 = keras.Sequential(
            [
                layers.Dense(units=num_patches),
                tfa.layers.GELU(),
                layers.Dense(units=embedding_dim),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.normalize = layers.LayerNormalization(epsilon=1e-6)
        self.mlp3 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )
        self.channel_projection2 = layers.Dense(units=embedding_dim)
        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        ########################################################################
        # Apply layer normalization.
        x = self.normalize(x)
        # Transpose inputs from [num_batches, num_patches, hidden_units] to [num_batches, hidden_units, num_patches].
        x_channels = tf.linalg.matrix_transpose(x)
        # Apply mlp1 on each channel independently.
        mlp1_outputs = self.mlp1(x_channels)
        # Transpose mlp1_outputs from [num_batches, hidden_dim, num_patches] to [num_batches, num_patches, hidden_units].
        mlp1_outputs = tf.linalg.matrix_transpose(mlp1_outputs)
        # Add skip connection.
        x = mlp1_outputs + inputs
        # Apply layer normalization.
        x_patches = self.normalize(x)
        # Apply mlp2 on each patch independtenly.
        mlp2_outputs = self.mlp2(x_patches)
        # Add skip connection.
        x = x + mlp2_outputs
        ########################################################################
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.mlp3(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        x= x + x_projected
        return x

# %%
DiagnosticMLP_blocks = keras.Sequential(
    [DiagnosticMLP(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
DiagnosticMLP_classifier = build_classifier(DiagnosticMLP_blocks)

# %%
history_DiagnosticMLP = run_experiment(DiagnosticMLP_classifier)
# Out:
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 259/259 [==============================] - ETA: 0s - loss: 60.2966 - accuracy: 0.3720 - top5-acc: 1.0000 - Brier score: 24435.7793 - F1 score: 0.3747 - Recall: 0.8119 - Precision: 0.2927 - AUC: 0.5795
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 259/259 [==============================] - 720s 2s/step - loss: 60.2966 - accuracy: 0.3720 - top5-acc: 1.0000 - Brier score: 24435.7793 - F1 score: 0.3747 - Recall: 0.8119 - Precision: 0.2927 - AUC: 0.5795 - val_loss: 14.2310 - val_accuracy: 0.4935 - val_top5-acc: 1.0000 - val_Brier score: 2683.1765 - val_F1 score: 0.4966 - val_Recall: 0.9924 - val_Precision: 0.3122 - val_AUC: 0.6335 - lr: 0.0010
# Epoch 2/100
# 259/259 [==============================] - 23s 87ms/step - loss: 13.0705 - accuracy: 0.4643 - top5-acc: 1.0000 - Brier score: 1324.7173 - F1 score: 0.4743 - Recall: 0.7552 - Precision: 0.3452 - AUC: 0.6404 - val_loss: 10.0647 - val_accuracy: 0.5337 - val_top5-acc: 1.0000 - val_Brier score: 1477.2297 - val_F1 score: 0.5132 - val_Recall: 0.9598 - val_Precision: 0.3432 - val_AUC: 0.6748 - lr: 0.0010
# Epoch 3/100
# 259/259 [==============================] - 23s 87ms/step - loss: 10.1121 - accuracy: 0.5046 - top5-acc: 1.0000 - Brier score: 1115.0560 - F1 score: 0.5119 - Recall: 0.7507 - Precision: 0.3586 - AUC: 0.6534 - val_loss: 8.8181 - val_accuracy: 0.5641 - val_top5-acc: 1.0000 - val_Brier score: 1162.3639 - val_F1 score: 0.5283 - val_Recall: 0.5554 - val_Precision: 0.5659 - val_AUC: 0.7085 - lr: 0.0010
# Epoch 4/100
# 259/259 [==============================] - 23s 88ms/step - loss: 7.7856 - accuracy: 0.5399 - top5-acc: 1.0000 - Brier score: 1037.4739 - F1 score: 0.5443 - Recall: 0.7753 - Precision: 0.3502 - AUC: 0.6496 - val_loss: 2.6996 - val_accuracy: 0.6435 - val_top5-acc: 1.0000 - val_Brier score: 593.5712 - val_F1 score: 0.6681 - val_Recall: 0.9663 - val_Precision: 0.4247 - val_AUC: 0.7697 - lr: 0.0010
# Epoch 5/100
100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7884 - accuracy: 0.6721 - top5-acc: 1.0000 - Brier score: 67.6001 - F1 score: 0.6661 - Recall: 0.7407 - Precision: 0.3298 - AUC: 0.6256 - val_loss: 0.7286 - val_accuracy: 0.7370 - val_top5-acc: 1.0000 - val_Brier score: 91.6823 - val_F1 score: 0.7301 - val_Recall: 0.9978 - val_Precision: 0.3132 - val_AUC: 0.6460 - lr: 0.0010
# Epoch 26/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6472 - accuracy: 0.7155 - top5-acc: 1.0000 - Brier score: 31.7454 - F1 score: 0.7083 - Recall: 0.8760 - Precision: 0.3496 - AUC: 0.6800 - val_loss: 0.6690 - val_accuracy: 0.7304 - val_top5-acc: 1.0000 - val_Brier score: 23.6589 - val_F1 score: 0.7193 - val_Recall: 0.7804 - val_Precision: 0.5444 - val_AUC: 0.7983 - lr: 5.0000e-04
# Epoch 27/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6360 - accuracy: 0.7221 - top5-acc: 1.0000 - Brier score: 27.1703 - F1 score: 0.7109 - Recall: 0.6861 - Precision: 0.4009 - AUC: 0.6863 - val_loss: 0.5861 - val_accuracy: 0.7326 - val_top5-acc: 1.0000 - val_Brier score: 19.5651 - val_F1 score: 0.7370 - val_Recall: 0.8793 - val_Precision: 0.4930 - val_AUC: 0.8092 - lr: 5.0000e-04
# Epoch 28/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6588 - accuracy: 0.7069 - top5-acc: 1.0000 - Brier score: 24.6998 - F1 score: 0.6988 - Recall: 0.6955 - Precision: 0.4177 - AUC: 0.7016 - val_loss: 0.6603 - val_accuracy: 0.7261 - val_top5-acc: 1.0000 - val_Brier score: 39.9815 - val_F1 score: 0.7271 - val_Recall: 0.6891 - val_Precision: 0.5484 - val_AUC: 0.7666 - lr: 5.0000e-04
# Epoch 29/100
# 259/259 [==============================] - 23s 88ms/step - loss: 0.6587 - accuracy: 0.7050 - top5-acc: 1.0000 - Brier score: 29.8289 - F1 score: 0.6952 - Recall: 0.8696 - Precision: 0.3503 - AUC: 0.6799 - val_loss: 0.7022 - val_accuracy: 0.6304 - val_top5-acc: 1.0000 - val_Brier score: 18.8333 - val_F1 score: 0.6280 - val_Recall: 0.9261 - val_Precision: 0.4656 - val_AUC: 0.8081 - lr: 5.0000e-04
# Epoch 30/100
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6879 - accuracy: 0.7007 - top5-acc: 1.0000 - Brier score: 45.4819 - F1 score: 0.6919 - Recall: 0.7562 - Precision: 0.3475 - AUC: 0.6505 - val_loss: 0.6709 - val_accuracy: 0.6902 - val_top5-acc: 1.0000 - val_Brier score: 26.1380 - val_F1 score: 0.7012 - val_Recall: 0.8663 - val_Precision: 0.4457 - val_AUC: 0.7667 - lr: 5.0000e-04

# %%
plot_training_curves(history_DiagnosticMLP, 'DiagnosticMLP for Computed Tomography of the Chest')

# %% [markdown]
# ---

# %% [markdown]
# # 🟨 Comparison: CT of the Chest

# %%
def run_experiment_2(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
            keras.metrics.MeanSquaredError(name='Brier score'),
            keras.metrics.F1Score(name='F1 score'),
            keras.metrics.Recall(name='Recall'),
            keras.metrics.Precision(name='Precision'),
            keras.metrics.AUC(name='AUC'),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Fit the model.
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        batch_size=batch_size,
        epochs=50,
        validation_split=0.1,
        class_weight=class_weights_dict,
        callbacks=[reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %%
history_mlpmixer_ = run_experiment_2(mlpmixer_classifier)
history_fnet_ = run_experiment_2(fnet_classifier)
history_gmlp_ = run_experiment_2(gmlp_classifier)
history_resmlp_ = run_experiment_2(resmlp)
history_DiagnosticMLP_ = run_experiment_2(DiagnosticMLP_classifier)
# Out:
# Epoch 1/50
# 259/259 [==============================] - 740s 2s/step - loss: 19.8417 - accuracy: 0.4031 - top5-acc: 1.0000 - Brier score: 1822.8586 - F1 score: 0.3905 - Recall: 0.6418 - Precision: 0.3347 - AUC: 0.6170 - val_loss: 1.1212 - val_accuracy: 0.5739 - val_top5-acc: 1.0000 - val_Brier score: 8.2913 - val_F1 score: 0.5941 - val_Recall: 0.7750 - val_Precision: 0.4571 - val_AUC: 0.7593 - lr: 0.0010
# Epoch 2/50
# 259/259 [==============================] - 23s 87ms/step - loss: 1.0475 - accuracy: 0.5899 - top5-acc: 1.0000 - Brier score: 6.9679 - F1 score: 0.5875 - Recall: 0.8124 - Precision: 0.4177 - AUC: 0.7435 - val_loss: 0.9864 - val_accuracy: 0.6054 - val_top5-acc: 1.0000 - val_Brier score: 13.6488 - val_F1 score: 0.6323 - val_Recall: 0.8652 - val_Precision: 0.4472 - val_AUC: 0.7778 - lr: 0.0010
# Epoch 3/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.8960 - accuracy: 0.6269 - top5-acc: 1.0000 - Brier score: 6.5956 - F1 score: 0.6257 - Recall: 0.8757 - Precision: 0.4247 - AUC: 0.7740 - val_loss: 0.7668 - val_accuracy: 0.7011 - val_top5-acc: 1.0000 - val_Brier score: 11.8317 - val_F1 score: 0.7163 - val_Recall: 0.8902 - val_Precision: 0.4916 - val_AUC: 0.8199 - lr: 0.0010
# Epoch 4/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.8197 - accuracy: 0.6535 - top5-acc: 1.0000 - Brier score: 6.5519 - F1 score: 0.6490 - Recall: 0.8713 - Precision: 0.4584 - AUC: 0.7971 - val_loss: 0.7405 - val_accuracy: 0.6957 - val_top5-acc: 1.0000 - val_Brier score: 11.5994 - val_F1 score: 0.7093 - val_Recall: 0.8587 - val_Precision: 0.5157 - val_AUC: 0.8218 - lr: 0.0010
# Epoch 5/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7480 - accuracy: 0.6798 - top5-acc: 1.0000 - Brier score: 6.2968 - F1 score: 0.6732 - Recall: 0.8857 - Precision: 0.4782 - AUC: 0.8148 - val_loss: 0.6083 - val_accuracy: 0.7587 - val_top5-acc: 1.0000 - val_Brier score: 12.1242 - val_F1 score: 0.7575 - val_Recall: 0.9337 - val_Precision: 0.5159 - val_AUC: 0.8450 - lr: 0.0010
# Epoch 6/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0
50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6030 - accuracy: 0.7270 - top5-acc: 1.0000 - Brier score: 6.7148 - F1 score: 0.7174 - Recall: 0.9312 - Precision: 0.5042 - AUC: 0.8457 - val_loss: 0.5541 - val_accuracy: 0.7728 - val_top5-acc: 1.0000 - val_Brier score: 13.8592 - val_F1 score: 0.7545 - val_Recall: 0.9478 - val_Precision: 0.4941 - val_AUC: 0.8410 - lr: 5.0000e-04
# Epoch 15/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5800 - accuracy: 0.7435 - top5-acc: 1.0000 - Brier score: 6.0522 - F1 score: 0.7337 - Recall: 0.9402 - Precision: 0.5020 - AUC: 0.8472 - val_loss: 0.5155 - val_accuracy: 0.7859 - val_top5-acc: 1.0000 - val_Brier score: 10.6576 - val_F1 score: 0.7840 - val_Recall: 0.9696 - val_Precision: 0.4925 - val_AUC: 0.8454 - lr: 5.0000e-04
# Epoch 16/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5880 - accuracy: 0.7449 - top5-acc: 1.0000 - Brier score: 5.6496 - F1 score: 0.7335 - Recall: 0.9338 - Precision: 0.5046 - AUC: 0.8478 - val_loss: 0.5224 - val_accuracy: 0.7783 - val_top5-acc: 1.0000 - val_Brier score: 9.8832 - val_F1 score: 0.7745 - val_Recall: 0.9696 - val_Precision: 0.5088 - val_AUC: 0.8536 - lr: 5.0000e-04
# Epoch 17/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5831 - accuracy: 0.7395 - top5-acc: 1.0000 - Brier score: 5.3280 - F1 score: 0.7269 - Recall: 0.9336 - Precision: 0.5120 - AUC: 0.8532 - val_loss: 0.5725 - val_accuracy: 0.7663 - val_top5-acc: 1.0000 - val_Brier score: 9.6881 - val_F1 score: 0.7649 - val_Recall: 0.9652 - val_Precision: 0.5068 - val_AUC: 0.8506 - lr: 5.0000e-04
# Epoch 18/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5863 - accuracy: 0.7437 - top5-acc: 1.0000 - Brier score: 5.6010 - F1 score: 0.7322 - Recall: 0.9369 - Precision: 0.5075 - AUC: 0.8519 - val_loss: 0.5322 - val_accuracy: 0.7761 - val_top5-acc: 1.0000 - val_Brier score: 9.7646 - val_F1 score: 0.7790 - val_Recall: 0.9641 - val_Precision: 0.5305 - val_AUC: 0.8643 - lr: 5.0000e-04
# Epoch 19/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5997 - accuracy: 0.7378 - top5-acc: 1.0000 - Brier score: 5.3123 - F1 score: 0.7257 - Recall: 0.9358 - Precision: 0.5041 - AUC: 0.8492 - val_loss: 0.5052 - val_accuracy: 0.8000 - val_top5-acc: 1.0000 - val_Brier score: 9.7579 - val_F1 score: 0.7921 - val_Recall: 0.9652 - val_Precision: 0.5205 - val_AUC: 0.8623 - lr: 5.0000e-04
# Epoch 20/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6243 - accuracy: 0.7266 - top5-acc: 1.0000 - Brier score: 5.8635 - F1 score: 0.7154 - Recall: 0.9266 - Precision: 0.5023 - AUC: 0.8450 - val_loss: 0.5319 - val_accuracy: 0.7717 - val_top5-acc: 1.0000 - val_Brier score: 10.2241 - val_F1 score: 0.7737 - val_Recall: 0.9630 - val_Precision: 0.5133 - val_AUC: 0.8509 - lr: 5.0000e-04
# Epoch 21/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6083 - accuracy: 0.7350 - top5-acc: 1.0000 - Brier score: 5.7159 - F1 score: 0.7232 - Recall: 0.9277 - Precision: 0.5043 - AUC: 0.8462 - val_loss: 0.5495 - val_accuracy: 0.7630 - val_top5-acc: 1.0000 - val_Brier score: 11.5263 - val_F1 score: 0.7665 - val_Recall: 0.9533 - val_Precision: 0.5261 - val_AUC: 0.8580 - lr: 5.0000e-04
# Epoch 22/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.6012 - accuracy: 0.7303 - top5-acc: 1.0000 - Brier score: 5.8101 - F1 score: 0.7198 - Recall: 0.9410 - Precision: 0.4923 - AUC: 0.8419 - val_loss: 0.5339 - val_accuracy: 0.7772 - val_top5-acc: 1.0000 - val_Brier score: 10.6414 - val_F1 score: 0.7788 - val_Recall: 0.9750 - val_Precision: 0.5014 - val_AUC: 0.8460 - lr: 5.0000e-04
# Epoch 23/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6243 - accuracy: 0.7265 - top5-acc: 1.0000 - Brier score: 5.8643 - F1 score: 0.7158 - Recall: 0.9299 - Precision: 0.4948 - AUC: 0.8406 - val_loss: 0.5385 - val_accuracy: 0.7696 - val_top5-acc: 1.0000 - val_Brier score: 11.9404 - val_F1 score: 0.7710 - val_Recall: 0.9717 - val_Precision: 0.4972 - val_AUC: 0.8411 - lr: 5.0000e-04
# Epoch 24/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6073 - accuracy: 0.7307 - top5-acc: 1.0000 - Brier score: 5.8303 - F1 score: 0.7198 - Recall: 0.9421 - Precision: 0.4855 - AUC: 0.8382 - val_loss: 0.5191 - val_accuracy: 0.7793 - val_top5-acc: 1.0000 - val_Brier score: 9.4403 - val_F1 score: 0.7682 - val_Recall: 0.9685 - val_Precision: 0.4994 - val_AUC: 0.8493 - lr: 5.0000e-04
# Epoch 25/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5639 - accuracy: 0.7577 - top5-acc: 1.0000 - Brier score: 5.8428 - F1 score: 0.7438 - Recall: 0.9597 - Precision: 0.4836 - AUC: 0.8426 - val_loss: 0.5213 - val_accuracy: 0.7772 - val_top5-acc: 1.0000 - val_Brier score: 10.2422 - val_F1 score: 0.7630 - val_Recall: 0.9663 - val_Precision: 0.5071 - val_AUC: 0.8538 - lr: 2.5000e-04
# Epoch 26/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5620 - accuracy: 0.7534 - top5-acc: 1.0000 - Brier score: 5.4018 - F1 score: 0.7407 - Recall: 0.9534 - Precision: 0.4980 - AUC: 0.8528 - val_loss: 0.5134 - val_accuracy: 0.7761 - val_top5-acc: 1.0000 - val_Brier score: 8.2183 - val_F1 score: 0.7722 - val_Recall: 0.9728 - val_Precision: 0.5074 - val_AUC: 0.8568 - lr: 2.5000e-04
# Epoch 27/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5676 - accuracy: 0.7621 - top5-acc: 1.0000 - Brier score: 5.0001 - F1 score: 0.7490 - Recall: 0.9537 - Precision: 0.4972 - AUC: 0.8519 - val_loss: 0.5051 - val_accuracy: 0.7848 - val_top5-acc: 1.0000 - val_Brier score: 9.3000 - val_F1 score: 0.7773 - val_Recall: 0.9728 - val_Precision: 0.5114 - val_AUC: 0.8579 - lr: 2.5000e-04
# Epoch 28/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5766 - accuracy: 0.7518 - top5-acc: 1.0000 - Brier score: 4.8753 - F1 score: 0.7386 - Recall: 0.9484 - Precision: 0.5046 - AUC: 0.8546 - val_loss: 0.5208 - val_accuracy: 0.7848 - val_top5-acc: 1.0000 - val_Brier score: 9.0145 - val_F1 score: 0.7824 - val_Recall: 0.9685 - val_Precision: 0.5031 - val_AUC: 0.8511 - lr: 2.5000e-04
# Epoch 29/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5755 - accuracy: 0.7469 - top5-acc: 1.0000 - Brier score: 4.7747 - F1 score: 0.7353 - Recall: 0.9459 - Precision: 0.5055 - AUC: 0.8561 - val_loss: 0.5049 - val_accuracy: 0.7924 - val_top5-acc: 1.0000 - val_Brier score: 9.0543 - val_F1 score: 0.7855 - val_Recall: 0.9685 - val_Precision: 0.5168 - val_AUC: 0.8653 - lr: 2.5000e-04
# Epoch 30/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5710 - accuracy: 0.7548 - top5-acc: 1.0000 - Brier score: 4.7877 - F1 score: 0.7429 - Recall: 0.9468 - Precision: 0.5118 - AUC: 0.8597 - val_loss: 0.5197 - val_accuracy: 0.7783 - val_top5-acc: 1.0000 - val_Brier score: 9.9675 - val_F1 score: 0.7756 - val_Recall: 0.9652 - val_Precision: 0.5295 - val_AUC: 0.8667 - lr: 2.5000e-04
# Epoch 31/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5766 - accuracy: 0.7534 - top5-acc: 1.0000 - Brier score: 4.8267 - F1 score: 0.7398 - Recall: 0.9391 - Precision: 0.5144 - AUC: 0.8589 - val_loss: 0.5081 - val_accuracy: 0.7815 - val_top5-acc: 1.0000 - val_Brier score: 9.4570 - val_F1 score: 0.7704 - val_Recall: 0.9641 - val_Precision: 0.5418 - val_AUC: 0.8720 - lr: 2.5000e-04
# Epoch 32/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5948 - accuracy: 0.7444 - top5-acc: 1.0000 - Brier score: 5.0979 - F1 score: 0.7330 - Recall: 0.9341 - Precision: 0.5068 - AUC: 0.8534 - val_loss: 0.5513 - val_accuracy: 0.7717 - val_top5-acc: 1.0000 - val_Brier score: 10.5383 - val_F1 score: 0.7622 - val_Recall: 0.9598 - val_Precision: 0.5051 - val_AUC: 0.8522 - lr: 2.5000e-04
# Epoch 33/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5760 - accuracy: 0.7513 - top5-acc: 1.0000 - Brier score: 4.9124 - F1 score: 0.7377 - Recall: 0.9429 - Precision: 0.5087 - AUC: 0.8559 - val_loss: 0.5447 - val_accuracy: 0.7543 - val_top5-acc: 1.0000 - val_Brier score: 8.9664 - val_F1 score: 0.7579 - val_Recall: 0.9717 - val_Precision: 0.5085 - val_AUC: 0.8541 - lr: 2.5000e-04
# Epoch 34/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5898 - accuracy: 0.7461 - top5-acc: 1.0000 - Brier score: 4.8395 - F1 score: 0.7327 - Recall: 0.9345 - Precision: 0.5125 - AUC: 0.8566 - val_loss: 0.5526 - val_accuracy: 0.7685 - val_top5-acc: 1.0000 - val_Brier score: 9.8499 - val_F1 score: 0.7692 - val_Recall: 0.9685 - val_Precision: 0.5189 - val_AUC: 0.8591 - lr: 2.5000e-04
# Epoch 35/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5628 - accuracy: 0.7587 - top5-acc: 1.0000 - Brier score: 4.9565 - F1 score: 0.7450 - Recall: 0.9400 - Precision: 0.5172 - AUC: 0.8610 - val_loss: 0.5137 - val_accuracy: 0.7804 - val_top5-acc: 1.0000 - val_Brier score: 6.9634 - val_F1 score: 0.7584 - val_Recall: 0.9696 - val_Precision: 0.5247 - val_AUC: 0.8719 - lr: 1.2500e-04
# Epoch 36/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5629 - accuracy: 0.7610 - top5-acc: 1.0000 - Brier score: 4.6093 - F1 score: 0.7479 - Recall: 0.9462 - Precision: 0.5197 - AUC: 0.8661 - val_loss: 0.5378 - val_accuracy: 0.7620 - val_top5-acc: 1.0000 - val_Brier score: 6.6728 - val_F1 score: 0.7446 - val_Recall: 0.9511 - val_Precision: 0.5385 - val_AUC: 0.8755 - lr: 1.2500e-04
# Epoch 37/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5666 - accuracy: 0.7565 - top5-acc: 1.0000 - Brier score: 4.4034 - F1 score: 0.7435 - Recall: 0.9421 - Precision: 0.5208 - AUC: 0.8642 - val_loss: 0.4959 - val_accuracy: 0.7826 - val_top5-acc: 1.0000 - val_Brier score: 6.6132 - val_F1 score: 0.7620 - val_Recall: 0.9685 - val_Precision: 0.5272 - val_AUC: 0.8736 - lr: 1.2500e-04
# Epoch 38/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5630 - accuracy: 0.7613 - top5-acc: 1.0000 - Brier score: 4.1393 - F1 score: 0.7462 - Recall: 0.9394 - Precision: 0.5285 - AUC: 0.8704 - val_loss: 0.5095 - val_accuracy: 0.7826 - val_top5-acc: 1.0000 - val_Brier score: 7.3479 - val_F1 score: 0.7771 - val_Recall: 0.9707 - val_Precision: 0.5275 - val_AUC: 0.8704 - lr: 1.2500e-04
# Epoch 39/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5617 - accuracy: 0.7613 - top5-acc: 1.0000 - Brier score: 4.1270 - F1 score: 0.7471 - Recall: 0.9462 - Precision: 0.5292 - AUC: 0.8703 - val_loss: 0.5383 - val_accuracy: 0.7685 - val_top5-acc: 1.0000 - val_Brier score: 5.7449 - val_F1 score: 0.7643 - val_Recall: 0.9565 - val_Precision: 0.5304 - val_AUC: 0.8756 - lr: 1.2500e-04
# Epoch 40/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5643 - accuracy: 0.7588 - top5-acc: 1.0000 - Brier score: 4.0312 - F1 score: 0.7445 - Recall: 0.9408 - Precision: 0.5301 - AUC: 0.8714 - val_loss: 0.5235 - val_accuracy: 0.7750 - val_top5-acc: 1.0000 - val_Brier score: 6.5009 - val_F1 score: 0.7733 - val_Recall: 0.9522 - val_Precision: 0.5485 - val_AUC: 0.8779 - lr: 1.2500e-04
# Epoch 41/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5672 - accuracy: 0.7588 - top5-acc: 1.0000 - Brier score: 4.1529 - F1 score: 0.7453 - Recall: 0.9383 - Precision: 0.5329 - AUC: 0.8703 - val_loss: 0.5324 - val_accuracy: 0.7739 - val_top5-acc: 1.0000 - val_Brier score: 6.0722 - val_F1 score: 0.7731 - val_Recall: 0.9478 - val_Precision: 0.5440 - val_AUC: 0.8788 - lr: 1.2500e-04
# Epoch 42/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5811 - accuracy: 0.7541 - top5-acc: 1.0000 - Brier score: 4.1564 - F1 score: 0.7406 - Recall: 0.9381 - Precision: 0.5300 - AUC: 0.8693 - val_loss: 0.5209 - val_accuracy: 0.7739 - val_top5-acc: 1.0000 - val_Brier score: 7.9216 - val_F1 score: 0.7726 - val_Recall: 0.9630 - val_Precision: 0.5466 - val_AUC: 0.8741 - lr: 1.2500e-04
# Epoch 43/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5603 - accuracy: 0.7598 - top5-acc: 1.0000 - Brier score: 4.3233 - F1 score: 0.7481 - Recall: 0.9393 - Precision: 0.5333 - AUC: 0.8720 - val_loss: 0.5145 - val_accuracy: 0.7826 - val_top5-acc: 1.0000 - val_Brier score: 6.1423 - val_F1 score: 0.7770 - val_Recall: 0.9641 - val_Precision: 0.5389 - val_AUC: 0.8796 - lr: 6.2500e-05
# Epoch 44/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5640 - accuracy: 0.7638 - top5-acc: 1.0000 - Brier score: 3.7895 - F1 score: 0.7491 - Recall: 0.9385 - Precision: 0.5416 - AUC: 0.8768 - val_loss: 0.5318 - val_accuracy: 0.7707 - val_top5-acc: 1.0000 - val_Brier score: 5.1602 - val_F1 score: 0.7647 - val_Recall: 0.9391 - val_Precision: 0.5625 - val_AUC: 0.8857 - lr: 6.2500e-05
# Epoch 45/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5618 - accuracy: 0.7642 - top5-acc: 1.0000 - Brier score: 3.6465 - F1 score: 0.7493 - Recall: 0.9351 - Precision: 0.5466 - AUC: 0.8790 - val_loss: 0.5327 - val_accuracy: 0.7728 - val_top5-acc: 1.0000 - val_Brier score: 4.8440 - val_F1 score: 0.7648 - val_Recall: 0.9348 - val_Precision: 0.5703 - val_AUC: 0.8878 - lr: 6.2500e-05
# Epoch 46/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5587 - accuracy: 0.7705 - top5-acc: 1.0000 - Brier score: 3.5053 - F1 score: 0.7558 - Recall: 0.9362 - Precision: 0.5507 - AUC: 0.8811 - val_loss: 0.5369 - val_accuracy: 0.7674 - val_top5-acc: 1.0000 - val_Brier score: 4.4710 - val_F1 score: 0.7564 - val_Recall: 0.9380 - val_Precision: 0.5608 - val_AUC: 0.8866 - lr: 6.2500e-05
# Epoch 47/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5676 - accuracy: 0.7622 - top5-acc: 1.0000 - Brier score: 3.4195 - F1 score: 0.7463 - Recall: 0.9330 - Precision: 0.5542 - AUC: 0.8811 - val_loss: 0.5367 - val_accuracy: 0.7826 - val_top5-acc: 1.0000 - val_Brier score: 4.2738 - val_F1 score: 0.7764 - val_Recall: 0.9326 - val_Precision: 0.5720 - val_AUC: 0.8872 - lr: 6.2500e-05
# Epoch 48/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5651 - accuracy: 0.7682 - top5-acc: 1.0000 - Brier score: 3.2875 - F1 score: 0.7529 - Recall: 0.9307 - Precision: 0.5567 - AUC: 0.8844 - val_loss: 0.5436 - val_accuracy: 0.7739 - val_top5-acc: 1.0000 - val_Brier score: 4.0904 - val_F1 score: 0.7710 - val_Recall: 0.9304 - val_Precision: 0.5741 - val_AUC: 0.8898 - lr: 3.1250e-05
# Epoch 49/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5776 - accuracy: 0.7624 - top5-acc: 1.0000 - Brier score: 2.8866 - F1 score: 0.7457 - Recall: 0.9230 - Precision: 0.5657 - AUC: 0.8853 - val_loss: 0.5549 - val_accuracy: 0.7717 - val_top5-acc: 1.0000 - val_Brier score: 3.4284 - val_F1 score: 0.7650 - val_Recall: 0.9250 - val_Precision: 0.5735 - val_AUC: 0.8911 - lr: 3.1250e-05
# Epoch 50/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5840 - accuracy: 0.7615 - top5-acc: 1.0000 - Brier score: 2.6908 - F1 score: 0.7452 - Recall: 0.9223 - Precision: 0.5662 - AUC: 0.8880 - val_loss: 0.5575 - val_accuracy: 0.7663 - val_top5-acc: 1.0000 - val_Brier score: 3.3541 - val_F1 score: 0.7631 - val_Recall: 0.9239 - val_Precision: 0.5771 - val_AUC: 0.8884 - lr: 3.1250e-05
# Epoch 1/50
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 259/259 [==============================] - ETA: 0s - loss: 1.2215 - accuracy: 0.4131 - top5-acc: 1.0000 - Brier score: 0.5669 - F1 score: 0.3989 - Recall: 0.4796 - Precision: 0.3968 - AUC: 0.6693
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 259/259 [==============================] - 28s 87ms/step - loss: 1.2215 - accuracy: 0.4131 - top5-acc: 1.0000 - Brier score: 0.5669 - F1 score: 0.3989 - Recall: 0.4796 - Precision: 0.3968 - AUC: 0.6693 - val_loss: 0.9615 - val_accuracy: 0.5957 - val_top5-acc: 1.0000 - val_Brier score: 0.8272 - val_F1 score: 0.5547 - val_Recall: 0.7630 - val_Precision: 0.4573 - val_AUC: 0.8182 - lr: 0.0010
# Epoch 2/50
# 259/259 [==============================] - 23s 85ms/step - loss: 1.0522 - accuracy: 0.5158 - top5-acc: 1.0000 - Brier score: 1.0544 - F1 score: 0.4964 - Recall: 0.7060 - Precision: 0.4281 - AUC: 0.7500 - val_loss: 0.8705 - val_accuracy: 0.5652 - val_top5-acc: 1.0000 - val_Brier score: 1.8198 - val_F1 score: 0.5613 - val_Recall: 0.8435 - val_Precision: 0.4740 - val_AUC: 0.8081 - lr: 0.0010
# Epoch 3/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.9001 - accuracy: 0.5957 - top5-acc: 1.0000 - Brier score: 1.7109 - F1 score: 0.5806 - Recall: 0.8398 - Precision: 0.4407 - AUC: 0.7952 - val_loss: 0.8370 - val_accuracy: 0.5880 - val_top5-acc: 1.0000 - val_Brier score: 2.5688 - val_F1 score: 0.5834 - val_Recall: 0.8967 - val_Precision: 0.4486 - val_AUC: 0.8088 - lr: 0.0010
# Epoch 4/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.8495 - accuracy: 0.6103 - top5-acc: 1.0000 - Brier score: 2.2399 - F1 score: 0.5992 - Recall: 0.8779 - Precision: 0.4402 - AUC: 0.7989 - val_loss: 0.9382 - val_accuracy: 0.5630 - val_top5-acc: 1.0000 - val_Brier score: 2.2951 - val_F1 score: 0.5350 - val_Recall: 0.8207 - val_Precision: 0.4658 - val_AUC: 0.7972 - lr: 0.0010
# Epoch 5/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.8075 - accuracy: 0.6310 - top5-acc: 1.0000 - Brier score: 2.4635 - F1 score: 0.6189 - Recall: 0.8904 - Precision: 0.4546 - AUC: 0.8108 - val_loss: 0.7634 - val_accuracy: 0.6380 - val_top5-acc: 1.0000 - val_Brier score: 2.1569 - val_F1 score: 0.6275 - val_Recall: 0.9054 - val_Precision: 0.4755 - val_AUC: 0.8361 - lr: 0.0010
# Epoch 6/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0
50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.6559 - accuracy: 0.7185 - top5-acc: 1.0000 - Brier score: 3.9528 - F1 score: 0.7035 - Recall: 0.9202 - Precision: 0.5039 - AUC: 0.8478 - val_loss: 0.7681 - val_accuracy: 0.6424 - val_top5-acc: 1.0000 - val_Brier score: 5.6336 - val_F1 score: 0.6401 - val_Recall: 0.9141 - val_Precision: 0.5018 - val_AUC: 0.8394 - lr: 0.0010
# Epoch 14/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6214 - accuracy: 0.7286 - top5-acc: 1.0000 - Brier score: 4.4459 - F1 score: 0.7114 - Recall: 0.9307 - Precision: 0.5171 - AUC: 0.8576 - val_loss: 0.6449 - val_accuracy: 0.7000 - val_top5-acc: 1.0000 - val_Brier score: 6.6063 - val_F1 score: 0.7061 - val_Recall: 0.9554 - val_Precision: 0.4897 - val_AUC: 0.8497 - lr: 5.0000e-04
# Epoch 15/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6057 - accuracy: 0.7405 - top5-acc: 1.0000 - Brier score: 4.4352 - F1 score: 0.7261 - Recall: 0.9361 - Precision: 0.5195 - AUC: 0.8589 - val_loss: 0.6060 - val_accuracy: 0.7174 - val_top5-acc: 1.0000 - val_Brier score: 6.5761 - val_F1 score: 0.7240 - val_Recall: 0.9630 - val_Precision: 0.5069 - val_AUC: 0.8573 - lr: 5.0000e-04
# Epoch 16/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.6054 - accuracy: 0.7411 - top5-acc: 1.0000 - Brier score: 4.3407 - F1 score: 0.7260 - Recall: 0.9330 - Precision: 0.5254 - AUC: 0.8618 - val_loss: 0.5920 - val_accuracy: 0.7489 - val_top5-acc: 1.0000 - val_Brier score: 5.6612 - val_F1 score: 0.7525 - val_Recall: 0.9630 - val_Precision: 0.5190 - val_AUC: 0.8649 - lr: 5.0000e-04
# Epoch 17/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6024 - accuracy: 0.7431 - top5-acc: 1.0000 - Brier score: 4.2768 - F1 score: 0.7278 - Recall: 0.9300 - Precision: 0.5326 - AUC: 0.8643 - val_loss: 0.6173 - val_accuracy: 0.7065 - val_top5-acc: 1.0000 - val_Brier score: 5.4859 - val_F1 score: 0.7222 - val_Recall: 0.9554 - val_Precision: 0.5183 - val_AUC: 0.8627 - lr: 5.0000e-04
# Epoch 18/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5937 - accuracy: 0.7455 - top5-acc: 1.0000 - Brier score: 4.5060 - F1 score: 0.7302 - Recall: 0.9333 - Precision: 0.5351 - AUC: 0.8654 - val_loss: 0.6437 - val_accuracy: 0.7228 - val_top5-acc: 1.0000 - val_Brier score: 8.6257 - val_F1 score: 0.7356 - val_Recall: 0.9576 - val_Precision: 0.4791 - val_AUC: 0.8359 - lr: 5.0000e-04
# Epoch 19/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5926 - accuracy: 0.7496 - top5-acc: 1.0000 - Brier score: 4.5877 - F1 score: 0.7337 - Recall: 0.9288 - Precision: 0.5338 - AUC: 0.8655 - val_loss: 0.6257 - val_accuracy: 0.7043 - val_top5-acc: 1.0000 - val_Brier score: 5.9989 - val_F1 score: 0.7103 - val_Recall: 0.9435 - val_Precision: 0.5204 - val_AUC: 0.8652 - lr: 5.0000e-04
# Epoch 20/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5983 - accuracy: 0.7494 - top5-acc: 1.0000 - Brier score: 4.5301 - F1 score: 0.7343 - Recall: 0.9241 - Precision: 0.5396 - AUC: 0.8678 - val_loss: 0.6241 - val_accuracy: 0.7207 - val_top5-acc: 1.0000 - val_Brier score: 5.7991 - val_F1 score: 0.7210 - val_Recall: 0.9239 - val_Precision: 0.5452 - val_AUC: 0.8699 - lr: 5.0000e-04
# Epoch 21/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5900 - accuracy: 0.7501 - top5-acc: 1.0000 - Brier score: 4.4215 - F1 score: 0.7336 - Recall: 0.9208 - Precision: 0.5491 - AUC: 0.8715 - val_loss: 0.5880 - val_accuracy: 0.7196 - val_top5-acc: 1.0000 - val_Brier score: 5.0872 - val_F1 score: 0.7264 - val_Recall: 0.9370 - val_Precision: 0.5697 - val_AUC: 0.8813 - lr: 5.0000e-04
# Epoch 22/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5820 - accuracy: 0.7531 - top5-acc: 1.0000 - Brier score: 4.5550 - F1 score: 0.7403 - Recall: 0.9263 - Precision: 0.5502 - AUC: 0.8728 - val_loss: 0.6884 - val_accuracy: 0.6696 - val_top5-acc: 1.0000 - val_Brier score: 5.4745 - val_F1 score: 0.6721 - val_Recall: 0.9228 - val_Precision: 0.5306 - val_AUC: 0.8612 - lr: 5.0000e-04
# Epoch 23/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5749 - accuracy: 0.7594 - top5-acc: 1.0000 - Brier score: 4.5495 - F1 score: 0.7451 - Recall: 0.9247 - Precision: 0.5521 - AUC: 0.8715 - val_loss: 0.6091 - val_accuracy: 0.7250 - val_top5-acc: 1.0000 - val_Brier score: 6.5763 - val_F1 score: 0.7385 - val_Recall: 0.9533 - val_Precision: 0.5414 - val_AUC: 0.8674 - lr: 5.0000e-04
# Epoch 24/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5834 - accuracy: 0.7493 - top5-acc: 1.0000 - Brier score: 4.6001 - F1 score: 0.7351 - Recall: 0.9202 - Precision: 0.5466 - AUC: 0.8706 - val_loss: 0.5651 - val_accuracy: 0.7467 - val_top5-acc: 1.0000 - val_Brier score: 5.9722 - val_F1 score: 0.7434 - val_Recall: 0.9402 - val_Precision: 0.5639 - val_AUC: 0.8781 - lr: 5.0000e-04
# Epoch 25/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5732 - accuracy: 0.7562 - top5-acc: 1.0000 - Brier score: 4.7187 - F1 score: 0.7417 - Recall: 0.9217 - Precision: 0.5508 - AUC: 0.8735 - val_loss: 0.5747 - val_accuracy: 0.7250 - val_top5-acc: 1.0000 - val_Brier score: 5.6410 - val_F1 score: 0.7341 - val_Recall: 0.9424 - val_Precision: 0.5561 - val_AUC: 0.8757 - lr: 5.0000e-04
# Epoch 26/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5812 - accuracy: 0.7488 - top5-acc: 1.0000 - Brier score: 4.7914 - F1 score: 0.7355 - Recall: 0.9211 - Precision: 0.5488 - AUC: 0.8708 - val_loss: 0.6215 - val_accuracy: 0.7065 - val_top5-acc: 1.0000 - val_Brier score: 6.3243 - val_F1 score: 0.7106 - val_Recall: 0.9359 - val_Precision: 0.5425 - val_AUC: 0.8691 - lr: 5.0000e-04
# Epoch 27/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5843 - accuracy: 0.7475 - top5-acc: 1.0000 - Brier score: 4.7299 - F1 score: 0.7337 - Recall: 0.9215 - Precision: 0.5496 - AUC: 0.8716 - val_loss: 0.6526 - val_accuracy: 0.6880 - val_top5-acc: 1.0000 - val_Brier score: 5.4799 - val_F1 score: 0.6955 - val_Recall: 0.9261 - val_Precision: 0.5532 - val_AUC: 0.8691 - lr: 5.0000e-04
# Epoch 28/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5733 - accuracy: 0.7528 - top5-acc: 1.0000 - Brier score: 4.7286 - F1 score: 0.7388 - Recall: 0.9262 - Precision: 0.5531 - AUC: 0.8746 - val_loss: 0.5825 - val_accuracy: 0.7370 - val_top5-acc: 1.0000 - val_Brier score: 5.8315 - val_F1 score: 0.7388 - val_Recall: 0.9272 - val_Precision: 0.5675 - val_AUC: 0.8808 - lr: 5.0000e-04
# Epoch 29/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5736 - accuracy: 0.7589 - top5-acc: 1.0000 - Brier score: 4.6545 - F1 score: 0.7454 - Recall: 0.9212 - Precision: 0.5566 - AUC: 0.8753 - val_loss: 0.6305 - val_accuracy: 0.7185 - val_top5-acc: 1.0000 - val_Brier score: 7.2464 - val_F1 score: 0.7209 - val_Recall: 0.9348 - val_Precision: 0.5332 - val_AUC: 0.8665 - lr: 5.0000e-04
# Epoch 30/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5412 - accuracy: 0.7688 - top5-acc: 1.0000 - Brier score: 5.1636 - F1 score: 0.7561 - Recall: 0.9347 - Precision: 0.5608 - AUC: 0.8804 - val_loss: 0.5498 - val_accuracy: 0.7467 - val_top5-acc: 1.0000 - val_Brier score: 6.0196 - val_F1 score: 0.7502 - val_Recall: 0.9370 - val_Precision: 0.5697 - val_AUC: 0.8859 - lr: 2.5000e-04
# Epoch 31/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5384 - accuracy: 0.7722 - top5-acc: 1.0000 - Brier score: 4.9528 - F1 score: 0.7587 - Recall: 0.9329 - Precision: 0.5659 - AUC: 0.8813 - val_loss: 0.5687 - val_accuracy: 0.7500 - val_top5-acc: 1.0000 - val_Brier score: 5.9352 - val_F1 score: 0.7483 - val_Recall: 0.9217 - val_Precision: 0.5631 - val_AUC: 0.8815 - lr: 2.5000e-04
# Epoch 32/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5416 - accuracy: 0.7703 - top5-acc: 1.0000 - Brier score: 5.0931 - F1 score: 0.7576 - Recall: 0.9289 - Precision: 0.5626 - AUC: 0.8805 - val_loss: 0.5690 - val_accuracy: 0.7348 - val_top5-acc: 1.0000 - val_Brier score: 6.0455 - val_F1 score: 0.7408 - val_Recall: 0.9359 - val_Precision: 0.5491 - val_AUC: 0.8764 - lr: 2.5000e-04
# Epoch 33/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5366 - accuracy: 0.7708 - top5-acc: 1.0000 - Brier score: 5.0891 - F1 score: 0.7587 - Recall: 0.9351 - Precision: 0.5649 - AUC: 0.8827 - val_loss: 0.5632 - val_accuracy: 0.7359 - val_top5-acc: 1.0000 - val_Brier score: 6.0191 - val_F1 score: 0.7381 - val_Recall: 0.9261 - val_Precision: 0.5832 - val_AUC: 0.8840 - lr: 2.5000e-04
# Epoch 34/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5341 - accuracy: 0.7759 - top5-acc: 1.0000 - Brier score: 4.9371 - F1 score: 0.7617 - Recall: 0.9299 - Precision: 0.5736 - AUC: 0.8849 - val_loss: 0.5661 - val_accuracy: 0.7424 - val_top5-acc: 1.0000 - val_Brier score: 6.6438 - val_F1 score: 0.7502 - val_Recall: 0.9435 - val_Precision: 0.5625 - val_AUC: 0.8834 - lr: 2.5000e-04
# Epoch 35/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5423 - accuracy: 0.7699 - top5-acc: 1.0000 - Brier score: 4.8658 - F1 score: 0.7592 - Recall: 0.9256 - Precision: 0.5743 - AUC: 0.8849 - val_loss: 0.5504 - val_accuracy: 0.7402 - val_top5-acc: 1.0000 - val_Brier score: 5.3269 - val_F1 score: 0.7493 - val_Recall: 0.9283 - val_Precision: 0.5743 - val_AUC: 0.8877 - lr: 2.5000e-04
# Epoch 36/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5320 - accuracy: 0.7765 - top5-acc: 1.0000 - Brier score: 4.8675 - F1 score: 0.7644 - Recall: 0.9305 - Precision: 0.5738 - AUC: 0.8838 - val_loss: 0.5587 - val_accuracy: 0.7576 - val_top5-acc: 1.0000 - val_Brier score: 5.9934 - val_F1 score: 0.7545 - val_Recall: 0.9293 - val_Precision: 0.5840 - val_AUC: 0.8867 - lr: 1.2500e-04
# Epoch 37/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5353 - accuracy: 0.7743 - top5-acc: 1.0000 - Brier score: 4.4905 - F1 score: 0.7597 - Recall: 0.9278 - Precision: 0.5746 - AUC: 0.8873 - val_loss: 0.5403 - val_accuracy: 0.7554 - val_top5-acc: 1.0000 - val_Brier score: 5.6358 - val_F1 score: 0.7511 - val_Recall: 0.9413 - val_Precision: 0.5804 - val_AUC: 0.8907 - lr: 1.2500e-04
# Epoch 38/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5255 - accuracy: 0.7805 - top5-acc: 1.0000 - Brier score: 4.7022 - F1 score: 0.7650 - Recall: 0.9265 - Precision: 0.5722 - AUC: 0.8861 - val_loss: 0.5599 - val_accuracy: 0.7489 - val_top5-acc: 1.0000 - val_Brier score: 6.0827 - val_F1 score: 0.7474 - val_Recall: 0.9293 - val_Precision: 0.5677 - val_AUC: 0.8833 - lr: 1.2500e-04
# Epoch 39/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5390 - accuracy: 0.7703 - top5-acc: 1.0000 - Brier score: 4.6589 - F1 score: 0.7567 - Recall: 0.9224 - Precision: 0.5729 - AUC: 0.8838 - val_loss: 0.5795 - val_accuracy: 0.7424 - val_top5-acc: 1.0000 - val_Brier score: 5.9450 - val_F1 score: 0.7385 - val_Recall: 0.9174 - val_Precision: 0.5734 - val_AUC: 0.8839 - lr: 1.2500e-04
# Epoch 40/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5378 - accuracy: 0.7736 - top5-acc: 1.0000 - Brier score: 4.6713 - F1 score: 0.7595 - Recall: 0.9237 - Precision: 0.5723 - AUC: 0.8855 - val_loss: 0.6081 - val_accuracy: 0.7283 - val_top5-acc: 1.0000 - val_Brier score: 5.1103 - val_F1 score: 0.7281 - val_Recall: 0.8978 - val_Precision: 0.5756 - val_AUC: 0.8775 - lr: 1.2500e-04
# Epoch 41/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5426 - accuracy: 0.7664 - top5-acc: 1.0000 - Brier score: 4.4533 - F1 score: 0.7535 - Recall: 0.9200 - Precision: 0.5774 - AUC: 0.8858 - val_loss: 0.5874 - val_accuracy: 0.7337 - val_top5-acc: 1.0000 - val_Brier score: 5.4316 - val_F1 score: 0.7329 - val_Recall: 0.9065 - val_Precision: 0.5673 - val_AUC: 0.8770 - lr: 1.2500e-04
# Epoch 42/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5490 - accuracy: 0.7685 - top5-acc: 1.0000 - Brier score: 4.5200 - F1 score: 0.7544 - Recall: 0.9154 - Precision: 0.5751 - AUC: 0.8845 - val_loss: 0.5741 - val_accuracy: 0.7326 - val_top5-acc: 1.0000 - val_Brier score: 5.2796 - val_F1 score: 0.7334 - val_Recall: 0.9141 - val_Precision: 0.5780 - val_AUC: 0.8840 - lr: 1.2500e-04
# Epoch 43/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5356 - accuracy: 0.7726 - top5-acc: 1.0000 - Brier score: 4.2768 - F1 score: 0.7604 - Recall: 0.9187 - Precision: 0.5803 - AUC: 0.8881 - val_loss: 0.5738 - val_accuracy: 0.7446 - val_top5-acc: 1.0000 - val_Brier score: 5.1939 - val_F1 score: 0.7359 - val_Recall: 0.9098 - val_Precision: 0.5945 - val_AUC: 0.8824 - lr: 6.2500e-05
# Epoch 44/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5441 - accuracy: 0.7756 - top5-acc: 1.0000 - Brier score: 4.0027 - F1 score: 0.7617 - Recall: 0.9146 - Precision: 0.5858 - AUC: 0.8893 - val_loss: 0.5766 - val_accuracy: 0.7370 - val_top5-acc: 1.0000 - val_Brier score: 4.9277 - val_F1 score: 0.7342 - val_Recall: 0.9043 - val_Precision: 0.5830 - val_AUC: 0.8842 - lr: 6.2500e-05
# Epoch 45/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5480 - accuracy: 0.7680 - top5-acc: 1.0000 - Brier score: 3.9496 - F1 score: 0.7522 - Recall: 0.9107 - Precision: 0.5826 - AUC: 0.8875 - val_loss: 0.5579 - val_accuracy: 0.7511 - val_top5-acc: 1.0000 - val_Brier score: 5.2397 - val_F1 score: 0.7440 - val_Recall: 0.9239 - val_Precision: 0.5739 - val_AUC: 0.8895 - lr: 6.2500e-05
# Epoch 46/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5533 - accuracy: 0.7676 - top5-acc: 1.0000 - Brier score: 3.9779 - F1 score: 0.7543 - Recall: 0.9089 - Precision: 0.5791 - AUC: 0.8875 - val_loss: 0.6006 - val_accuracy: 0.7283 - val_top5-acc: 1.0000 - val_Brier score: 5.0159 - val_F1 score: 0.7246 - val_Recall: 0.8989 - val_Precision: 0.5676 - val_AUC: 0.8815 - lr: 6.2500e-05
# Epoch 47/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.5610 - accuracy: 0.7621 - top5-acc: 1.0000 - Brier score: 3.7540 - F1 score: 0.7475 - Recall: 0.9041 - Precision: 0.5816 - AUC: 0.8874 - val_loss: 0.5801 - val_accuracy: 0.7326 - val_top5-acc: 1.0000 - val_Brier score: 4.5812 - val_F1 score: 0.7267 - val_Recall: 0.9033 - val_Precision: 0.5811 - val_AUC: 0.8878 - lr: 6.2500e-05
# Epoch 48/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5572 - accuracy: 0.7682 - top5-acc: 1.0000 - Brier score: 3.4741 - F1 score: 0.7523 - Recall: 0.9049 - Precision: 0.5874 - AUC: 0.8921 - val_loss: 0.5672 - val_accuracy: 0.7391 - val_top5-acc: 1.0000 - val_Brier score: 4.1667 - val_F1 score: 0.7346 - val_Recall: 0.9065 - val_Precision: 0.5974 - val_AUC: 0.8893 - lr: 3.1250e-05
# Epoch 49/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5704 - accuracy: 0.7598 - top5-acc: 1.0000 - Brier score: 3.3245 - F1 score: 0.7433 - Recall: 0.8990 - Precision: 0.5890 - AUC: 0.8900 - val_loss: 0.5929 - val_accuracy: 0.7261 - val_top5-acc: 1.0000 - val_Brier score: 3.8852 - val_F1 score: 0.7204 - val_Recall: 0.8870 - val_Precision: 0.5930 - val_AUC: 0.8851 - lr: 3.1250e-05
# Epoch 50/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5742 - accuracy: 0.7598 - top5-acc: 1.0000 - Brier score: 3.1829 - F1 score: 0.7445 - Recall: 0.8935 - Precision: 0.5872 - AUC: 0.8887 - val_loss: 0.5862 - val_accuracy: 0.7348 - val_top5-acc: 1.0000 - val_Brier score: 3.9145 - val_F1 score: 0.7265 - val_Recall: 0.9033 - val_Precision: 0.5906 - val_AUC: 0.8868 - lr: 3.1250e-05
# Epoch 1/50
# 259/259 [==============================] - 29s 91ms/step - loss: 1.3516 - accuracy: 0.3201 - top5-acc: 1.0000 - Brier score: 0.8214 - F1 score: 0.3172 - Recall: 0.2149 - Precision: 0.3549 - AUC: 0.5810 - val_loss: 0.9460 - val_accuracy: 0.4891 - val_top5-acc: 1.0000 - val_Brier score: 3.4197 - val_F1 score: 0.4938 - val_Recall: 0.8163 - val_Precision: 0.4915 - val_AUC: 0.8111 - lr: 0.0010
# Epoch 2/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.9463 - accuracy: 0.5513 - top5-acc: 1.0000 - Brier score: 1.7822 - F1 score: 0.5463 - Recall: 0.7197 - Precision: 0.4731 - AUC: 0.7789 - val_loss: 0.7463 - val_accuracy: 0.6435 - val_top5-acc: 1.0000 - val_Brier score: 2.9654 - val_F1 score: 0.6450 - val_Recall: 0.8391 - val_Precision: 0.5402 - val_AUC: 0.8447 - lr: 0.0010
# Epoch 3/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.8662 - accuracy: 0.6018 - top5-acc: 1.0000 - Brier score: 1.9012 - F1 score: 0.5910 - Recall: 0.7838 - Precision: 0.5000 - AUC: 0.8088 - val_loss: 0.8773 - val_accuracy: 0.5598 - val_top5-acc: 1.0000 - val_Brier score: 3.5495 - val_F1 score: 0.5263 - val_Recall: 0.8315 - val_Precision: 0.5020 - val_AUC: 0.8168 - lr: 0.0010
# Epoch 4/50
# 259/259 [==============================] - 23s 85ms/step - loss: 0.8204 - accuracy: 0.6272 - top5-acc: 1.0000 - Brier score: 2.0802 - F1 score: 0.6139 - Recall: 0.8348 - Precision: 0.4912 - AUC: 0.8207 - val_loss: 0.7219 - val_accuracy: 0.6598 - val_top5-acc: 1.0000 - val_Brier score: 3.7001 - val_F1 score: 0.6707 - val_Recall: 0.9065 - val_Precision: 0.4854 - val_AUC: 0.8323 - lr: 0.0010
# Epoch 5/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7891 - accuracy: 0.6359 - top5-acc: 1.0000 - Brier score: 2.5242 - F1 score: 0.6213 - Recall: 0.8533 - Precision: 0.4875 - AUC: 0.8217 - val_loss: 0.8560 - val_accuracy: 0.6087 - val_top5-acc: 1.0000 - val_Brier score: 5.5966 - val_F1 score: 0.6009 - val_Recall: 0.8902 - val_Precision: 0.4500 - val_AUC: 0.8015 - lr: 0.0010
# Epoch 6/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7797 - accuracy: 0.6455 - top5-acc: 1.0000 - Brier score: 2.5920 - F1 score: 0.6318 - Recall: 0.8598 - Precision: 0.4946 - AUC: 0.8257 - val_loss: 0.7875 - val_accuracy: 0.5946 - val_top5-acc: 1.0000 - val_Brier score: 6.1501 - val_F1 score: 0.5840 - val_Recall: 0.9304 - val_Precision: 0.4489 - val_AUC: 0.8056 - lr: 0.0010
# Epoch 7/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7570 - accuracy: 0.6636 - top5-acc: 1.0000 - Brier score: 2.7212 - F1 score: 0.6489 - Recall: 0.8686 - Precision: 0.4925 - AUC: 0.8276 - val_loss: 0.7408 - val_accuracy: 0.6207 - val_top5-acc: 1.0000 - val_Brier score: 5.9790 - val_F1 score: 0.6207 - val_Recall: 0.9304 - val_Precision: 0.4597 - val_AUC: 0.8162 - lr: 0.0010
# Epoch 8/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7203 - accuracy: 0.6694 - top5-acc: 1.0000 - Brier score: 3.0961 - F1 score: 0.6586 - Recall: 0.8786 - Precision: 0.5077 - AUC: 0.8390 - val_loss: 0.6939 - val_accuracy: 0.6935 - val_top5-acc: 1.0000 - val_Brier score: 5.6596 - val_F1 score: 0.7053 - val_Recall: 0.9304 - val_Precision: 0.4748 - val_AUC: 0.8232 - lr: 0.0010
# Epoch 9/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7299 - accuracy: 0.6721 - top5-acc: 1.0000 - Brier score: 3.2257 - F1 score: 0.6602 - Recall: 0.8676 - Precision: 0.5066 - AUC: 0.8336 - val_loss: 0.6897 - val_accuracy: 0.6793 - val_top5-acc: 1.0000 - val_Brier score: 5.3733 - val_F1 score: 0.6948 - val_Recall: 0.9315 - val_Precision: 0.4842 - val_AUC: 0.8329 - lr: 0.0010
# Epoch 10/50
# ...
# Epoch 12/50
# 259/259 [==============================] - 23s 87ms/step - loss: 1.0421 - accuracy: 0.6456 - top5-acc: 1.0000 - Brier score: 149.0231 - F1 score: 0.6405 - Recall: 0.8956 - Precision: 0.3437 - AUC: 0.6677 - val_loss: 0.7015 - val_accuracy: 0.7174 - val_top5-acc: 1.0000 - val_Brier score: 136.0271 - val_F1 score: 0.7126 - val_Recall: 0.9663 - val_Precision: 0.3689 - val_AUC: 0.7120 - lr: 0.0010
# Epoch 13/50
# 259/259 [==============================] - 23s 86ms/step - loss: 1.0020 - accuracy: 0.6449 - top5-acc: 1.0000 - Brier score: 108.1311 - F1 score: 0.6384 - Recall: 0.8865 - Precision: 0.3468 - AUC: 0.6719 - val_loss: 0.7174 - val_accuracy: 0.7380 - val_top5-acc: 1.0000 - val_Brier score: 123.1571 - val_F1 score: 0.7182 - val_Recall: 0.8174 - val_Precision: 0.3845 - val_AUC: 0.7004 - lr: 0.0010
# Epoch 14/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.8644 - accuracy: 0.6578 - top5-acc: 1.0000 - Brier score: 96.5251 - F1 score: 0.6510 - Recall: 0.8925 - Precision: 0.3260 - AUC: 0.6458 - val_loss: 0.9039 - val_accuracy: 0.6065 - val_top5-acc: 1.0000 - val_Brier score: 93.1494 - val_F1 score: 0.5820 - val_Recall: 0.6663 - val_Precision: 0.4278 - val_AUC: 0.7030 - lr: 0.0010
# Epoch 15/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7717 - accuracy: 0.6752 - top5-acc: 1.0000 - Brier score: 90.1192 - F1 score: 0.6684 - Recall: 0.4876 - Precision: 0.3744 - AUC: 0.6145 - val_loss: 0.6608 - val_accuracy: 0.6728 - val_top5-acc: 1.0000 - val_Brier score: 69.9742 - val_F1 score: 0.6819 - val_Recall: 0.9750 - val_Precision: 0.3600 - val_AUC: 0.7048 - lr: 0.0010
# Epoch 16/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7723 - accuracy: 0.6664 - top5-acc: 1.0000 - Brier score: 70.5852 - F1 score: 0.6591 - Recall: 0.7303 - Precision: 0.3478 - AUC: 0.6430 - val_loss: 0.7073 - val_accuracy: 0.6467 - val_top5-acc: 1.0000 - val_Brier score: 60.3034 - val_F1 score: 0.6544 - val_Recall: 0.9717 - val_Precision: 0.3612 - val_AUC: 0.7071 - lr: 0.0010
# Epoch 17/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7459 - accuracy: 0.6717 - top5-acc: 1.0000 - Brier score: 49.5675 - F1 score: 0.6650 - Recall: 0.8257 - Precision: 0.3365 - AUC: 0.6486 - val_loss: 0.5934 - val_accuracy: 0.7370 - val_top5-acc: 1.0000 - val_Brier score: 47.6860 - val_F1 score: 0.7503 - val_Recall: 0.9696 - val_Precision: 0.3603 - val_AUC: 0.7065 - lr: 0.0010
# Epoch 18/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7042 - accuracy: 0.6842 - top5-acc: 1.0000 - Brier score: 51.1435 - F1 score: 0.6782 - Recall: 0.8104 - Precision: 0.3284 - AUC: 0.6368 - val_loss: 0.6691 - val_accuracy: 0.7207 - val_top5-acc: 1.0000 - val_Brier score: 43.3268 - val_F1 score: 0.7102 - val_Recall: 0.9478 - val_Precision: 0.3627 - val_AUC: 0.7031 - lr: 0.0010
# Epoch 19/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7663 - accuracy: 0.6616 - top5-acc: 1.0000 - Brier score: 42.7732 - F1 score: 0.6558 - Recall: 0.7844 - Precision: 0.3506 - AUC: 0.6594 - val_loss: 0.7487 - val_accuracy: 0.6196 - val_top5-acc: 1.0000 - val_Brier score: 54.6819 - val_F1 score: 0.6005 - val_Recall: 0.9793 - val_Precision: 0.3368 - val_AUC: 0.6857 - lr: 0.0010
# Epoch 20/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.7635 - accuracy: 0.6698 - top5-acc: 1.0000 - Brier score: 55.8514 - F1 score: 0.6638 - Recall: 0.7131 - Precision: 0.3444 - AUC: 0.6376 - val_loss: 0.8162 - val_accuracy: 0.6087 - val_top5-acc: 1.0000 - val_Brier score: 42.8861 - val_F1 score: 0.5796 - val_Recall: 0.8957 - val_Precision: 0.3858 - val_AUC: 0.7188 - lr: 0.0010
# Epoch 21/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7389 - accuracy: 0.6759 - top5-acc: 1.0000 - Brier score: 44.7191 - F1 score: 0.6708 - Recall: 0.7804 - Precision: 0.3419 - AUC: 0.6504 - val_loss: 0.8128 - val_accuracy: 0.6141 - val_top5-acc: 1.0000 - val_Brier score: 59.5027 - val_F1 score: 0.6216 - val_Recall: 0.7967 - val_Precision: 0.3810 - val_AUC: 0.6900 - lr: 0.0010
# Epoch 22/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.7692 - accuracy: 0.6654 - top5-acc: 1.0000 - Brier score: 64.3722 - F1 score: 0.6604 - Recall: 0.8249 - Precision: 0.3169 - AUC: 0.6240 - val_loss: 0.6182 - val_accuracy: 0.7685 - val_top5-acc: 1.0000 - val_Brier score: 189.6385 - val_F1 score: 0.7412 - val_Recall: 0.9978 - val_Precision: 0.2731 - val_AUC: 0.5659 - lr: 0.0010
# Epoch 23/50
# 259/259 [==============================] - 23s 88ms/step - loss: 0.6358 - accuracy: 0.7173 - top5-acc: 1.0000 - Brier score: 52.2964 - F1 score: 0.7093 - Recall: 0.9059 - Precision: 0.3111 - AUC: 0.6292 - val_loss: 0.6204 - val_accuracy: 0.7457 - val_top5-acc: 1.0000 - val_Brier score: 136.4472 - val_F1 score: 0.7465 - val_Recall: 0.9989 - val_Precision: 0.2600 - val_AUC: 0.5295 - lr: 5.0000e-04
# Epoch 24/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6302 - accuracy: 0.7157 - top5-acc: 1.0000 - Brier score: 40.0706 - F1 score: 0.7076 - Recall: 0.8727 - Precision: 0.3254 - AUC: 0.6485 - val_loss: 0.6312 - val_accuracy: 0.6989 - val_top5-acc: 1.0000 - val_Brier score: 53.4131 - val_F1 score: 0.7079 - val_Recall: 0.9315 - val_Precision: 0.3670 - val_AUC: 0.7052 - lr: 5.0000e-04
# Epoch 25/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6548 - accuracy: 0.7072 - top5-acc: 1.0000 - Brier score: 34.6022 - F1 score: 0.6981 - Recall: 0.8399 - Precision: 0.3400 - AUC: 0.6603 - val_loss: 0.5874 - val_accuracy: 0.7185 - val_top5-acc: 1.0000 - val_Brier score: 68.6966 - val_F1 score: 0.7332 - val_Recall: 0.9967 - val_Precision: 0.2807 - val_AUC: 0.5938 - lr: 5.0000e-04
# Epoch 26/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.6487 - accuracy: 0.7015 - top5-acc: 1.0000 - Brier score: 35.6299 - F1 score: 0.6945 - Recall: 0.7377 - Precision: 0.3692 - AUC: 0.6687 - val_loss: 0.7203 - val_accuracy: 0.6543 - val_top5-acc: 1.0000 - val_Brier score: 87.9582 - val_F1 score: 0.6617 - val_Recall: 0.9967 - val_Precision: 0.2906 - val_AUC: 0.6161 - lr: 5.0000e-04
# Epoch 27/50
# 259/259 [==============================] - 23s 88ms/step - loss: 0.6633 - accuracy: 0.7009 - top5-acc: 1.0000 - Brier score: 39.4086 - F1 score: 0.6915 - Recall: 0.8900 - Precision: 0.3307 - AUC: 0.6572 - val_loss: 0.6832 - val_accuracy: 0.7043 - val_top5-acc: 1.0000 - val_Brier score: 52.0122 - val_F1 score: 0.7052 - val_Recall: 0.9880 - val_Precision: 0.3161 - val_AUC: 0.6648 - lr: 5.0000e-04
# Epoch 28/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6791 - accuracy: 0.6973 - top5-acc: 1.0000 - Brier score: 41.4377 - F1 score: 0.6897 - Recall: 0.8575 - Precision: 0.3355 - AUC: 0.6566 - val_loss: 0.5888 - val_accuracy: 0.7772 - val_top5-acc: 1.0000 - val_Brier score: 43.1024 - val_F1 score: 0.7528 - val_Recall: 0.9565 - val_Precision: 0.3592 - val_AUC: 0.7113 - lr: 5.0000e-04
# Epoch 29/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6756 - accuracy: 0.6998 - top5-acc: 1.0000 - Brier score: 42.6626 - F1 score: 0.6914 - Recall: 0.8869 - Precision: 0.3271 - AUC: 0.6518 - val_loss: 0.9200 - val_accuracy: 0.6000 - val_top5-acc: 1.0000 - val_Brier score: 74.0684 - val_F1 score: 0.5671 - val_Recall: 0.8837 - val_Precision: 0.3570 - val_AUC: 0.6814 - lr: 5.0000e-04
# Epoch 30/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6710 - accuracy: 0.7052 - top5-acc: 1.0000 - Brier score: 55.2560 - F1 score: 0.7000 - Recall: 0.7665 - Precision: 0.3347 - AUC: 0.6366 - val_loss: 0.6272 - val_accuracy: 0.7620 - val_top5-acc: 1.0000 - val_Brier score: 116.7718 - val_F1 score: 0.7574 - val_Recall: 0.9989 - val_Precision: 0.2681 - val_AUC: 0.5502 - lr: 5.0000e-04
# Epoch 31/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5943 - accuracy: 0.7338 - top5-acc: 1.0000 - Brier score: 32.9400 - F1 score: 0.7237 - Recall: 0.8553 - Precision: 0.3424 - AUC: 0.6672 - val_loss: 0.5437 - val_accuracy: 0.7859 - val_top5-acc: 1.0000 - val_Brier score: 63.5176 - val_F1 score: 0.7813 - val_Recall: 0.9946 - val_Precision: 0.2981 - val_AUC: 0.6302 - lr: 2.5000e-04
# Epoch 32/50
# 259/259 [==============================] - 23s 86ms/step - loss: 0.5827 - accuracy: 0.7428 - top5-acc: 1.0000 - Brier score: 34.8978 - F1 score: 0.7319 - Recall: 0.8839 - Precision: 0.3389 - AUC: 0.6671 - val_loss: 0.6544 - val_accuracy: 0.7576 - val_top5-acc: 1.0000 - val_Brier score: 52.2721 - val_F1 score: 0.7532 - val_Recall: 0.9457 - val_Precision: 0.3802 - val_AUC: 0.7208 - lr: 2.5000e-04
# Epoch 33/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5950 - accuracy: 0.7241 - top5-acc: 1.0000 - Brier score: 44.0022 - F1 score: 0.7160 - Recall: 0.9383 - Precision: 0.3138 - AUC: 0.6400 - val_loss: 0.6093 - val_accuracy: 0.7587 - val_top5-acc: 1.0000 - val_Brier score: 86.3603 - val_F1 score: 0.7577 - val_Recall: 0.9946 - val_Precision: 0.2988 - val_AUC: 0.6344 - lr: 2.5000e-04
# Epoch 34/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6179 - accuracy: 0.7255 - top5-acc: 1.0000 - Brier score: 28.8163 - F1 score: 0.7161 - Recall: 0.7796 - Precision: 0.3718 - AUC: 0.6819 - val_loss: 0.5835 - val_accuracy: 0.7533 - val_top5-acc: 1.0000 - val_Brier score: 59.3559 - val_F1 score: 0.7549 - val_Recall: 0.4022 - val_Precision: 0.6086 - val_AUC: 0.6711 - lr: 2.5000e-04
# Epoch 35/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5949 - accuracy: 0.7429 - top5-acc: 1.0000 - Brier score: 32.2424 - F1 score: 0.7339 - Recall: 0.8311 - Precision: 0.3524 - AUC: 0.6737 - val_loss: 0.6408 - val_accuracy: 0.6837 - val_top5-acc: 1.0000 - val_Brier score: 38.3929 - val_F1 score: 0.6903 - val_Recall: 0.8109 - val_Precision: 0.3939 - val_AUC: 0.7076 - lr: 2.5000e-04
# Epoch 36/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.6160 - accuracy: 0.7251 - top5-acc: 1.0000 - Brier score: 37.3193 - F1 score: 0.7162 - Recall: 0.8774 - Precision: 0.3331 - AUC: 0.6569 - val_loss: 0.7072 - val_accuracy: 0.6957 - val_top5-acc: 1.0000 - val_Brier score: 80.5560 - val_F1 score: 0.7004 - val_Recall: 0.9967 - val_Precision: 0.2892 - val_AUC: 0.6082 - lr: 2.5000e-04
# Epoch 37/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5642 - accuracy: 0.7481 - top5-acc: 1.0000 - Brier score: 38.1450 - F1 score: 0.7384 - Recall: 0.9575 - Precision: 0.3137 - AUC: 0.6457 - val_loss: 0.5287 - val_accuracy: 0.7837 - val_top5-acc: 1.0000 - val_Brier score: 64.3310 - val_F1 score: 0.7750 - val_Recall: 0.9978 - val_Precision: 0.2850 - val_AUC: 0.5988 - lr: 1.2500e-04
# Epoch 38/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5702 - accuracy: 0.7442 - top5-acc: 1.0000 - Brier score: 25.4559 - F1 score: 0.7340 - Recall: 0.9443 - Precision: 0.3414 - AUC: 0.6857 - val_loss: 0.5697 - val_accuracy: 0.7641 - val_top5-acc: 1.0000 - val_Brier score: 59.0937 - val_F1 score: 0.7644 - val_Recall: 0.9989 - val_Precision: 0.2913 - val_AUC: 0.6207 - lr: 1.2500e-04
# Epoch 39/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5739 - accuracy: 0.7423 - top5-acc: 1.0000 - Brier score: 34.7025 - F1 score: 0.7332 - Recall: 0.9796 - Precision: 0.3109 - AUC: 0.6490 - val_loss: 0.5284 - val_accuracy: 0.7750 - val_top5-acc: 1.0000 - val_Brier score: 46.0470 - val_F1 score: 0.7745 - val_Recall: 0.9967 - val_Precision: 0.3114 - val_AUC: 0.6599 - lr: 1.2500e-04
# Epoch 40/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5781 - accuracy: 0.7424 - top5-acc: 1.0000 - Brier score: 23.8608 - F1 score: 0.7302 - Recall: 0.8532 - Precision: 0.3637 - AUC: 0.6925 - val_loss: 0.6142 - val_accuracy: 0.6924 - val_top5-acc: 1.0000 - val_Brier score: 24.7890 - val_F1 score: 0.6984 - val_Recall: 0.9272 - val_Precision: 0.4129 - val_AUC: 0.7540 - lr: 1.2500e-04
# Epoch 41/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5723 - accuracy: 0.7479 - top5-acc: 1.0000 - Brier score: 23.8209 - F1 score: 0.7392 - Recall: 0.9231 - Precision: 0.3627 - AUC: 0.7087 - val_loss: 0.5403 - val_accuracy: 0.7761 - val_top5-acc: 1.0000 - val_Brier score: 45.7723 - val_F1 score: 0.7748 - val_Recall: 0.9946 - val_Precision: 0.3480 - val_AUC: 0.7079 - lr: 1.2500e-04
# Epoch 42/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5771 - accuracy: 0.7432 - top5-acc: 1.0000 - Brier score: 32.4540 - F1 score: 0.7335 - Recall: 0.9837 - Precision: 0.3118 - AUC: 0.6518 - val_loss: 0.6769 - val_accuracy: 0.6793 - val_top5-acc: 1.0000 - val_Brier score: 36.1665 - val_F1 score: 0.6851 - val_Recall: 0.9793 - val_Precision: 0.3696 - val_AUC: 0.7200 - lr: 1.2500e-04
# Epoch 43/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5826 - accuracy: 0.7338 - top5-acc: 1.0000 - Brier score: 18.3091 - F1 score: 0.7250 - Recall: 0.7924 - Precision: 0.4233 - AUC: 0.7333 - val_loss: 0.5939 - val_accuracy: 0.7620 - val_top5-acc: 1.0000 - val_Brier score: 32.1465 - val_F1 score: 0.7493 - val_Recall: 0.9859 - val_Precision: 0.3722 - val_AUC: 0.7289 - lr: 1.2500e-04
# Epoch 44/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5728 - accuracy: 0.7458 - top5-acc: 1.0000 - Brier score: 21.7867 - F1 score: 0.7349 - Recall: 0.8507 - Precision: 0.3794 - AUC: 0.7090 - val_loss: 0.7600 - val_accuracy: 0.6380 - val_top5-acc: 1.0000 - val_Brier score: 40.5931 - val_F1 score: 0.6271 - val_Recall: 0.9946 - val_Precision: 0.3442 - val_AUC: 0.7017 - lr: 1.2500e-04
# Epoch 45/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5512 - accuracy: 0.7531 - top5-acc: 1.0000 - Brier score: 23.1961 - F1 score: 0.7422 - Recall: 0.9748 - Precision: 0.3411 - AUC: 0.6959 - val_loss: 0.6626 - val_accuracy: 0.7109 - val_top5-acc: 1.0000 - val_Brier score: 35.7565 - val_F1 score: 0.7158 - val_Recall: 0.9891 - val_Precision: 0.3623 - val_AUC: 0.7182 - lr: 6.2500e-05
# Epoch 46/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5523 - accuracy: 0.7537 - top5-acc: 1.0000 - Brier score: 16.7314 - F1 score: 0.7425 - Recall: 0.9574 - Precision: 0.3827 - AUC: 0.7417 - val_loss: 0.5824 - val_accuracy: 0.7348 - val_top5-acc: 1.0000 - val_Brier score: 29.7879 - val_F1 score: 0.7416 - val_Recall: 0.9924 - val_Precision: 0.3734 - val_AUC: 0.7345 - lr: 6.2500e-05
# Epoch 47/50
# 259/259 [==============================] - 23s 88ms/step - loss: 0.5458 - accuracy: 0.7609 - top5-acc: 1.0000 - Brier score: 14.2694 - F1 score: 0.7512 - Recall: 0.9414 - Precision: 0.4004 - AUC: 0.7565 - val_loss: 0.6186 - val_accuracy: 0.7207 - val_top5-acc: 1.0000 - val_Brier score: 22.4587 - val_F1 score: 0.7266 - val_Recall: 0.9663 - val_Precision: 0.4072 - val_AUC: 0.7612 - lr: 6.2500e-05
# Epoch 48/50
# 259/259 [==============================] - 23s 88ms/step - loss: 0.5643 - accuracy: 0.7465 - top5-acc: 1.0000 - Brier score: 13.8185 - F1 score: 0.7355 - Recall: 0.9569 - Precision: 0.3938 - AUC: 0.7535 - val_loss: 0.6370 - val_accuracy: 0.7207 - val_top5-acc: 1.0000 - val_Brier score: 21.1839 - val_F1 score: 0.7223 - val_Recall: 0.9772 - val_Precision: 0.3893 - val_AUC: 0.7466 - lr: 6.2500e-05
# Epoch 49/50
# 259/259 [==============================] - 23s 87ms/step - loss: 0.5658 - accuracy: 0.7522 - top5-acc: 1.0000 - Brier score: 11.5704 - F1 score: 0.7414 - Recall: 0.8352 - Precision: 0.4551 - AUC: 0.7753 - val_loss: 0.6169 - val_accuracy: 0.7239 - val_top5-acc: 1.0000 - val_Brier score: 19.1807 - val_F1 score: 0.7307 - val_Recall: 0.9663 - val_Precision: 0.4032 - val_AUC: 0.7560 - lr: 6.2500e-05
# Epoch 50/50
# 259/259 [==============================] - 24s 89ms/step - loss: 0.5490 - accuracy: 0.7656 - top5-acc: 1.0000 - Brier score: 10.3437 - F1 score: 0.7540 - Recall: 0.9317 - Precision: 0.4347 - AUC: 0.7843 - val_loss: 0.5938 - val_accuracy: 0.7370 - val_top5-acc: 1.0000 - val_Brier score: 21.1315 - val_F1 score: 0.7428 - val_Recall: 0.9696 - val_Precision: 0.3998 - val_AUC: 0.7551 - lr: 3.1250e-05

# %%
def plot_comparison_curves(history_mlpmixer_, history_fnet_, history_gmlp_, history_resmlp_, history_DiagnosticMLP_):
    epochs = range(len(history_mlpmixer_.history['loss']))
    loss_1 = np.array(history_mlpmixer_.history['val_loss'])
    loss_2 = np.array(history_fnet_.history['val_loss'])
    loss_3 = np.array(history_gmlp_.history['val_loss'])
    loss_4 = np.array(history_resmlp_.history['val_loss'])
    loss_5 = np.array(history_DiagnosticMLP_.history['val_loss'])

    accuracy_1 = np.array(history_mlpmixer_.history['val_accuracy'])
    accuracy_2 = np.array(history_fnet_.history['val_accuracy'])
    accuracy_3 = np.array(history_gmlp_.history['val_accuracy'])
    accuracy_4 = np.array(history_resmlp_.history['val_accuracy'])
    accuracy_5 = np.array(history_DiagnosticMLP_.history['val_accuracy'])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    #plt.style.use('ggplot')
    plt.style.use('seaborn-whitegrid')

    # Plot loss
    ax1.plot(epochs, loss_1, label='MLP-Mixer', marker='.', )
    ax1.plot(epochs, loss_2, label='FNet', marker='.', )
    ax1.plot(epochs, loss_3, label='gMLP', marker='.', )
    ax1.plot(epochs, loss_4, label='ResMLP', marker='.', )
    ax1.plot(epochs, loss_5, label='DiagnosticMLP', marker='.', )

    ax1.set_title('Loss Comparison - CT of the Chest', fontsize=10)
    ax1.set_xlabel('Epochs', fontsize=10)
    ax1.legend(fontsize=10, borderaxespad=1, frameon=True)

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy_1, label='MLP-Mixer', marker='.')
    ax2.plot(epochs, accuracy_2, label='FNet', marker='.')
    ax2.plot(epochs, accuracy_3, label='gMLP', marker='.')
    ax2.plot(epochs, accuracy_4, label='ResMLP', marker='.')
    ax2.plot(epochs, accuracy_5, label='DiagnosticMLP', marker='.')

    ax2.set_title('Accuracy Comparison - CT of the Chest', fontsize=10)
    ax2.set_xlabel('Epochs', fontsize=10)
    ax2.legend(fontsize=10, borderaxespad=1, frameon=True)

# %%
plot_comparison_curves(history_mlpmixer_, history_fnet_, history_gmlp_, history_resmlp_, history_DiagnosticMLP_)
# Out:
# <ipython-input-29-da1899254b03>:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
